# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaVKarthikeyan/AA-Stagecoach-Project/blob/main/File_Share_5_Fetching_the_time_table_of_a_given_stop_point_of_given_lineID%2C_direction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fetching Time table and dividing to slots- (changing 24 to 00)

# %%
import requests
import pandas as pd

# Function to fetch and display timetable
def fetch_and_display_timetable(line_id, stop_point_id, direction):
    try:
        url = f"https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()

        # Extract the timetable
        schedules = data.get('timetable', {}).get('routes', [{}])[0].get('schedules', [])
        if not schedules:
            print("No timetable available.")
            return

        # Create a list of dictionaries to store timetable entries
        timetable_entries = []
        for schedule in schedules:
            for entry in schedule.get('knownJourneys', []):
                timetable_entries.append({
                    'Hour': int(entry['hour']),
                    'Minute': int(entry['minute']),
                    'Line ID': line_id,
                    'Stop Point ID': stop_point_id,
                    'Direction': direction.capitalize()
                })

        # Create a DataFrame and display it in a readable format
        df = pd.DataFrame(timetable_entries)
        df = df.sort_values(by=['Hour', 'Minute'])
        df['Time'] = df.apply(lambda row: f"{row['Hour']:02d}:{row['Minute']:02d}", axis=1)

        # Slot assignment
        df['Slot'] = df['Hour'] + 1
        df['Slot'] = df['Slot'].apply(lambda x: x if x <= 24 else x - 24)

        # Adjust hours to range 00-23
        df['Hour'] = df['Hour'].apply(lambda x: x if x < 24 else 0)
        df['Time'] = df.apply(lambda row: f"{row['Hour']:02d}:{row['Minute']:02d}", axis=1)

        # Display timetable by slots
        current_slot = 1
        print("\nTimetable:")
        while current_slot <= 24:
            slot_start = (current_slot - 1) % 24
            slot_end = current_slot % 24
            print(f"\nSlot {current_slot:02d} (Hour {slot_start:02d}:00 to Hour {slot_end:02d}:00)")
            slot_df = df[df['Slot'] == current_slot]
            if not slot_df.empty:
                print(slot_df[['Time', 'Line ID', 'Stop Point ID', 'Direction']].to_string(index=False))
            else:
                print("No entries")
            current_slot += 1

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    stop_point_id = input("Enter stop point ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_and_display_timetable(line_id, stop_point_id, direction)
# Out:
# Enter line ID: 179
# Enter stop point ID: 490005183E
# Enter direction (e.g., inbound or outbound): outbound
#
# Timetable:
#
# Slot 01 (Hour 00:00 to Hour 01:00)
#  Time Line ID Stop Point ID Direction
# 00:02     179    490005183E  Outbound
# 00:02     179    490005183E  Outbound
# 00:07     179    490005183E  Outbound
# 00:07     179    490005183E  Outbound
# 00:22     179    490005183E  Outbound
# 00:22     179    490005183E  Outbound
# 00:27     179    490005183E  Outbound
# 00:27     179    490005183E  Outbound
# 00:42     179    490005183E  Outbound
# 00:42     179    490005183E  Outbound
# 00:47     179    490005183E  Outbound
# 00:47     179    490005183E  Outbound
#
# Slot 02 (Hour 01:00 to Hour 02:00)
# No entries
#
# Slot 03 (Hour 02:00 to Hour 03:00)
# No entries
#
# Slot 04 (Hour 03:00 to Hour 04:00)
# No entries
#
# Slot 05 (Hour 04:00 to Hour 05:00)
#  Time Line ID Stop Point ID Direction
# 04:57     179    490005183E  Outbound
# 04:57     179    490005183E  Outbound
# 04:57     179    490005183E  Outbound
#
# Slot 06 (Hour 05:00 to Hour 06:00)
#  Time Line ID Stop Point ID Direction
# 05:17     179    490005183E  Outbound
# 05:17     179    490005183E  Outbound
# 05:17     179    490005183E  Outbound
# 05:37     179    490005183E  Outbound
# 05:37     179    490005183E  Outbound
# 05:37     179    490005183E  Outbound
# 05:57     179    490005183E  Outbound
# 05:57     179    490005183E  Outbound
# 05:57     179    490005183E  Outbound
#
# Slot 07 (Hour 06:00 to Hour 07:00)
#  Time Line ID Stop Point ID Direction
# 06:17     179    490005183E  Outbound
# 06:17     179    490005183E  Outbound
# 06:17     179    490005183E  Outbound
# 06:34     179    490005183E  Outbound
# 06:34     179    490005183E  Outbound
# 06:37     179    490005183E  Outbound
# 06:42     179    490005183E  Outbound
# 06:46     179    490005183E  Outbound
# 06:46     179    490005183E  Outbound
# 06:57     179    490005183E  Outbound
# 06:58     179    490005183E  Outbound
# 06:58     179    490005183E  Outbound
#
# Slot 08 (Hour 07:00 to Hour 08:00)
#  Time Line ID Stop Point ID Direction
# 07:08     179    490005183E  Outbound
# 07:08     179    490005183E  Outbound
# 07:12     179    490005183E  Outbound
# 07:17     179    490005183E  Outbound
# 07:18     179    490005183E  Outbound
# 07:18     179    490005183E  Outbound
# 07:30     179    490005183E  Outbound
# 07:30     179    490005183E  Outbound
# 07:37     179    490005183E  Outbound
# 07:42     179    490005183E  Outbound
# 07:43     179    490005183E  Outbound
# 07:43     179    490005183E  Outbound
# 07:52     179    490005183E  Outbound
# 07:55     179    490005183E  Outbound
# 07:55     179    490005183E  Outbound
#
# Slot 09 (Hour 08:00 to Hour 09:00)
#  Time Line ID Stop Point ID Direction
# 08:07     179    490005183E  Outbound
# 08:07     179    490005183E  Outbound
# 08:07     179    490005183E  Outbound
# 08:12     179    490005183E  Outbound
# 08:21     179    490005183E  Outbound
# 08:21     179    490005183E  Outbound
# 08:23     179    490005183E  Outbound
# 08:32     179    490005183E  Outbound
# 08:34     179    490005183E  Outbound
# 08:34     179    490005183E  Outbound
# 08:34     179    490005183E  Outbound
# 08:45     179    490005183E  Outbound
# 08:47     179    490005183E  Outbound
# 08:47     179    490005183E  Outbound
# 08:52     179    490005183E  Outbound
# 08:56     179    490005183E  Outbound
# 08:59     179    490005183E  Outbound
# 08:59     179    490005183E  Outbound
#
# Slot 10 (Hour 09:00 to Hour 10:00)
#  Time Line ID Stop Point ID Direction
# 09:08     179    490005183E  Outbound
# 09:11     179    490005183E  Outbound
# 09:11     179    490005183E  Outbound
# 09:12     179    490005183E  Outbound
# 09:20     179    490005183E  Outbound
# 09:22     179    490005183E  Outbound
# 09:22     179    490005183E  Outbound
# 09:31     179    490005183E  Outbound
# 09:32     179    490005183E  Outbound
# 09:34     179    490005183E  Outbound
# 09:34     179    490005183E  Outbound
# 09:42     179    490005183E  Outbound
# 09:46     179    490005183E  Outbound
# 09:46     179    490005183E  Outbound
# 09:51     179    490005183E  Outbound
# 09:53     179    490005183E  Outbound
# 09:58     179    490005183E  Outbound
# 09:58     179    490005183E  Outbound
#
# Slot 11 (Hour 10:00 to Hour 11:00)
#  Time Line ID Stop Point ID Direction
# 10:04     179    490005183E  Outbound
# 10:10     179    490005183E  Outbound
# 10:10     179    490005183E  Outbound
# 10:10     179    490005183E  Outbound
# 10:16     179    490005183E  Outbound
# 10:22     179    490005183E  Outbound
# 10:22     179    490005183E  Outbound
# 10:28     179    490005183E  Outbound
# 10:29     179    490005183E  Outbound
# 10:34     179    490005183E  Outbound
# 10:34     179    490005183E  Outbound
# 10:40     179    490005183E  Outbound
# 10:46     179    490005183E  Outbound
# 10:46     179    490005183E  Outbound
# 10:48     179    490005183E  Outbound
# 10:52     179    490005183E  Outbound
# 10:58     179    490005183E  Outbound
# 10:58     179    490005183E  Outbound
#
# Slot 12 (Hour 11:00 to Hour 12:00)
#  Time Line ID Stop Point ID Direction
# 11:05     179    490005183E  Outbound
# 11:09     179    490005183E  Outbound
# 11:10     179    490005183E  Outbound
# 11:10     179    490005183E  Outbound
# 11:17     179    490005183E  Outbound
# 11:22     179    490005183E  Outbound
# 11:22     179    490005183E  Outbound
# 11:29     179    490005183E  Outbound
# 11:29     179    490005183E  Outbound
# 11:34     179    490005183E  Outbound
# 11:34     179    490005183E  Outbound
# 11:41     179    490005183E  Outbound
# 11:46     179    490005183E  Outbound
# 11:46     179    490005183E  Outbound
# 11:49     179    490005183E  Outbound
# 11:53     179    490005183E  Outbound
# 11:58     179    490005183E  Outbound
# 11:58     179    490005183E  Outbound
#
# Slot 13 (Hour 12:00 to Hour 13:00)
#  Time Line ID Stop Point ID Direction
# 12:05     179    490005183E  Outbound
# 12:09     179    490005183E  Outbound
# 12:10     179    490005183E  Outbound
# 12:10     179    490005183E  Outbound
# 12:17     179    490005183E  Outbound
# 12:22     179    490005183E  Outbound
# 12:22     179    490005183E  Outbound
# 12:28     179    490005183E  Outbound
# 12:29     179    490005183E  Outbound
# 12:34     179    490005183E  Outbound
# 12:34     179    490005183E  Outbound
# 12:39     179    490005183E  Outbound
# 12:46     179    490005183E  Outbound
# 12:46     179    490005183E  Outbound
# 12:49     179    490005183E  Outbound
# 12:50     179    490005183E  Outbound
# 12:58     179    490005183E  Outbound
# 12:58     179    490005183E  Outbound
#
# Slot 14 (Hour 13:00 to Hour 14:00)
#  Time Line ID Stop Point ID Direction
# 13:02     179    490005183E  Outbound
# 13:09     179    490005183E  Outbound
# 13:10     179    490005183E  Outbound
# 13:10     179    490005183E  Outbound
# 13:14     179    490005183E  Outbound
# 13:22     179    490005183E  Outbound
# 13:22     179    490005183E  Outbound
# 13:26     179    490005183E  Outbound
# 13:29     179    490005183E  Outbound
# 13:34     179    490005183E  Outbound
# 13:34     179    490005183E  Outbound
# 13:38     179    490005183E  Outbound
# 13:46     179    490005183E  Outbound
# 13:46     179    490005183E  Outbound
# 13:49     179    490005183E  Outbound
# 13:50     179    490005183E  Outbound
# 13:58     179    490005183E  Outbound
# 13:58     179    490005183E  Outbound
#
# Slot 15 (Hour 14:00 to Hour 15:00)
#  Time Line ID Stop Point ID Direction
# 14:02     179    490005183E  Outbound
# 14:09     179    490005183E  Outbound
# 14:10     179    490005183E  Outbound
# 14:10     179    490005183E  Outbound
# 14:14     179    490005183E  Outbound
# 14:21     179    490005183E  Outbound
# 14:21     179    490005183E  Outbound
# 14:26     179    490005183E  Outbound
# 14:30     179    490005183E  Outbound
# 14:31     179    490005183E  Outbound
# 14:31     179    490005183E  Outbound
# 14:38     179    490005183E  Outbound
# 14:41     179    490005183E  Outbound
# 14:41     179    490005183E  Outbound
# 14:50     179    490005183E  Outbound
# 14:51     179    490005183E  Outbound
# 14:51     179    490005183E  Outbound
# 14:51     179    490005183E  Outbound
#
# Slot 16 (Hour 15:00 to Hour 16:00)
#  Time Line ID Stop Point ID Direction
# 15:01     179    490005183E  Outbound
# 15:01     179    490005183E  Outbound
# 15:02     179    490005183E  Outbound
# 15:12     179    490005183E  Outbound
# 15:13     179    490005183E  Outbound
# 15:13     179    490005183E  Outbound
# 15:13     179    490005183E  Outbound
# 15:24     179    490005183E  Outbound
# 15:24     179    490005183E  Outbound
# 15:25     179    490005183E  Outbound
# 15:32     179    490005183E  Outbound
# 15:35     179    490005183E  Outbound
# 15:35     179    490005183E  Outbound
# 15:37     179    490005183E  Outbound
# 15:47     179    490005183E  Outbound
# 15:47     179    490005183E  Outbound
# 15:49     179    490005183E  Outbound
# 15:51     179    490005183E  Outbound
# 15:57     179    490005183E  Outbound
# 15:57     179    490005183E  Outbound
#
# Slot 17 (Hour 16:00 to Hour 17:00)
#  Time Line ID Stop Point ID Direction
# 16:01     179    490005183E  Outbound
# 16:10     179    490005183E  Outbound
# 16:10     179    490005183E  Outbound
# 16:11     179    490005183E  Outbound
# 16:13     179    490005183E  Outbound
# 16:23     179    490005183E  Outbound
# 16:23     179    490005183E  Outbound
# 16:25     179    490005183E  Outbound
# 16:31     179    490005183E  Outbound
# 16:35     179    490005183E  Outbound
# 16:35     179    490005183E  Outbound
# 16:37     179    490005183E  Outbound
# 16:48     179    490005183E  Outbound
# 16:48     179    490005183E  Outbound
# 16:49     179    490005183E  Outbound
# 16:52     179    490005183E  Outbound
#
# Slot 18 (Hour 17:00 to Hour 18:00)
#  Time Line ID Stop Point ID Direction
# 17:00     179    490005183E  Outbound
# 17:00     179    490005183E  Outbound
# 17:01     179    490005183E  Outbound
# 17:13     179    490005183E  Outbound
# 17:13     179    490005183E  Outbound
# 17:13     179    490005183E  Outbound
# 17:13     179    490005183E  Outbound
# 17:25     179    490005183E  Outbound
# 17:25     179    490005183E  Outbound
# 17:25     179    490005183E  Outbound
# 17:33     179    490005183E  Outbound
# 17:37     179    490005183E  Outbound
# 17:37     179    490005183E  Outbound
# 17:37     179    490005183E  Outbound
# 17:49     179    490005183E  Outbound
# 17:49     179    490005183E  Outbound
# 17:50     179    490005183E  Outbound
# 17:53     179    490005183E  Outbound
#
# Slot 19 (Hour 18:00 to Hour 19:00)
#  Time Line ID Stop Point ID Direction
# 18:01     179    490005183E  Outbound
# 18:01     179    490005183E  Outbound
# 18:03     179    490005183E  Outbound
# 18:13     179    490005183E  Outbound
# 18:13     179    490005183E  Outbound
# 18:13     179    490005183E  Outbound
# 18:15     179    490005183E  Outbound
# 18:25     179    490005183E  Outbound
# 18:25     179    490005183E  Outbound
# 18:27     179    490005183E  Outbound
# 18:33     179    490005183E  Outbound
# 18:37     179    490005183E  Outbound
# 18:37     179    490005183E  Outbound
# 18:40     179    490005183E  Outbound
# 18:49     179    490005183E  Outbound
# 18:49     179    490005183E  Outbound
# 18:53     179    490005183E  Outbound
# 18:55     179    490005183E  Outbound
#
# Slot 20 (Hour 19:00 to Hour 20:00)
#  Time Line ID Stop Point ID Direction
# 19:01     179    490005183E  Outbound
# 19:01     179    490005183E  Outbound
# 19:10     179    490005183E  Outbound
# 19:12     179    490005183E  Outbound
# 19:12     179    490005183E  Outbound
# 19:13     179    490005183E  Outbound
# 19:24     179    490005183E  Outbound
# 19:24     179    490005183E  Outbound
# 19:26     179    490005183E  Outbound
# 19:34     179    490005183E  Outbound
# 19:37     179    490005183E  Outbound
# 19:37     179    490005183E  Outbound
# 19:42     179    490005183E  Outbound
# 19:52     179    490005183E  Outbound
# 19:52     179    490005183E  Outbound
# 19:55     179    490005183E  Outbound
#
# Slot 21 (Hour 20:00 to Hour 21:00)
#  Time Line ID Stop Point ID Direction
# 20:02     179    490005183E  Outbound
# 20:07     179    490005183E  Outbound
# 20:07     179    490005183E  Outbound
# 20:16     179    490005183E  Outbound
# 20:22     179    490005183E  Outbound
# 20:27     179    490005183E  Outbound
# 20:27     179    490005183E  Outbound
# 20:37     179    490005183E  Outbound
# 20:42     179    490005183E  Outbound
# 20:47     179    490005183E  Outbound
# 20:47     179    490005183E  Outbound
# 20:57     179    490005183E  Outbound
#
# Slot 22 (Hour 21:00 to Hour 22:00)
#  Time Line ID Stop Point ID Direction
# 21:02     179    490005183E  Outbound
# 21:07     179    490005183E  Outbound
# 21:07     179    490005183E  Outbound
# 21:18     179    490005183E  Outbound
# 21:22     179    490005183E  Outbound
# 21:27     179    490005183E  Outbound
# 21:27     179    490005183E  Outbound
# 21:40     179    490005183E  Outbound
# 21:42     179    490005183E  Outbound
# 21:47     179    490005183E  Outbound
# 21:47     179    490005183E  Outbound
#
# Slot 23 (Hour 22:00 to Hour 23:00)
#  Time Line ID Stop Point ID Direction
# 22:00     179    490005183E  Outbound
# 22:01     179    490005183E  Outbound
# 22:07     179    490005183E  Outbound
# 22:07     179    490005183E  Outbound
# 22:20     179    490005183E  Outbound
# 22:21     179    490005183E  Outbound
# 22:27     179    490005183E  Outbound
# 22:27     179    490005183E  Outbound
# 22:40     179    490005183E  Outbound
# 22:41     179    490005183E  Outbound
# 22:47     179    490005183E  Outbound
# 22:47     179    490005183E  Outbound
#
# Slot 24 (Hour 23:00 to Hour 00:00)
#  Time Line ID Stop Point ID Direction
# 23:01     179    490005183E  Outbound
# 23:01     179    490005183E  Outbound
# 23:07     179    490005183E  Outbound
# 23:07     179    490005183E  Outbound
# 23:21     179    490005183E  Outbound
# 23:22     179    490005183E  Outbound
# 23:27     179    490005183E  Outbound
# 23:27     179    490005183E  Outbound
# 23:42     179    490005183E  Outbound
# 23:42     179    490005183E  Outbound
# 23:47     179    490005183E  Outbound
# 23:47     179    490005183E  Outbound
