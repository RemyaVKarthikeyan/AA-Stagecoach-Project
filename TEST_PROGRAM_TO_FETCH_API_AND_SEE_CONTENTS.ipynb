# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaVKarthikeyan/AA-Stagecoach-Project/blob/main/TEST_PROGRAM_TO_FETCH_API_AND_SEE_CONTENTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# Fetch user inputs
line_id = input("Enter the line id: ")
stop_point_id = input("Enter the stop point id (naptanId): ")
direction = input("Enter the direction (inbound/outbound): ")

# Construct the API URL
timetable_url = f"https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}"

# Make GET request to fetch data
response = requests.get(timetable_url)

# Check if request was successful
if response.status_code == 200:
    timetable_data = response.json()

    # Convert JSON to DataFrame
    df = pd.json_normalize(timetable_data)

    # Determine output file format based on the structure of data
    output_format = 'csv'  # Default to CSV

    # Check if Excel format is more appropriate (e.g., if data has multiple sheets)
    if 'sheets' in timetable_data:
        output_format = 'xlsx'

    # Save to a file
    filename = f"timetable_{line_id}_{stop_point_id}.{output_format}"
    if output_format == 'csv':
        df.to_csv(filename, index=False)
    elif output_format == 'xlsx':
        df.to_excel(filename, index=False)

    print(f"Data saved to {filename}")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Enter the line id: 214
# Enter the stop point id (naptanId): 490008660N
# Enter the direction (inbound/outbound): inbound
# Data saved to timetable_214_490008660N.csv

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt  # Optional: for plotting in Colab

# Fetch user inputs
line_id = input("Enter the line id: ")
stop_point_id = input("Enter the stop point id (naptanId): ")
direction = input("Enter the direction (inbound/outbound): ")

# Construct the API URL
timetable_url = f"https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}"

# Make GET request to fetch data
response = requests.get(timetable_url)

# Check if request was successful
if response.status_code == 200:
    timetable_data = response.json()

    # Display data in Colab
    print("Timetable Data:")
    df = pd.json_normalize(timetable_data)
    display(df)  # Display DataFrame in Colab

    # Optional: Plotting (example)
    # If you have numeric data suitable for plotting, you can use matplotlib or seaborn
    # Example: Plotting a simple bar chart
    if 'time' in df.columns:
        plt.figure(figsize=(10, 6))
        df['time'].value_counts().plot(kind='bar')
        plt.title('Distribution of Time')
        plt.xlabel('Time')
        plt.ylabel('Count')
        plt.show()

    # Save to a CSV file
    filename = f"timetable_{line_id}_{stop_point_id}.csv"
    df.to_csv(filename, index=False)
    print(f"Data saved to {filename}")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Enter the line id: 214
# Enter the stop point id (naptanId): 490008660N
# Enter the direction (inbound/outbound): outbound
# Timetable Data:
#                                                $type lineId lineName  \
# 0  Tfl.Api.Presentation.Entities.TimetableRespons...    214      214
#
#   direction                                           stations  \
# 0   inbound  [{'$type': 'Tfl.Api.Presentation.Entities.Matc...
#
#                                                stops  \
# 0  [{'$type': 'Tfl.Api.Presentation.Entities.Matc...
#
#                                      timetable.$type  \
# 0  Tfl.Api.Presentation.Entities.Timetable, Tfl.A...
#
#   timetable.departureStopId                                   timetable.routes
# 0                490008660N  [{'$type': 'Tfl.Api.Presentation.Entities.Time...
# Data saved to timetable_214_490008660N.csv

# %%
import requests
import json

# API endpoint URL
url = 'https://api.tfl.gov.uk/Line/214/StopPoints'

# Making GET request to the API
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse JSON response
    data = response.json()

    # Displaying the data
    print(json.dumps(data, indent=2))  # Pretty-print JSON data

else:
    print(f"Failed to retrieve data: {response.status_code} - {response.reason}")
# Out:
# [
#   {
#     "$type": "Tfl.Api.Presentation.Entities.StopPoint, Tfl.Api.Presentation.Entities",
#     "naptanId": "490000007R",
#     "indicator": "Stop R",
#     "stopLetter": "R",
#     "modes": [
#       "bus"
#     ],
#     "icsCode": "1018977",
#     "stopType": "NaptanPublicBusCoachTram",
#     "stationNaptan": "490G00018977",
#     "lines": [
#       {
#         "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#         "id": "205",
#         "name": "205",
#         "uri": "/Line/205",
#         "type": "Line",
#         "crowding": {
#           "$type": "Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities"
#         },
#         "routeType": "Unknown",
#         "status": "Unknown"
#       },
#       {
#         "$type": "Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities",
#         "id": "214",
#         "name": "214",
#         "uri": "/Line/214",
#         "type": "Line",
#         "crowding": {
# ...

# %%
import requests
import pandas as pd

# API endpoint URL
url = 'https://api.tfl.gov.uk/Line/214/StopPoints'

# Making GET request to the API
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse JSON response
    data = response.json()

    # Convert JSON to DataFrame
    df = pd.json_normalize(data)

    # Display the DataFrame
    display(df)

else:
    print(f"Failed to retrieve data: {response.status_code} - {response.reason}")
# Out:
#                                                  $type     naptanId indicator  \
# 0    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000007R    Stop R
# 1    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000036L    Stop L
# 2    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000036R    Stop R
# 3    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000123A   Stop KB
# 4    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000123B   Stop KF
# ..                                                 ...          ...       ...
# 116  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490G01276S       NaN
# 117  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490G15194G       NaN
# 118  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...  940GZZLUAGL       NaN
# 119  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...  940GZZLUCTN       NaN
# 120  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...  940GZZLUMTC       NaN
#
# ...

# %%
import requests
import pandas as pd

# API endpoint URL
url = 'https://api.tfl.gov.uk/Line/214/StopPoints'

# Making GET request to the API
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse JSON response
    data = response.json()

    # Convert JSON to DataFrame
    df = pd.json_normalize(data)

    # Save DataFrame to CSV file
    df.to_csv('tfl_line_214_stop_points.csv', index=False)

    print('CSV file saved successfully.')

else:
    print(f"Failed to retrieve data: {response.status_code} - {response.reason}")
# Out:
# CSV file saved successfully.

# %%
########### Python 3.2 #############
import urllib.request, json

try:
    url = "https://api.tfl.gov.uk/Line/179/StopPoints"

    hdr ={
    # Request headers
    'Cache-Control': 'no-cache',
    }

    req = urllib.request.Request(url, headers=hdr)

    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    print(response.read())
except Exception as e:
    print(e)
####################################
# Out:
# 200
# ...

# %%
import urllib.request
import json
import pandas as pd

try:
    url = "https://api.tfl.gov.uk/Line/179/StopPoints"

    hdr = {
        'Cache-Control': 'no-cache',
    }

    req = urllib.request.Request(url, headers=hdr)
    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)

    # Read and decode JSON response
    data = json.loads(response.read().decode('utf-8'))

    # Create DataFrame from JSON data
    df = pd.json_normalize(data)

    # Print the DataFrame (optional)
    print(df)

    # Save DataFrame to CSV file
    df.to_csv('tfl_stop_points.csv', index=False)

except Exception as e:
    print(e)
# Out:
#                                                  $type     naptanId indicator  \
# 0    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000085A   Stop WQ
# 1    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000217E    Stop E
# 2    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490001063C    Stop C
# 3    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490001063F    Stop F
# 4    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490001157G    Stop G
# ..                                                 ...          ...       ...
# 142  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490G01063B       NaN
# 143  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490G15122C       NaN
# 144  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...  910GCHINGFD       NaN
# 145  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   910GILFORD       NaN
# 146  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...  940GZZLUSWF       NaN
#
# ...

# %%
import urllib.request
import json
import pandas as pd

try:
    url = "https://api.tfl.gov.uk/Line/179/StopPoints?direction=inbound"

    hdr = {
        'Cache-Control': 'no-cache',
    }

    req = urllib.request.Request(url, headers=hdr)
    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)

    # Read and decode JSON response
    data = json.loads(response.read().decode('utf-8'))

    # Create DataFrame from JSON data
    df = pd.json_normalize(data)

    # Print the DataFrame (optional)
    print(df)

    # Save DataFrame to CSV file
    df.to_csv('tfl_stop_points_dir_incl.csv', index=False)

except Exception as e:
    print(e)
# Out:
#                                                  $type     naptanId indicator  \
# 0    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000085A   Stop WQ
# 1    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490000217E    Stop E
# 2    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490001063C    Stop C
# 3    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490001063F    Stop F
# 4    Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490001157G    Stop G
# ..                                                 ...          ...       ...
# 142  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490G01063B       NaN
# 143  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   490G15122C       NaN
# 144  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...  910GCHINGFD       NaN
# 145  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...   910GILFORD       NaN
# 146  Tfl.Api.Presentation.Entities.StopPoint, Tfl.A...  940GZZLUSWF       NaN
#
# ...

# %%
import urllib.request
import json
import pandas as pd

try:
    url = "https://api.tfl.gov.uk/Line/179/StopPoints?direction=inbound"

    hdr = {
        'Cache-Control': 'no-cache',
    }

    req = urllib.request.Request(url, headers=hdr)
    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)

    # Read and decode JSON response
    data = json.loads(response.read().decode('utf-8'))

    # Create DataFrame from JSON data
    df = pd.json_normalize(data)

    # Display distinct entries from the commonName column
    distinct_entries = df['commonName'].unique()
    print("Distinct Entries from commonName:")
    for entry in distinct_entries:
        print(entry)

    # Save DataFrame to CSV file
    df.to_csv('tfl_stop_points_dir_incl.csv', index=False)

except Exception as e:
    print(e)
# Out:
# Distinct Entries from commonName:
# Gants Hill Station / Woodford Avenue
# South Woodford Station
# Chingford Station
# Ilford Station
# Bancroft's School
# Beehive Lane
# Mornington Avenue
# Bethell Avenue
# Buxton Road
# Ilford / Chapel Road
# Charlie Brown's Roundabout
# Lechmere Approach
# Charlie Browns Roundabout
# Chingford Lane
# Balgonie Road
# Chelmsford Road
# Churchfields
# Churchill Memorial
# Claybury Broadway
# Forest Road
# Friday Hill
# Kings Road / Friday Hill
# Southend Road
# George Lane Shopping Centre
# Glenwood Gardens
# Grasmere Gardens
# Longwood Gardens
# Hainault Street
# George Lane / Chigwell Road
# Highwood Gardens
# Redbridge Central Library
# High Road Ilford
# Kimberley Road
# Monkhams Lane
# Northview Drive
# Woodford Trading Estate
# Onslow Gardens
# Woodford / Roding Lane North
# Woodford / Roding Lane South
# Seymour Court
# Stanley Road
# Station Road / Chingford Station
# Station Road / the Green
# Coventry Road
# Beal Road
# Northbrook Road
# ...

# %%
import requests
import csv

def get_line_route(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if data.get('mode') == 'bus':
            stations = data.get('stations', [])
            return stations
        else:
            print(f"The provided line ID {line_id} does not correspond to a bus route.")
            return None
    else:
        print(f"Failed to fetch data for line {line_id} and direction {direction}. Status code: {response.status_code}")
        return None

def save_to_csv(line_id, stations):
    filename = f"{line_id}_route.csv"
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['ID', 'Name'])
        for station in stations:
            writer.writerow([station['id'], station['name']])

    print(f"Saved route for line {line_id} to {filename}")

# Example usage
if __name__ == "__main__":
    line_id = '22' # Replace with your desired line ID
    direction = 'outbound'  # Replace with your desired direction (e.g., 'inbound')

    stations = get_line_route(line_id, direction)
    if stations:
        save_to_csv(line_id, stations)
# Out:
# Saved route for line 22 to 22_route.csv

# %%
import requests
import csv

def get_line_route(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if data.get('mode') == 'bus':
            stop_points = []
            stations = data.get('stations', [])
            for stop in stations:
                stop_points.append({
                    'id': stop['id'],
                    'name': stop['name']
                })
            return stop_points
        else:
            print(f"The provided line ID {line_id} does not correspond to a bus route.")
            return None
    else:
        print(f"Failed to fetch data for line {line_id} and direction {direction}. Status code: {response.status_code}")
        return None

def save_to_csv(line_id, stop_points):
    filename = f"{line_id}_stops.csv"
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['ID', 'Name'])
        for stop in stop_points:
            writer.writerow([stop['id'], stop['name']])

    print(f"Saved stop points for line {line_id} to {filename}")

# Example usage
if __name__ == "__main__":
    line_id = '22'  # Replace with your desired line ID
    direction = 'outbound'  # Replace with your desired direction (e.g., 'inbound')

    stop_points = get_line_route(line_id, direction)
    if stop_points:
        save_to_csv(line_id, stop_points)
# Out:
# Saved stop points for line 22 to 22_stops.csv

# %%
import requests

def get_start_and_end_points(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        if data.get('modeName') == 'bus':
            for route_section in data.get('routeSections', []):
                if route_section.get('direction', '') == direction:
                    start_point = route_section.get('originationName', 'Unknown')
                    end_point = route_section.get('destinationName', 'Unknown')
                    return start_point, end_point
            print(f"Direction '{direction}' not found for line {line_id}.")
        else:
            print(f"The provided line ID {line_id} does not correspond to a bus route.")
    else:
        print(f"Failed to fetch data for line {line_id}. Status code: {response.status_code}")

    return None, None

# Example usage
if __name__ == "__main__":
    line_id = '22'  # Replace with your desired line ID
    direction = 'outbound'  # Replace with your desired direction (e.g., 'inbound')

    start_point, end_point = get_start_and_end_points(line_id, direction)
    if start_point and end_point:
        print(f"Start point: {start_point}")
        print(f"End point: {end_point}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-94d29bd85c4e> in <cell line: 25>()
#      27     direction = 'outbound'  # Replace with your desired direction (e.g., 'inbound')
#      28
# ---> 29     start_point, end_point = get_start_and_end_points(line_id, direction)
#      30     if start_point and end_point:
#      31         print(f"Start point: {start_point}")
#
# <ipython-input-5-94d29bd85c4e> in get_start_and_end_points(line_id, direction)
#       8         data = response.json()
#       9
# ---> 10         if data.get('modeName') == 'bus':
#      11             for route_section in data.get('routeSections', []):
#      12                 if route_section.get('direction', '') == direction:
#
# AttributeError: 'list' object has no attribute 'get'

# %%
import requests

def get_start_and_end_points(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        if isinstance(data, list):
            # If data is a list, assume it contains multiple items (e.g., for multiple routes)
            for item in data:
                if item.get('modeName') == 'bus':
                    data = item  # Select the first bus item found
                    break

        if isinstance(data, dict) and data.get('modeName') == 'bus':
            for route_section in data.get('routeSections', []):
                if route_section.get('direction', '') == direction:
                    start_point = route_section.get('originationName', 'Unknown')
                    end_point = route_section.get('destinationName', 'Unknown')
                    return start_point, end_point
            print(f"Direction '{direction}' not found for line {line_id}.")
        else:
            print(f"The provided line ID {line_id} does not correspond to a bus route.")
    else:
        print(f"Failed to fetch data for line {line_id}. Status code: {response.status_code}")

    return None, None

# Example usage
if __name__ == "__main__":
    line_id = '22'  # Replace with your desired line ID
    direction = 'inbound'  # Replace with your desired direction (e.g., 'inbound')

    start_point, end_point = get_start_and_end_points(line_id, direction)
    if start_point and end_point:
        print(f"Start point: {start_point}")
        print(f"End point: {end_point}")
# Out:
# Direction 'inbound' not found for line 22.

# %%
import requests

def get_start_and_end_points(line_id):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/outbound"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        stops = data.get('stopPointSequences', [])

        if stops:
            # First stop is the starting point
            start_point = stops[0].get('name', 'Unknown')

            # Last stop is the destination point
            end_point = stops[-1].get('name', 'Unknown')

            return start_point, end_point
        else:
            print(f"No stop points found for line {line_id}.")
    else:
        print(f"Failed to fetch data for line {line_id}. Status code: {response.status_code}")

    return None, None

# Example usage
if __name__ == "__main__":
    line_id = '22'  # Replace with your desired line ID (without 'bus-')

    start_point, end_point = get_start_and_end_points(line_id)
    if start_point and end_point:
        print(f"Start point: {start_point}")
        print(f"End point: {end_point}")
# Out:
# Start point: Unknown
# End point: Unknown

# %%
import requests

def get_routes_with_stops(line_ids):
    url = f"https://api.tfl.gov.uk/Line/{','.join(line_ids)}/Route"
    params = {
        'serviceTypes': 'Regular'  # Default service type, you can change it if needed
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        routes = []

        for route in data:
            route_name = route.get('name', 'Unknown Route')
            origin_stop_id = route.get('routeSections')[0].get('originationStopId', 'Unknown')
            origin_stop_name = route.get('routeSections')[0].get('originationName', 'Unknown')
            destination_stop_id = route.get('routeSections')[-1].get('destinationStopId', 'Unknown')
            destination_stop_name = route.get('routeSections')[-1].get('destinationName', 'Unknown')

            routes.append({
                'name': route_name,
                'origin_stop_id': origin_stop_id,
                'origin_stop_name': origin_stop_name,
                'destination_stop_id': destination_stop_id,
                'destination_stop_name': destination_stop_name
            })

        return routes
    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        return None

# Example usage
if __name__ == "__main__":
    line_ids = ['22']  # Replace with your desired line IDs

    routes = get_routes_with_stops(line_ids)
    if routes:
        for route in routes:
            print(f"Route Name: {route['name']}")
            print(f"Origin: {route['origin_stop_name']} (ID: {route['origin_stop_id']})")
            print(f"Destination: {route['destination_stop_name']} (ID: {route['destination_stop_id']})")
            print("---")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f8b730a667ad> in <cell line: 35>()
#      36     line_ids = ['22']  # Replace with your desired line IDs
#      37
# ---> 38     routes = get_routes_with_stops(line_ids)
#      39     if routes:
#      40         for route in routes:
#
# <ipython-input-9-f8b730a667ad> in get_routes_with_stops(line_ids)
#      13
#      14         for route in data:
# ---> 15             route_name = route.get('name', 'Unknown Route')
#      16             origin_stop_id = route.get('routeSections')[0].get('originationStopId', 'Unknown')
#      17             origin_stop_name = route.get('routeSections')[0].get('originationName', 'Unknown')
#
# AttributeError: 'str' object has no attribute 'get'

# %%
import requests

def get_routes_with_stops(line_ids):
    if isinstance(line_ids, str):
        line_ids = [line_ids]  # Convert single line ID string to a list

    url = f"https://api.tfl.gov.uk/Line/{','.join(line_ids)}/Route"
    params = {
        'serviceTypes': 'Regular'  # Default service type, you can change it if needed
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        routes = []

        for route in data:
            route_name = route.get('name', 'Unknown Route')
            origin_stop_id = route.get('routeSections')[0].get('originationStopId', 'Unknown')
            origin_stop_name = route.get('routeSections')[0].get('originationName', 'Unknown')
            destination_stop_id = route.get('routeSections')[-1].get('destinationStopId', 'Unknown')
            destination_stop_name = route.get('routeSections')[-1].get('destinationName', 'Unknown')

            routes.append({
                'name': route_name,
                'origin_stop_id': origin_stop_id,
                'origin_stop_name': origin_stop_name,
                'destination_stop_id': destination_stop_id,
                'destination_stop_name': destination_stop_name
            })

        return routes
    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        return None

# Example usage
if __name__ == "__main__":
    line_ids = '22'  # Replace with your desired line ID as a string (for single ID)

    routes = get_routes_with_stops(line_ids)
    if routes:
        for route in routes:
            print(f"Route Name: {route['name']}")
            print(f"Origin: {route['origin_stop_name']} (ID: {route['origin_stop_id']})")
            print(f"Destination: {route['destination_stop_name']} (ID: {route['destination_stop_id']})")
            print("---")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-6aa1c9da6e23> in <cell line: 38>()
#      39     line_ids = '22'  # Replace with your desired line ID as a string (for single ID)
#      40
# ---> 41     routes = get_routes_with_stops(line_ids)
#      42     if routes:
#      43         for route in routes:
#
# <ipython-input-10-6aa1c9da6e23> in get_routes_with_stops(line_ids)
#      16
#      17         for route in data:
# ---> 18             route_name = route.get('name', 'Unknown Route')
#      19             origin_stop_id = route.get('routeSections')[0].get('originationStopId', 'Unknown')
#      20             origin_stop_name = route.get('routeSections')[0].get('originationName', 'Unknown')
#
# AttributeError: 'str' object has no attribute 'get'

# %%
import requests

def get_routes_with_stops(line_ids):
    if isinstance(line_ids, str):
        line_ids = [line_ids]  # Convert single line ID string to a list

    url = f"https://api.tfl.gov.uk/Line/{','.join(line_ids)}/Route"
    params = {
        'serviceTypes': 'Regular'  # Default service type, you can change it if needed
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        try:
            data = response.json()
            routes = []

            for route in data:
                route_name = route.get('name', 'Unknown Route')
                origin_stop_id = route.get('routeSections')[0].get('originationStopId', 'Unknown')
                origin_stop_name = route.get('routeSections')[0].get('originationName', 'Unknown')
                destination_stop_id = route.get('routeSections')[-1].get('destinationStopId', 'Unknown')
                destination_stop_name = route.get('routeSections')[-1].get('destinationName', 'Unknown')

                routes.append({
                    'name': route_name,
                    'origin_stop_id': origin_stop_id,
                    'origin_stop_name': origin_stop_name,
                    'destination_stop_id': destination_stop_id,
                    'destination_stop_name': destination_stop_name
                })

            return routes

        except Exception as e:
            print(f"Error parsing JSON response: {e}")
            return None

    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        return None

# Example usage
if __name__ == "__main__":
    line_ids = '22'  # Replace with your desired line ID as a string (for single ID)

    routes = get_routes_with_stops(line_ids)
    if routes:
        for route in routes:
            print(f"Route Name: {route['name']}")
            print(f"Origin: {route['origin_stop_name']} (ID: {route['origin_stop_id']})")
            print(f"Destination: {route['destination_stop_name']} (ID: {route['destination_stop_id']})")
            print("---")
# Out:
# Error parsing JSON response: 'str' object has no attribute 'get'

# %%
import requests

def get_routes_with_stops(line_ids):
    if isinstance(line_ids, str):
        line_ids = [line_ids]  # Convert single line ID string to a list

    url = f"https://api.tfl.gov.uk/Line/{','.join(line_ids)}/Route"
    params = {
        'serviceTypes': 'Regular'  # Default service type, you can change it if needed
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        try:
            data = response.json()  # Attempt to parse response as JSON
            routes = []

            for route in data:
                route_name = route.get('name', 'Unknown Route')
                origin_stop_id = route.get('routeSections')[0].get('originationStopId', 'Unknown')
                origin_stop_name = route.get('routeSections')[0].get('originationName', 'Unknown')
                destination_stop_id = route.get('routeSections')[-1].get('destinationStopId', 'Unknown')
                destination_stop_name = route.get('routeSections')[-1].get('destinationName', 'Unknown')

                routes.append({
                    'name': route_name,
                    'origin_stop_id': origin_stop_id,
                    'origin_stop_name': origin_stop_name,
                    'destination_stop_id': destination_stop_id,
                    'destination_stop_name': destination_stop_name
                })

            return routes

        except ValueError as ve:
            print(f"ValueError: Failed to parse JSON response: {ve}")
            print(f"Response content: {response.text}")
            return None

        except Exception as e:
            print(f"Error: {e}")
            return None

    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        return None

# Example usage
if __name__ == "__main__":
    line_ids = '22'  # Replace with your desired line ID as a string (for single ID)

    routes = get_routes_with_stops(line_ids)
    if routes:
        for route in routes:
            print(f"Route Name: {route['name']}")
            print(f"Origin: {route['origin_stop_name']} (ID: {route['origin_stop_id']})")
            print(f"Destination: {route['destination_stop_name']} (ID: {route['destination_stop_id']})")
            print("---")
# Out:
# Error: 'str' object has no attribute 'get'

# %% [markdown]
# Code fetching the origination and destination details of a line ID

# %%
import requests

def fetch_route_details(line_id):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        for section in route_sections:
            direction = section.get('direction', 'Unknown')
            origination_name = section.get('originationName', 'Unknown')
            destination_name = section.get('destinationName', 'Unknown')
            originator = section.get('originator', 'Unknown')
            destination = section.get('destination', 'Unknown')

            print(f"Direction: {direction}")
            print(f"Origination Name: {origination_name}")
            print(f"Destination Name: {destination_name}")
            print(f"Originator: {originator}")
            print(f"Destination: {destination}")
            print("---")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Example usage
if __name__ == "__main__":
    line_id = '141'
    fetch_route_details(line_id)
# Out:
# Direction: outbound
# Origination Name: Tottenhall Road
# Destination Name: London Bridge Station
# Originator: 490010333W
# Destination: 490000139CZ
# ---
# Direction: inbound
# Origination Name: London Bridge Station
# Destination Name: Tottenhall Road
# Originator: 490000139CZ
# Destination: 490010333T
# ---

# %% [markdown]
# General code fetching the origination and destination details of a line ID and direction input by the user

# %%
import requests

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Example usage
if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")

    fetch_route_details(line_id, direction)
# Out:
# Enter line ID: 22
# Enter direction (e.g., inbound or outbound): outbound
# Direction: outbound
# Origination Name: Putney Common
# Destination Name: Margaret Street / Oxford Circus
# Originator: 490011281N
# Destination: 490000173N
# ---

# %% [markdown]
# code fetching the origination and destination details of a line ID and direction input by the user and displaying the latitudes and longitude of the stop points

# %%
import requests

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                fetch_and_print_stop_points(line_id, originator, destination, direction)

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_print_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            print("Stop Points:")
            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    print(f"Latitude: {lat}, Longitude: {lon}")

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

# Example usage
if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")

    fetch_route_details(line_id, direction)
# Out:
# Enter line ID: 22
# Enter direction (e.g., inbound or outbound): outbound
# Direction: outbound
# Origination Name: Putney Common
# Destination Name: Margaret Street / Oxford Circus
# Originator: 490011281N
# Destination: 490000173N
# ---
# Stop Points:
# Latitude: 51.468027, Longitude: -0.228249
# Latitude: 51.468386, Longitude: -0.228249
# Latitude: 51.468388, Longitude: -0.227811
# Latitude: 51.468388, Longitude: -0.227811
# Latitude: 51.46846, Longitude: -0.224819
# Latitude: 51.468407, Longitude: -0.224289
# Latitude: 51.468224, Longitude: -0.223446
# Latitude: 51.468224, Longitude: -0.223446
# Latitude: 51.467656, Longitude: -0.221064
# Latitude: 51.467289, Longitude: -0.219223
# Latitude: 51.467289, Longitude: -0.219223
# Latitude: 51.467163, Longitude: -0.218175
# Latitude: 51.467136, Longitude: -0.216981
# Latitude: 51.467022, Longitude: -0.216626
# Latitude: 51.466297, Longitude: -0.214883
# Latitude: 51.466297, Longitude: -0.214883
# ...

# %% [markdown]
# code fetching the origination and destination details of a line ID and direction input by the user and displaying the stop Id, stop name , latitudes and longitude of the stop points

# %%
import requests

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                fetch_and_print_stop_points(line_id, originator, destination, direction)

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_print_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            print("Stop Points:")
            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    print(f"Latitude: {lat}, Longitude: {lon}")

                    # Fetching and printing stop details using the lat and lon
                    fetch_and_print_stop_details(lat, lon)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

def fetch_and_print_stop_details(lat, lon):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        stop_points = data.get('stopPoints', [])

        if stop_points:
            for stop_point in stop_points:
                stop_id = stop_point.get('id', 'Unknown')
                stop_name = stop_point.get('commonName', 'Unknown')

                print(f"Stop ID: {stop_id}")
                print(f"Stop Name: {stop_name}")
                print(f"Latitude: {lat}, Longitude: {lon}")
                print("---")

        else:
            print("No stop points found near this location.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop details: {e}")

# Example usage
if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")

    fetch_route_details(line_id, direction)
# Out:
# Enter line ID: 22
# Enter direction (e.g., inbound or outbound): outbound
# Direction: outbound
# Origination Name: Putney Common
# Destination Name: Margaret Street / Oxford Circus
# Originator: 490011281N
# Destination: 490000173N
# ---
# Stop Points:
# Latitude: 51.468027, Longitude: -0.228249
# Stop ID: 490011281S
# Stop Name: Putney Common
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490011281N
# Stop Name: Putney Common
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490012375E
# Stop Name: Commondale
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490012375W
# Stop Name: Commondale
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Latitude: 51.468386, Longitude: -0.228249
# Stop ID: 490011281S
# Stop Name: Putney Common
# Latitude: 51.468386, Longitude: -0.228249
# ---
# Stop ID: 490011281N
# Stop Name: Putney Common
# Latitude: 51.468386, Longitude: -0.228249
# ---
# Stop ID: 490012375E
# Stop Name: Commondale
# ...

# %% [markdown]
# code fetching the origination and destination details of a line ID and direction input by the user and displaying the stop id, stop name,latitudes and longitude of the stop points (distinct stop point Id)

# %%
import requests

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                fetch_and_print_stop_points(line_id, originator, destination, direction)

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_print_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            print("Stop Points:")
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and printing stop details using the lat and lon
                    fetch_and_print_stop_details(lat, lon, printed_stop_ids)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

def fetch_and_print_stop_details(lat, lon, printed_stop_ids):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        stop_points = data.get('stopPoints', [])

        if stop_points:
            for stop_point in stop_points:
                stop_id = stop_point.get('id', 'Unknown')

                # Print only if stop ID has not been printed before
                if stop_id not in printed_stop_ids:
                    stop_name = stop_point.get('commonName', 'Unknown')

                    print(f"Stop ID: {stop_id}")
                    print(f"Stop Name: {stop_name}")
                    print(f"Latitude: {lat}, Longitude: {lon}")
                    print("---")

                    # Add stop ID to printed set
                    printed_stop_ids.add(stop_id)

        else:
            print("No stop points found near this location.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop details: {e}")

# Example usage
if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")

    fetch_route_details(line_id, direction)
# Out:
# Enter line ID: 22
# Enter direction (e.g., inbound or outbound): outbound
# Direction: outbound
# Origination Name: Putney Common
# Destination Name: Margaret Street / Oxford Circus
# Originator: 490011281N
# Destination: 490000173N
# ---
# Stop Points:
# Stop ID: 490011281S
# Stop Name: Putney Common
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490011281N
# Stop Name: Putney Common
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490012375E
# Stop Name: Commondale
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490012375W
# Stop Name: Commondale
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490006825E
# Stop Name: Festing Road
# Latitude: 51.46846, Longitude: -0.224819
# ---
# Stop ID: 490006825W
# Stop Name: Festing Road
# Latitude: 51.46846, Longitude: -0.224819
# ---
# Stop ID: 490011828E
# Stop Name: Ruvigny Gardens
# Latitude: 51.467656, Longitude: -0.221064
# ---
# Stop ID: 490011828W
# Stop Name: Ruvigny Gardens
# ...

# %% [markdown]
# code fetching the origination and destination details of a line ID and direction input by the user and displaying the stop id, stop name, latitudes and longitude of the stop points (distinct entries of stop points-ignoring the aplhabetical letters in the stop ID)

# %%
import requests
import re

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                fetch_and_print_stop_points(line_id, originator, destination, direction)

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_print_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            print("Stop Points:")
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and printing stop details using the lat and lon
                    fetch_and_print_stop_details(lat, lon, printed_stop_ids)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

def fetch_and_print_stop_details(lat, lon, printed_stop_ids):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        stop_points = data.get('stopPoints', [])

        if stop_points:
            for stop_point in stop_points:
                stop_id = stop_point.get('id', 'Unknown')

                # Extract numeric part from stop ID using regex
                numeric_stop_id = re.search(r'\d+', stop_id).group() if stop_id else None

                # Print only if numeric part of stop ID has not been printed before
                if numeric_stop_id and numeric_stop_id not in printed_stop_ids:
                    stop_name = stop_point.get('commonName', 'Unknown')

                    print(f"Stop ID: {numeric_stop_id}")
                    print(f"Stop Name: {stop_name}")
                    print(f"Latitude: {lat}, Longitude: {lon}")
                    print("---")

                    # Add numeric stop ID to printed set
                    printed_stop_ids.add(numeric_stop_id)

        else:
            print("No stop points found near this location.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop details: {e}")

# Example usage
if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")

    fetch_route_details(line_id, direction)

# %%
import requests
import re
import time

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                fetch_and_print_stop_points(line_id, originator, destination, direction)

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_print_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            print("Stop Points:")
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and printing stop details using the lat and lon
                    fetch_and_print_stop_details(lat, lon, printed_stop_ids)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

def fetch_and_print_stop_details(lat, lon, printed_stop_ids, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                print(f"Rate limit exceeded. Retrying in {2**attempt} seconds...")
                time.sleep(2**attempt)
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Extract numeric part from stop ID using regex
                    numeric_stop_id = re.search(r'\d+', stop_id).group() if stop_id else None

                    # Print only if numeric part of stop ID has not been printed before
                    if numeric_stop_id and numeric_stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        print(f"Stop ID: {numeric_stop_id}")
                        print(f"Stop Name: {stop_name}")
                        print(f"Latitude: {lat}, Longitude: {lon}")
                        print("---")

                        # Add numeric stop ID to printed set
                        printed_stop_ids.add(numeric_stop_id)

            else:
                print("No stop points found near this location.")

            break  # Exit loop if successful

        else:
            print(f"Error fetching stop details after {retries} attempts.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop details: {e}")

# Example usage
if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")

    fetch_route_details(line_id, direction)
# Out:
# Enter line ID: 22
# Enter direction (e.g., inbound or outbound): outbound
# Direction: outbound
# Origination Name: Putney Common
# Destination Name: Margaret Street / Oxford Circus
# Originator: 490011281N
# Destination: 490000173N
# ---
# Stop Points:
# Stop ID: 490011281
# Stop Name: Putney Common
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490012375
# Stop Name: Commondale
# Latitude: 51.468027, Longitude: -0.228249
# ---
# Stop ID: 490006825
# Stop Name: Festing Road
# Latitude: 51.46846, Longitude: -0.224819
# ---
# Stop ID: 490011828
# Stop Name: Ruvigny Gardens
# Latitude: 51.467656, Longitude: -0.221064
# ---
# Stop ID: 490013344
# Stop Name: Putney Pier
# Latitude: 51.467163, Longitude: -0.218175
# ---
# Stop ID: 490011278
# Stop Name: St Mary's Church / Putney Pier
# Latitude: 51.467136, Longitude: -0.216981
# ---
# Stop ID: 490011279
# Stop Name: Brewhouse Lane
# Latitude: 51.466297, Longitude: -0.214883
# ---
# Stop ID: 490011286
# ...
