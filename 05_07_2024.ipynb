# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaVKarthikeyan/AA-Stagecoach-Project/blob/main/05_07_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 05/07/2024- File share 26

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Stop Point ID', 'Number of Buses Observed', 'AWT (minutes)'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT_minutes': [],
            'Number_of_buses': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT_minutes'].append(scheduled_wait_time)
                swt_data['Number_of_buses'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['Number_of_buses'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT_minutes'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [stop_point_id, num_buses_observed, awt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {current_hour}")
        print(awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: 124
#
#
# QSI stop points for direction 124_A
#
#   Route_Dir_QSI_No                             STOP_Name           ID
# 0           124_A1  Stanstead Road / St Dunstans College   490004863Z
# 1           124_A2     Catford Road / Lewisham Town Hall   490009117J
# 2           124_A3                           Ardoch Road   490007967S
# 3           124_A4                        Whitefoot Lane   490014581S
# 4           124_A5                    Grove Park Station   490015256C
# 5           124_A6                       Court Farm Road   490005655E
# 6           124_A7                    Mottingham Station   490001200A
# 7           124_A8                       Newmarket Green  490010238N2
#
#
# QSI stop points for direction 124_B
#
#   Route_Dir_QSI_No                          STOP_Name          ID
# 0           124_B1                Holy Trinity Church  490008321S
# 3           124_B2  Eltham High Street / Passey Place  490006537M
# 4           124_B3                    Newmarket Green  490010238E
# 5           124_B4                 Mottingham Station  490001200B
# 6           124_B5                    Court Farm Road  490005655W
# 7           124_B6                 Grove Park Station  490015256D
# 8           124_B7                     Whitefoot Lane  490014581N
# 9           124_B8                        Ardoch Road  490003369N
#
# Today is Friday. The selected Schedule name is Monday to Friday.
#
#
# SWT DataFrame at hour 10
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z     5.000000                6
# 1            124_A2   490009117J     5.000000                6
# 2            124_A3   490007967S     5.000000                6
# 3            124_A4   490014581S     5.000000                6
# 4            124_A5   490015256C     5.000000                6
# 5            124_A6   490005655E     5.000000                6
# 6            124_A7   490001200A     5.000000                6
# 7            124_A8  490010238N2     5.000000                6
# 8            124_B1   490008321S     5.000000                6
# 9            124_B2   490006537M     5.000000                6
# 10           124_B3   490010238E     5.000000                6
# 11           124_B4   490001200B     5.000000                6
# 12           124_B5   490005655W     5.000000                6
# 13           124_B6   490015256D     5.000000                6
# 14           124_B7   490014581N     5.000000                6
# 15           124_B8   490003369N     4.285714                7
#
#
# AWT DataFrame at hour 10
# Empty DataFrame
# Columns: [Stop Point ID, Number of Buses Observed, AWT (minutes)]
# Index: []
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490014581S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.68
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  109.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.45
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.45
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  108.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    4.34
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)   -0.66
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  83.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -1.23
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)    4.5
# 3  Time difference between 1st and last observed ...    3.0
# 4                                      AWT (minutes)    1.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -3.5
#
#
# Summary Metrics for 490015256D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  130.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    6.87
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.87
#
#
# Summary Metrics for 490014581N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    5.00
# 2                               Total WAWT (minutes)  146.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    7.71
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    2.71
#
#
# Summary Metrics for 490003369N:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    3.000000
# 2                               Total WAWT (minutes)  162.500000
# 3  Time difference between 1st and last observed ...   19.000000
# 4                                      AWT (minutes)    8.550000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)    4.260000
#
#
# SWT DataFrame at hour 10
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z     5.000000                6
# 1            124_A2   490009117J     5.000000                6
# 2            124_A3   490007967S     5.000000                6
# 3            124_A4   490014581S     5.000000                6
# 4            124_A5   490015256C     5.000000                6
# 5            124_A6   490005655E     5.000000                6
# 6            124_A7   490001200A     5.000000                6
# 7            124_A8  490010238N2     5.000000                6
# 8            124_B1   490008321S     5.000000                6
# 9            124_B2   490006537M     5.000000                6
# 10           124_B3   490010238E     5.000000                6
# 11           124_B4   490001200B     5.000000                6
# 12           124_B5   490005655W     5.000000                6
# 13           124_B6   490015256D     5.000000                6
# 14           124_B7   490014581N     5.000000                6
# 15           124_B8   490003369N     4.285714                7
#
#
# AWT DataFrame at hour 10
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004863Z                         1           0.00
# 1     490009117J                         3           5.26
# 2     490007967S                         2           6.50
# 3     490014581S                         3           5.68
# 4     490015256C                         3           5.45
# 5     490005655E                         4           4.34
# 6    490010238N2                         4           3.77
# 7     490008321S                         1           0.00
# 8     490006537M                         1           0.00
# 9     490005655W                         3           1.50
# 10    490015256D                         4           6.87
# 11    490014581N                         5           7.71
# 12    490003369N                         3           8.55
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  134.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.85
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.85
#
#
# Summary Metrics for 490014581S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.68
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  109.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.45
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.45
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  108.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    4.34
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)   -0.66
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  83.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -1.23
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   18.00
# 4                                      AWT (minutes)    7.22
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    2.22
#
#
# Summary Metrics for 490014581N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   18.00
# 4                                      AWT (minutes)    7.22
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    2.22
#
#
# Summary Metrics for 490003369N:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    3.000000
# 2                               Total WAWT (minutes)  162.500000
# 3  Time difference between 1st and last observed ...   19.000000
# 4                                      AWT (minutes)    8.550000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)    4.260000
#
#
# SWT DataFrame at hour 10
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z     5.000000                6
# 1            124_A2   490009117J     5.000000                6
# 2            124_A3   490007967S     5.000000                6
# 3            124_A4   490014581S     5.000000                6
# 4            124_A5   490015256C     5.000000                6
# 5            124_A6   490005655E     5.000000                6
# 6            124_A7   490001200A     5.000000                6
# 7            124_A8  490010238N2     5.000000                6
# 8            124_B1   490008321S     5.000000                6
# 9            124_B2   490006537M     5.000000                6
# 10           124_B3   490010238E     5.000000                6
# 11           124_B4   490001200B     5.000000                6
# 12           124_B5   490005655W     5.000000                6
# 13           124_B6   490015256D     5.000000                6
# 14           124_B7   490014581N     5.000000                6
# 15           124_B8   490003369N     4.285714                7
#
#
# AWT DataFrame at hour 10
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004863Z                         1           0.00
# 1     490009117J                         3           5.26
# 2     490007967S                         2           6.50
# 3     490014581S                         3           5.68
# 4     490015256C                         3           5.45
# 5     490005655E                         4           4.34
# 6    490010238N2                         4           3.77
# 7     490008321S                         1           0.00
# 8     490006537M                         1           0.00
# 9     490005655W                         3           1.50
# 10    490015256D                         4           6.87
# 11    490014581N                         5           7.71
# 12    490003369N                         3           8.55
# 13    490004863Z                         1           0.00
# 14    490009117J                         2           5.00
# 15    490007967S                         3           5.85
# 16    490014581S                         3           5.68
# 17    490015256C                         3           5.45
# 18    490005655E                         4           4.34
# 19   490010238N2                         4           3.77
# 20    490008321S                         2           5.00
# 21    490006537M                         2           5.50
# 22    490005655W                         2           0.00
# 23    490015256D                         3           7.22
# 24    490014581N                         4           7.22
# 25    490003369N                         3           8.55
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490014581S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.68
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  109.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.45
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.45
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  18.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.44
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  74.50
# 3  Time difference between 1st and last observed ...  21.00
# 4                                      AWT (minutes)   3.55
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -1.45
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)    2.0
# 3  Time difference between 1st and last observed ...    2.0
# 4                                      AWT (minutes)    1.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -4.0
#
#
# Summary Metrics for 490014581N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   18.00
# 4                                      AWT (minutes)    7.22
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    2.22
#
#
# Summary Metrics for 490003369N:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    3.000000
# 2                               Total WAWT (minutes)  162.500000
# 3  Time difference between 1st and last observed ...   19.000000
# 4                                      AWT (minutes)    8.550000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)    4.260000
#
#
# SWT DataFrame at hour 10
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z     5.000000                6
# 1            124_A2   490009117J     5.000000                6
# 2            124_A3   490007967S     5.000000                6
# 3            124_A4   490014581S     5.000000                6
# 4            124_A5   490015256C     5.000000                6
# 5            124_A6   490005655E     5.000000                6
# 6            124_A7   490001200A     5.000000                6
# 7            124_A8  490010238N2     5.000000                6
# 8            124_B1   490008321S     5.000000                6
# 9            124_B2   490006537M     5.000000                6
# 10           124_B3   490010238E     5.000000                6
# 11           124_B4   490001200B     5.000000                6
# 12           124_B5   490005655W     5.000000                6
# 13           124_B6   490015256D     5.000000                6
# 14           124_B7   490014581N     5.000000                6
# 15           124_B8   490003369N     4.285714                7
#
#
# AWT DataFrame at hour 10
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004863Z                         1           0.00
# 1     490009117J                         3           5.26
# 2     490007967S                         2           6.50
# 3     490014581S                         3           5.68
# 4     490015256C                         3           5.45
# 5     490005655E                         4           4.34
# 6    490010238N2                         4           3.77
# 7     490008321S                         1           0.00
# 8     490006537M                         1           0.00
# 9     490005655W                         3           1.50
# 10    490015256D                         4           6.87
# 11    490014581N                         5           7.71
# 12    490003369N                         3           8.55
# 13    490004863Z                         1           0.00
# 14    490009117J                         2           5.00
# 15    490007967S                         3           5.85
# 16    490014581S                         3           5.68
# 17    490015256C                         3           5.45
# 18    490005655E                         4           4.34
# 19   490010238N2                         4           3.77
# 20    490008321S                         2           5.00
# 21    490006537M                         2           5.50
# 22    490005655W                         2           0.00
# 23    490015256D                         3           7.22
# 24    490014581N                         4           7.22
# 25    490003369N                         3           8.55
# 26    490004863Z                         1           0.00
# 27    490009117J                         2           5.00
# 28    490007967S                         3           5.26
# 29    490014581S                         3           5.68
# 30    490015256C                         3           5.45
# 31    490005655E                         3           4.56
# 32   490010238N2                         4           3.55
# 33    490008321S                         2           5.00
# 34    490006537M                         2           5.50
# 35    490005655W                         2           0.00
# 36    490015256D                         2           1.00
# 37    490014581N                         4           7.22
# 38    490003369N                         3           8.55
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490014581S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.68
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  109.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.45
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.45
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  18.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.44
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  42.50
# 3  Time difference between 1st and last observed ...  13.00
# 4                                      AWT (minutes)   3.27
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -1.73
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)    2.0
# 3  Time difference between 1st and last observed ...    2.0
# 4                                      AWT (minutes)    1.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -4.0
#
#
# Summary Metrics for 490014581N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   18.00
# 4                                      AWT (minutes)    7.22
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    2.22
#
#
# Summary Metrics for 490003369N:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    3.000000
# 2                               Total WAWT (minutes)  180.500000
# 3  Time difference between 1st and last observed ...   19.000000
# 4                                      AWT (minutes)    9.500000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)    5.210000
#
#
# SWT DataFrame at hour 10
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z     5.000000                6
# 1            124_A2   490009117J     5.000000                6
# 2            124_A3   490007967S     5.000000                6
# 3            124_A4   490014581S     5.000000                6
# 4            124_A5   490015256C     5.000000                6
# 5            124_A6   490005655E     5.000000                6
# 6            124_A7   490001200A     5.000000                6
# 7            124_A8  490010238N2     5.000000                6
# 8            124_B1   490008321S     5.000000                6
# 9            124_B2   490006537M     5.000000                6
# 10           124_B3   490010238E     5.000000                6
# 11           124_B4   490001200B     5.000000                6
# 12           124_B5   490005655W     5.000000                6
# 13           124_B6   490015256D     5.000000                6
# 14           124_B7   490014581N     5.000000                6
# 15           124_B8   490003369N     4.285714                7
#
#
# AWT DataFrame at hour 10
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004863Z                         1           0.00
# 1     490009117J                         3           5.26
# 2     490007967S                         2           6.50
# 3     490014581S                         3           5.68
# 4     490015256C                         3           5.45
# 5     490005655E                         4           4.34
# 6    490010238N2                         4           3.77
# 7     490008321S                         1           0.00
# 8     490006537M                         1           0.00
# 9     490005655W                         3           1.50
# 10    490015256D                         4           6.87
# 11    490014581N                         5           7.71
# 12    490003369N                         3           8.55
# 13    490004863Z                         1           0.00
# 14    490009117J                         2           5.00
# 15    490007967S                         3           5.85
# 16    490014581S                         3           5.68
# 17    490015256C                         3           5.45
# 18    490005655E                         4           4.34
# 19   490010238N2                         4           3.77
# 20    490008321S                         2           5.00
# 21    490006537M                         2           5.50
# 22    490005655W                         2           0.00
# 23    490015256D                         3           7.22
# 24    490014581N                         4           7.22
# 25    490003369N                         3           8.55
# 26    490004863Z                         1           0.00
# 27    490009117J                         2           5.00
# 28    490007967S                         3           5.26
# 29    490014581S                         3           5.68
# 30    490015256C                         3           5.45
# 31    490005655E                         3           4.56
# 32   490010238N2                         4           3.55
# 33    490008321S                         2           5.00
# 34    490006537M                         2           5.50
# 35    490005655W                         2           0.00
# 36    490015256D                         2           1.00
# 37    490014581N                         4           7.22
# 38    490003369N                         3           8.55
# 39    490004863Z                         1           0.00
# 40    490009117J                         2           5.00
# 41    490007967S                         3           5.26
# 42    490014581S                         3           5.68
# 43    490015256C                         3           5.45
# 44    490005655E                         3           4.56
# 45   490010238N2                         3           3.27
# 46    490008321S                         1           0.00
# 47    490006537M                         2           5.50
# 48    490005655W                         2           0.00
# 49    490015256D                         2           1.00
# 50    490014581N                         4           7.22
# 51    490003369N                         3           9.50
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490014581S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  112.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.36
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.36
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  109.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.45
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.45
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  18.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.44
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  42.50
# 3  Time difference between 1st and last observed ...  13.00
# 4                                      AWT (minutes)   3.27
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -1.73
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    4.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)    2.0
# 3  Time difference between 1st and last observed ...    2.0
# 4                                      AWT (minutes)    1.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -4.0
# ...
#
#
# AWT DataFrame at hour 10
#     Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0      490004863Z                         1           0.00
# 1      490009117J                         3           5.26
# 2      490007967S                         2           6.50
# 3      490014581S                         3           5.68
# 4      490015256C                         3           5.45
# ..            ...                       ...            ...
# 122    490015256C                         3           5.55
# 123    490005655E                         3           4.56
# 124   490010238N2                         3           3.90
# 125    490008321S                         2          10.00
# 126    490006537M                         2          10.00
#
# [127 rows x 3 columns]
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490014581S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  116.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.55
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  18.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.44
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)   58.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    3.9
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -1.1
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  200.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)   10.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  200.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)   10.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490003369N:
#                                               Metric     Value
# 0          Number of buses scheduled per hour (nbph)  7.000000
# 1                           Number of buses observed  2.000000
# 2                               Total WAWT (minutes)  0.000000
# 3  Time difference between 1st and last observed ...  0.000000
# 4                                      AWT (minutes)  0.000000
# 5                                      SWT (minutes)  4.285714
# 6                                      EWT (minutes) -4.290000
#
#
# SWT DataFrame at hour 10
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z     5.000000                6
# 1            124_A2   490009117J     5.000000                6
# 2            124_A3   490007967S     5.000000                6
# 3            124_A4   490014581S     5.000000                6
# 4            124_A5   490015256C     5.000000                6
# 5            124_A6   490005655E     5.000000                6
# 6            124_A7   490001200A     5.000000                6
# 7            124_A8  490010238N2     5.000000                6
# 8            124_B1   490008321S     5.000000                6
# 9            124_B2   490006537M     5.000000                6
# 10           124_B3   490010238E     5.000000                6
# 11           124_B4   490001200B     5.000000                6
# 12           124_B5   490005655W     5.000000                6
# 13           124_B6   490015256D     5.000000                6
# 14           124_B7   490014581N     5.000000                6
# 15           124_B8   490003369N     4.285714                7
#
#
# AWT DataFrame at hour 10
#     Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0      490004863Z                         1           0.00
# 1      490009117J                         3           5.26
# 2      490007967S                         2           6.50
# 3      490014581S                         3           5.68
# 4      490015256C                         3           5.45
# ..            ...                       ...            ...
# 133   490010238N2                         3           3.90
# 134    490008321S                         2          10.00
# 135    490006537M                         2          10.00
# 136    490005655W                         1           0.00
# 137    490003369N                         2           0.00
#
# [138 rows x 3 columns]
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490014581S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  116.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.55
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  142.50
# 3  Time difference between 1st and last observed ...   29.00
# 4                                      AWT (minutes)    4.91
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)   -0.09
#
#
# Summary Metrics for 490010238N2:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  102.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    5.39
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.39
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490015256D?direction=inbound
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490014581N?direction=inbound
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490003369N?direction=inbound
#
#
# SWT DataFrame at hour 10
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z     5.000000                6
# 1            124_A2   490009117J     5.000000                6
# 2            124_A3   490007967S     5.000000                6
# 3            124_A4   490014581S     5.000000                6
# 4            124_A5   490015256C     5.000000                6
# 5            124_A6   490005655E     5.000000                6
# 6            124_A7   490001200A     5.000000                6
# 7            124_A8  490010238N2     5.000000                6
# 8            124_B1   490008321S     5.000000                6
# 9            124_B2   490006537M     5.000000                6
# 10           124_B3   490010238E     5.000000                6
# 11           124_B4   490001200B     5.000000                6
# 12           124_B5   490005655W     5.000000                6
# 13           124_B6   490015256D     5.000000                6
# 14           124_B7   490014581N     5.000000                6
# 15           124_B8   490003369N     4.285714                7
#
#
# AWT DataFrame at hour 10
#     Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0      490004863Z                         1           0.00
# 1      490009117J                         3           5.26
# 2      490007967S                         2           6.50
# 3      490014581S                         3           5.68
# 4      490015256C                         3           5.45
# ..            ...                       ...            ...
# 143    490005655E                         4           4.91
# 144   490010238N2                         3           5.39
# 145    490008321S                         1           0.00
# 146    490006537M                         1           0.00
# 147    490005655W                         1           0.00
#
# [148 rows x 3 columns]
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Modification to overwrite awt

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Stop Point ID', 'Number of Buses Observed', 'AWT (minutes)'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Stop Point ID', 'Number of Buses Observed', 'AWT (minutes)'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT_minutes': [],
            'Number_of_buses': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT_minutes'].append(scheduled_wait_time)
                swt_data['Number_of_buses'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['Number_of_buses'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT_minutes'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [stop_point_id, num_buses_observed, awt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {current_hour}")
        print(awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: w14
#
#
# QSI stop points for direction W14_A
#
#   Route_Dir_QSI_No                          STOP_Name          ID
# 0           W14_A1                         Cross Road  490004984N
# 1           W14_A2                     Orchard Estate  490010612W
# 2           W14_A3             South Woodford Station  490000217D
# 4           W14_A4   Wanstead Station  / George Green  490015125C
# 5           W14_A5                Leytonstone Station  490000137W
# 7           W14_A6  Leyton High Road / Leyton Station  490009136C
#
#
# QSI stop points for direction W14_B
#
#   Route_Dir_QSI_No                          STOP_Name          ID
# 0           W14_B1                       Leyton Mills  490015670N
# 1           W14_B2  Leyton High Road / Leyton Station  490009136D
# 2           W14_B3                        Harvey Road  490007882H
# 3           W14_B4                   Wanstead Station  490015125B
# 4           W14_B5             South Woodford Station  490015122C
# 5           W14_B6                     Orchard Estate  490010612E
#
# Today is Friday. The selected Schedule name is Monday to Friday.
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
# Empty DataFrame
# Columns: [Stop Point ID, Number of Buses Observed, AWT (minutes)]
# Index: []
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490015125B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -2.0
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1            0.0
# 1     490010612W                         1            0.0
# 2     490000217D                         2            7.5
# 3     490015125C                         2            8.5
# 4     490000137W                         2            7.5
# 5     490009136C                         1            0.0
# 6     490009136D                         1            0.0
# 7     490007882H                         2            8.5
# 8     490015125B                         2            5.5
# 9     490015122C                         2            6.5
# 10    490010612E                         2            8.0
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490015125B:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  205.00
# 3  Time difference between 1st and last observed ...   28.00
# 4                                      AWT (minutes)    7.32
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -0.18
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1           0.00
# 1     490010612W                         2           7.50
# 2     490000217D                         2           7.00
# 3     490015125C                         2           8.50
# 4     490000137W                         2           7.50
# 5     490009136C                         1           0.00
# 6     490009136D                         1           0.00
# 7     490007882H                         2           8.50
# 8     490015125B                         3           7.32
# 9     490015122C                         2           6.50
# 10    490010612E                         2           8.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015125B:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  205.00
# 3  Time difference between 1st and last observed ...   28.00
# 4                                      AWT (minutes)    7.32
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -0.18
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1           0.00
# 1     490010612W                         2           7.50
# 2     490000217D                         2           7.00
# 3     490015125C                         2           8.00
# 4     490000137W                         2           7.50
# 5     490009136C                         1           0.00
# 6     490009136D                         1           0.00
# 7     490007882H                         2           9.00
# 8     490015125B                         3           7.32
# 9     490015122C                         2           6.50
# 10    490010612E                         2           8.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015125B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1            0.0
# 1     490010612W                         2            7.5
# 2     490000217D                         2            7.0
# 3     490015125C                         2            8.0
# 4     490000137W                         2            7.5
# 5     490009136C                         1            0.0
# 6     490009136D                         1            0.0
# 7     490007882H                         2            9.0
# 8     490015125B                         2            8.5
# 9     490015122C                         2            6.5
# 10    490010612E                         2            8.0
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015125B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1            0.0
# 1     490010612W                         2            7.5
# 2     490000217D                         2            7.0
# 3     490015125C                         2            8.0
# 4     490000137W                         2            7.5
# 5     490009136C                         1            0.0
# 6     490009136D                         1            0.0
# 7     490007882H                         2            9.0
# 8     490015125B                         2            8.5
# 9     490015122C                         2            6.5
# 10    490010612E                         2            8.0
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015125B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1            0.0
# 1     490010612W                         2            7.5
# 2     490000217D                         2            7.0
# 3     490015125C                         2            8.0
# 4     490000137W                         2            7.5
# 5     490009136C                         1            0.0
# 6     490009136D                         1            0.0
# 7     490007882H                         2            9.0
# 8     490015125B                         2            8.5
# 9     490015122C                         2            6.5
# 10    490010612E                         2            8.0
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490015670N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015125B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1            0.0
# 1     490010612W                         2            7.5
# 2     490000217D                         2            6.5
# 3     490015125C                         2            8.0
# 4     490000137W                         2            7.5
# 5     490009136C                         1            0.0
# 6     490015670N                         1            0.0
# 7     490009136D                         1            0.0
# 8     490007882H                         2            9.0
# 9     490015125B                         2            8.5
# 10    490015122C                         2            6.5
# 11    490010612E                         2            8.0
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004984N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490000137W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490015670N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015125B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0            W14_A1  490004984N          7.5                4
# 1            W14_A2  490010612W          7.5                4
# 2            W14_A3  490000217D          7.5                4
# 3            W14_A4  490015125C          7.5                4
# 4            W14_A5  490000137W          7.5                4
# 5            W14_A6  490009136C          7.5                4
# 6            W14_B1  490015670N          7.5                4
# 7            W14_B2  490009136D          7.5                4
# 8            W14_B3  490007882H          7.5                4
# 9            W14_B4  490015125B          7.5                4
# 10           W14_B5  490015122C          7.5                4
# 11           W14_B6  490010612E          7.5                4
#
#
# AWT DataFrame at hour 11
#    Stop Point ID  Number of Buses Observed  AWT (minutes)
# 0     490004984N                         1            0.0
# 1     490010612W                         2            7.5
# 2     490000217D                         2            6.5
# 3     490015125C                         2            7.0
# 4     490000137W                         2            7.5
# 5     490009136C                         1            0.0
# 6     490015670N                         1            0.0
# 7     490009136D                         1            0.0
# 8     490007882H                         2            9.0
# 9     490015125B                         2            8.5
# 10    490015122C                         2            6.5
# 11    490010612E                         2            8.0
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Modification

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Stop Point ID', 'AWT (minutes)','Number of Buses Observed'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Stop Point ID','AWT (minutes)','Number of Buses Observed'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT_minutes': [],
            'Number_of_buses': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT_minutes'].append(scheduled_wait_time)
                swt_data['Number_of_buses'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['Number_of_buses'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT_minutes'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [stop_point_id, awt,num_buses_observed]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {current_time_bst.strftime('%H:%M')}")
        print(awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: 25
#
#
# QSI stop points for direction 25_A
#
#   Route_Dir_QSI_No                             STOP_Name          ID
# 0            25_A1                       Hainault Street  490007657V
# 1            25_A2                     High Street North  490008189W
# 2            25_A3                          Green Street  490007497W
# 3            25_A4                 Stratford Bus Station  490012904T
# 4            25_A5                    Bow Church Station  490002019B
# 5            25_A6                      Mile End Station  490000146C
# 6            25_A7  Whitechapel Stn  / Royal London Hosp  490013541A
# 8            25_A8                       Aldgate Station  490000003R
# 9            25_A9              Bank Station  / Cornhill  490000013E
#
#
# QSI stop points for direction 25_B
#
#   Route_Dir_QSI_No                              STOP_Name          ID
# 1            25_B2               Bank Station  / Cornhill  490000013D
# 2            25_B3                        Aldgate Station  490000003Y
# 4            25_B4  Whitechapel Stn   / Royal London Hosp  490009873D
# 5            25_B5                       Mile End Station  490000146D
# 6            25_B6                     Bow Church Station  490002019A
# 7            25_B7                  Stratford Bus Station  490012904N
# 9            25_B8                      High Street North  490008189E
#
# Today is Friday. The selected Schedule name is Friday.
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             25_A1  490007657V     3.750000                8
# 1             25_A2  490008189W     3.750000                8
# 2             25_A3  490007497W     3.750000                8
# 3             25_A4  490012904T     4.285714                7
# 4             25_A5  490002019B     4.285714                7
# 5             25_A6  490000146C     3.750000                8
# 6             25_A7  490013541A     3.750000                8
# 7             25_A8  490000003R     3.750000                8
# 8             25_A9  490000013E     3.333333                9
# 9             25_B2  490000013D     3.750000                8
# 10            25_B3  490000003Y     3.750000                8
# 11            25_B4  490009873D     3.750000                8
# 12            25_B5  490000146D     4.285714                7
# 13            25_B6  490002019A     3.750000                8
# 14            25_B7  490012904N     4.285714                7
# 15            25_B8  490008189E     4.285714                7
#
#
# AWT DataFrame at hour 11:19
# Empty DataFrame
# Columns: [Stop Point ID, AWT (minutes), Number of Buses Observed]
# Index: []
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  50.00
# 3  Time difference between 1st and last observed ...  14.00
# 4                                      AWT (minutes)   3.57
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.18
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  75.000000
# 3  Time difference between 1st and last observed ...  18.000000
# 4                                      AWT (minutes)   4.170000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.120000
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  76.500000
# 3  Time difference between 1st and last observed ...  21.000000
# 4                                      AWT (minutes)   3.640000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.650000
#
#
# Summary Metrics for 490000146C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  97.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   4.41
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.66
#
#
# Summary Metrics for 490013541A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  56.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.02
#
#
# Summary Metrics for 490000003R:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  48.50
# 3  Time difference between 1st and last observed ...  13.00
# 4                                      AWT (minutes)   3.73
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.02
#
#
# Summary Metrics for 490000013E:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    9.000000
# 1                           Number of buses observed    5.000000
# 2                               Total WAWT (minutes)  110.500000
# 3  Time difference between 1st and last observed ...   27.000000
# 4                                      AWT (minutes)    4.090000
# 5                                      SWT (minutes)    3.333333
# 6                                      EWT (minutes)    0.760000
#
#
# Summary Metrics for 490000013D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  97.00
# 3  Time difference between 1st and last observed ...  24.00
# 4                                      AWT (minutes)   4.04
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.29
#
#
# Summary Metrics for 490000003Y:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  74.50
# 3  Time difference between 1st and last observed ...  21.00
# 4                                      AWT (minutes)   3.55
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.20
#
#
# Summary Metrics for 490009873D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  141.00
# 3  Time difference between 1st and last observed ...   28.00
# 4                                      AWT (minutes)    5.04
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    1.29
#
#
# Summary Metrics for 490000146D:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    5.000000
# 2                               Total WAWT (minutes)  114.000000
# 3  Time difference between 1st and last observed ...   28.000000
# 4                                      AWT (minutes)    4.070000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)   -0.220000
#
#
# Summary Metrics for 490002019A:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    5.00
# 2                               Total WAWT (minutes)  107.00
# 3  Time difference between 1st and last observed ...   26.00
# 4                                      AWT (minutes)    4.12
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.37
#
#
# Summary Metrics for 490012904N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   5.000000
# 2                               Total WAWT (minutes)  81.500000
# 3  Time difference between 1st and last observed ...  25.000000
# 4                                      AWT (minutes)   3.260000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -1.030000
#
#
# Summary Metrics for 490008189E:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   2.000000
# 2                               Total WAWT (minutes)  32.000000
# 3  Time difference between 1st and last observed ...   8.000000
# 4                                      AWT (minutes)   4.000000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.290000
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             25_A1  490007657V     3.750000                8
# 1             25_A2  490008189W     3.750000                8
# 2             25_A3  490007497W     3.750000                8
# 3             25_A4  490012904T     4.285714                7
# 4             25_A5  490002019B     4.285714                7
# 5             25_A6  490000146C     3.750000                8
# 6             25_A7  490013541A     3.750000                8
# 7             25_A8  490000003R     3.750000                8
# 8             25_A9  490000013E     3.333333                9
# 9             25_B2  490000013D     3.750000                8
# 10            25_B3  490000003Y     3.750000                8
# 11            25_B4  490009873D     3.750000                8
# 12            25_B5  490000146D     4.285714                7
# 13            25_B6  490002019A     3.750000                8
# 14            25_B7  490012904N     4.285714                7
# 15            25_B8  490008189E     4.285714                7
#
#
# AWT DataFrame at hour 11:19
#    Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0     490007657V           3.68                         4
# 1     490008189W           3.57                         3
# 2     490007497W           3.68                         4
# 3     490012904T           4.17                         4
# 4     490002019B           3.64                         4
# 5     490000146C           4.41                         4
# 6     490013541A           3.77                         3
# 7     490000003R           3.73                         3
# 8     490000013E           4.09                         5
# 9     490000013D           4.04                         4
# 10    490000003Y           3.55                         4
# 11    490009873D           5.04                         4
# 12    490000146D           4.07                         5
# 13    490002019A           4.12                         5
# 14    490012904N           3.26                         5
# 15    490008189E           4.00                         2
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  50.00
# 3  Time difference between 1st and last observed ...  14.00
# 4                                      AWT (minutes)   3.57
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.18
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  75.000000
# 3  Time difference between 1st and last observed ...  18.000000
# 4                                      AWT (minutes)   4.170000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.120000
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  76.500000
# 3  Time difference between 1st and last observed ...  21.000000
# 4                                      AWT (minutes)   3.640000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.650000
#
#
# Summary Metrics for 490000146C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  97.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   4.41
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.66
#
#
# Summary Metrics for 490013541A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  56.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.02
#
#
# Summary Metrics for 490000003R:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  65.00
# 3  Time difference between 1st and last observed ...  16.00
# 4                                      AWT (minutes)   4.06
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.31
#
#
# Summary Metrics for 490000013E:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    9.000000
# 1                           Number of buses observed    5.000000
# 2                               Total WAWT (minutes)  110.500000
# 3  Time difference between 1st and last observed ...   27.000000
# 4                                      AWT (minutes)    4.090000
# 5                                      SWT (minutes)    3.333333
# 6                                      EWT (minutes)    0.760000
#
#
# Summary Metrics for 490000013D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  97.00
# 3  Time difference between 1st and last observed ...  24.00
# 4                                      AWT (minutes)   4.04
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.29
#
#
# Summary Metrics for 490000003Y:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  74.50
# 3  Time difference between 1st and last observed ...  21.00
# 4                                      AWT (minutes)   3.55
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.20
#
#
# Summary Metrics for 490009873D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  141.00
# 3  Time difference between 1st and last observed ...   28.00
# 4                                      AWT (minutes)    5.04
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    1.29
#
#
# Summary Metrics for 490000146D:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    5.000000
# 2                               Total WAWT (minutes)  114.000000
# 3  Time difference between 1st and last observed ...   28.000000
# 4                                      AWT (minutes)    4.070000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)   -0.220000
#
#
# Summary Metrics for 490002019A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   5.00
# 2                               Total WAWT (minutes)  99.00
# 3  Time difference between 1st and last observed ...  24.00
# 4                                      AWT (minutes)   4.12
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.37
#
#
# Summary Metrics for 490012904N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   5.000000
# 2                               Total WAWT (minutes)  81.500000
# 3  Time difference between 1st and last observed ...  25.000000
# 4                                      AWT (minutes)   3.260000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -1.030000
#
#
# Summary Metrics for 490008189E:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   2.000000
# 2                               Total WAWT (minutes)  32.000000
# 3  Time difference between 1st and last observed ...   8.000000
# 4                                      AWT (minutes)   4.000000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.290000
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             25_A1  490007657V     3.750000                8
# 1             25_A2  490008189W     3.750000                8
# 2             25_A3  490007497W     3.750000                8
# 3             25_A4  490012904T     4.285714                7
# 4             25_A5  490002019B     4.285714                7
# 5             25_A6  490000146C     3.750000                8
# 6             25_A7  490013541A     3.750000                8
# 7             25_A8  490000003R     3.750000                8
# 8             25_A9  490000013E     3.333333                9
# 9             25_B2  490000013D     3.750000                8
# 10            25_B3  490000003Y     3.750000                8
# 11            25_B4  490009873D     3.750000                8
# 12            25_B5  490000146D     4.285714                7
# 13            25_B6  490002019A     3.750000                8
# 14            25_B7  490012904N     4.285714                7
# 15            25_B8  490008189E     4.285714                7
#
#
# AWT DataFrame at hour 11:19
#    Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0     490007657V           3.68                         4
# 1     490008189W           3.57                         3
# 2     490007497W           3.68                         4
# 3     490012904T           4.17                         4
# 4     490002019B           3.64                         4
# 5     490000146C           4.41                         4
# 6     490013541A           3.77                         3
# 7     490000003R           4.06                         3
# 8     490000013E           4.09                         5
# 9     490000013D           4.04                         4
# 10    490000003Y           3.55                         4
# 11    490009873D           5.04                         4
# 12    490000146D           4.07                         5
# 13    490002019A           4.12                         5
# 14    490012904N           3.26                         5
# 15    490008189E           4.00                         2
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.73
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.02
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  67.000000
# 3  Time difference between 1st and last observed ...  18.000000
# 4                                      AWT (minutes)   3.720000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.570000
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  76.500000
# 3  Time difference between 1st and last observed ...  21.000000
# 4                                      AWT (minutes)   3.640000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.650000
#
#
# Summary Metrics for 490000146C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  97.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   4.41
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.66
#
#
# Summary Metrics for 490013541A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  56.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.02
#
#
# Summary Metrics for 490000003R:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  65.00
# 3  Time difference between 1st and last observed ...  16.00
# 4                                      AWT (minutes)   4.06
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.31
#
#
# Summary Metrics for 490000013E:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   9.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  89.000000
# 3  Time difference between 1st and last observed ...  22.000000
# 4                                      AWT (minutes)   4.050000
# 5                                      SWT (minutes)   3.333333
# 6                                      EWT (minutes)   0.720000
#
#
# Summary Metrics for 490000013D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  106.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    4.26
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.51
#
#
# Summary Metrics for 490000003Y:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  74.50
# 3  Time difference between 1st and last observed ...  21.00
# 4                                      AWT (minutes)   3.55
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.20
#
#
# Summary Metrics for 490009873D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  56.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.02
#
#
# Summary Metrics for 490000146D:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    5.000000
# 2                               Total WAWT (minutes)  107.500000
# 3  Time difference between 1st and last observed ...   27.000000
# 4                                      AWT (minutes)    3.980000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)   -0.310000
#
#
# Summary Metrics for 490002019A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   5.00
# 2                               Total WAWT (minutes)  99.00
# 3  Time difference between 1st and last observed ...  24.00
# 4                                      AWT (minutes)   4.12
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.37
#
#
# Summary Metrics for 490012904N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  33.000000
# 3  Time difference between 1st and last observed ...  14.000000
# 4                                      AWT (minutes)   2.360000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -1.930000
#
#
# Summary Metrics for 490008189E:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   3.000000
# 2                               Total WAWT (minutes)  82.000000
# 3  Time difference between 1st and last observed ...  18.000000
# 4                                      AWT (minutes)   4.560000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)   0.270000
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             25_A1  490007657V     3.750000                8
# 1             25_A2  490008189W     3.750000                8
# 2             25_A3  490007497W     3.750000                8
# 3             25_A4  490012904T     4.285714                7
# 4             25_A5  490002019B     4.285714                7
# 5             25_A6  490000146C     3.750000                8
# 6             25_A7  490013541A     3.750000                8
# 7             25_A8  490000003R     3.750000                8
# 8             25_A9  490000013E     3.333333                9
# 9             25_B2  490000013D     3.750000                8
# 10            25_B3  490000003Y     3.750000                8
# 11            25_B4  490009873D     3.750000                8
# 12            25_B5  490000146D     4.285714                7
# 13            25_B6  490002019A     3.750000                8
# 14            25_B7  490012904N     4.285714                7
# 15            25_B8  490008189E     4.285714                7
#
#
# AWT DataFrame at hour 11:19
#    Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0     490007657V           3.68                         4
# 1     490008189W           3.73                         4
# 2     490007497W           3.68                         4
# 3     490012904T           3.72                         4
# 4     490002019B           3.64                         4
# 5     490000146C           4.41                         4
# 6     490013541A           3.77                         3
# 7     490000003R           4.06                         3
# 8     490000013E           4.05                         4
# 9     490000013D           4.26                         4
# 10    490000003Y           3.55                         4
# 11    490009873D           3.77                         3
# 12    490000146D           3.98                         5
# 13    490002019A           4.12                         5
# 14    490012904N           2.36                         4
# 15    490008189E           4.56                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.73
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.02
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  61.000000
# 3  Time difference between 1st and last observed ...  18.000000
# 4                                      AWT (minutes)   3.390000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.900000
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  76.500000
# 3  Time difference between 1st and last observed ...  21.000000
# 4                                      AWT (minutes)   3.640000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.650000
#
#
# Summary Metrics for 490000146C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  36.50
# 3  Time difference between 1st and last observed ...  11.00
# 4                                      AWT (minutes)   3.32
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.43
#
#
# Summary Metrics for 490013541A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  56.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.02
#
#
# Summary Metrics for 490000003R:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  113.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    4.54
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.79
#
#
# Summary Metrics for 490000013E:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   9.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  89.000000
# 3  Time difference between 1st and last observed ...  22.000000
# 4                                      AWT (minutes)   4.050000
# 5                                      SWT (minutes)   3.333333
# 6                                      EWT (minutes)   0.720000
#
#
# Summary Metrics for 490000013D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  106.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    4.26
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.51
#
#
# Summary Metrics for 490000003Y:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  92.50
# 3  Time difference between 1st and last observed ...  23.00
# 4                                      AWT (minutes)   4.02
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.27
#
#
# Summary Metrics for 490009873D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  56.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.02
#
#
# Summary Metrics for 490000146D:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    5.000000
# 2                               Total WAWT (minutes)  107.500000
# 3  Time difference between 1st and last observed ...   27.000000
# 4                                      AWT (minutes)    3.980000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)   -0.310000
#
#
# Summary Metrics for 490002019A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   5.00
# 2                               Total WAWT (minutes)  99.00
# 3  Time difference between 1st and last observed ...  24.00
# 4                                      AWT (minutes)   4.12
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.37
#
#
# Summary Metrics for 490012904N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  33.000000
# 3  Time difference between 1st and last observed ...  14.000000
# 4                                      AWT (minutes)   2.360000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -1.930000
#
#
# Summary Metrics for 490008189E:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   3.000000
# 2                               Total WAWT (minutes)  82.000000
# 3  Time difference between 1st and last observed ...  18.000000
# 4                                      AWT (minutes)   4.560000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)   0.270000
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             25_A1  490007657V     3.750000                8
# 1             25_A2  490008189W     3.750000                8
# 2             25_A3  490007497W     3.750000                8
# 3             25_A4  490012904T     4.285714                7
# 4             25_A5  490002019B     4.285714                7
# 5             25_A6  490000146C     3.750000                8
# 6             25_A7  490013541A     3.750000                8
# 7             25_A8  490000003R     3.750000                8
# 8             25_A9  490000013E     3.333333                9
# 9             25_B2  490000013D     3.750000                8
# 10            25_B3  490000003Y     3.750000                8
# 11            25_B4  490009873D     3.750000                8
# 12            25_B5  490000146D     4.285714                7
# 13            25_B6  490002019A     3.750000                8
# 14            25_B7  490012904N     4.285714                7
# 15            25_B8  490008189E     4.285714                7
#
#
# AWT DataFrame at hour 11:19
#    Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0     490007657V           3.68                         4
# 1     490008189W           3.73                         4
# 2     490007497W           3.68                         4
# 3     490012904T           3.39                         4
# 4     490002019B           3.64                         4
# 5     490000146C           3.32                         3
# 6     490013541A           3.77                         3
# 7     490000003R           4.54                         4
# 8     490000013E           4.05                         4
# 9     490000013D           4.26                         4
# 10    490000003Y           4.02                         4
# 11    490009873D           3.77                         3
# 12    490000146D           3.98                         5
# 13    490002019A           4.12                         5
# 14    490012904N           2.36                         4
# 15    490008189E           4.56                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.73
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.02
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   5.000000
# 2                               Total WAWT (minutes)  93.000000
# 3  Time difference between 1st and last observed ...  26.000000
# 4                                      AWT (minutes)   3.580000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.710000
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  76.500000
# 3  Time difference between 1st and last observed ...  21.000000
# 4                                      AWT (minutes)   3.640000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.650000
#
#
# Summary Metrics for 490000146C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# ...
# 7     490000003R           4.73                         4
# 8     490000013E           4.23                         4
# 9     490000013D           3.77                         3
# 10    490000003Y           4.72                         3
# 11    490009873D           4.62                         3
# 12    490000146D           3.93                         4
# 13    490002019A           4.18                         5
# 14    490012904N           3.20                         5
# 15    490008189E           6.50                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  88.50
# 3  Time difference between 1st and last observed ...  23.00
# 4                                      AWT (minutes)   3.85
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.10
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.73
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.02
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   5.000000
# 2                               Total WAWT (minutes)  90.500000
# 3  Time difference between 1st and last observed ...  25.000000
# 4                                      AWT (minutes)   3.620000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.670000
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  62.500000
# 3  Time difference between 1st and last observed ...  19.000000
# 4                                      AWT (minutes)   3.290000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -1.000000
#
#
# Summary Metrics for 490000146C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  77.00
# 3  Time difference between 1st and last observed ...  20.00
# 4                                      AWT (minutes)   3.85
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.10
#
#
# Summary Metrics for 490013541A:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  118.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    4.74
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.99
#
#
# Summary Metrics for 490000003R:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  123.00
# 3  Time difference between 1st and last observed ...   26.00
# 4                                      AWT (minutes)    4.73
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.98
#
#
# Summary Metrics for 490000013E:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    9.000000
# 1                           Number of buses observed    4.000000
# 2                               Total WAWT (minutes)  100.500000
# 3  Time difference between 1st and last observed ...   23.000000
# 4                                      AWT (minutes)    4.370000
# 5                                      SWT (minutes)    3.333333
# 6                                      EWT (minutes)    1.040000
#
#
# Summary Metrics for 490000013D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  56.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   3.77
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.02
#
#
# Summary Metrics for 490000003Y:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  106.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    4.26
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.51
#
#
# Summary Metrics for 490009873D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  96.50
# 3  Time difference between 1st and last observed ...  23.00
# 4                                      AWT (minutes)   4.20
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.45
#
#
# Summary Metrics for 490000146D:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  82.500000
# 3  Time difference between 1st and last observed ...  21.000000
# 4                                      AWT (minutes)   3.930000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.360000
#
#
# Summary Metrics for 490002019A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   5.00
# 2                               Total WAWT (minutes)  79.00
# 3  Time difference between 1st and last observed ...  24.00
# 4                                      AWT (minutes)   3.29
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.46
#
#
# Summary Metrics for 490012904N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   5.000000
# 2                               Total WAWT (minutes)  73.500000
# 3  Time difference between 1st and last observed ...  23.000000
# 4                                      AWT (minutes)   3.200000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -1.090000
#
#
# Summary Metrics for 490008189E:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)    7.000000
# 1                           Number of buses observed    2.000000
# 2                               Total WAWT (minutes)  128.000000
# 3  Time difference between 1st and last observed ...   16.000000
# 4                                      AWT (minutes)    8.000000
# 5                                      SWT (minutes)    4.285714
# 6                                      EWT (minutes)    3.710000
#
#
# SWT DataFrame at hour 11
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             25_A1  490007657V     3.750000                8
# 1             25_A2  490008189W     3.750000                8
# 2             25_A3  490007497W     3.750000                8
# 3             25_A4  490012904T     4.285714                7
# 4             25_A5  490002019B     4.285714                7
# 5             25_A6  490000146C     3.750000                8
# 6             25_A7  490013541A     3.750000                8
# 7             25_A8  490000003R     3.750000                8
# 8             25_A9  490000013E     3.333333                9
# 9             25_B2  490000013D     3.750000                8
# 10            25_B3  490000003Y     3.750000                8
# 11            25_B4  490009873D     3.750000                8
# 12            25_B5  490000146D     4.285714                7
# 13            25_B6  490002019A     3.750000                8
# 14            25_B7  490012904N     4.285714                7
# 15            25_B8  490008189E     4.285714                7
#
#
# AWT DataFrame at hour 11:19
#    Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0     490007657V           3.85                         4
# 1     490008189W           3.73                         4
# 2     490007497W           3.68                         4
# 3     490012904T           3.62                         5
# 4     490002019B           3.29                         4
# 5     490000146C           3.85                         4
# 6     490013541A           4.74                         4
# 7     490000003R           4.73                         4
# 8     490000013E           4.37                         4
# 9     490000013D           3.77                         3
# 10    490000003Y           4.26                         4
# 11    490009873D           4.20                         4
# 12    490000146D           3.93                         4
# 13    490002019A           3.29                         5
# 14    490012904N           3.20                         5
# 15    490008189E           8.00                         2
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  88.50
# 3  Time difference between 1st and last observed ...  23.00
# 4                                      AWT (minutes)   3.85
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.10
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.73
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.02
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  81.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   3.68
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)  -0.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   5.000000
# 2                               Total WAWT (minutes)  90.500000
# 3  Time difference between 1st and last observed ...  25.000000
# 4                                      AWT (minutes)   3.620000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -0.670000
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   4.000000
# 2                               Total WAWT (minutes)  62.500000
# 3  Time difference between 1st and last observed ...  19.000000
# 4                                      AWT (minutes)   3.290000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)  -1.000000
#
#
# Summary Metrics for 490000146C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  77.00
# 3  Time difference between 1st and last observed ...  20.00
# 4                                      AWT (minutes)   3.85
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.10
#
#
# Summary Metrics for 490013541A:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    8.00
# 1                           Number of buses observed    5.00
# 2                               Total WAWT (minutes)  123.00
# 3  Time difference between 1st and last observed ...   28.00
# 4                                      AWT (minutes)    4.39
# 5                                      SWT (minutes)    3.75
# 6                                      EWT (minutes)    0.64
#
#
# Summary Metrics for 490000003R:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   8.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  73.00
# 3  Time difference between 1st and last observed ...  16.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   3.75
# 6                                      EWT (minutes)   0.81
#
#
# Summary Metrics for 490000013E:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   9.000000
# 1                           Number of buses observed   3.000000
# 2                               Total WAWT (minutes)  68.500000
# 3  Time difference between 1st and last observed ...  15.000000
# 4                                      AWT (minutes)   4.570000
# 5                                      SWT (minutes)   3.333333
# 6                                      EWT (minutes)   1.240000
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# File share 27

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT (minutes)','Number of Buses Observed'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT (minutes)','Number of Buses Observed'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT_minutes': [],
            'Number_of_buses': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT_minutes'].append(scheduled_wait_time)
                swt_data['Number_of_buses'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['Number_of_buses'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT_minutes'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Streaming output truncated to the last 5000 lines.
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  140.50
# 3  Time difference between 1st and last observed ...   29.00
# 4                                      AWT (minutes)    4.84
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)   -0.16
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   40.5
# 3  Time difference between 1st and last observed ...    9.0
# 4                                      AWT (minutes)    4.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490010238N2:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   40.5
# 3  Time difference between 1st and last observed ...    9.0
# 4                                      AWT (minutes)    4.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490014581N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490003369N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  106.00
# 3  Time difference between 1st and last observed ...   18.00
# 4                                      AWT (minutes)    5.89
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.89
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z          5.0                6
# 1            124_A2   490009117J          5.0                6
# 2            124_A3   490007967S          5.0                6
# 3            124_A4   490014581S          5.0                6
# 4            124_A5   490015256C          5.0                6
# 5            124_A6   490005655E          5.0                6
# 6            124_A7   490001200A          5.0                6
# 7            124_A8  490010238N2          5.0                6
# 8            124_B1   490008321S          5.0                6
# 9            124_B2   490006537M          5.0                6
# 10           124_B3   490010238E          5.0                6
# 11           124_B4   490001200B          5.0                6
# 12           124_B5   490005655W          5.0                6
# 13           124_B6   490015256D          5.0                6
# 14           124_B7   490014581N          5.0                6
# 15           124_B8   490003369N          5.0                6
#
#
# AWT DataFrame at hour 12:20
#    Route_Dir_QSI_No Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0            124_A1    490004863Z           0.00                         1
# 1            124_A2    490009117J           5.00                         3
# 2            124_A3    490007967S           4.84                         4
# 3            124_A4    490014581S           4.76                         3
# 4            124_A5    490015256C           4.50                         2
# 5            124_A6    490005655E           5.05                         3
# 6            124_A8   490010238N2           5.26                         3
# 7            124_B1    490008321S           0.00                         1
# 8            124_B2    490006537M           0.00                         1
# 9            124_B5    490005655W           5.26                         3
# 10           124_B6    490015256D           4.50                         2
# 11           124_B7    490014581N           6.00                         2
# 12           124_B8    490003369N           5.89                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   40.5
# 3  Time difference between 1st and last observed ...    9.0
# 4                                      AWT (minutes)    4.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490010238N2:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  102.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    4.64
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)   -0.36
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  95.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   4.32
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.68
#
#
# Summary Metrics for 490014581N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  61.00
# 3  Time difference between 1st and last observed ...  12.00
# 4                                      AWT (minutes)   5.08
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)   0.08
#
#
# Summary Metrics for 490003369N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  148.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.17
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.17
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z          5.0                6
# 1            124_A2   490009117J          5.0                6
# 2            124_A3   490007967S          5.0                6
# 3            124_A4   490014581S          5.0                6
# 4            124_A5   490015256C          5.0                6
# 5            124_A6   490005655E          5.0                6
# 6            124_A7   490001200A          5.0                6
# 7            124_A8  490010238N2          5.0                6
# 8            124_B1   490008321S          5.0                6
# 9            124_B2   490006537M          5.0                6
# 10           124_B3   490010238E          5.0                6
# 11           124_B4   490001200B          5.0                6
# 12           124_B5   490005655W          5.0                6
# 13           124_B6   490015256D          5.0                6
# 14           124_B7   490014581N          5.0                6
# 15           124_B8   490003369N          5.0                6
#
#
# AWT DataFrame at hour 12:21
#    Route_Dir_QSI_No Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0            124_A1    490004863Z           0.00                         1
# 1            124_A2    490009117J           5.00                         2
# 2            124_A3    490007967S           5.00                         3
# 3            124_A4    490014581S           4.76                         3
# 4            124_A5    490015256C           4.50                         2
# 5            124_A6    490005655E           5.05                         3
# 6            124_A8   490010238N2           5.26                         3
# 7            124_B1    490008321S           0.00                         1
# 8            124_B2    490006537M           0.00                         1
# 9            124_B5    490005655W           4.64                         4
# 10           124_B6    490015256D           4.32                         4
# 11           124_B7    490014581N           5.08                         3
# 12           124_B8    490003369N           6.17                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490010238N2:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.55
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  392.0
# 3  Time difference between 1st and last observed ...   28.0
# 4                                      AWT (minutes)   14.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    9.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  52.00
# 3  Time difference between 1st and last observed ...  12.00
# 4                                      AWT (minutes)   4.33
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.67
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  95.00
# 3  Time difference between 1st and last observed ...  22.00
# 4                                      AWT (minutes)   4.32
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.68
#
#
# Summary Metrics for 490014581N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  61.00
# 3  Time difference between 1st and last observed ...  12.00
# 4                                      AWT (minutes)   5.08
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)   0.08
#
#
# Summary Metrics for 490003369N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  148.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.17
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.17
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z          5.0                6
# 1            124_A2   490009117J          5.0                6
# 2            124_A3   490007967S          5.0                6
# 3            124_A4   490014581S          5.0                6
# 4            124_A5   490015256C          5.0                6
# 5            124_A6   490005655E          5.0                6
# 6            124_A7   490001200A          5.0                6
# 7            124_A8  490010238N2          5.0                6
# 8            124_B1   490008321S          5.0                6
# 9            124_B2   490006537M          5.0                6
# 10           124_B3   490010238E          5.0                6
# 11           124_B4   490001200B          5.0                6
# 12           124_B5   490005655W          5.0                6
# 13           124_B6   490015256D          5.0                6
# 14           124_B7   490014581N          5.0                6
# 15           124_B8   490003369N          5.0                6
#
#
# AWT DataFrame at hour 12:21
#    Route_Dir_QSI_No Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0            124_A1    490004863Z           0.00                         1
# 1            124_A2    490009117J           5.00                         2
# 2            124_A3    490007967S           5.00                         3
# 3            124_A4    490014581S           4.76                         3
# 4            124_A5    490015256C           4.76                         3
# 5            124_A6    490005655E           5.05                         3
# 6            124_A8   490010238N2           5.55                         3
# 7            124_B1    490008321S          14.00                         2
# 8            124_B2    490006537M           0.00                         1
# 9            124_B5    490005655W           4.33                         3
# 10           124_B6    490015256D           4.32                         4
# 11           124_B7    490014581N           5.08                         3
# 12           124_B8    490003369N           6.17                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490010238N2:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.55
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  392.0
# 3  Time difference between 1st and last observed ...   28.0
# 4                                      AWT (minutes)   14.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    9.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.68
#
#
# Summary Metrics for 490014581N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490003369N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  184.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    6.83
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.83
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z          5.0                6
# 1            124_A2   490009117J          5.0                6
# 2            124_A3   490007967S          5.0                6
# 3            124_A4   490014581S          5.0                6
# 4            124_A5   490015256C          5.0                6
# 5            124_A6   490005655E          5.0                6
# 6            124_A7   490001200A          5.0                6
# 7            124_A8  490010238N2          5.0                6
# 8            124_B1   490008321S          5.0                6
# 9            124_B2   490006537M          5.0                6
# 10           124_B3   490010238E          5.0                6
# 11           124_B4   490001200B          5.0                6
# 12           124_B5   490005655W          5.0                6
# 13           124_B6   490015256D          5.0                6
# 14           124_B7   490014581N          5.0                6
# 15           124_B8   490003369N          5.0                6
#
#
# AWT DataFrame at hour 12:22
#    Route_Dir_QSI_No Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0            124_A1    490004863Z           0.00                         1
# 1            124_A2    490009117J           5.26                         3
# 2            124_A3    490007967S           5.00                         3
# 3            124_A4    490014581S           4.76                         3
# 4            124_A5    490015256C           4.76                         3
# 5            124_A6    490005655E           5.05                         3
# 6            124_A8   490010238N2           5.55                         3
# 7            124_B1    490008321S          14.00                         2
# 8            124_B2    490006537M           0.00                         1
# 9            124_B5    490005655W           5.00                         2
# 10           124_B6    490015256D           5.68                         3
# 11           124_B7    490014581N           6.00                         2
# 12           124_B8    490003369N           6.83                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  145.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.04
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.04
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  92.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.87
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.13
#
#
# Summary Metrics for 490010238N2:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  392.0
# 3  Time difference between 1st and last observed ...   28.0
# 4                                      AWT (minutes)   14.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    9.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.68
#
#
# Summary Metrics for 490014581N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490003369N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  184.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    6.83
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.83
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z          5.0                6
# 1            124_A2   490009117J          5.0                6
# 2            124_A3   490007967S          5.0                6
# 3            124_A4   490014581S          5.0                6
# 4            124_A5   490015256C          5.0                6
# 5            124_A6   490005655E          5.0                6
# 6            124_A7   490001200A          5.0                6
# 7            124_A8  490010238N2          5.0                6
# 8            124_B1   490008321S          5.0                6
# 9            124_B2   490006537M          5.0                6
# 10           124_B3   490010238E          5.0                6
# 11           124_B4   490001200B          5.0                6
# 12           124_B5   490005655W          5.0                6
# 13           124_B6   490015256D          5.0                6
# 14           124_B7   490014581N          5.0                6
# 15           124_B8   490003369N          5.0                6
#
#
# AWT DataFrame at hour 12:23
#    Route_Dir_QSI_No Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0            124_A1    490004863Z           0.00                         1
# 1            124_A2    490009117J           6.04                         3
# 2            124_A3    490007967S           5.00                         3
# 3            124_A4    490014581S           4.76                         3
# 4            124_A5    490015256C           4.76                         3
# 5            124_A6    490005655E           4.87                         3
# 6            124_A8   490010238N2           5.26                         3
# 7            124_B1    490008321S          14.00                         2
# 8            124_B2    490006537M           0.00                         1
# 9            124_B5    490005655W           5.00                         2
# 10           124_B6    490015256D           5.68                         3
# 11           124_B7    490014581N           6.00                         2
# 12           124_B8    490003369N           6.83                         3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  145.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.04
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.04
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  92.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.87
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.13
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# ...
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  156.00
# 3  Time difference between 1st and last observed ...   28.00
# 4                                      AWT (minutes)    5.57
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.57
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  74.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.38
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.62
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  78.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.62
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.38
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490014581N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490003369N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z          5.0                6
# 1            124_A2   490009117J          5.0                6
# 2            124_A3   490007967S          5.0                6
# 3            124_A4   490014581S          5.0                6
# 4            124_A5   490015256C          5.0                6
# 5            124_A6   490005655E          5.0                6
# 6            124_A7   490001200A          5.0                6
# 7            124_A8  490010238N2          5.0                6
# 8            124_B1   490008321S          5.0                6
# 9            124_B2   490006537M          5.0                6
# 10           124_B3   490010238E          5.0                6
# 11           124_B4   490001200B          5.0                6
# 12           124_B5   490005655W          5.0                6
# 13           124_B6   490015256D          5.0                6
# 14           124_B7   490014581N          5.0                6
# 15           124_B8   490003369N          5.0                6
#
#
# AWT DataFrame at hour 12:40
#    Route_Dir_QSI_No Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0            124_A1    490004863Z           5.00                         2
# 1            124_A2    490009117J           5.00                         3
# 2            124_A3    490007967S           5.55                         3
# 3            124_A4    490014581S           6.50                         3
# 4            124_A5    490015256C           5.57                         4
# 5            124_A6    490005655E           4.38                         3
# 6            124_A8   490010238N2           4.62                         3
# 7            124_B1    490008321S           0.00                         1
# 8            124_B2    490006537M           0.00                         1
# 9            124_B5    490005655W           0.00                         1
# 10           124_B6    490015256D           0.00                         1
# 11           124_B7    490014581N           0.00                         1
# 12           124_B8    490003369N           0.00                         1
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007967S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.55
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015256C:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  156.00
# 3  Time difference between 1st and last observed ...   28.00
# 4                                      AWT (minutes)    5.57
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.57
#
#
# Summary Metrics for 490005655E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  74.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.38
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.62
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  78.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.62
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.38
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490015256D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490014581N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490003369N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No           ID  SWT_minutes  Number_of_buses
# 0            124_A1   490004863Z          5.0                6
# 1            124_A2   490009117J          5.0                6
# 2            124_A3   490007967S          5.0                6
# 3            124_A4   490014581S          5.0                6
# 4            124_A5   490015256C          5.0                6
# 5            124_A6   490005655E          5.0                6
# 6            124_A7   490001200A          5.0                6
# 7            124_A8  490010238N2          5.0                6
# 8            124_B1   490008321S          5.0                6
# 9            124_B2   490006537M          5.0                6
# 10           124_B3   490010238E          5.0                6
# 11           124_B4   490001200B          5.0                6
# 12           124_B5   490005655W          5.0                6
# 13           124_B6   490015256D          5.0                6
# 14           124_B7   490014581N          5.0                6
# 15           124_B8   490003369N          5.0                6
#
#
# AWT DataFrame at hour 12:41
#    Route_Dir_QSI_No Stop Point ID  AWT (minutes)  Number of Buses Observed
# 0            124_A1    490004863Z           5.00                         2
# 1            124_A2    490009117J           5.00                         3
# 2            124_A3    490007967S           5.55                         3
# 3            124_A4    490014581S           5.00                         2
# 4            124_A5    490015256C           5.57                         4
# 5            124_A6    490005655E           4.38                         3
# 6            124_A8   490010238N2           4.62                         3
# 7            124_B1    490008321S           0.00                         1
# 8            124_B2    490006537M           0.00                         1
# 9            124_B5    490005655W           0.00                         1
# 10           124_B6    490015256D           0.00                         1
# 11           124_B7    490014581N           0.00                         1
# 12           124_B8    490003369N           0.00                         1
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# File share 28

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:10
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  144.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   32.0
# 3  Time difference between 1st and last observed ...    8.0
# 4                                      AWT (minutes)    4.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -2.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  121.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:11
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             3  0.00
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  6.00             2  0.00
# 3             D7_A4    490006092N  8.50             2  2.50
# 4             D7_A5    490004584N  4.00             2 -2.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  6.00             2  0.00
# 7             D7_B3    490000038F  5.55             3 -0.45
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.50             3 -0.50
# 10            D7_B6    490013513N  5.00             2 -1.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  144.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   32.0
# 3  Time difference between 1st and last observed ...    8.0
# 4                                      AWT (minutes)    4.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -2.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  121.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:11
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             3  0.00
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  6.00             2  0.00
# 3             D7_A4    490006092N  8.50             2  2.50
# 4             D7_A5    490004584N  4.00             2 -2.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  7.00             2  1.00
# 7             D7_B3    490000038F  5.55             3 -0.45
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.50             3 -0.50
# 10            D7_B6    490013513N  5.00             2 -1.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   32.0
# 3  Time difference between 1st and last observed ...    8.0
# 4                                      AWT (minutes)    4.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -2.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  121.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:12
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             2  0.00
# 1             D7_A2    490013513S  8.00             2  2.00
# 2             D7_A3    490002048Z  8.50             2  2.50
# 3             D7_A4    490006092N  6.00             2  0.00
# 4             D7_A5    490004584N  4.00             2 -2.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  7.00             2  1.00
# 7             D7_B3    490000038F  5.55             3 -0.45
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.50             3 -0.50
# 10            D7_B6    490013513N  5.00             2 -1.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   32.0
# 3  Time difference between 1st and last observed ...    8.0
# 4                                      AWT (minutes)    4.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -2.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:13
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             2  0.00
# 1             D7_A2    490013513S  8.00             2  2.00
# 2             D7_A3    490002048Z  8.50             2  2.50
# 3             D7_A4    490006092N  6.00             2  0.00
# 4             D7_A5    490004584N  4.00             2 -2.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  7.00             2  1.00
# 7             D7_B3    490000038F  5.55             3 -0.45
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.26             3 -0.74
# 10            D7_B6    490013513N  5.00             2 -1.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   32.0
# 3  Time difference between 1st and last observed ...    8.0
# 4                                      AWT (minutes)    4.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -2.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:13
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             2  0.00
# 1             D7_A2    490013513S  8.00             2  2.00
# 2             D7_A3    490002048Z  8.50             2  2.50
# 3             D7_A4    490006092N  6.00             2  0.00
# 4             D7_A5    490004584N  4.00             2 -2.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  6.50             2  0.50
# 7             D7_B3    490000038F  5.55             3 -0.45
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.26             3 -0.74
# 10            D7_B6    490013513N  5.00             2 -1.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   40.5
# 3  Time difference between 1st and last observed ...    9.0
# 4                                      AWT (minutes)    4.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.5
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:14
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             2  0.00
# 1             D7_A2    490013513S  8.00             2  2.00
# 2             D7_A3    490002048Z  8.50             2  2.50
# 3             D7_A4    490006092N  6.00             2  0.00
# 4             D7_A5    490004584N  4.50             2 -1.50
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  7.00             2  1.00
# 7             D7_B3    490000038F  5.55             3 -0.45
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.26             3 -0.74
# 10            D7_B6    490013513N  5.00             2 -1.00
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  112.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.36
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.64
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# ...
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.36
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.64
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:24
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             3  0.00
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  6.00             2  0.00
# 3             D7_A4    490006092N  8.50             2  2.50
# 4             D7_A5    490004584N  6.00             2  0.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  8.00             2  2.00
# 7             D7_B3    490000038F  8.00             2  2.00
# 8             D7_B4    490006092S  4.56             3 -1.44
# 9             D7_B5    490002048X  4.76             3 -1.24
# 10            D7_B6    490013513N  5.36             3 -0.64
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  144.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  18.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.44
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.24
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  112.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.36
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.64
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:24
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             3  0.00
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  6.00             2  0.00
# 3             D7_A4    490006092N  8.50             2  2.50
# 4             D7_A5    490004584N  6.00             2  0.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  8.00             2  2.00
# 7             D7_B3    490000038F  8.00             2  2.00
# 8             D7_B4    490006092S  4.56             3 -1.44
# 9             D7_B5    490002048X  4.76             3 -1.24
# 10            D7_B6    490013513N  5.36             3 -0.64
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  144.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  82.00
# 3  Time difference between 1st and last observed ...  18.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.44
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.24
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  112.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.36
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.64
#
#
# SWT DataFrame at hour 12
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 12:25
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             3  0.00
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  6.00             2  0.00
# 3             D7_A4    490006092N  8.50             2  2.50
# 4             D7_A5    490004584N  6.00             2  0.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  8.00             2  2.00
# 7             D7_B3    490000038F  8.00             2  2.00
# 8             D7_B4    490006092S  4.56             3 -1.44
# 9             D7_B5    490002048X  4.76             3 -1.24
# 10            D7_B6    490013513N  5.36             3 -0.64
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Route A SWT calculation

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_direction_a(swt_df):

          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A**
          filtered_df_A = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')]
          filtered_df_B = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')]

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A['SWT_No_Buses_Sch_Product_A'] = filtered_df_A['SWT'] * filtered_df_A['No_Buses_Sch']
          filtered_df_B['SWT_No_Buses_Sch_Product_B'] = filtered_df_B['SWT'] * filtered_df_B['No_Buses_Sch']

          # Find the sum of these products
          sum_products_A = filtered_df_A['SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B = filtered_df_B['SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A = filtered_df_A['No_Buses_Sch'].sum()
          total_no_buses_sch_B = filtered_df_B['No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A / total_no_buses_sch_A if total_no_buses_sch_A > 0 else 0
          route_swt_direction_B = sum_products_B / total_no_buses_sch_B if total_no_buses_sch_B > 0 else 0

          # Print the result
          print(f"\nRoute SWT (direction A): {route_swt_direction_A}")
          print(f"\nRoute SWT (direction B): {route_swt_direction_B}")

        # Calculate and print Route SWT (direction A)
        calculate_route_swt_direction_a(swt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: w14
#
#
# QSI stop points for direction W14_A
#
#   Route_Dir_QSI_No                          STOP_Name          ID
# 0           W14_A1                         Cross Road  490004984N
# 1           W14_A2                     Orchard Estate  490010612W
# 2           W14_A3             South Woodford Station  490000217D
# 4           W14_A4   Wanstead Station  / George Green  490015125C
# 5           W14_A5                Leytonstone Station  490000137W
# 7           W14_A6  Leyton High Road / Leyton Station  490009136C
#
#
# QSI stop points for direction W14_B
#
#   Route_Dir_QSI_No                          STOP_Name          ID
# 0           W14_B1                       Leyton Mills  490015670N
# 1           W14_B2  Leyton High Road / Leyton Station  490009136D
# 2           W14_B3                        Harvey Road  490007882H
# 3           W14_B4                   Wanstead Station  490015125B
# 4           W14_B5             South Woodford Station  490015122C
# 5           W14_B6                     Orchard Estate  490010612E
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 14
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0            W14_A1  490004984N  7.5             4
# 1            W14_A2  490010612W  7.5             4
# 2            W14_A3  490000217D  7.5             4
# 3            W14_A4  490015125C  7.5             4
# 4            W14_A5  490000137W  7.5             4
# 5            W14_A6  490009136C  7.5             4
# 6            W14_B1  490015670N  7.5             4
# 7            W14_B2  490009136D  7.5             4
# 8            W14_B3  490007882H  7.5             4
# 9            W14_B4  490015125B  7.5             4
# 10           W14_B5  490015122C  7.5             4
# 11           W14_B6  490010612E  7.5             4
#
#
# AWT DataFrame at hour 14:36
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route SWT (direction A): 7.5
#
# Route SWT (direction B): 7.5
#
#
# Waiting to fetch updated data...
# <ipython-input-3-5a1ec47e4819>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A['SWT_No_Buses_Sch_Product_A'] = filtered_df_A['SWT'] * filtered_df_A['No_Buses_Sch']
# <ipython-input-3-5a1ec47e4819>:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B['SWT_No_Buses_Sch_Product_B'] = filtered_df_B['SWT'] * filtered_df_B['No_Buses_Sch']
#
#
# Summary Metrics for 490010612W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490000217D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490015125C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  225.0
# 3  Time difference between 1st and last observed ...   30.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490000137W:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  138.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    6.02
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -1.48
#
#
# Summary Metrics for 490009136C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -2.0
#
#
# Summary Metrics for 490009136D:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490007882H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490015125B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490015122C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490010612E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# SWT DataFrame at hour 14
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0            W14_A1  490004984N  7.5             4
# 1            W14_A2  490010612W  7.5             4
# 2            W14_A3  490000217D  7.5             4
# 3            W14_A4  490015125C  7.5             4
# 4            W14_A5  490000137W  7.5             4
# 5            W14_A6  490009136C  7.5             4
# 6            W14_B1  490015670N  7.5             4
# 7            W14_B2  490009136D  7.5             4
# 8            W14_B3  490007882H  7.5             4
# 9            W14_B4  490015125B  7.5             4
# 10           W14_B5  490015122C  7.5             4
# 11           W14_B6  490010612E  7.5             4
#
#
# AWT DataFrame at hour 14:36
#   Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0           W14_A2    490010612W  0.00             1 -7.50
# 1           W14_A3    490000217D  7.00             2 -0.50
# 2           W14_A4    490015125C  7.50             3  0.00
# 3           W14_A5    490000137W  6.02             3 -1.48
# 4           W14_A6    490009136C  5.50             2 -2.00
# 5           W14_B2    490009136D  7.50             2  0.00
# 6           W14_B3    490007882H  8.00             2  0.50
# 7           W14_B4    490015125B  0.00             1 -7.50
# 8           W14_B5    490015122C  0.00             1 -7.50
# 9           W14_B6    490010612E  0.00             1 -7.50
#
# Route SWT (direction A): 7.5
#
# Route SWT (direction B): 7.5
#
#
# Waiting to fetch updated data...
# <ipython-input-3-5a1ec47e4819>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A['SWT_No_Buses_Sch_Product_A'] = filtered_df_A['SWT'] * filtered_df_A['No_Buses_Sch']
# <ipython-input-3-5a1ec47e4819>:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B['SWT_No_Buses_Sch_Product_B'] = filtered_df_B['SWT'] * filtered_df_B['No_Buses_Sch']
# Execution interrupted. Exiting the loop.

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df,awt_df):

          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')]
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')]

          # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A**
          filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')]
          filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')]

          # Assuming filtered_df_A and filtered_df_B are slices from another DataFrame for route SWT calculation
          filtered_df_A_swt = filtered_df_A_swt.copy()
          filtered_df_B_swt = filtered_df_B_swt.copy()

          # Assuming filtered_df_A and filtered_df_B are slices from another DataFrame for route AWT calculation
          filtered_df_A_awt = filtered_df_A_awt.copy()
          filtered_df_B_awt = filtered_df_B_awt.copy()

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
          filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']

          # Calculate the product of AWT and No_Buses_Obs for each row
          filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
          filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'].sum()

          # Find the sum of these products (Route AWT)
          sum_products_A_awt = filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'].sum()
          sum_products_B_awt = filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:,'No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:,'No_Buses_Sch'].sum()

          # Calculate the total sum of No_Buses_Obs for the filtered rows
          total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:,'No_Buses_Obs'].sum()
          total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:,'No_Buses_Obs'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Compute the Route SWT (direction A)
          route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
          route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          # Round the results to two decimal places
          route_awt_direction_A = round(route_awt_direction_A, 2)
          route_awt_direction_B = round(route_awt_direction_B, 2)

          route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
          route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

          # Print the SWT results
          print(f"\nRoute SWT (direction A): {route_swt_direction_A}")
          print(f"\nRoute SWT (direction B): {route_swt_direction_B}")

          # Print the result
          print(f"\nRoute AWT (direction A): {route_awt_direction_A}")
          print(f"\nRoute AWT (direction B): {route_awt_direction_B}")

          print(f"\nRoute EWT (direction A): {route_ewt_direction_A}")
          print(f"\nRoute EWT (direction B): {route_ewt_direction_B}")

        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 15
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  7.5             4
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 15:21
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route SWT (direction A): 6.25
#
# Route SWT (direction B): 6.0
#
# Route AWT (direction A): 0
#
# Route AWT (direction B): 0
#
# Route EWT (direction A): -6.25
#
# Route EWT (direction B): -6.0
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    3.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  65.00
# 3  Time difference between 1st and last observed ...  14.00
# 4                                      AWT (minutes)   4.64
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.36
#
#
# Summary Metrics for 490015151H:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  160.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.67
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.67
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  138.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    6.02
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.02
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  169.0
# 3  Time difference between 1st and last observed ...   26.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# SWT DataFrame at hour 15
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  7.5             4
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 15:22
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.50             2  0.50
# 1             D7_A2    490013513S  6.50             2 -1.00
# 2             D7_A3    490002048Z  9.00             2  3.00
# 3             D7_A4    490006092N  6.00             2  0.00
# 4             D7_A5    490004584N  4.64             3 -1.36
# 5             D7_B1    490015151H  6.67             3  0.67
# 6             D7_B2    490004584S  8.50             2  2.50
# 7             D7_B3    490000038F  5.00             2 -1.00
# 8             D7_B4    490006092S  6.02             3  0.02
# 9             D7_B5    490002048X  5.00             2 -1.00
# 10            D7_B6    490013513N  6.50             3  0.50
#
# Route SWT (direction A): 6.25
#
# Route SWT (direction B): 6.0
#
# Route AWT (direction A): 6.36
#
# Route AWT (direction B): 6.3
#
# Route EWT (direction A): 0.11
#
# Route EWT (direction B): 0.3
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  162.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    9.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    3.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  65.00
# 3  Time difference between 1st and last observed ...  14.00
# 4                                      AWT (minutes)   4.64
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.36
#
#
# Summary Metrics for 490015151H:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  160.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.67
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.67
#
#
# Execution interrupted. Exiting the loop.

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df, awt_df):
          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')]
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')]

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt['SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
          filtered_df_B_swt['SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt['SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt['SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt['No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt['No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          # Print the SWT results
          print(f"\nRoute SWT (direction A): {route_swt_direction_A}")
          print(f"\nRoute SWT (direction B): {route_swt_direction_B}")

          if not awt_df.empty:
              # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
              filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')]
              filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')]

              # Calculate the product of AWT and No_Buses_Obs for each row
              filtered_df_A_awt['AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
              filtered_df_B_awt['AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']

              # Find the sum of these products (Route AWT)
              sum_products_A_awt = filtered_df_A_awt['AWT_No_Buses_Obs_Product_A'].sum()
              sum_products_B_awt = filtered_df_B_awt['AWT_No_Buses_Obs_Product_B'].sum()

              # Calculate the total sum of No_Buses_Obs for the filtered rows
              total_no_buses_obs_A_awt = filtered_df_A_awt['No_Buses_Obs'].sum()
              total_no_buses_obs_B_awt = filtered_df_B_awt['No_Buses_Obs'].sum()

              # Compute the Route AWT (direction A)
              route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
              route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

              # Round the results to two decimal places
              route_awt_direction_A = round(route_awt_direction_A, 2)
              route_awt_direction_B = round(route_awt_direction_B, 2)

              route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
              route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

              # Print the AWT and EWT results
              print(f"\nRoute AWT (direction A): {route_awt_direction_A}")
              print(f"\nRoute AWT (direction B): {route_awt_direction_B}")

              print(f"\nRoute EWT (direction A): {route_ewt_direction_A}")
              print(f"\nRoute EWT (direction B): {route_ewt_direction_B}")

          else:
              # Print the message when AWT dataframe is empty
              print("\nRoute AWT (direction A): AWT dataframe not ready")
              print("\nRoute AWT (direction B): AWT dataframe not ready")
              print("\nRoute EWT (direction A): AWT dataframe not ready")
              print("\nRoute EWT (direction B): AWT dataframe not ready")


        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 15
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  7.5             4
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 15:32
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route SWT (direction A): 6.25
#
# Route SWT (direction B): 6.0
#
# Route AWT (direction A): AWT dataframe not ready
#
# Route AWT (direction B): AWT dataframe not ready
#
# Route EWT (direction A): AWT dataframe not ready
#
# Route EWT (direction B): AWT dataframe not ready
#
#
# Waiting to fetch updated data...
# <ipython-input-10-f68267c38821>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt['SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-10-f68267c38821>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt['SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -1.24
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  170.00
# 3  Time difference between 1st and last observed ...   26.00
# 4                                      AWT (minutes)    6.54
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.54
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  264.5
# 3  Time difference between 1st and last observed ...   23.0
# 4                                      AWT (minutes)   11.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    5.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  288.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)   12.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    6.0
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  148.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.17
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.17
#
#
# SWT DataFrame at hour 15
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  7.5             4
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 15:32
#    Route_Dir_QSI_No Stop Point ID    AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G   6.00             2  0.00
# 1             D7_A2    490013513S   6.26             3 -1.24
# 2             D7_A3    490002048Z   6.50             2  0.50
# 3             D7_A4    490006092N   6.54             3  0.54
# 4             D7_A5    490004584N   0.00             1 -6.00
# 5             D7_B1    490015151H   0.00             1 -6.00
# 6             D7_B2    490004584S  11.50             2  5.50
# 7             D7_B3    490000038F  12.00             2  6.00
# 8             D7_B4    490006092S   6.50             2  0.50
# 9             D7_B5    490002048X   7.00             2  1.00
# 10            D7_B6    490013513N   6.17             3  0.17
#
# Route SWT (direction A): 6.25
#
# Route SWT (direction B): 6.0
#
# Route AWT (direction A): 5.76
#
# Route AWT (direction B): 7.71
#
# Route EWT (direction A): -0.49
#
# Route EWT (direction B): 1.71
#
#
# Waiting to fetch updated data...
# <ipython-input-10-f68267c38821>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt['SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-10-f68267c38821>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt['SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
# <ipython-input-10-f68267c38821>:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_awt['AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
# <ipython-input-10-f68267c38821>:351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_awt['AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']
# Execution interrupted. Exiting the loop.

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df, awt_df):
          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')]
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')]

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
          filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:,'No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:,'No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          # Print the SWT results
          print(f"\nRoute SWT , AWT, EWT at time : {now.strftime('%H:%M')}")
          print(f"\nRoute SWT (direction A): {route_swt_direction_A}")
          print(f"\nRoute SWT (direction B): {route_swt_direction_B}")

          if not awt_df.empty:
              # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
              filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')]
              filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')]

              # Calculate the product of AWT and No_Buses_Obs for each row
              filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
              filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']

              # Find the sum of these products (Route AWT)
              sum_products_A_awt = filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'].sum()
              sum_products_B_awt = filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'].sum()

              # Calculate the total sum of No_Buses_Obs for the filtered rows
              total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:,'No_Buses_Obs'].sum()
              total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:,'No_Buses_Obs'].sum()

              # Compute the Route AWT (direction A)
              route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
              route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

              # Round the results to two decimal places
              route_awt_direction_A = round(route_awt_direction_A, 2)
              route_awt_direction_B = round(route_awt_direction_B, 2)

              route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
              route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

              # Print the AWT and EWT results
              print(f"\nRoute AWT (direction A): {route_awt_direction_A}")
              print(f"\nRoute AWT (direction B): {route_awt_direction_B}")

              print(f"\nRoute EWT (direction A): {route_ewt_direction_A}")
              print(f"\nRoute EWT (direction B): {route_ewt_direction_B}")

          else:
              # Print the message when AWT dataframe is empty
              print("\nRoute AWT (direction A): AWT dataframe not ready")
              print("\nRoute AWT (direction B): AWT dataframe not ready")
              print("\nRoute EWT (direction A): AWT dataframe not ready")
              print("\nRoute EWT (direction B): AWT dataframe not ready")


        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 15
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  7.5             4
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 15:42
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route SWT , AWT, EWT at time : 15:42
#
# Route SWT (direction A): 6.25
#
# Route SWT (direction B): 6.0
#
# Route AWT (direction A): AWT dataframe not ready
#
# Route AWT (direction B): AWT dataframe not ready
#
# Route EWT (direction A): AWT dataframe not ready
#
# Route EWT (direction B): AWT dataframe not ready
#
#
# Waiting to fetch updated data...
# <ipython-input-12-10b6ba4e468b>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-12-10b6ba4e468b>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
# Execution interrupted. Exiting the loop.

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df, awt_df):
          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')]
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')]

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
          filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:,'No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:,'No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          if not awt_df.empty:
              # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
              filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')]
              filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')]

              # Calculate the product of AWT and No_Buses_Obs for each row
              filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
              filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']

              # Find the sum of these products (Route AWT)
              sum_products_A_awt = filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'].sum()
              sum_products_B_awt = filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'].sum()

              # Calculate the total sum of No_Buses_Obs for the filtered rows
              total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:,'No_Buses_Obs'].sum()
              total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:,'No_Buses_Obs'].sum()

              # Compute the Route AWT (direction A)
              route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
              route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

              # Round the results to two decimal places
              route_awt_direction_A = round(route_awt_direction_A, 2)
              route_awt_direction_B = round(route_awt_direction_B, 2)

              route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
              route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

              # Print the Route direction A SWT, AWT, EWT results
              print(f"\nRoute {line_id_input} direction A SWT , AWT, EWT at time : {now.strftime('%H:%M')}")
              print(f"\nRoute SWT (direction A): {route_swt_direction_A}")
              print(f"\nRoute AWT (direction A): {route_awt_direction_A}")
              print(f"\nRoute EWT (direction A): {route_ewt_direction_A}")

              # Print the Route direction A SWT, AWT, EWT results
              print(f"\nRoute {line_id_input} direction B SWT , AWT, EWT at time : {now.strftime('%H:%M')}")
              print(f"\nRoute SWT (direction B): {route_swt_direction_B}")
              print(f"\nRoute AWT (direction B): {route_awt_direction_B}")
              print(f"\nRoute EWT (direction B): {route_ewt_direction_B}")

          else:
              # Print the message when AWT dataframe is empty
              print(f"\nRoute {line_id_input} direction A SWT at time : {now.strftime('%H:%M')}")
              print(f"\nRoute SWT (direction A): {route_swt_direction_A}")
              print(f"\nRoute {line_id_input} direction B SWT at time : {now.strftime('%H:%M')}")
              print(f"\nRoute SWT (direction B): {route_swt_direction_B}")
              print("\nUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready")

        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 15
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  7.5             4
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 15:58
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route d7 direction A SWT at time : 15:58
#
# Route SWT (direction A): 6.25
#
# Route d7 direction B SWT at time : 15:58
#
# Route SWT (direction B): 6.0
#
# Unable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready
#
#
# Waiting to fetch updated data...
# <ipython-input-15-3cae98222c05>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-15-3cae98222c05>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -1.82
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  132.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.76
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.24
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  78.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.62
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.38
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   18.0
# 3  Time difference between 1st and last observed ...    6.0
# 4                                      AWT (minutes)    3.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -3.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  186.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    7.46
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    1.46
#
#
# SWT DataFrame at hour 15
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  7.5             4
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 15:59
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.00             2  0.00
# 1             D7_A2    490013513S  5.68             3 -1.82
# 2             D7_A3    490002048Z  5.00             2 -1.00
# 3             D7_A4    490006092N  6.50             2  0.50
# 4             D7_A5    490004584N  8.00             2  2.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  5.55             3 -0.45
# 7             D7_B3    490000038F  5.76             3 -0.24
# 8             D7_B4    490006092S  4.62             3 -1.38
# 9             D7_B5    490002048X  3.00             2 -3.00
# 10            D7_B6    490013513N  7.46             3  1.46
#
# Route d7 direction A SWT , AWT, EWT at time : 15:59
#
# Route SWT (direction A): 6.25
#
# Route AWT (direction A): 6.19
#
# Route EWT (direction A): -0.06
#
# Route d7 direction B SWT , AWT, EWT at time : 15:59
#
# Route SWT (direction B): 6.0
#
# Route AWT (direction B): 5.51
#
# Route EWT (direction B): -0.49
#
#
# Waiting to fetch updated data...
# <ipython-input-15-3cae98222c05>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-15-3cae98222c05>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
# <ipython-input-15-3cae98222c05>:346: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
# <ipython-input-15-3cae98222c05>:347: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Modify the below code to print SWT, AWT , EWT of route in table form

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df, awt_df):
          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')]
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')]

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
          filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:,'No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:,'No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          # Initialize route_awt_direction_A and route_awt_direction_B
          route_awt_direction_A = 0
          route_awt_direction_B = 0
          route_ewt_direction_A = 0
          route_ewt_direction_B = 0

          if not awt_df.empty:
              # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
              filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')]
              filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')]

              # Calculate the product of AWT and No_Buses_Obs for each row
              filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
              filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']

              # Find the sum of these products (Route AWT)
              sum_products_A_awt = filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'].sum()
              sum_products_B_awt = filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'].sum()

              # Calculate the total sum of No_Buses_Obs for the filtered rows
              total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:,'No_Buses_Obs'].sum()
              total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:,'No_Buses_Obs'].sum()

              # Compute the Route AWT (direction A)
              route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
              route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

              # Round the results to two decimal places
              route_awt_direction_A = round(route_awt_direction_A, 2)
              route_awt_direction_B = round(route_awt_direction_B, 2)

              route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
              route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

              # Print the results in a formatted table
              print(f"\n\033[1m\033[4mRoute SWT , AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A}]).to_string(index=False))


              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}]).to_string(index=False))

          else:
              print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))

              print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 16
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 16:19
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route D7 SWT at time : 16:19
#
# Line Id Direction  SWT AWT EWT
#      D7         A  6.0   -   -
#
# Route d7 direction B SWT at time : 16:19
#
# Line Id Direction  SWT AWT EWT
#      D7         B  6.0   -   -
#
# Unable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready
#
#
#
# Waiting to fetch updated data...
# <ipython-input-17-14c366230971>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-17-14c366230971>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  134.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.85
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.15
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  121.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.24
#
#
# SWT DataFrame at hour 16
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 16:20
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  5.00             2 -1.00
# 1             D7_A2    490013513S  5.85             3 -0.15
# 2             D7_A3    490002048Z  7.00             2  1.00
# 3             D7_A4    490006092N  6.26             3  0.26
# 4             D7_A5    490004584N  5.00             2 -1.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  5.50             3 -0.50
# 7             D7_B3    490000038F  5.50             2 -0.50
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.00             2 -1.00
# 10            D7_B6    490013513N  4.76             3 -1.24
#
# Route SWT , AWT, EWT at time : 16:20
#
# Line Id Direction  SWT  AWT   EWT
#      D7         A  6.0 5.86 -0.14
# Line Id Direction  SWT  AWT  EWT
#      D7         B  6.0  5.3 -0.7
#
#
# Waiting to fetch updated data...
# <ipython-input-17-14c366230971>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-17-14c366230971>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
# <ipython-input-17-14c366230971>:352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
# <ipython-input-17-14c366230971>:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  134.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.85
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.15
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -1.24
#
#
# SWT DataFrame at hour 16
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  6.0             5
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  6.0             5
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 16:20
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  5.00             2 -1.00
# 1             D7_A2    490013513S  5.85             3 -0.15
# 2             D7_A3    490002048Z  7.00             2  1.00
# 3             D7_A4    490006092N  6.26             3  0.26
# 4             D7_A5    490004584N  5.00             2 -1.00
# 5             D7_B1    490015151H  6.00             2  0.00
# 6             D7_B2    490004584S  5.26             3 -0.74
# 7             D7_B3    490000038F  5.50             2 -0.50
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.00             2 -1.00
# 10            D7_B6    490013513N  4.76             3 -1.24
#
# Route SWT , AWT, EWT at time : 16:20
#
# Line Id Direction  SWT  AWT   EWT
#      D7         A  6.0 5.86 -0.14
# Line Id Direction  SWT  AWT   EWT
#      D7         B  6.0 5.26 -0.74
#
#
# Waiting to fetch updated data...
# <ipython-input-17-14c366230971>:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch']
# <ipython-input-17-14c366230971>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch']
# <ipython-input-17-14c366230971>:352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs']
# <ipython-input-17-14c366230971>:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs']
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Further modification

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df, awt_df):
          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
          filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:,'No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:,'No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          # Initialize route_awt_direction_A and route_awt_direction_B
          route_awt_direction_A = 0
          route_awt_direction_B = 0
          route_ewt_direction_A = 0
          route_ewt_direction_B = 0

          if not awt_df.empty:
              # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
              filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
              filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

              # Calculate the product of AWT and No_Buses_Obs for each row
              filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
              filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()

              # Find the sum of these products (Route AWT)
              sum_products_A_awt = filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'].sum()
              sum_products_B_awt = filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'].sum()

              # Calculate the total sum of No_Buses_Obs for the filtered rows
              total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:,'No_Buses_Obs'].sum()
              total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:,'No_Buses_Obs'].sum()

              # Compute the Route AWT (direction A)
              route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
              route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

              # Round the results to two decimal places
              route_awt_direction_A = round(route_awt_direction_A, 2)
              route_awt_direction_B = round(route_awt_direction_B, 2)

              route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
              route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

              # Print the results in the desired format
              print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")

              df_direction_A = pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A}])
              df_direction_B = pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}])

              print(df_direction_A[['Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
              print(df_direction_B[['Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

          else:
              print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))
              print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:11
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route D7 SWT at time : 17:11
#
# Line Id Direction  SWT AWT EWT
#      D7         A  6.0   -   -
# Line Id Direction  SWT AWT EWT
#      D7         B 5.62   -   -
#
# Unable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready
#
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  220.5
# 3  Time difference between 1st and last observed ...   21.0
# 4                                      AWT (minutes)   10.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    4.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  134.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.85
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.15
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:12
#    Route_Dir_QSI_No Stop Point ID    AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G   6.50             2  0.50
# 1             D7_A2    490013513S   6.00             2  0.00
# 2             D7_A3    490002048Z   7.00             2  1.00
# 3             D7_A4    490006092N  10.50             2  4.50
# 4             D7_A5    490004584N   0.00             1 -6.00
# 5             D7_B1    490015151H   5.50             2  0.50
# 6             D7_B2    490004584S   5.85             3 -0.15
# 7             D7_B3    490000038F   5.05             3  0.05
# 8             D7_B4    490006092S   5.00             2 -1.00
# 9             D7_B5    490002048X   5.00             2 -1.00
# 10            D7_B6    490013513N   7.00             2  1.00
#
# Route SWT, AWT, EWT at time : 17:12
#
# Line Id Direction  SWT  AWT  EWT
#      D7         A  6.0 6.67 0.67
# Line Id Direction  SWT  AWT   EWT
#      D7         B 5.62 5.55 -0.07
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  220.5
# 3  Time difference between 1st and last observed ...   21.0
# 4                                      AWT (minutes)   10.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    4.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  134.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.85
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.15
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  92.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.87
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.13
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:12
#    Route_Dir_QSI_No Stop Point ID    AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G   6.50             2  0.50
# 1             D7_A2    490013513S   6.00             2  0.00
# 2             D7_A3    490002048Z   7.00             2  1.00
# 3             D7_A4    490006092N  10.50             2  4.50
# 4             D7_A5    490004584N   0.00             1 -6.00
# 5             D7_B1    490015151H   5.50             2  0.50
# 6             D7_B2    490004584S   5.85             3 -0.15
# 7             D7_B3    490000038F   4.87             3 -0.13
# 8             D7_B4    490006092S   5.00             2 -1.00
# 9             D7_B5    490002048X   5.00             2 -1.00
# 10            D7_B6    490013513N   7.00             2  1.00
#
# Route SWT, AWT, EWT at time : 17:12
#
# Line Id Direction  SWT  AWT  EWT
#      D7         A  6.0 6.67 0.67
# Line Id Direction  SWT  AWT   EWT
#      D7         B 5.62 5.51 -0.11
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  220.5
# 3  Time difference between 1st and last observed ...   21.0
# 4                                      AWT (minutes)   10.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    4.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  134.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.85
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.15
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  92.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.87
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.13
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:13
#    Route_Dir_QSI_No Stop Point ID    AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G   6.50             2  0.50
# 1             D7_A2    490013513S   6.00             2  0.00
# 2             D7_A3    490002048Z   7.00             2  1.00
# 3             D7_A4    490006092N  10.50             2  4.50
# 4             D7_A5    490004584N   0.00             1 -6.00
# 5             D7_B1    490015151H   5.50             2  0.50
# 6             D7_B2    490004584S   5.85             3 -0.15
# 7             D7_B3    490000038F   4.87             3 -0.13
# 8             D7_B4    490006092S   5.00             2 -1.00
# 9             D7_B5    490002048X   5.00             2 -1.00
# 10            D7_B6    490013513N   7.00             2  1.00
#
# Route SWT, AWT, EWT at time : 17:13
#
# Line Id Direction  SWT  AWT  EWT
#      D7         A  6.0 6.67 0.67
# Line Id Direction  SWT  AWT   EWT
#      D7         B 5.62 5.51 -0.11
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  134.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.85
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.15
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  102.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    5.39
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.39
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.91
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.09
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:14
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.26             3  0.26
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  7.00             2  1.00
# 3             D7_A4    490006092N  0.00             1 -6.00
# 4             D7_A5    490004584N  0.00             1 -6.00
# 5             D7_B1    490015151H  5.50             2  0.50
# 6             D7_B2    490004584S  5.85             3 -0.15
# 7             D7_B3    490000038F  5.39             3  0.39
# 8             D7_B4    490006092S  5.00             2 -1.00
# 9             D7_B5    490002048X  5.55             3 -0.45
# 10            D7_B6    490013513N  5.91             3 -0.09
#
# Route SWT, AWT, EWT at time : 17:14
#
# Line Id Direction  SWT  AWT   EWT
#      D7         A  6.0 4.98 -1.02
# Line Id Direction  SWT  AWT   EWT
#      D7         B 5.62 5.57 -0.05
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  148.00
# 3  Time difference between 1st and last observed ...   24.00
# 4                                      AWT (minutes)    6.17
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.17
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  102.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    5.39
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.39
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.91
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.09
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:14
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.26             3  0.26
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  7.00             2  1.00
# 3             D7_A4    490006092N  0.00             1 -6.00
# 4             D7_A5    490004584N  0.00             1 -6.00
# 5             D7_B1    490015151H  5.50             2  0.50
# 6             D7_B2    490004584S  6.17             3  0.17
# 7             D7_B3    490000038F  5.39             3  0.39
# 8             D7_B4    490006092S  5.00             2 -1.00
# 9             D7_B5    490002048X  5.55             3 -0.45
# 10            D7_B6    490013513N  5.91             3 -0.09
#
# Route SWT, AWT, EWT at time : 17:14
#
# Line Id Direction  SWT  AWT   EWT
#      D7         A  6.0 4.98 -1.02
# Line Id Direction  SWT  AWT  EWT
#      D7         B 5.62 5.63 0.01
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  162.5
# 3  Time difference between 1st and last observed ...   25.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  102.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    5.39
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.39
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.91
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.09
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:15
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.26             3  0.26
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  7.00             2  1.00
# 3             D7_A4    490006092N  0.00             1 -6.00
# 4             D7_A5    490004584N  0.00             1 -6.00
# 5             D7_B1    490015151H  5.50             2  0.50
# 6             D7_B2    490004584S  6.50             3  0.50
# 7             D7_B3    490000038F  5.39             3  0.39
# 8             D7_B4    490006092S  5.00             2 -1.00
# 9             D7_B5    490002048X  5.55             3 -0.45
# 10            D7_B6    490013513N  5.91             3 -0.09
#
# Route SWT, AWT, EWT at time : 17:15
#
# Line Id Direction  SWT  AWT   EWT
#      D7         A  6.0 4.98 -1.02
# Line Id Direction  SWT  AWT  EWT
#      D7         B 5.62 5.69 0.07
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  162.5
# 3  Time difference between 1st and last observed ...   25.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  102.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    5.39
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.39
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  130.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.91
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.09
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:15
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.26             3  0.26
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  7.00             2  1.00
# 3             D7_A4    490006092N  0.00             1 -6.00
# 4             D7_A5    490004584N  0.00             1 -6.00
# 5             D7_B1    490015151H  5.50             2  0.50
# 6             D7_B2    490004584S  6.50             3  0.50
# 7             D7_B3    490000038F  5.39             3  0.39
# 8             D7_B4    490006092S  5.00             2 -1.00
# 9             D7_B5    490002048X  5.55             3 -0.45
# 10            D7_B6    490013513N  5.91             3 -0.09
#
# Route SWT, AWT, EWT at time : 17:15
#
# Line Id Direction  SWT  AWT   EWT
#      D7         A  6.0 4.98 -1.02
# Line Id Direction  SWT  AWT  EWT
#      D7         B 5.62 5.69 0.07
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  156.50
# 3  Time difference between 1st and last observed ...   25.00
# 4                                      AWT (minutes)    6.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  132.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.76
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.76
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  162.5
# 3  Time difference between 1st and last observed ...   25.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  102.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    5.39
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.39
#
#
# Summary Metrics for 490006092S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.74
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  122.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.55
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.45
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  144.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    6.28
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.28
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:16
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  6.26             3  0.26
# 1             D7_A2    490013513S  6.00             2  0.00
# 2             D7_A3    490002048Z  7.00             2  1.00
# 3             D7_A4    490006092N  0.00             1 -6.00
# 4             D7_A5    490004584N  0.00             1 -6.00
# 5             D7_B1    490015151H  5.76             3  0.76
# 6             D7_B2    490004584S  6.50             3  0.50
# 7             D7_B3    490000038F  5.39             3  0.39
# 8             D7_B4    490006092S  5.26             3 -0.74
# 9             D7_B5    490002048X  5.55             3 -0.45
# 10            D7_B6    490013513N  6.28             3  0.28
#
# Route SWT, AWT, EWT at time : 17:16
#
# Line Id Direction  SWT  AWT   EWT
#      D7         A  6.0 4.98 -1.02
# Line Id Direction  SWT  AWT  EWT
#      D7         B 5.62 5.79 0.17
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Furher modification

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df, awt_df):
          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
          filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:,'No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:,'No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          # Initialize route_awt_direction_A and route_awt_direction_B
          route_awt_direction_A = 0
          route_awt_direction_B = 0
          route_ewt_direction_A = 0
          route_ewt_direction_B = 0

          if not awt_df.empty:
              # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
              filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
              filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

              # Calculate the product of AWT and No_Buses_Obs for each row
              filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
              filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()


              # Find the sum of these products (Route AWT)
              sum_products_A_awt = filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'].sum()
              sum_products_B_awt = filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'].sum()

              # Calculate the total sum of No_Buses_Obs for the filtered rows
              total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:,'No_Buses_Obs'].sum()
              total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:,'No_Buses_Obs'].sum()

              # Compute the Route AWT (direction A)
              route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
              route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

              # Round the results to two decimal places
              route_awt_direction_A = round(route_awt_direction_A, 2)
              route_awt_direction_B = round(route_awt_direction_B, 2)

              route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
              route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

              # Print the results in the desired format
              print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")

              df_direction_A = pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A}])
              df_direction_B = pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}])

              print(df_direction_A[['Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
              print(df_direction_B[['Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

          else:
              print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))
              print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:01
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Unable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready
#
#
# Route D7 SWT at time : 17:01
#
# Line Id Direction  SWT AWT EWT
#      D7         A  6.0   -   -
# Line Id Direction  SWT AWT EWT
#      D7         B 5.62   -   -
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  264.5
# 3  Time difference between 1st and last observed ...   23.0
# 4                                      AWT (minutes)   11.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    5.5
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  242.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)   11.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    5.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  242.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)   11.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    5.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  188.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    6.98
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    0.98
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   18.0
# 3  Time difference between 1st and last observed ...    6.0
# 4                                      AWT (minutes)    3.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -3.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  220.5
# 3  Time difference between 1st and last observed ...   21.0
# 4                                      AWT (minutes)   10.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    4.5
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  106.00
# 3  Time difference between 1st and last observed ...   18.00
# 4                                      AWT (minutes)    5.89
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.11
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:01
#    Route_Dir_QSI_No Stop Point ID    AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G   6.50             2  0.50
# 1             D7_A2    490013513S  11.50             2  5.50
# 2             D7_A3    490002048Z  11.00             2  5.00
# 3             D7_A4    490006092N   0.00             1 -6.00
# 4             D7_A5    490004584N  11.00             2  5.00
# 5             D7_B1    490015151H   5.50             2  0.50
# 6             D7_B2    490004584S   6.98             3  0.98
# 7             D7_B3    490000038F   8.50             2  3.50
# 8             D7_B4    490006092S   3.00             2 -3.00
# 9             D7_B5    490002048X  10.50             2  4.50
# 10            D7_B6    490013513N   5.89             3 -0.11
#
# Unable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready
#
#
# Route SWT, AWT, EWT at time : 17:01
#
# Line Id Direction  SWT  AWT  EWT
#      D7         A  6.0 8.89 2.89
# Line Id Direction  SWT  AWT  EWT
#      D7         B 5.62 6.69 1.07
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  242.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)   11.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    5.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  242.0
# 3  Time difference between 1st and last observed ...   22.0
# 4                                      AWT (minutes)   11.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    5.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   60.5
# 3  Time difference between 1st and last observed ...   11.0
# 4                                      AWT (minutes)    5.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  133.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    4.94
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -1.06
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   5.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  42.50
# 3  Time difference between 1st and last observed ...  13.00
# 4                                      AWT (minutes)   3.27
# 5                                      SWT (minutes)   6.00
# 6                                      EWT (minutes)  -2.73
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  218.00
# 3  Time difference between 1st and last observed ...   26.00
# 4                                      AWT (minutes)    8.38
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    2.38
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  106.00
# 3  Time difference between 1st and last observed ...   18.00
# 4                                      AWT (minutes)    5.89
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.11
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  6.0             5
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  6.0             5
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  5.0             6
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  5.0             6
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 17:02
#    Route_Dir_QSI_No Stop Point ID    AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G   6.50             2  0.50
# 1             D7_A2    490013513S   0.00             1 -6.00
# 2             D7_A3    490002048Z  11.00             2  5.00
# 3             D7_A4    490006092N   0.00             1 -6.00
# 4             D7_A5    490004584N  11.00             2  5.00
# 5             D7_B1    490015151H   5.50             2  0.50
# 6             D7_B2    490004584S   4.94             4 -1.06
# 7             D7_B3    490000038F   8.50             2  3.50
# 8             D7_B4    490006092S   3.27             3 -2.73
# 9             D7_B5    490002048X   8.38             3  2.38
# 10            D7_B6    490013513N   5.89             3 -0.11
#
# Unable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready
#
#
# Route SWT, AWT, EWT at time : 17:02
#
# Line Id Direction  SWT  AWT  EWT
#      D7         A  6.0 7.12 1.12
# Line Id Direction  SWT  AWT  EWT
#      D7         B 5.62  5.9 0.28
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# File share 29

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        # Function to calculate Route SWT (direction A), Route SWT (direction B)
        def calculate_route_swt_awt(swt_df, awt_df):
          # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
          filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
          filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

          # Calculate the product of SWT and No_Buses_Sch for each row
          filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
          filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

          # Find the sum of these products (Route SWT)
          sum_products_A_swt = filtered_df_A_swt.loc[:,'SWT_No_Buses_Sch_Product_A'].sum()
          sum_products_B_swt = filtered_df_B_swt.loc[:,'SWT_No_Buses_Sch_Product_B'].sum()

          # Calculate the total sum of No_Buses_Sch for the filtered rows
          total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:,'No_Buses_Sch'].sum()
          total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:,'No_Buses_Sch'].sum()

          # Compute the Route SWT (direction A)
          route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
          route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

          # Round the results to two decimal places
          route_swt_direction_A = round(route_swt_direction_A, 2)
          route_swt_direction_B = round(route_swt_direction_B, 2)

          # Initialize route_awt_direction_A and route_awt_direction_B
          route_awt_direction_A = 0
          route_awt_direction_B = 0
          route_ewt_direction_A = 0
          route_ewt_direction_B = 0

          if not awt_df.empty:
              # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
              filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
              filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

              # Calculate the product of AWT and No_Buses_Obs for each row
              filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
              filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()

              # Find the sum of these products (Route AWT)
              sum_products_A_awt = filtered_df_A_awt.loc[:,'AWT_No_Buses_Obs_Product_A'].sum()
              sum_products_B_awt = filtered_df_B_awt.loc[:,'AWT_No_Buses_Obs_Product_B'].sum()

              # Calculate the total sum of No_Buses_Obs for the filtered rows
              total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:,'No_Buses_Obs'].sum()
              total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:,'No_Buses_Obs'].sum()

              # Compute the Route AWT (direction A)
              route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
              route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

              # Round the results to two decimal places
              route_awt_direction_A = round(route_awt_direction_A, 2)
              route_awt_direction_B = round(route_awt_direction_B, 2)

              route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
              route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

              # Print the results in the desired format
              print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")

              df_direction_A = pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A}])
              df_direction_B = pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}])

              print(df_direction_A[['Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
              print(df_direction_B[['Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

          else:
              print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))
              print(pd.DataFrame([{'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}]).to_string(index=False))
              print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output()
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Please enter the lineID: 425
#
#
# QSI stop points for direction 425_A
#
#   Route_Dir_QSI_No                         STOP_Name          ID
# 0           425_A1                   Hainault Street  490007657V
# 1           425_A2                 High Street North  490008189W
# 2           425_A3                      Green Street  490007497W
# 3           425_A4             Stratford Bus Station  490012904T
# 4           425_A5                Bow Church Station  490002019B
# 6           425_A6  Mile End Station / Mile End Road  490000146G
# 7           425_A7                      Moulins Road  490010068N
# 8           425_A8                 Homerton Hospital  490008327F
#
#
# QSI stop points for direction 425_B
#
#   Route_Dir_QSI_No                          STOP_Name          ID
# 0           425_B1                   Nightingale Road  490010280N
# 2           425_B2  Homerton Hospital / Wardle Street  490008327E
# 3           425_B3                     Penshurst Road  490012255S
# 4           425_B4        Mile End Station / Bow Road  490015151H
# 6           425_B5                 Bow Church Station  490002019A
# 7           425_B6              Stratford Bus Station  490012904B
# 8           425_B7                  High Street North  490008189E
#
# Today is Saturday. The selected Schedule name is Saturday.
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID       SWT  No_Buses_Sch
# 0            425_A1  490007657V  5.000000             6
# 1            425_A2  490008189W  5.000000             6
# 2            425_A3  490007497W  5.000000             6
# 3            425_A4  490012904T  5.000000             6
# 4            425_A5  490002019B  4.285714             7
# 5            425_A6  490000146G  5.000000             6
# 6            425_A7  490010068N  5.000000             6
# 7            425_A8  490008327F  5.000000             6
# 8            425_B1  490010280N  5.000000             6
# 9            425_B2  490008327E  5.000000             6
# 10           425_B3  490012255S  5.000000             6
# 11           425_B4  490015151H  5.000000             6
# 12           425_B5  490002019A  5.000000             6
# 13           425_B6  490012904B  5.000000             6
# 14           425_B7  490008189E  5.000000             6
#
#
# AWT DataFrame at hour 17:27
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, Stop Point ID, AWT, No_Buses_Obs, EWT]
# Index: []
#
# Route 425 SWT at time : 17:27
#
# Line Id Direction  SWT AWT EWT
#     425         A  4.9   -   -
# Line Id Direction  SWT AWT EWT
#     425         B  5.0   -   -
#
# Unable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready
#
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  87.00
# 3  Time difference between 1st and last observed ...  20.00
# 4                                      AWT (minutes)   4.35
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.65
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  82.50
# 3  Time difference between 1st and last observed ...  21.00
# 4                                      AWT (minutes)   3.93
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -1.07
#
#
# Summary Metrics for 490012904T:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  84.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.97
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.03
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   2.000000
# 2                               Total WAWT (minutes)  84.500000
# 3  Time difference between 1st and last observed ...  13.000000
# 4                                      AWT (minutes)   6.500000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)   2.210000
#
#
# Summary Metrics for 490000146G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  196.0
# 3  Time difference between 1st and last observed ...   28.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490010068N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490008327F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.0
#
#
# Summary Metrics for 490010280N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490008327E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490012255S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)   81.0
# 3  Time difference between 1st and last observed ...   18.0
# 4                                      AWT (minutes)    4.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490002019A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  72.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.26
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.74
#
#
# Summary Metrics for 490012904B:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  146.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    5.43
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.43
#
#
# Summary Metrics for 490008189E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  178.00
# 3  Time difference between 1st and last observed ...   26.00
# 4                                      AWT (minutes)    6.85
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.85
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID       SWT  No_Buses_Sch
# 0            425_A1  490007657V  5.000000             6
# 1            425_A2  490008189W  5.000000             6
# 2            425_A3  490007497W  5.000000             6
# 3            425_A4  490012904T  5.000000             6
# 4            425_A5  490002019B  4.285714             7
# 5            425_A6  490000146G  5.000000             6
# 6            425_A7  490010068N  5.000000             6
# 7            425_A8  490008327F  5.000000             6
# 8            425_B1  490010280N  5.000000             6
# 9            425_B2  490008327E  5.000000             6
# 10           425_B3  490012255S  5.000000             6
# 11           425_B4  490015151H  5.000000             6
# 12           425_B5  490002019A  5.000000             6
# 13           425_B6  490012904B  5.000000             6
# 14           425_B7  490008189E  5.000000             6
#
#
# AWT DataFrame at hour 17:29
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0            425_A1    490007657V  5.00             3  0.00
# 1            425_A2    490008189W  4.35             4 -0.65
# 2            425_A3    490007497W  3.93             4 -1.07
# 3            425_A4    490012904T  4.97             3 -0.03
# 4            425_A5    490002019B  6.50             2  2.21
# 5            425_A6    490000146G  7.00             3  2.00
# 6            425_A7    490010068N  6.00             2  1.00
# 7            425_A8    490008327F  8.00             2  3.00
# 8            425_B1    490010280N  5.00             3  0.00
# 9            425_B2    490008327E  5.26             3  0.26
# 10           425_B3    490012255S  5.05             3  0.05
# 11           425_B4    490015151H  4.50             3 -0.50
# 12           425_B5    490002019A  4.26             3 -0.74
# 13           425_B6    490012904B  5.43             4  0.43
# 14           425_B7    490008189E  6.85             3  1.85
#
# Route SWT, AWT, EWT at time : 17:29
#
# Line Id Direction  SWT  AWT  EWT
#     425         A  4.9 5.44 0.54
# Line Id Direction  SWT  AWT  EWT
#     425         B  5.0  5.2  0.2
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490008189W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  89.50
# 3  Time difference between 1st and last observed ...  21.00
# 4                                      AWT (minutes)   4.26
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.74
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   4.00
# 2                               Total WAWT (minutes)  73.00
# 3  Time difference between 1st and last observed ...  20.00
# 4                                      AWT (minutes)   3.65
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -1.35
#
#
# Summary Metrics for 490012904T:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  84.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.97
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.03
#
#
# Summary Metrics for 490002019B:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)   7.000000
# 1                           Number of buses observed   2.000000
# 2                               Total WAWT (minutes)  84.500000
# 3  Time difference between 1st and last observed ...  13.000000
# 4                                      AWT (minutes)   6.500000
# 5                                      SWT (minutes)   4.285714
# 6                                      EWT (minutes)   2.210000
#
#
# Summary Metrics for 490000146G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  196.0
# 3  Time difference between 1st and last observed ...   28.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490010068N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490008327F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.0
#
#
# Summary Metrics for 490010280N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  100.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490008327E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  110.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.26
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.26
#
#
# Summary Metrics for 490012255S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  112.50
# 3  Time difference between 1st and last observed ...   21.00
# 4                                      AWT (minutes)    5.36
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.36
#
#
# Summary Metrics for 490015151H:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  101.00
# 3  Time difference between 1st and last observed ...   20.00
# 4                                      AWT (minutes)    5.05
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.05
#
#
# Summary Metrics for 490002019A:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  90.50
# 3  Time difference between 1st and last observed ...  19.00
# 4                                      AWT (minutes)   4.76
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.24
#
#
# Summary Metrics for 490012904B:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    4.00
# 2                               Total WAWT (minutes)  146.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    5.43
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.43
#
#
# Summary Metrics for 490008189E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  74.50
# 3  Time difference between 1st and last observed ...  17.00
# 4                                      AWT (minutes)   4.38
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.62
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No          ID       SWT  No_Buses_Sch
# 0            425_A1  490007657V  5.000000             6
# 1            425_A2  490008189W  5.000000             6
# 2            425_A3  490007497W  5.000000             6
# 3            425_A4  490012904T  5.000000             6
# 4            425_A5  490002019B  4.285714             7
# 5            425_A6  490000146G  5.000000             6
# 6            425_A7  490010068N  5.000000             6
# 7            425_A8  490008327F  5.000000             6
# 8            425_B1  490010280N  5.000000             6
# 9            425_B2  490008327E  5.000000             6
# 10           425_B3  490012255S  5.000000             6
# 11           425_B4  490015151H  5.000000             6
# 12           425_B5  490002019A  5.000000             6
# 13           425_B6  490012904B  5.000000             6
# 14           425_B7  490008189E  5.000000             6
#
#
# AWT DataFrame at hour 17:30
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0            425_A1    490007657V  5.00             3  0.00
# 1            425_A2    490008189W  4.26             4 -0.74
# 2            425_A3    490007497W  3.65             4 -1.35
# 3            425_A4    490012904T  4.97             3 -0.03
# 4            425_A5    490002019B  6.50             2  2.21
# 5            425_A6    490000146G  7.00             3  2.00
# 6            425_A7    490010068N  6.00             2  1.00
# 7            425_A8    490008327F  8.00             2  3.00
# 8            425_B1    490010280N  5.00             3  0.00
# 9            425_B2    490008327E  5.26             3  0.26
# 10           425_B3    490012255S  5.36             3  0.36
# 11           425_B4    490015151H  5.05             3  0.05
# 12           425_B5    490002019A  4.76             3 -0.24
# 13           425_B6    490012904B  5.43             4  0.43
# 14           425_B7    490008189E  4.38             3 -0.62
#
# Route SWT, AWT, EWT at time : 17:30
#
# Line Id Direction  SWT  AWT  EWT
#     425         A  4.9 5.37 0.47
# Line Id Direction  SWT  AWT  EWT
#     425         B  5.0 5.05 0.05
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# File share 30 - Route_EWT_df

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time


# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        def calculate_route_swt_awt(swt_df, awt_df):

            # Function to calculate Route SWT (direction A), Route SWT (direction B)

            # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
            filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
            filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

            # Calculate the product of SWT and No_Buses_Sch for each row
            filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
            filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

            # Find the sum of these products (Route SWT)
            sum_products_A_swt = filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'].sum()
            sum_products_B_swt = filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'].sum()

            # Calculate the total sum of No_Buses_Sch for the filtered rows
            total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:, 'No_Buses_Sch'].sum()
            total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:, 'No_Buses_Sch'].sum()

            # Compute the Route SWT (direction A)
            route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
            route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

            # Round the results to two decimal places
            route_swt_direction_A = round(route_swt_direction_A, 2)
            route_swt_direction_B = round(route_swt_direction_B, 2)

            # Initialize route_awt_direction_A and route_awt_direction_B
            route_awt_direction_A = 0
            route_awt_direction_B = 0
            route_ewt_direction_A = 0
            route_ewt_direction_B = 0

            if not awt_df.empty:
                # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
                filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
                filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

                # Calculate the product of AWT and No_Buses_Obs for each row
                filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
                filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()

                # Find the sum of these products (Route AWT)
                sum_products_A_awt = filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'].sum()
                sum_products_B_awt = filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'].sum()

                # Calculate the total sum of No_Buses_Obs for the filtered rows
                total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:, 'No_Buses_Obs'].sum()
                total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:, 'No_Buses_Obs'].sum()

                # Compute the Route AWT (direction A)
                route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
                route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

                # Round the results to two decimal places
                route_awt_direction_A = round(route_awt_direction_A, 2)
                route_awt_direction_B = round(route_awt_direction_B, 2)

                # Calculate Route EWT (direction A and B)
                route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
                route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

                # Prepare Route_EWT_df
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}
                ])

                # Print the results in the desired format
                print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

            else:
                # If awt_df is empty, print only SWT and indicate that AWT and EWT could not be calculated
                print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}
                ])
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
                print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

            return route_EWT_df
        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output(wait=True)
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)


# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  73.00
# 3  Time difference between 1st and last observed ...  16.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.44
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  68.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   4.57
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.43
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  74.00
# 3  Time difference between 1st and last observed ...  14.00
# 4                                      AWT (minutes)   5.29
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)   0.29
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  146.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    6.64
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.64
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.0
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.5
#
#
# Summary Metrics for 490010238E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.5
#
#
# Summary Metrics for 490005655W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490015256D:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  102.50
# 3  Time difference between 1st and last observed ...   19.00
# 4                                      AWT (minutes)    5.39
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    0.39
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490014581N?direction=inbound
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490003369N?direction=inbound
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No           ID  SWT  No_Buses_Sch
# 0            124_A1   490004863Z  6.0             5
# 1            124_A2   490009117J  5.0             6
# 2            124_A3   490007967S  5.0             6
# 3            124_A4   490014581S  5.0             6
# 4            124_A5   490015256C  5.0             6
# 5            124_A6   490005655E  5.0             6
# 6            124_A7   490001200A  5.0             6
# 7            124_A8  490010238N2  5.0             6
# 8            124_B1   490008321S  5.0             6
# 9            124_B2   490006537M  5.0             6
# 10           124_B3   490010238E  5.0             6
# 11           124_B4   490001200B  5.0             6
# 12           124_B5   490005655W  5.0             6
# 13           124_B6   490015256D  5.0             6
# 14           124_B7   490014581N  5.0             6
# 15           124_B8   490003369N  5.0             6
#
#
# AWT DataFrame at hour 17:58
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0            124_A1    490004863Z  0.00             1 -6.00
# 1            124_A2    490009117J  7.50             2  2.50
# 2            124_A3    490007967S  4.56             3 -0.44
# 3            124_A4    490014581S  4.57             3 -0.43
# 4            124_A5    490015256C  5.29             3  0.29
# 5            124_A6    490005655E  6.64             3  1.64
# 6            124_A8   490010238N2  8.00             2  3.00
# 7            124_B1    490008321S  0.00             1 -5.00
# 8            124_B2    490006537M  8.50             2  3.50
# 9            124_B3    490010238E  8.50             2  3.50
# 10           124_B5    490005655W  6.50             2  1.50
# 11           124_B6    490015256D  5.39             3  0.39
#
# Route SWT, AWT, EWT at time : 17:58
#
#  Time Line Id Direction  SWT  AWT  EWT
# 17:58     124         A 5.11 5.54 0.43
# 17:58     124         B 5.00 6.32 1.32
#
#
# Waiting to fetch updated data...

# %% [markdown]
# File share 31 - Route  EWT _df (modified code)

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time
from IPython.display import clear_output

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        def calculate_route_swt_awt(swt_df, awt_df):

            # Function to calculate Route SWT (direction A), Route SWT (direction B)

            # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
            filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
            filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

            # Calculate the product of SWT and No_Buses_Sch for each row
            filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
            filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

            # Find the sum of these products (Route SWT)
            sum_products_A_swt = filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'].sum()
            sum_products_B_swt = filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'].sum()

            # Calculate the total sum of No_Buses_Sch for the filtered rows
            total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:, 'No_Buses_Sch'].sum()
            total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:, 'No_Buses_Sch'].sum()

            # Compute the Route SWT (direction A)
            route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
            route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

            # Round the results to two decimal places
            route_swt_direction_A = round(route_swt_direction_A, 2)
            route_swt_direction_B = round(route_swt_direction_B, 2)

            # Initialize route_awt_direction_A and route_awt_direction_B
            route_awt_direction_A = 0
            route_awt_direction_B = 0
            route_ewt_direction_A = 0
            route_ewt_direction_B = 0

            if not awt_df.empty:
                # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
                filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
                filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

                # Calculate the product of AWT and No_Buses_Obs for each row
                filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
                filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()

                # Find the sum of these products (Route AWT)
                sum_products_A_awt = filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'].sum()
                sum_products_B_awt = filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'].sum()

                # Calculate the total sum of No_Buses_Obs for the filtered rows
                total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:, 'No_Buses_Obs'].sum()
                total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:, 'No_Buses_Obs'].sum()

                # Compute the Route AWT (direction A)
                route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
                route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

                # Round the results to two decimal places
                route_awt_direction_A = round(route_awt_direction_A, 2)
                route_awt_direction_B = round(route_awt_direction_B, 2)

                # Calculate Route EWT (direction A and B)
                route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
                route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

                # Prepare Route_EWT_df
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}
                ])

                # Print the results in the desired format
                print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

            else:
                # If awt_df is empty, print only SWT and indicate that AWT and EWT could not be calculated
                print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}
                ])
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
                print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

            return route_EWT_df
        # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df)

        # Wait for the next 30 seconds
        #clear_output(wait=True)
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)
        clear_output(wait=True)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
#
#
# Summary Metrics for 490004863Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490009117J:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490007967S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  73.00
# 3  Time difference between 1st and last observed ...  16.00
# 4                                      AWT (minutes)   4.56
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.44
#
#
# Summary Metrics for 490014581S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  68.50
# 3  Time difference between 1st and last observed ...  15.00
# 4                                      AWT (minutes)   4.57
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)  -0.43
#
#
# Summary Metrics for 490015256C:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                           Number of buses observed   3.00
# 2                               Total WAWT (minutes)  74.00
# 3  Time difference between 1st and last observed ...  14.00
# 4                                      AWT (minutes)   5.29
# 5                                      SWT (minutes)   5.00
# 6                                      EWT (minutes)   0.29
#
#
# Summary Metrics for 490005655E:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  146.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    6.64
# 5                                      SWT (minutes)    5.00
# 6                                      EWT (minutes)    1.64
#
#
# Summary Metrics for 490010238N2:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.0
#
#
# Summary Metrics for 490008321S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490006537M:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)   -5.0
#
#
# Summary Metrics for 490010238E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    3.5
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490001200B?direction=inbound
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490005655W?direction=inbound
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490015256D?direction=inbound
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490014581N?direction=inbound
# Error fetching data: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/124/Arrivals/490003369N?direction=inbound
#
#
# SWT DataFrame at hour 17
#    Route_Dir_QSI_No           ID  SWT  No_Buses_Sch
# 0            124_A1   490004863Z  6.0             5
# 1            124_A2   490009117J  5.0             6
# 2            124_A3   490007967S  5.0             6
# 3            124_A4   490014581S  5.0             6
# 4            124_A5   490015256C  5.0             6
# 5            124_A6   490005655E  5.0             6
# 6            124_A7   490001200A  5.0             6
# 7            124_A8  490010238N2  5.0             6
# 8            124_B1   490008321S  5.0             6
# 9            124_B2   490006537M  5.0             6
# 10           124_B3   490010238E  5.0             6
# 11           124_B4   490001200B  5.0             6
# 12           124_B5   490005655W  5.0             6
# 13           124_B6   490015256D  5.0             6
# 14           124_B7   490014581N  5.0             6
# 15           124_B8   490003369N  5.0             6
#
#
# AWT DataFrame at hour 17:59
#   Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0           124_A1    490004863Z  0.00             1 -6.00
# 1           124_A2    490009117J  7.50             2  2.50
# 2           124_A3    490007967S  4.56             3 -0.44
# 3           124_A4    490014581S  4.57             3 -0.43
# 4           124_A5    490015256C  5.29             3  0.29
# 5           124_A6    490005655E  6.64             3  1.64
# 6           124_A8   490010238N2  8.00             2  3.00
# 7           124_B1    490008321S  0.00             1 -5.00
# 8           124_B2    490006537M  0.00             1 -5.00
# 9           124_B3    490010238E  8.50             2  3.50
#
# Route SWT, AWT, EWT at time : 17:59
#
#  Time Line Id Direction  SWT  AWT   EWT
# 17:59     124         A 5.11 5.54  0.43
# 17:59     124         B 5.00 4.25 -0.75
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Modification (File share 31) - to write route_df to excel file

# %%
# !pip install xlsxwriter
import xlsxwriter
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time
from IPython.display import clear_output


# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        def calculate_route_swt_awt(swt_df, awt_df, lineID, now):
            # Function to calculate Route SWT, AWT, EWT and export to Excel

            # Function to calculate Route SWT (direction A), Route SWT (direction B)

            # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
            filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
            filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

            # Calculate the product of SWT and No_Buses_Sch for each row
            filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
            filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

            # Find the sum of these products (Route SWT)
            sum_products_A_swt = filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'].sum()
            sum_products_B_swt = filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'].sum()

            # Calculate the total sum of No_Buses_Sch for the filtered rows
            total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:, 'No_Buses_Sch'].sum()
            total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:, 'No_Buses_Sch'].sum()

            # Compute the Route SWT (direction A)
            route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
            route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

            # Round the results to two decimal places
            route_swt_direction_A = round(route_swt_direction_A, 2)
            route_swt_direction_B = round(route_swt_direction_B, 2)

            # Initialize route_awt_direction_A and route_awt_direction_B
            route_awt_direction_A = 0
            route_awt_direction_B = 0
            route_ewt_direction_A = 0
            route_ewt_direction_B = 0

            if not awt_df.empty:
                # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
                filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
                filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

                # Calculate the product of AWT and No_Buses_Obs for each row
                filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
                filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()

                # Find the sum of these products (Route AWT)
                sum_products_A_awt = filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'].sum()
                sum_products_B_awt = filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'].sum()

                # Calculate the total sum of No_Buses_Obs for the filtered rows
                total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:, 'No_Buses_Obs'].sum()
                total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:, 'No_Buses_Obs'].sum()

                # Compute the Route AWT (direction A)
                route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
                route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

                # Round the results to two decimal places
                route_awt_direction_A = round(route_awt_direction_A, 2)
                route_awt_direction_B = round(route_awt_direction_B, 2)

                # Calculate Route EWT (direction A and B)
                route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
                route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

                # Prepare Route_EWT_df
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}
                ])

                # Export to Excel
                excel_filename = 'route_ewt.xlsx'
                with pd.ExcelWriter(excel_filename, engine='xlsxwriter') as writer:
                    # Write direction A data to sheet route_ewt_A
                    route_EWT_df[route_EWT_df['Direction'] == 'A'].to_excel(writer, sheet_name='route_ewt_A', index=False)

                    # Write direction B data to sheet route_ewt_B
                    route_EWT_df[route_EWT_df['Direction'] == 'B'].to_excel(writer, sheet_name='route_ewt_B', index=False)

                print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

            else:
                # If awt_df is empty, print only SWT and indicate that AWT and EWT could not be calculated
                print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}
                ])
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
                print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

            return route_EWT_df
       # Calculate and print Route SWT (direction A)
        calculate_route_swt_awt(swt_df, awt_df, lineID, now)

        # Wait for the next 30 seconds
        #clear_output(wait=True)
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)
        clear_output(wait=True)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  144.5
# 3  Time difference between 1st and last observed ...   17.0
# 4                                      AWT (minutes)    8.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.5
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  225.0
# 3  Time difference between 1st and last observed ...   30.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490002048X:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  216.50
# 3  Time difference between 1st and last observed ...   29.00
# 4                                      AWT (minutes)    7.47
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)    1.47
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    2.0
#
#
# SWT DataFrame at hour 19
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  6.0             5
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  6.0             5
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  6.0             5
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  6.0             5
# 9             D7_B5  490002048X  6.0             5
# 10            D7_B6  490013513N  6.0             5
#
#
# AWT DataFrame at hour 19:44
#    Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0             D7_A1    490011107G  0.00             1 -7.50
# 1             D7_A2    490013513S  8.50             2  2.50
# 2             D7_A3    490002048Z  8.00             2  2.00
# 3             D7_A4    490006092N  7.00             2 -0.50
# 4             D7_A5    490004584N  6.00             2  0.00
# 5             D7_B1    490015151H  7.50             2  0.00
# 6             D7_B2    490004584S  7.50             2  1.50
# 7             D7_B3    490000038F  7.50             3  0.00
# 8             D7_B4    490006092S  7.00             2  1.00
# 9             D7_B5    490002048X  7.47             3  1.47
# 10            D7_B6    490013513N  8.00             2  2.00
#
# Route SWT, AWT, EWT at time : 19:44
#
#  Time Line Id Direction  SWT  AWT  EWT
# 19:44      D7         A 6.52 6.56 0.04
# 19:44      D7         B 6.43 7.49 1.06
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Modification (File share 31) - appending data to csv file

# %%
import os
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time
from IPython.display import clear_output

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        def calculate_route_swt_awt(swt_df, awt_df):

            # Function to calculate Route SWT (direction A), Route SWT (direction B)

            # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
            filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
            filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

            # Calculate the product of SWT and No_Buses_Sch for each row
            filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
            filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

            # Find the sum of these products (Route SWT)
            sum_products_A_swt = filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'].sum()
            sum_products_B_swt = filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'].sum()

            # Calculate the total sum of No_Buses_Sch for the filtered rows
            total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:, 'No_Buses_Sch'].sum()
            total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:, 'No_Buses_Sch'].sum()

            # Compute the Route SWT (direction A)
            route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
            route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

            # Round the results to two decimal places
            route_swt_direction_A = round(route_swt_direction_A, 2)
            route_swt_direction_B = round(route_swt_direction_B, 2)

            # Initialize route_awt_direction_A and route_awt_direction_B
            route_awt_direction_A = 0
            route_awt_direction_B = 0
            route_ewt_direction_A = 0
            route_ewt_direction_B = 0

            if not awt_df.empty:
                # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
                filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
                filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

                # Calculate the product of AWT and No_Buses_Obs for each row
                filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
                filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()

                # Find the sum of these products (Route AWT)
                sum_products_A_awt = filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'].sum()
                sum_products_B_awt = filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'].sum()

                # Calculate the total sum of No_Buses_Obs for the filtered rows
                total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:, 'No_Buses_Obs'].sum()
                total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:, 'No_Buses_Obs'].sum()

                # Compute the Route AWT (direction A)
                route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
                route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

                # Round the results to two decimal places
                route_awt_direction_A = round(route_awt_direction_A, 2)
                route_awt_direction_B = round(route_awt_direction_B, 2)

                # Calculate Route EWT (direction A and B)
                route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
                route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

                # Prepare Route_EWT_df
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}
                ])

                # Print the results in the desired format
                print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

            else:
                # If awt_df is empty, print only SWT and indicate that AWT and EWT could not be calculated
                print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}
                ])
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
                print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

            return route_EWT_df

        def append_route_EWT_df_to_csv(route_EWT_df, csv_file_path='/content/route_ewt.csv'):

            # Check if the CSV file exists
            file_exists = os.path.isfile(csv_file_path)

            # Append the DataFrame to the CSV file
            route_EWT_df.to_csv(csv_file_path, mode='a', header=not file_exists, index=False)

            print(f"Data appended to {csv_file_path}")

        # Calculate and print Route SWT (direction A)
        route_EWT_df = calculate_route_swt_awt(swt_df, awt_df)
        append_route_EWT_df_to_csv(route_EWT_df, csv_file_path='/content/route_ewt.csv')

        # Wait for the next 30 seconds
        #clear_output(wait=True)
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)
        clear_output(wait=True)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
#
#
# Summary Metrics for 490007657V:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  144.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490008189W:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  125.00
# 3  Time difference between 1st and last observed ...   22.00
# 4                                      AWT (minutes)    5.68
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.32
#
#
# Summary Metrics for 490007497W:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490012904T:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490002019B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490000146G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  288.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)   12.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    7.0
#
#
# Summary Metrics for 490010068N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -6.0
#
#
# Summary Metrics for 490008327F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   50.0
# 3  Time difference between 1st and last observed ...   10.0
# 4                                      AWT (minutes)    5.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -1.0
#
#
# Summary Metrics for 490010280N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  144.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490008327E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  144.0
# 3  Time difference between 1st and last observed ...   24.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490012255S:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  132.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.76
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.24
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490002019A:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    5.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  132.50
# 3  Time difference between 1st and last observed ...   23.00
# 4                                      AWT (minutes)    5.76
# 5                                      SWT (minutes)    6.00
# 6                                      EWT (minutes)   -0.24
#
#
# Summary Metrics for 490012904B:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  104.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.2
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)   -0.8
#
#
# Summary Metrics for 490008189E:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    6.0
# 1                           Number of buses observed    3.0
# 2                               Total WAWT (minutes)  104.0
# 3  Time difference between 1st and last observed ...   20.0
# 4                                      AWT (minutes)    5.2
# 5                                      SWT (minutes)    5.0
# 6                                      EWT (minutes)    0.2
#
#
# SWT DataFrame at hour 20
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0            425_A1  490007657V  6.0             5
# 1            425_A2  490008189W  6.0             5
# 2            425_A3  490007497W  6.0             5
# 3            425_A4  490012904T  6.0             5
# 4            425_A5  490002019B  6.0             5
# 5            425_A6  490000146G  5.0             6
# 6            425_A7  490010068N  6.0             5
# 7            425_A8  490008327F  6.0             5
# 8            425_B1  490010280N  6.0             5
# 9            425_B2  490008327E  6.0             5
# 10           425_B3  490012255S  6.0             5
# 11           425_B4  490015151H  5.0             6
# 12           425_B5  490002019A  6.0             5
# 13           425_B6  490012904B  6.0             5
# 14           425_B7  490008189E  5.0             6
#
#
# AWT DataFrame at hour 20:40
#    Route_Dir_QSI_No Stop Point ID    AWT  No_Buses_Obs   EWT
# 0            425_A1    490007657V   6.00             3  0.00
# 1            425_A2    490008189W   5.68             3 -0.32
# 2            425_A3    490007497W   6.50             2  0.50
# 3            425_A4    490012904T   5.00             2 -1.00
# 4            425_A5    490002019B   0.00             1 -6.00
# 5            425_A6    490000146G  12.00             2  7.00
# 6            425_A7    490010068N   0.00             1 -6.00
# 7            425_A8    490008327F   5.00             2 -1.00
# 8            425_B1    490010280N   6.00             3  0.00
# 9            425_B2    490008327E   6.00             3  0.00
# 10           425_B3    490012255S   5.76             3 -0.24
# 11           425_B4    490015151H   6.00             2  1.00
# 12           425_B5    490002019A   5.76             3 -0.24
# 13           425_B6    490012904B   5.20             3 -0.80
# 14           425_B7    490008189E   5.20             3  0.20
#
# Route SWT, AWT, EWT at time : 20:40
#
#  Time Line Id Direction  SWT  AWT   EWT
# 20:40     425         A 5.85 5.75 -0.10
# 20:40     425         B 5.68 5.69  0.01
# Data appended to /content/route_ewt.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Execution interrupted. Exiting the loop.

# %% [markdown]
# Splitting to two differnt csv files

# %%
import os
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time
from IPython.display import clear_output

# Initialize empty DataFrame for AWT data
awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID', 'AWT','No_Buses_Obs','EWT'])

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID, df):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Remove duplicate stop names with the same Route_Dir_QSI_No and different IDs
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'], keep='first')

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT': [],
        'No_Buses_Sch': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    current_hour = datetime.now(bst).hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    # Track printed timetable stop IDs
    printed_timetable_stop_ids = []

    while True:
        # Clear previous awt_data DataFrame
        awt_data = pd.DataFrame(columns=['Route_Dir_QSI_No','Stop Point ID','AWT','No_Buses_Obs','EWT'])

        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Clear previous SWT data
        swt_data = {
            'Route_Dir_QSI_No': [],
            'ID': [],
            'SWT': [],
            'No_Buses_Sch': []
        }

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                print(f"Invalid route direction for Route_Dir_QSI_No: {route_dir_qsi_no}")
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT'].append(scheduled_wait_time)
                swt_data['No_Buses_Sch'].append(total_buses_this_hour)

                # Fetch arrival predictions based on SWT data for printed timetable stop IDs
                if stop_point_id in printed_timetable_stop_ids:
                    # Fetch arrival predictions
                    arrival_predictions_df, station_name = fetch_arrival_predictions(lineID, stop_point_id, direction)

                    if arrival_predictions_df is not None and not arrival_predictions_df.empty:
                        #print(f"\nArrival Predictions for stop point {stop_point_id} ({station_name}):")
                        #print(arrival_predictions_df.to_string(index=False))
                        print(f"   ")
                        # Calculating summary metrics
                        total_wawt = arrival_predictions_df['WAWT'].sum()
                        min_arrival = arrival_predictions_df['Expected Arrival (BST)'].min().replace(second=0, microsecond=0)
                        max_arrival = arrival_predictions_df['Expected Arrival (BST)'].max().replace(second=0, microsecond=0)
                        time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                        num_buses_observed = arrival_predictions_df['Vehicle ID'].nunique()

                        # Calculating AWT, SWT, and EWT
                        nbph = swt_data['No_Buses_Sch'][swt_data['ID'].index(stop_point_id)]
                        swt = swt_data['SWT'][swt_data['ID'].index(stop_point_id)]
                        awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                        ewt = round(awt - swt, 2)

                        summary_df = pd.DataFrame({
                            'Metric': ['Number of buses scheduled per hour (nbph)', 'Number of buses observed', 'Total WAWT (minutes)',
                                       'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                            'Value': [nbph, num_buses_observed, total_wawt, time_diff_minutes, awt, swt, ewt]
                        })

                        print(f"\nSummary Metrics for {stop_point_id}:")
                        print(summary_df)

                        # Append to awt_data DataFrame
                        awt_data.loc[len(awt_data)] = [swt_data['Route_Dir_QSI_No'][swt_data['ID'].index(stop_point_id)],stop_point_id, awt,num_buses_observed,ewt]

                    # Remove the stop ID from printed_timetable_stop_ids to avoid redundant fetches
                    printed_timetable_stop_ids.remove(stop_point_id)

        # Update printed timetable stop IDs
        printed_timetable_stop_ids = swt_data['ID']

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)
        awt_df = pd.DataFrame(awt_data)
        # Print the SWT DataFrame
        print(f"\n\nSWT DataFrame at hour {current_hour}")
        print(swt_df)

        print(f"\n\nAWT DataFrame at hour {now.strftime('%H:%M')}")
        print(awt_df)

        def calculate_route_swt_awt(swt_df, awt_df):

            # Function to calculate Route SWT (direction A), Route SWT (direction B)

            # Filter the swt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
            filtered_df_A_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
            filtered_df_B_swt = swt_df[swt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

            # Calculate the product of SWT and No_Buses_Sch for each row
            filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'] = filtered_df_A_swt['SWT'] * filtered_df_A_swt['No_Buses_Sch'].copy()
            filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'] = filtered_df_B_swt['SWT'] * filtered_df_B_swt['No_Buses_Sch'].copy()

            # Find the sum of these products (Route SWT)
            sum_products_A_swt = filtered_df_A_swt.loc[:, 'SWT_No_Buses_Sch_Product_A'].sum()
            sum_products_B_swt = filtered_df_B_swt.loc[:, 'SWT_No_Buses_Sch_Product_B'].sum()

            # Calculate the total sum of No_Buses_Sch for the filtered rows
            total_no_buses_sch_A_swt = filtered_df_A_swt.loc[:, 'No_Buses_Sch'].sum()
            total_no_buses_sch_B_swt = filtered_df_B_swt.loc[:, 'No_Buses_Sch'].sum()

            # Compute the Route SWT (direction A)
            route_swt_direction_A = sum_products_A_swt / total_no_buses_sch_A_swt if total_no_buses_sch_A_swt > 0 else 0
            route_swt_direction_B = sum_products_B_swt / total_no_buses_sch_B_swt if total_no_buses_sch_B_swt > 0 else 0

            # Round the results to two decimal places
            route_swt_direction_A = round(route_swt_direction_A, 2)
            route_swt_direction_B = round(route_swt_direction_B, 2)

            # Initialize route_awt_direction_A and route_awt_direction_B
            route_awt_direction_A = 0
            route_awt_direction_B = 0
            route_ewt_direction_A = 0
            route_ewt_direction_B = 0

            if not awt_df.empty:
                # Filter the awt_df to include only rows where Route_Dir_QSI_No matches the pattern _A** and _B**
                filtered_df_A_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_A')].copy()
                filtered_df_B_awt = awt_df[awt_df['Route_Dir_QSI_No'].str.contains('_B')].copy()

                # Calculate the product of AWT and No_Buses_Obs for each row
                filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'] = filtered_df_A_awt['AWT'] * filtered_df_A_awt['No_Buses_Obs'].copy()
                filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'] = filtered_df_B_awt['AWT'] * filtered_df_B_awt['No_Buses_Obs'].copy()

                # Find the sum of these products (Route AWT)
                sum_products_A_awt = filtered_df_A_awt.loc[:, 'AWT_No_Buses_Obs_Product_A'].sum()
                sum_products_B_awt = filtered_df_B_awt.loc[:, 'AWT_No_Buses_Obs_Product_B'].sum()

                # Calculate the total sum of No_Buses_Obs for the filtered rows
                total_no_buses_obs_A_awt = filtered_df_A_awt.loc[:, 'No_Buses_Obs'].sum()
                total_no_buses_obs_B_awt = filtered_df_B_awt.loc[:, 'No_Buses_Obs'].sum()

                # Compute the Route AWT (direction A)
                route_awt_direction_A = sum_products_A_awt / total_no_buses_obs_A_awt if total_no_buses_obs_A_awt > 0 else 0
                route_awt_direction_B = sum_products_B_awt / total_no_buses_obs_B_awt if total_no_buses_obs_B_awt > 0 else 0

                # Round the results to two decimal places
                route_awt_direction_A = round(route_awt_direction_A, 2)
                route_awt_direction_B = round(route_awt_direction_B, 2)

                # Calculate Route EWT (direction A and B)
                route_ewt_direction_A = round(route_awt_direction_A - route_swt_direction_A, 2)
                route_ewt_direction_B = round(route_awt_direction_B - route_swt_direction_B, 2)

                # Prepare Route_EWT_df
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': route_awt_direction_A, 'EWT': route_ewt_direction_A},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': route_awt_direction_B, 'EWT': route_ewt_direction_B}
                ])

                # Print the results in the desired format
                print(f"\n\033[1m\033[4mRoute SWT, AWT, EWT at time : {now.strftime('%H:%M')}\033[0m\n")
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))

            else:
                # If awt_df is empty, print only SWT and indicate that AWT and EWT could not be calculated
                print(f"\n\033[1m\033[4mRoute {lineID} SWT at time : {now.strftime('%H:%M')}\033[0m\n")
                route_EWT_df = pd.DataFrame([
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'A', 'SWT': route_swt_direction_A, 'AWT': '-', 'EWT': '-'},
                    {'Time': now.strftime('%H:%M'), 'Line Id': lineID, 'Direction': 'B', 'SWT': route_swt_direction_B, 'AWT': '-', 'EWT': '-'}
                ])
                print(route_EWT_df[['Time', 'Line Id', 'Direction', 'SWT', 'AWT', 'EWT']].to_string(index=False))
                print(f"\n\033[1m\033[4mUnable to calculate Route AWT and EWT for direction A and B as the AWT dataframe is not ready\033[0m\n")

            return route_EWT_df

        def append_route_EWT_df_to_csv(route_EWT_df, csv_file_path='/content/route_ewt.csv'):
          # Check if the CSV files for directions A and B exist
          csv_file_path_A = '/content/route_EWT_A.csv'
          csv_file_path_B = '/content/route_EWT_B.csv'

          # Check if the CSV files exist
          file_exists_A = os.path.isfile(csv_file_path_A)
          file_exists_B = os.path.isfile(csv_file_path_B)

          # Split the DataFrame based on 'Direction' column
          route_EWT_A_df = route_EWT_df[route_EWT_df['Direction'] == 'A']
          route_EWT_B_df = route_EWT_df[route_EWT_df['Direction'] == 'B']

          # Append the DataFrame to the respective CSV files
          route_EWT_A_df.to_csv(csv_file_path_A, mode='a', header=not file_exists_A, index=False)
          route_EWT_B_df.to_csv(csv_file_path_B, mode='a', header=not file_exists_B, index=False)

          print(f"Data appended to {csv_file_path_A} and {csv_file_path_B}")

        # Calculate and print Route SWT (direction A)
        route_EWT_df = calculate_route_swt_awt(swt_df, awt_df)
        append_route_EWT_df_to_csv(route_EWT_df, csv_file_path='/content/route_ewt.csv')

        # Wait for the next 30 seconds
        #clear_output(wait=True)
        print("\n\nWaiting to fetch updated data...\n\n")
        time.sleep(30)
        clear_output(wait=True)

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (BST)'] = pd.to_datetime(df['Expected Arrival (BST)'])  # Convert to datetime
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None
        time.sleep(30)  # Wait for 30 seconds before fetching data again

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    line_id_input = input("Please enter the lineID: ")

    while True:
        try:
            # Find and display the route details
            find_route_details(line_id_input, df)

            time.sleep(30)

        except KeyboardInterrupt:
            print("\n\nExecution interrupted. Exiting the loop.\n")
            break
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.5
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490015151H:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:28
#   Route_Dir_QSI_No Stop Point ID  AWT  No_Buses_Obs  EWT
# 0            D7_A1    490011107G  7.5             2  0.0
# 1            D7_A2    490013513S  7.5             2  1.5
# 2            D7_A3    490002048Z  7.0             2 -0.5
# 3            D7_A4    490006092N  7.5             2  0.0
# 4            D7_A5    490004584N  7.5             2  0.0
# 5            D7_B1    490015151H  0.0             1 -7.5
# 6            D7_B2    490004584S  0.0             1 -7.5
# 7            D7_B4    490006092S  0.0             1 -7.5
# 8            D7_B5    490002048X  0.0             1 -7.5
# 9            D7_B6    490013513N  7.0             2 -0.5
#
# Route SWT, AWT, EWT at time : 23:28
#
#  Time Line Id Direction  SWT  AWT   EWT
# 23:28      D7         A 7.14 7.40  0.26
# 23:28      D7         B 7.50 2.33 -5.17
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    1.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:29
#   Route_Dir_QSI_No Stop Point ID  AWT  No_Buses_Obs  EWT
# 0            D7_A1    490011107G  7.5             2  0.0
# 1            D7_A2    490013513S  7.0             2  1.0
# 2            D7_A3    490002048Z  7.0             2 -0.5
# 3            D7_A4    490006092N  7.5             2  0.0
# 4            D7_A5    490004584N  0.0             1 -7.5
# 5            D7_B4    490006092S  0.0             1 -7.5
# 6            D7_B5    490002048X  0.0             1 -7.5
# 7            D7_B6    490013513N  7.0             2 -0.5
#
# Route SWT, AWT, EWT at time : 23:29
#
#  Time Line Id Direction  SWT  AWT  EWT
# 23:29      D7         A 7.14 6.44 -0.7
# 23:29      D7         B 7.50 3.50 -4.0
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    5.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    6.0
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  182.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    6.76
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -0.74
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:29
#   Route_Dir_QSI_No Stop Point ID   AWT  No_Buses_Obs   EWT
# 0            D7_A1    490011107G  7.50             2  0.00
# 1            D7_A2    490013513S  6.50             2  0.50
# 2            D7_A3    490002048Z  7.00             2 -0.50
# 3            D7_A4    490006092N  7.50             2  0.00
# 4            D7_A5    490004584N  0.00             1 -7.50
# 5            D7_B2    490004584S  0.00             1 -7.50
# 6            D7_B3    490000038F  0.00             1 -7.50
# 7            D7_B4    490006092S  0.00             1 -7.50
# 8            D7_B5    490002048X  0.00             1 -7.50
# 9            D7_B6    490013513N  6.76             3 -0.74
#
# Route SWT, AWT, EWT at time : 23:29
#
#  Time Line Id Direction  SWT  AWT   EWT
# 23:29      D7         A 7.14 6.33 -0.81
# 23:29      D7         B 7.50 2.90 -4.60
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        5.00
# 1                           Number of buses observed        3.00
# 2                               Total WAWT (minutes)  1015397.00
# 3  Time difference between 1st and last observed ...       28.00
# 4                                      AWT (minutes)    36264.18
# 5                                      SWT (minutes)        6.00
# 6                                      EWT (minutes)    36258.18
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   98.0
# 3  Time difference between 1st and last observed ...   14.0
# 4                                      AWT (minutes)    7.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -0.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  182.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    6.76
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -0.74
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:30
#   Route_Dir_QSI_No Stop Point ID       AWT  No_Buses_Obs       EWT
# 0            D7_A1    490011107G      7.50             2      0.00
# 1            D7_A2    490013513S  36264.18             3  36258.18
# 2            D7_A3    490002048Z      7.00             2     -0.50
# 3            D7_A4    490006092N      7.50             2      0.00
# 4            D7_A5    490004584N      0.00             1     -7.50
# 5            D7_B2    490004584S      0.00             1     -7.50
# 6            D7_B3    490000038F      0.00             1     -7.50
# 7            D7_B4    490006092S      8.00             2      0.50
# 8            D7_B5    490002048X      7.50             2      0.00
# 9            D7_B6    490013513N      6.76             3     -0.74
#
# Route SWT, AWT, EWT at time : 23:30
#
#  Time Line Id Direction  SWT      AWT      EWT
# 23:30      D7         A 7.14 10883.65 10876.51
# 23:30      D7         B 7.50     5.70    -1.80
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        5.00
# 1                           Number of buses observed        3.00
# 2                               Total WAWT (minutes)  1015397.00
# 3  Time difference between 1st and last observed ...       28.00
# 4                                      AWT (minutes)    36264.18
# 5                                      SWT (minutes)        6.00
# 6                                      EWT (minutes)    36258.18
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  182.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    6.76
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -0.74
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:30
#   Route_Dir_QSI_No Stop Point ID       AWT  No_Buses_Obs       EWT
# 0            D7_A1    490011107G      7.50             2      0.00
# 1            D7_A2    490013513S  36264.18             3  36258.18
# 2            D7_A3    490002048Z      6.00             2     -1.50
# 3            D7_A4    490006092N      6.00             2     -1.50
# 4            D7_A5    490004584N      0.00             1     -7.50
# 5            D7_B2    490004584S      0.00             1     -7.50
# 6            D7_B3    490000038F      0.00             1     -7.50
# 7            D7_B4    490006092S      8.00             2      0.50
# 8            D7_B5    490002048X      7.50             2      0.00
# 9            D7_B6    490013513N      6.76             3     -0.74
#
# Route SWT, AWT, EWT at time : 23:30
#
#  Time Line Id Direction  SWT      AWT      EWT
# 23:30      D7         A 7.14 10883.15 10876.01
# 23:30      D7         B 7.50     5.70    -1.80
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        5.00
# 1                           Number of buses observed        3.00
# 2                               Total WAWT (minutes)  1015397.00
# 3  Time difference between 1st and last observed ...       28.00
# 4                                      AWT (minutes)    36264.18
# 5                                      SWT (minutes)        6.00
# 6                                      EWT (minutes)    36258.18
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    4.00
# 1                           Number of buses observed    3.00
# 2                               Total WAWT (minutes)  182.50
# 3  Time difference between 1st and last observed ...   27.00
# 4                                      AWT (minutes)    6.76
# 5                                      SWT (minutes)    7.50
# 6                                      EWT (minutes)   -0.74
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:31
#   Route_Dir_QSI_No Stop Point ID       AWT  No_Buses_Obs       EWT
# 0            D7_A1    490011107G      7.50             2      0.00
# 1            D7_A2    490013513S  36264.18             3  36258.18
# 2            D7_A3    490002048Z      6.00             2     -1.50
# 3            D7_A4    490006092N      6.00             2     -1.50
# 4            D7_A5    490004584N      0.00             1     -7.50
# 5            D7_B2    490004584S      0.00             1     -7.50
# 6            D7_B3    490000038F      0.00             1     -7.50
# 7            D7_B4    490006092S      8.00             2      0.50
# 8            D7_B5    490002048X      7.50             2      0.00
# 9            D7_B6    490013513N      6.76             3     -0.74
#
# Route SWT, AWT, EWT at time : 23:31
#
#  Time Line Id Direction  SWT      AWT      EWT
# 23:31      D7         A 7.14 10883.15 10876.01
# 23:31      D7         B 7.50     5.70    -1.80
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        5.00
# 1                           Number of buses observed        3.00
# 2                               Total WAWT (minutes)  1015397.00
# 3  Time difference between 1st and last observed ...       28.00
# 4                                      AWT (minutes)    36264.18
# 5                                      SWT (minutes)        6.00
# 6                                      EWT (minutes)    36258.18
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   72.0
# 3  Time difference between 1st and last observed ...   12.0
# 4                                      AWT (minutes)    6.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490004584S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490000038F:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    1.0
# 2                               Total WAWT (minutes)    0.0
# 3  Time difference between 1st and last observed ...    0.0
# 4                                      AWT (minutes)    0.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -7.5
#
#
# Summary Metrics for 490006092S:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  128.0
# 3  Time difference between 1st and last observed ...   16.0
# 4                                      AWT (minutes)    8.0
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513N:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)   84.5
# 3  Time difference between 1st and last observed ...   13.0
# 4                                      AWT (minutes)    6.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)   -1.0
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:32
#   Route_Dir_QSI_No Stop Point ID       AWT  No_Buses_Obs       EWT
# 0            D7_A1    490011107G      7.50             2      0.00
# 1            D7_A2    490013513S  36264.18             3  36258.18
# 2            D7_A3    490002048Z      6.00             2     -1.50
# 3            D7_A4    490006092N      6.00             2     -1.50
# 4            D7_A5    490004584N      0.00             1     -7.50
# 5            D7_B2    490004584S      0.00             1     -7.50
# 6            D7_B3    490000038F      0.00             1     -7.50
# 7            D7_B4    490006092S      8.00             2      0.50
# 8            D7_B5    490002048X      7.50             2      0.00
# 9            D7_B6    490013513N      6.50             2     -1.00
#
# Route SWT, AWT, EWT at time : 23:32
#
#  Time Line Id Direction  SWT      AWT      EWT
# 23:32      D7         A 7.14 10883.15 10876.01
# 23:32      D7         B 7.50     5.50    -2.00
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# 1                           Number of buses observed    2.0
# 2                               Total WAWT (minutes)  112.5
# 3  Time difference between 1st and last observed ...   15.0
# 4                                      AWT (minutes)    7.5
# 5                                      SWT (minutes)    7.5
# 6                                      EWT (minutes)    0.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        5.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1015312.5
# 3  Time difference between 1st and last observed ...       15.0
# 4                                      AWT (minutes)    67687.5
# 5                                      SWT (minutes)        6.0
# 6                                      EWT (minutes)    67681.5
#
#
# Summary Metrics for 490002048Z:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)    4.0
# ...
# 3  Time difference between 1st and last observed ...       12.0
# 4                                      AWT (minutes)    84966.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    84958.5
#
#
# Summary Metrics for 490015151H:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1015312.5
# 3  Time difference between 1st and last observed ...       15.0
# 4                                      AWT (minutes)    67687.5
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    67680.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1015312.5
# 3  Time difference between 1st and last observed ...       15.0
# 4                                      AWT (minutes)    67687.5
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    67680.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        4.00
# 1                           Number of buses observed        2.00
# 2                               Total WAWT (minutes)  1016738.00
# 3  Time difference between 1st and last observed ...       14.00
# 4                                      AWT (minutes)    72624.14
# 5                                      SWT (minutes)        7.50
# 6                                      EWT (minutes)    72616.64
#
#
# Summary Metrics for 490006092S:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        4.00
# 1                           Number of buses observed        2.00
# 2                               Total WAWT (minutes)  1012464.50
# 3  Time difference between 1st and last observed ...       17.00
# 4                                      AWT (minutes)    59556.74
# 5                                      SWT (minutes)        7.50
# 6                                      EWT (minutes)    59549.24
#
#
# Summary Metrics for 490002048X:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        4.00
# 1                           Number of buses observed        2.00
# 2                               Total WAWT (minutes)  1012464.50
# 3  Time difference between 1st and last observed ...       17.00
# 4                                      AWT (minutes)    59556.74
# 5                                      SWT (minutes)        7.50
# 6                                      EWT (minutes)    59549.24
#
#
# Summary Metrics for 490013513N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1013888.0
# 3  Time difference between 1st and last observed ...       16.0
# 4                                      AWT (minutes)    63368.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    63360.5
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:45
#    Route_Dir_QSI_No Stop Point ID       AWT  No_Buses_Obs       EWT
# 0             D7_A1    490011107G  67687.50             2  67680.00
# 1             D7_A2    490013513S  84966.00             2  84960.00
# 2             D7_A3    490002048Z  92820.05             2  92812.55
# 3             D7_A4    490006092N  84966.00             2  84958.50
# 4             D7_A5    490004584N  84966.00             2  84958.50
# 5             D7_B1    490015151H  67687.50             2  67680.00
# 6             D7_B2    490004584S  67687.50             2  67680.00
# 7             D7_B3    490000038F  72624.14             2  72616.64
# 8             D7_B4    490006092S  59556.74             2  59549.24
# 9             D7_B5    490002048X  59556.74             2  59549.24
# 10            D7_B6    490013513N  63368.00             2  63360.50
#
# Route SWT, AWT, EWT at time : 23:45
#
#  Time Line Id Direction  SWT      AWT      EWT
# 23:45      D7         A 7.14 83081.11 83073.97
# 23:45      D7         B 7.50 65080.10 65072.60
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1015312.5
# 3  Time difference between 1st and last observed ...       15.0
# 4                                      AWT (minutes)    67687.5
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    67680.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        5.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1019592.0
# 3  Time difference between 1st and last observed ...       12.0
# 4                                      AWT (minutes)    84966.0
# 5                                      SWT (minutes)        6.0
# 6                                      EWT (minutes)    84960.0
#
#
# Summary Metrics for 490002048Z:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1022450.0
# 3  Time difference between 1st and last observed ...       10.0
# 4                                      AWT (minutes)   102245.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)   102237.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1019592.0
# 3  Time difference between 1st and last observed ...       12.0
# 4                                      AWT (minutes)    84966.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    84958.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        4.00
# 1                           Number of buses observed        2.00
# 2                               Total WAWT (minutes)  1021020.50
# 3  Time difference between 1st and last observed ...       11.00
# 4                                      AWT (minutes)    92820.05
# 5                                      SWT (minutes)        7.50
# 6                                      EWT (minutes)    92812.55
#
#
# Summary Metrics for 490015151H:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1015312.5
# 3  Time difference between 1st and last observed ...       15.0
# 4                                      AWT (minutes)    67687.5
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    67680.0
#
#
# Summary Metrics for 490004584S:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1015312.5
# 3  Time difference between 1st and last observed ...       15.0
# 4                                      AWT (minutes)    67687.5
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    67680.0
#
#
# Summary Metrics for 490000038F:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        4.00
# 1                           Number of buses observed        2.00
# 2                               Total WAWT (minutes)  1016738.00
# 3  Time difference between 1st and last observed ...       14.00
# 4                                      AWT (minutes)    72624.14
# 5                                      SWT (minutes)        7.50
# 6                                      EWT (minutes)    72616.64
#
#
# Summary Metrics for 490006092S:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1013888.0
# 3  Time difference between 1st and last observed ...       16.0
# 4                                      AWT (minutes)    63368.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    63360.5
#
#
# Summary Metrics for 490002048X:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        4.00
# 1                           Number of buses observed        2.00
# 2                               Total WAWT (minutes)  1012464.50
# 3  Time difference between 1st and last observed ...       17.00
# 4                                      AWT (minutes)    59556.74
# 5                                      SWT (minutes)        7.50
# 6                                      EWT (minutes)    59549.24
#
#
# Summary Metrics for 490013513N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1013888.0
# 3  Time difference between 1st and last observed ...       16.0
# 4                                      AWT (minutes)    63368.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    63360.5
#
#
# SWT DataFrame at hour 23
#    Route_Dir_QSI_No          ID  SWT  No_Buses_Sch
# 0             D7_A1  490011107G  7.5             4
# 1             D7_A2  490013513S  6.0             5
# 2             D7_A3  490002048Z  7.5             4
# 3             D7_A4  490006092N  7.5             4
# 4             D7_A5  490004584N  7.5             4
# 5             D7_B1  490015151H  7.5             4
# 6             D7_B2  490004584S  7.5             4
# 7             D7_B3  490000038F  7.5             4
# 8             D7_B4  490006092S  7.5             4
# 9             D7_B5  490002048X  7.5             4
# 10            D7_B6  490013513N  7.5             4
#
#
# AWT DataFrame at hour 23:45
#    Route_Dir_QSI_No Stop Point ID        AWT  No_Buses_Obs        EWT
# 0             D7_A1    490011107G   67687.50             2   67680.00
# 1             D7_A2    490013513S   84966.00             2   84960.00
# 2             D7_A3    490002048Z  102245.00             2  102237.50
# 3             D7_A4    490006092N   84966.00             2   84958.50
# 4             D7_A5    490004584N   92820.05             2   92812.55
# 5             D7_B1    490015151H   67687.50             2   67680.00
# 6             D7_B2    490004584S   67687.50             2   67680.00
# 7             D7_B3    490000038F   72624.14             2   72616.64
# 8             D7_B4    490006092S   63368.00             2   63360.50
# 9             D7_B5    490002048X   59556.74             2   59549.24
# 10            D7_B6    490013513N   63368.00             2   63360.50
#
# Route SWT, AWT, EWT at time : 23:45
#
#  Time Line Id Direction  SWT      AWT      EWT
# 23:45      D7         A 7.14 86536.91 86529.77
# 23:45      D7         B 7.50 65715.31 65707.81
# Data appended to /content/route_EWT_A.csv and /content/route_EWT_B.csv
#
#
# Waiting to fetch updated data...
#
#
#
#
# Summary Metrics for 490011107G:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1015312.5
# 3  Time difference between 1st and last observed ...       15.0
# 4                                      AWT (minutes)    67687.5
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    67680.0
#
#
# Summary Metrics for 490013513S:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        5.00
# 1                           Number of buses observed        3.00
# 2                               Total WAWT (minutes)  1021133.00
# 3  Time difference between 1st and last observed ...       26.00
# 4                                      AWT (minutes)    39274.35
# 5                                      SWT (minutes)        6.00
# 6                                      EWT (minutes)    39268.35
#
#
# Summary Metrics for 490002048Z:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1022450.0
# 3  Time difference between 1st and last observed ...       10.0
# 4                                      AWT (minutes)   102245.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)   102237.5
#
#
# Summary Metrics for 490006092N:
#                                               Metric      Value
# 0          Number of buses scheduled per hour (nbph)        4.0
# 1                           Number of buses observed        2.0
# 2                               Total WAWT (minutes)  1019592.0
# 3  Time difference between 1st and last observed ...       12.0
# 4                                      AWT (minutes)    84966.0
# 5                                      SWT (minutes)        7.5
# 6                                      EWT (minutes)    84958.5
#
#
# Summary Metrics for 490004584N:
#                                               Metric       Value
# 0          Number of buses scheduled per hour (nbph)        4.00
# 1                           Number of buses observed        2.00
# 2                               Total WAWT (minutes)  1021020.50
# 3  Time difference between 1st and last observed ...       11.00
# 4                                      AWT (minutes)    92820.05
# 5                                      SWT (minutes)        7.50
# 6                                      EWT (minutes)    92812.55
