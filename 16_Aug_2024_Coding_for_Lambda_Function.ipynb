# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaVKarthikeyan/AA-Stagecoach-Project/blob/main/16_Aug_2024_Coding_for_Lambda_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time
import logging
import signal
import sys

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def fetch_data(url, retries=3):
    """Fetch data from a URL with retry logic."""
    for attempt in range(retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            return response.json()
        except requests.RequestException as e:
            logging.error(f"Error fetching data from {url}: {e}")
            if attempt < retries - 1:
                time.sleep(2)  # Backoff before retrying
            else:
                return None

def save_data(df_routes, df_arrivals):
    """Save the DataFrames to CSV files."""
    df_routes.to_csv('all_bus_routes.csv', index=False)
    df_arrivals.to_csv('live_bus_arrivals.csv', index=False)
    logging.info("Data saved to CSV files.")

def signal_handler(sig, frame):
    """Handle interruptions and save data."""
    logging.info("Interrupted! Saving data...")
    save_data(pd.DataFrame(all_routes), pd.DataFrame(live_arrivals))
    sys.exit(0)

# Register the signal handler for interruptions
signal.signal(signal.SIGINT, signal_handler)

# Initialize variables
all_routes = []
live_arrivals = []

try:
    # Step 1: Fetch all bus lines in London
    bus_lines_url = "https://api.tfl.gov.uk/Line/Mode/bus"
    bus_lines = fetch_data(bus_lines_url)

    if bus_lines:
        bus_line_ids = [line['id'] for line in bus_lines]
        logging.info(f"Retrieved {len(bus_line_ids)} bus lines.")
    else:
        logging.error("Failed to retrieve bus lines data.")
        bus_line_ids = []

    # Step 2: Fetch stop points and live arrivals for each bus line
    for line_id in bus_line_ids:
        for direction in ['inbound', 'outbound']:
            route_url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
            route_data = fetch_data(route_url)

            if route_data and route_data.get('stopPointSequences'):
                stop_points = route_data['stopPointSequences'][0]['stopPoint']

                for stop in stop_points:
                    stop['lineId'] = line_id
                    stop['direction'] = direction
                    all_routes.append(stop)

                    # Fetch live arrival data for each stop
                    stop_point_id = stop['id']
                    arrivals_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
                    arrivals_data = fetch_data(arrivals_url)

                    if arrivals_data:
                        for arrival in arrivals_data:
                            arrival['lineId'] = line_id
                            arrival['stopPointId'] = stop_point_id
                            live_arrivals.append(arrival)

                    # Small delay to avoid overwhelming the API
                    time.sleep(0.5)
            else:
                logging.warning(f"No stop point sequences found for line {line_id} in {direction} direction.")

        # Small delay between lines to avoid overwhelming the API
        time.sleep(1)

finally:
    # Ensure data is saved if the process ends
    save_data(pd.DataFrame(all_routes), pd.DataFrame(live_arrivals))
# Out:
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/1/Arrivals/490006180S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/1/Arrivals/490006180S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/1/Arrivals/490006180S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/1/Arrivals/490006180S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/1/Arrivals/490006180S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/1/Arrivals/490006180S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/1/Arrivals/490013939S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/1/Arrivals/490013939S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/1/Arrivals/490013939S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/1/Arrivals/490013939S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/1/Arrivals/490013939S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/1/Arrivals/490013939S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/1/Arrivals/490012664S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/1/Arrivals/490012664S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490000251W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490000251W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490000251W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490000251W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490000251W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490000251W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490006246W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490006246W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490006246W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490006246W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490014016N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490014016N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490013687K: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490013687K
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/100/Arrivals/490012020A: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/100/Arrivals/490012020A
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490009682N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490009682N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490009682N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490009682N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490009682N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490009682N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490006358N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490006358N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490004881J: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490004881J
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490004653S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490004653S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490003921S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490003921S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490011801S1: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490011801S1
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490006360R: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490006360R
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490006360R: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490006360R
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490006360R: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490006360R
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490010218V: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490010218V
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/101/Arrivals/490006359S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/101/Arrivals/490006359S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490000067E: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490000067E
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490005509N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490005509N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490000028C: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490000028C
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490000028C: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490000028C
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490000028C: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490000028C
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490004490N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490004490N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490009800E: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490009800E
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490015301E: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490015301E
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490009357E: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490009357E
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490005509S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490005509S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490013880L: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490013880L
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490013880L: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490013880L
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490013880L: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490013880L
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490013254J: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490013254J
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490009967W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490009967W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490014478W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490014478W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/102/Arrivals/490003723W: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/102/Arrivals/490003723W
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490005834N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490005834N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490001243V: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490001243V
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490011659H: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490011659H
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490007262N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490007262N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490010016S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490010016S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490009715S: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490009715S
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490011667HD: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490011667HD
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490000058B: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490000058B
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490000058B: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490000058B
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/103/Arrivals/490009126E: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/103/Arrivals/490009126E
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/104/Arrivals/490003151R: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/104/Arrivals/490003151R
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/104/Arrivals/490011052N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/104/Arrivals/490011052N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/104/Arrivals/490011052M: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/104/Arrivals/490011052M
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/104/Arrivals/490011052M: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/104/Arrivals/490011052M
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/104/Arrivals/490013958F: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/104/Arrivals/490013958F
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/105/Arrivals/490013235N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/105/Arrivals/490013235N
# ERROR:root:Error fetching data from https://api.tfl.gov.uk/Line/105/Arrivals/490007802N: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/105/Arrivals/490007802N
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
