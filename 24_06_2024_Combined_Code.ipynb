# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaVKarthikeyan/AA-Stagecoach-Project/blob/main/24_06_2024_Combined_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv
import re
import time
from datetime import datetime, timedelta
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pytz

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)

                if all_stop_details:
                    # Write to CSV file
                    write_to_csv(all_stop_details)

                    # Display data from CSV file
                    display_data_from_csv()

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and appending stop details using the lat and lon
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                time.sleep(2**attempt)  # Exponential backoff
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Append to all_stop_details only if stop ID has not been printed before
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })

                        # Add stop ID to printed set
                        printed_stop_ids.add(stop_id)

            else:
                # If no stop points found, continue to next attempt
                continue

            break  # Exit loop if successful

        else:
            # If maximum retries exceeded, handle quietly (you can add logging or alternative handling here)
            pass

    except requests.exceptions.RequestException as e:
        # Handle other request exceptions (you can add logging or alternative handling here)
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']

    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

def display_data_from_csv():
    print("Data from CSV:")

    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)

        # Print headers
        headers_printed = False

        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')  # BST timezone for London

    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)

    return bst_dt.strftime('%H:%M:%S')

def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}

        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        data = response.json()

        if len(data) == 0:
            print("No arrival predictions found.")
            return None, None

        station_name = data[0]['stationName']

        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)  # Convert GMT to BST
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')  # Format to HH:MM
            })

        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))

        return df, station_name

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None  # Return None if there's an error

def create_dashboard(df, station_name):
    current_time_utc = datetime.utcnow()
    current_time_bst = convert_to_bst(current_time_utc)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=[current_time_bst],
        y=[0],
        mode='markers+text',
        marker=dict(size=40, symbol='square', color='black'),
        name='Stop Point',
        text=f"{current_time_bst}",  # Display only the current time below the square
        textposition='bottom center',
        hoverinfo='text'
    ))

    fig.add_annotation(
        x=current_time_bst,
        y=0,
        text=f"{station_name}<br>{stop_point_id}",
        showarrow=False,
        font=dict(size=14, color="black"),
        yshift=40  # Adjust the yshift to move the label above the square
    )

    y_gap = 0.01  # 1 cm gap in graph units
    for i, row in df.iterrows():
        y_pos = 0 + (i + 1) * y_gap

        fig.add_trace(go.Scatter(
            x=[row['Expected Arrival (BST)']],
            y=[y_pos],
            mode='markers+text',
            marker=dict(size=20, symbol='arrow-bar-down', color='blue'),
            name='Bus Arrival',
            text=f"Bus ID: {row['Vehicle ID']}<br>Arrival Time: {row['Expected Arrival (BST)']}",
            textposition='top center',
            hoverinfo='text'
        ))

    fig.update_layout(
        title=f"Expected Bus Arrivals at {station_name}",
        xaxis_title="Time",
        yaxis_title="",
        yaxis=dict(showticklabels=False),
        showlegend=False,
        height=400,
        margin=dict(l=0, r=0, t=40, b=0)
    )

    fig.show()

# Sample Inputs
line_id = input("Enter the Line ID (e.g., 205, 25): ")
direction = input("Enter the direction (inbound or outbound): ")
buses_per_hour = int(input("Enter the number of buses per hour: "))

fetch_route_details(line_id, direction)

df_stops = pd.read_csv('stop_details.csv')

print(df_stops)

selected_stop_input = input("Enter the row number, stop ID, or stop name of the stop you're interested in: ")

if selected_stop_input.isdigit():
    selected_stop = df_stops.loc[df_stops['Sl. No.'] == int(selected_stop_input)]
else:
    selected_stop = df_stops.loc[
        (df_stops['Stop ID'].str.contains(selected_stop_input, case=False)) |
        (df_stops['Stop Name'].str.contains(selected_stop_input, case=False))
    ]

if selected_stop.empty:
    print("No matching stop found.")
else:
    stop_point_id = selected_stop.iloc[0]['Stop ID']
    stop_point_name = selected_stop.iloc[0]['Stop Name']

    df_predictions, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)

    if df_predictions is not None:
        print(df_predictions)
        create_dashboard(df_predictions, station_name)
# Out:
# Enter the Line ID (e.g., 205, 25): 214
# Enter the direction (inbound or outbound): inbound
# Enter the number of buses per hour: 6
# Direction: inbound
# Origination Name: Finsbury Square
# Destination Name: Highgate School
# Originator: 490015209C
# Destination: 490008160N
# ---
# Data written to 'stop_details.csv' successfully.
# Data from CSV:
# 1      490015209K Finsbury Square / Moorgate
# 2      490015209C Finsbury Square
# 3      490006850J Finsbury Square / Moorgate
# 4      490006850G Finsbury Square
# 5      490006850H Finsbury Square
# 6      490003831E Finsbury Street
# 7      490015209D Finsbury Square
# 8      490003831W Finsbury Street
# 9      490000149B Moorgate Station
# 10     490000149M Moorgate
# 11     490006850F Finsbury Square
# 12     490006612E Epworth Street
# 13     490000169ZA Old Street Station
# 14     490015195N Old Street
# 15     490015195M City Road / Leonard Street
# 16     490000169K Shoreditch Fire Station
# 17     490015194F Old Street Station
# 18     490000169L Old Street Station
# 19     490010109E Old Street Roundabout
# 20     490015194G Bunhill Row
# 21     490015193S Old Street Station
# 22     490015193D Old Street Stn   / Moorfields Eye Hosp
# 23     490010108C Old Street Station
# 24     490011249A Moorfields Eye Hospital
# 25     490010012N Moorfields Eye Hospital
# 26     490018497N Bath Street
# 27     490010012E Moorfields Eye Hospital
# 28     490014780W Windsor Terrace
# 29     490014780E Windsor Terrace
# 30     490016371N Shoreditch Police Station
# 31     490018499N Ironmonger Row  Norman Street
# 32     490016371S Shoreditch Police Station
# 33     490018498W Radnor Street  Lizard Street
# 34     490004937W Central Street
# 35     490004937E Central Street
# 36     490006309S Hall Street
# 37     490015107S City University
# 38     490003327K Angel Islington
# 39     490003327H Angel Islington / City Road
# 40     490003327J Angel Islington
# 41     490013229M St John Street / Goswell Road
# 42     490013229P St John Street / Goswell Road
# 43     490011678SA Rosebery Avenue / Sadler's Wells Theatre
# 44     490000007R Pentonville Road / Baron Street
# 45     490015108S Angel Station
# 46     490010926S Penton Rise
# 47     490005904W Penton Rise
# 48     490005904E Penton Rise
# 49     490010928E Penton Street
# 50     490018490  Percy Circus
# 51     490010929L King's Cross Road / Pentonville Road
# 52     490001172K King's Cross Road
# 53     490004354N Swinton Street
# 54     490001172X King's Cross / Caledonian Road
# 55     490000129R King's Cross Station
# 56     490013117O Swinton Street
# 57     490001171H King's Cross Stn   / Pentonville Rd
# 58     490000129D King's Cross Station
# 59     490000129E King's Cross Station
# 60     490005916N King's Cross Station   / York Way
# 61     490001171G King's Cross Station   / York Way
# 62     490012553B St Pancras Intern'l & King's X Stns
# 63     490004722M St Pancras International Station
# 64     490004722A St Pancras International Station
# 65     490004722W St Pancras International Station
# 66     490001276S St Pancras International Station
# 67     490018897  St Pancras Olympic Shuttle
# 68     490001276Z St Pancras International Station
# 69     490016573N Chenies Place
# 70     490016573S Chenies Place
# 71     490012870W St Pancras Old Church
# 72     490012869S St Pancras Hospital
# 73     490011756W Royal College Street
# 74     490011756E Royal College Street
# 75     490011057H Oakley Square
# 76     490005493N Royal Veterinary College
# 77     490000152K Mornington Crescent Station
# 78     490000152G Mornington Cres Stn / Camden Tn Library
# 79     490000152F Mornington Cres Stn / Camden Tn Library
# 80     490000152C Mornington Crescent Station
# 81     490000152D Mornington Crescent Station
# 82     490000152A Mornington Crescent Station
# 83     490011057L Plender Street
# 84     490004714E Camden High Street
# 85     490015384V Pratt Street
# 86     490004714J Camden High Street
# 87     490011168S2 Pratt Street
# 88     490011168S1 Pratt Street
# 89     490003380N Arlington Road
# 90     490015041Y Camden Town Station
# 91     490003698W Bayham Street
# 92     490015041X Camden Town Station
# 93     490015531T Camden Town Station  / Bayham Street
# 94     490015041Q Camden High Street
# 95     490015531S Camden Town Station
# 96     490000036Z Camden Town Station
# 97     490000036S Camden Town Station
# 98     490000036L Kentish Town Road
# 99     490000036R Camden Town Station / Camden Street
# 100    490000036N Camden Town / Camden Road
# 101    490004713D Camden Gardens
# 102    490004713E Camden Gardens
# 103    490007927A Hawley Road
# 104    490001045E Royal College Street / Ivor Street
# 105    490001045G Camden Road Station
# 106    490011755S Royal College Street
# 107    490008663W Kentish Town Road
# 108    490007927M Hawley Road
# 109    490011199S Kentish Town Road / Prince of Wales Road
# 110    490011199R Prince of Wales Road
# 111    490015246N Kentish Town Road
# 112    490007082K Kentish Town Post Office
# 113    490004894L Kentish Town Post Office
# 114    490000123A Kentish Town Station
# 115    490000123E Kentish Town Station
# 116    490000123B Kentish Town Station
# 117    490006943E Fortess Road
# 118    490008662G Fortess Walk
# 119    490008661N Fortess Walk
# 120    490008660S Greenwood Centre
# 121    490008660N Lady Somerset Road
# 122    490015367S Lady Somerset Road
# 123    490007308N Gordon House Road
# 124    490007308W Gordon House Road
# 125    490005974S Gordon House Road
# 126    490007308E Gordon House Road
# 127    490005974N Glenhurst Avenue / Lissenden Gardens
# 128    490014902N William Ellis School
# 129    490014697S William Ellis School
# 130    490015528S1 Parliament Hill Fields
# 131    490010852S2 Parliament Hill Fields
# 132    490010852N1 Parliament Hill Fields
# 133    490010852N Parliament Hill Fields
# 134    490008306E Swains Lane
# 135    490010482N Oakeshott Avenue
# 136    490010482S Oakeshott Avenue
# 137    490015831S Holly Lodge Gardens
# 138    490009837N Merton Lane
# 139    490012812V St Michael's Church
# 140    490016698N Pond Square
# 141    490012303W South Grove
# 142    490012303N South Grove
# 143    490012303E South Grove
# 144    49008160Z1 Highgate School / Hampstead Lane
# 145    490008160S Highgate School
# 146    490008160N Highgate School
# 147    490008158W Highgate Close
#      Sl. No.     Stop ID                         Stop Name
# 0          1  490015209K        Finsbury Square / Moorgate
# 1          2  490015209C                   Finsbury Square
# 2          3  490006850J        Finsbury Square / Moorgate
# 3          4  490006850G                   Finsbury Square
# 4          5  490006850H                   Finsbury Square
# ..       ...         ...                               ...
# 142      143  490012303E                       South Grove
# 143      144  49008160Z1  Highgate School / Hampstead Lane
# 144      145  490008160S                   Highgate School
# 145      146  490008160N                   Highgate School
# 146      147  490008158W                    Highgate Close
#
# [147 rows x 3 columns]
# Enter the row number, stop ID, or stop name of the stop you're interested in: 25
#   Line Vehicle ID  Stop Point Direction Expected Arrival (BST)  \
# 3  214    LA19KBV  490010012N   inbound               17:06:00
# 1  214    LA19KBK  490010012N   inbound               17:13:00
# 0  214    LA19KAO  490010012N   inbound               17:21:00
# 2  214    LA19KBN  490010012N   inbound               17:28:00
#
#   Expected Arrival (HM)  Headway (minutes)  AWT/bus (minutes)  WAWT
# 3   1900-01-01 17:06:00                0.0                0.0   0.0
# 1   1900-01-01 17:13:00                7.0                3.5  24.5
# 0   1900-01-01 17:21:00                8.0                4.0  32.0
# 2   1900-01-01 17:28:00                7.0                3.5  24.5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f9a352da-bc6c-4d81-9c9a-c0206b122fbb" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9a352da-bc6c-4d81-9c9a-c0206b122fbb")) {                    Plotly.newPlot(                        "f9a352da-bc6c-4d81-9c9a-c0206b122fbb",                        [{"hoverinfo":"text","marker":{"color":"black","size":40,"symbol":"square"},"mode":"markers+text","name":"Stop Point","text":"17:02:46","textposition":"bottom center","x":["17:02:46"],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KBV\u003cbr\u003eArrival Time: 17:06:00","textposition":"top center","x":["17:06:00"],"y":[0.04],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KBK\u003cbr\u003eArrival Time: 17:13:00","textposition":"top center","x":["17:13:00"],"y":[0.02],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KAO\u003cbr\u003eArrival Time: 17:21:00","textposition":"top center","x":["17:21:00"],"y":[0.01],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KBN\u003cbr\u003eArrival Time: 17:28:00","textposition":"top center","x":["17:28:00"],"y":[0.03],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...

# %%
import requests
import csv
import re
import time
from datetime import datetime, timedelta
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pytz

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)

                if all_stop_details:
                    # Write to CSV file
                    write_to_csv(all_stop_details)

                    # Display data from CSV file
                    display_data_from_csv()

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and appending stop details using the lat and lon
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                time.sleep(2**attempt)  # Exponential backoff
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Append to all_stop_details only if stop ID has not been printed before
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })

                        # Add stop ID to printed set
                        printed_stop_ids.add(stop_id)

            else:
                # If no stop points found, continue to next attempt
                continue

            break  # Exit loop if successful

        else:
            # If maximum retries exceeded, handle quietly (you can add logging or alternative handling here)
            pass

    except requests.exceptions.RequestException as e:
        # Handle other request exceptions (you can add logging or alternative handling here)
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']

    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

def display_data_from_csv():
    print("Data from CSV:")

    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)

        # Print headers
        headers_printed = False

        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')  # BST timezone for London

    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)

    return bst_dt.strftime('%H:%M:%S')

def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}

        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        data = response.json()

        if len(data) == 0:
            print("No arrival predictions found.")
            return None, None

        station_name = data[0]['stationName']

        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)  # Convert GMT to BST
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')  # Format to HH:MM
            })

        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))

        return df, station_name

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None  # Return None if there's an error

def create_dashboard(df, station_name):
    current_time_utc = datetime.utcnow()
    current_time_bst = convert_to_bst(current_time_utc)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=[current_time_bst],
        y=[0],
        mode='markers+text',
        marker=dict(size=40, symbol='square', color='black'),
        name='Stop Point',
        text=f"{current_time_bst}",  # Display only the current time below the square
        textposition='bottom center',
        hoverinfo='text'
    ))

    fig.add_annotation(
        x=current_time_bst,
        y=0,
        text=f"{station_name}<br>{stop_point_id}",
        showarrow=False,
        font=dict(size=14, color="black"),
        yshift=40  # Adjust the yshift to move the label above the square
    )

    y_gap = 0.01  # 1 cm gap in graph units
    for i, row in df.iterrows():
        y_pos = 0 + (i + 1) * y_gap

        fig.add_trace(go.Scatter(
            x=[row['Expected Arrival (BST)']],
            y=[y_pos],
            mode='markers+text',
            marker=dict(size=20, symbol='arrow-bar-down', color='blue'),
            name='Bus Arrival',
            text=f"Bus ID: {row['Vehicle ID']}<br>Arrival Time: {row['Expected Arrival (BST)']}",
            textposition='top center',
            hoverinfo='text'
        ))

    fig.update_layout(
        title=f"Expected Bus Arrivals at {station_name}",
        xaxis_title="Time",
        yaxis_title="",
        yaxis=dict(showticklabels=False),
        showlegend=False,
        height=400,
        margin=dict(l=0, r=0, t=40, b=0)
    )

    fig.show()

def calculate_summary_metrics(dfs):
    concatenated_df = pd.concat(dfs)
    summary = concatenated_df.describe(include='all')
    return summary

# Sample Inputs
line_id = input("Enter the Line ID (e.g., 205, 25): ")
direction = input("Enter the direction (inbound or outbound): ")
buses_per_hour = int(input("Enter the number of buses per hour: "))

fetch_route_details(line_id, direction)

df_stops = pd.read_csv('stop_details.csv')

print(df_stops)

selected_stop_input = input("Enter the row numbers, stop IDs, or stop names of the stops you're interested in (comma separated): ")
selected_stops = [item.strip() for item in selected_stop_input.split(',')]

matching_stops = pd.DataFrame()

for stop in selected_stops:
    if stop.isdigit():
        matching_stops = matching_stops.append(df_stops.loc[df_stops['Sl. No.'] == int(stop)], ignore_index=True)
    else:
        matching_stops = matching_stops.append(
            df_stops.loc[
                (df_stops['Stop ID'].str.contains(stop, case=False)) |
                (df_stops['Stop Name'].str.contains(stop, case=False))
            ], ignore_index=True
        )

if matching_stops.empty:
    print("No matching stops found.")
else:
    df_predictions_list = []
    for index, stop_row in matching_stops.iterrows():
        stop_point_id = stop_row['Stop ID']
        stop_point_name = stop_row['Stop Name']
        df_predictions, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
        if df_predictions is not None:
            df_predictions_list.append(df_predictions)
            create_dashboard(df_predictions, stop_point_name)

    if df_predictions_list:
        summary_metrics = calculate_summary_metrics(df_predictions_list)
        print("Summary Metrics:")
        print(summary_metrics)
# Out:
# Enter the Line ID (e.g., 205, 25): 214
# Enter the direction (inbound or outbound): inbound
# Enter the number of buses per hour: 6
# Direction: inbound
# Origination Name: Finsbury Square
# Destination Name: Highgate School
# Originator: 490015209C
# Destination: 490008160N
# ---
# Data written to 'stop_details.csv' successfully.
# Data from CSV:
# 1      490015209K Finsbury Square / Moorgate
# 2      490015209C Finsbury Square
# 3      490006850J Finsbury Square / Moorgate
# 4      490006850G Finsbury Square
# 5      490006850H Finsbury Square
# 6      490003831E Finsbury Street
# 7      490015209D Finsbury Square
# 8      490003831W Finsbury Street
# 9      490000149B Moorgate Station
# 10     490000149M Moorgate
# 11     490006850F Finsbury Square
# 12     490006612E Epworth Street
# 13     490000169ZA Old Street Station
# 14     490015195N Old Street
# 15     490015195M City Road / Leonard Street
# 16     490000169K Shoreditch Fire Station
# 17     490015194F Old Street Station
# 18     490000169L Old Street Station
# 19     490010109E Old Street Roundabout
# 20     490015194G Bunhill Row
# 21     490015193S Old Street Station
# 22     490015193D Old Street Stn   / Moorfields Eye Hosp
# 23     490010108C Old Street Station
# 24     490011249A Moorfields Eye Hospital
# 25     490010012N Moorfields Eye Hospital
# 26     490018497N Bath Street
# 27     490010012E Moorfields Eye Hospital
# 28     490014780W Windsor Terrace
# 29     490014780E Windsor Terrace
# 30     490016371N Shoreditch Police Station
# 31     490018499N Ironmonger Row  Norman Street
# 32     490016371S Shoreditch Police Station
# 33     490018498W Radnor Street  Lizard Street
# 34     490004937W Central Street
# 35     490004937E Central Street
# 36     490006309S Hall Street
# 37     490015107S City University
# 38     490003327K Angel Islington
# 39     490003327H Angel Islington / City Road
# 40     490003327J Angel Islington
# 41     490013229M St John Street / Goswell Road
# 42     490013229P St John Street / Goswell Road
# 43     490011678SA Rosebery Avenue / Sadler's Wells Theatre
# 44     490000007R Pentonville Road / Baron Street
# 45     490015108S Angel Station
# 46     490010928W Penton Street / Chapel Market
# 47     490018488S Claremont Square
# 48     490018488N Claremont Square
# 49     490003650T Baron Street / Chapel Market
# 50     490018489W Cruikshank Street  Amwell St
# 51     490018498E Cruikshank Street  Amwell St
# 52     490010928E Penton Street
# 53     490010926S Penton Rise
# 54     490005904W Penton Rise
# 55     490005904E Penton Rise
# 56     490018490  Percy Circus
# 57     490010929L King's Cross Road / Pentonville Road
# 58     490001172K King's Cross Road
# 59     490004354N Swinton Street
# 60     490001172X King's Cross / Caledonian Road
# 61     490000129R King's Cross Station
# 62     490013117O Swinton Street
# 63     490001171H King's Cross Stn   / Pentonville Rd
# 64     490000129D King's Cross Station
# 65     490000129E King's Cross Station
# 66     490005916N King's Cross Station   / York Way
# 67     490001171G King's Cross Station   / York Way
# 68     490012553B St Pancras Intern'l & King's X Stns
# 69     490004722M St Pancras International Station
# 70     490004722A St Pancras International Station
# 71     490004722W St Pancras International Station
# 72     490001276S St Pancras International Station
# 73     490018897  St Pancras Olympic Shuttle
# 74     490001276Z St Pancras International Station
# 75     490016573N Chenies Place
# 76     490016573S Chenies Place
# 77     490012870W St Pancras Old Church
# 78     490012869S St Pancras Hospital
# 79     490011756W Royal College Street
# 80     490011756E Royal College Street
# 81     490011057H Oakley Square
# 82     490005493N Royal Veterinary College
# 83     490000152K Mornington Crescent Station
# 84     490000152G Mornington Cres Stn / Camden Tn Library
# 85     490000152F Mornington Cres Stn / Camden Tn Library
# 86     490000152C Mornington Crescent Station
# 87     490000152D Mornington Crescent Station
# 88     490000152A Mornington Crescent Station
# 89     490011057L Plender Street
# 90     490004714E Camden High Street
# 91     490004714J Camden High Street
# 92     490011168S1 Pratt Street
# 93     490011168S2 Pratt Street
# 94     490015384V Pratt Street
# 95     490003380N Arlington Road
# 96     490015041Y Camden Town Station
# 97     490003698W Bayham Street
# 98     490015041X Camden Town Station
# 99     490015531T Camden Town Station  / Bayham Street
# 100    490015041Q Camden High Street
# 101    490015531S Camden Town Station
# 102    490000036Z Camden Town Station
# 103    490000036S Camden Town Station
# 104    490000036L Kentish Town Road
# 105    490000036R Camden Town Station / Camden Street
# 106    490000036N Camden Town / Camden Road
# 107    490004713D Camden Gardens
# 108    490004713E Camden Gardens
# 109    490007927A Hawley Road
# 110    490001045E Royal College Street / Ivor Street
# 111    490001045G Camden Road Station
# 112    490011755S Royal College Street
# 113    490008663W Kentish Town Road
# 114    490007927M Hawley Road
# 115    490011199S Kentish Town Road / Prince of Wales Road
# 116    490011199R Prince of Wales Road
# 117    490015246N Kentish Town Road
# 118    490007082K Kentish Town Post Office
# 119    490004894L Kentish Town Post Office
# 120    490000123A Kentish Town Station
# 121    490000123E Kentish Town Station
# 122    490000123B Kentish Town Station
# 123    490006943E Fortess Road
# 124    490008662G Fortess Walk
# 125    490008661N Fortess Walk
# 126    490008660S Greenwood Centre
# 127    490008660N Lady Somerset Road
# 128    490015367S Lady Somerset Road
# 129    490007308N Gordon House Road
# 130    490007308W Gordon House Road
# 131    490005974S Gordon House Road
# 132    490007308E Gordon House Road
# 133    490005974N Glenhurst Avenue / Lissenden Gardens
# 134    490014902N William Ellis School
# 135    490014697S William Ellis School
# 136    490015528S1 Parliament Hill Fields
# 137    490010852S2 Parliament Hill Fields
# 138    490010852N1 Parliament Hill Fields
# 139    490010852N Parliament Hill Fields
# 140    490008306E Swains Lane
# 141    490010482N Oakeshott Avenue
# 142    490010482S Oakeshott Avenue
# 143    490015831S Holly Lodge Gardens
# 144    490009837N Merton Lane
# 145    490012812V St Michael's Church
# 146    490016698N Pond Square
# 147    490012303W South Grove
# 148    490012303N South Grove
# 149    490012303E South Grove
# 150    49008160Z1 Highgate School / Hampstead Lane
# 151    490008160S Highgate School
# 152    490008160N Highgate School
# 153    490008158W Highgate Close
#      Sl. No.     Stop ID                         Stop Name
# 0          1  490015209K        Finsbury Square / Moorgate
# 1          2  490015209C                   Finsbury Square
# 2          3  490006850J        Finsbury Square / Moorgate
# 3          4  490006850G                   Finsbury Square
# 4          5  490006850H                   Finsbury Square
# ..       ...         ...                               ...
# 148      149  490012303E                       South Grove
# 149      150  49008160Z1  Highgate School / Hampstead Lane
# 150      151  490008160S                   Highgate School
# 151      152  490008160N                   Highgate School
# 152      153  490008158W                    Highgate Close
#
# [153 rows x 3 columns]
# Enter the row numbers, stop IDs, or stop names of the stops you're interested in (comma separated): 25,69
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ec0a8754ad5a> in <cell line: 285>()
#     285 for stop in selected_stops:
#     286     if stop.isdigit():
# --> 287         matching_stops = matching_stops.append(df_stops.loc[df_stops['Sl. No.'] == int(stop)], ignore_index=True)
#     288     else:
#     289         matching_stops = matching_stops.append(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import requests
import csv
import re
import time
from datetime import datetime, timedelta
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pytz

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)

                if all_stop_details:
                    # Write to CSV file
                    write_to_csv(all_stop_details)

                    # Display data from CSV file
                    display_data_from_csv()

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and appending stop details using the lat and lon
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                time.sleep(2**attempt)  # Exponential backoff
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Append to all_stop_details only if stop ID has not been printed before
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })

                        # Add stop ID to printed set
                        printed_stop_ids.add(stop_id)

            else:
                # If no stop points found, continue to next attempt
                continue

            break  # Exit loop if successful

        else:
            # If maximum retries exceeded, handle quietly (you can add logging or alternative handling here)
            pass

    except requests.exceptions.RequestException as e:
        # Handle other request exceptions (you can add logging or alternative handling here)
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']

    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

def display_data_from_csv():
    print("Data from CSV:")

    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)

        # Print headers
        headers_printed = False

        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')  # BST timezone for London

    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)

    return bst_dt.strftime('%H:%M:%S')

def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}

        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        data = response.json()

        if len(data) == 0:
            print("No arrival predictions found.")
            return None, None

        station_name = data[0]['stationName']

        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)  # Convert GMT to BST
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')  # Format to HH:MM
            })

        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))

        return df, station_name

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None  # Return None if there's an error

def create_dashboard(df, station_name):
    current_time_utc = datetime.utcnow()
    current_time_bst = convert_to_bst(current_time_utc)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=[current_time_bst],
        y=[0],
        mode='markers+text',
        marker=dict(size=40, symbol='square', color='black'),
        name='Stop Point',
        text=f"{current_time_bst}",  # Display only the current time below the square
        textposition='bottom center',
        hoverinfo='text'
    ))

    fig.add_annotation(
        x=current_time_bst,
        y=0,
        text=f"{station_name}<br>{stop_point_id}",
        showarrow=False,
        font=dict(size=14, color="black"),
        yshift=40  # Adjust the yshift to move the label above the square
    )

    y_gap = 0.01  # 1 cm gap in graph units
    for i, row in df.iterrows():
        y_pos = 0 + (i + 1) * y_gap

        fig.add_trace(go.Scatter(
            x=[row['Expected Arrival (BST)']],
            y=[y_pos],
            mode='markers+text',
            marker=dict(size=20, symbol='arrow-bar-down', color='blue'),
            name='Bus Arrival',
            text=f"Bus ID: {row['Vehicle ID']}<br>Arrival Time: {row['Expected Arrival (BST)']}",
            textposition='top center',
            hoverinfo='text'
        ))

    fig.update_layout(
        title=f"Expected Bus Arrivals at {station_name}",
        xaxis_title="Time",
        yaxis_title="",
        yaxis=dict(showticklabels=False),
        showlegend=False,
        height=400,
        margin=dict(l=0, r=0, t=40, b=0)
    )

    fig.show()

def calculate_summary_metrics(dfs):
    concatenated_df = pd.concat(dfs)
    summary = concatenated_df.describe(include='all')
    return summary

# Sample Inputs
line_id = input("Enter the Line ID (e.g., 205, 25): ")
direction = input("Enter the direction (inbound or outbound): ")
buses_per_hour = int(input("Enter the number of buses per hour: "))

fetch_route_details(line_id, direction)

df_stops = pd.read_csv('stop_details.csv')

print(df_stops)

selected_stop_input = input("Enter the row numbers, stop IDs, or stop names of the stops you're interested in (comma separated): ")
selected_stops = [item.strip() for item in selected_stop_input.split(',')]

matching_stops = pd.DataFrame()

for stop in selected_stops:
    if stop.isdigit():
        matching_stops = pd.concat([matching_stops, df_stops.loc[df_stops['Sl. No.'] == int(stop)]], ignore_index=True)
    else:
        matching_stops = pd.concat([
            matching_stops,
            df_stops.loc[
                (df_stops['Stop ID'].str.contains(stop, case=False)) |
                (df_stops['Stop Name'].str.contains(stop, case=False))
            ]
        ], ignore_index=True)

if matching_stops.empty:
    print("No matching stops found.")
else:
    df_predictions_list = []
    for index, stop_row in matching_stops.iterrows():
        stop_point_id = stop_row['Stop ID']
        stop_point_name = stop_row['Stop Name']
        df_predictions, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
        if df_predictions is not None:
            df_predictions_list.append(df_predictions)
            create_dashboard(df_predictions, stop_point_name)

    if df_predictions_list:
        summary_metrics = calculate_summary_metrics(df_predictions_list)
        print("Summary Metrics:")
        print(summary_metrics)
# Out:
# Enter the Line ID (e.g., 205, 25): 214
# Enter the direction (inbound or outbound): inbound
# Enter the number of buses per hour: 6
# Direction: inbound
# Origination Name: Finsbury Square
# Destination Name: Highgate School
# Originator: 490015209C
# Destination: 490008160N
# ---
# Data written to 'stop_details.csv' successfully.
# Data from CSV:
# 1      490015209K Finsbury Square / Moorgate
# 2      490015209C Finsbury Square
# 3      490006850J Finsbury Square / Moorgate
# 4      490006850G Finsbury Square
# 5      490006850H Finsbury Square
# 6      490003831E Finsbury Street
# 7      490015209D Finsbury Square
# 8      490003831W Finsbury Street
# 9      490000149B Moorgate Station
# 10     490000149M Moorgate
# 11     490006850F Finsbury Square
# 12     490006612E Epworth Street
# 13     490000169ZA Old Street Station
# 14     490015195N Old Street
# 15     490015195M City Road / Leonard Street
# 16     490000169K Shoreditch Fire Station
# 17     490015194F Old Street Station
# 18     490000169L Old Street Station
# 19     490010109E Old Street Roundabout
# 20     490015194G Bunhill Row
# 21     490015193S Old Street Station
# 22     490015193D Old Street Stn   / Moorfields Eye Hosp
# 23     490010108C Old Street Station
# 24     490011249A Moorfields Eye Hospital
# 25     490010012N Moorfields Eye Hospital
# 26     490018497N Bath Street
# 27     490010012E Moorfields Eye Hospital
# 28     490014780W Windsor Terrace
# 29     490014780E Windsor Terrace
# 30     490016371N Shoreditch Police Station
# 31     490018499N Ironmonger Row  Norman Street
# 32     490016371S Shoreditch Police Station
# 33     490018498W Radnor Street  Lizard Street
# 34     490004937W Central Street
# 35     490004937E Central Street
# 36     490006309S Hall Street
# 37     490015107S City University
# 38     490003327K Angel Islington
# 39     490003327H Angel Islington / City Road
# 40     490003327J Angel Islington
# 41     490013229M St John Street / Goswell Road
# 42     490013229P St John Street / Goswell Road
# 43     490011678SA Rosebery Avenue / Sadler's Wells Theatre
# 44     490000007R Pentonville Road / Baron Street
# 45     490015108S Angel Station
# 46     490018488S Claremont Square
# 47     490018488N Claremont Square
# 48     490010928W Penton Street / Chapel Market
# 49     490018489W Cruikshank Street  Amwell St
# 50     490018498E Cruikshank Street  Amwell St
# 51     490010928E Penton Street
# 52     490003650T Baron Street / Chapel Market
# 53     490010926S Penton Rise
# 54     490005904W Penton Rise
# 55     490005904E Penton Rise
# 56     490018490  Percy Circus
# 57     490010929L King's Cross Road / Pentonville Road
# 58     490001172K King's Cross Road
# 59     490004354N Swinton Street
# 60     490001172X King's Cross / Caledonian Road
# 61     490000129R King's Cross Station
# 62     490013117O Swinton Street
# 63     490001171H King's Cross Stn   / Pentonville Rd
# 64     490000129D King's Cross Station
# 65     490000129E King's Cross Station
# 66     490005916N King's Cross Station   / York Way
# 67     490001171G King's Cross Station   / York Way
# 68     490012553B St Pancras Intern'l & King's X Stns
# 69     490004722M St Pancras International Station
# 70     490004722A St Pancras International Station
# 71     490004722W St Pancras International Station
# 72     490001276S St Pancras International Station
# 73     490018897  St Pancras Olympic Shuttle
# 74     490001276Z St Pancras International Station
# 75     490016573N Chenies Place
# 76     490016573S Chenies Place
# 77     490012870W St Pancras Old Church
# 78     490012869S St Pancras Hospital
# 79     490011756W Royal College Street
# 80     490011756E Royal College Street
# 81     490011057H Oakley Square
# 82     490005493N Royal Veterinary College
# 83     490000152K Mornington Crescent Station
# 84     490000152G Mornington Cres Stn / Camden Tn Library
# 85     490000152F Mornington Cres Stn / Camden Tn Library
# 86     490000152C Mornington Crescent Station
# 87     490000152D Mornington Crescent Station
# 88     490000152A Mornington Crescent Station
# 89     490011057L Plender Street
# 90     490004714E Camden High Street
# 91     490004714J Camden High Street
# 92     490011168S1 Pratt Street
# 93     490011168S2 Pratt Street
# 94     490015384V Pratt Street
# 95     490003380N Arlington Road
# 96     490015041Y Camden Town Station
# 97     490003698W Bayham Street
# 98     490015041X Camden Town Station
# 99     490015531T Camden Town Station  / Bayham Street
# 100    490015041Q Camden High Street
# 101    490015531S Camden Town Station
# 102    490000036Z Camden Town Station
# 103    490000036S Camden Town Station
# 104    490000036L Kentish Town Road
# 105    490000036R Camden Town Station / Camden Street
# 106    490000036N Camden Town / Camden Road
# 107    490004713D Camden Gardens
# 108    490004713E Camden Gardens
# 109    490007927A Hawley Road
# 110    490001045E Royal College Street / Ivor Street
# 111    490001045G Camden Road Station
# 112    490011755S Royal College Street
# 113    490008663W Kentish Town Road
# 114    490007927M Hawley Road
# 115    490011199S Kentish Town Road / Prince of Wales Road
# 116    490011199R Prince of Wales Road
# 117    490015246N Kentish Town Road
# 118    490007082K Kentish Town Post Office
# 119    490004894L Kentish Town Post Office
# 120    490000123A Kentish Town Station
# 121    490000123E Kentish Town Station
# 122    490000123B Kentish Town Station
# 123    490006943E Fortess Road
# 124    490008662G Fortess Walk
# 125    490008661N Fortess Walk
# 126    490008660S Greenwood Centre
# 127    490008660N Lady Somerset Road
# 128    490015367S Lady Somerset Road
# 129    490007308N Gordon House Road
# 130    490007308W Gordon House Road
# 131    490005974S Gordon House Road
# 132    490007308E Gordon House Road
# 133    490005974N Glenhurst Avenue / Lissenden Gardens
# 134    490014902N William Ellis School
# 135    490014697S William Ellis School
# 136    490015528S1 Parliament Hill Fields
# 137    490010852S2 Parliament Hill Fields
# 138    490010852N1 Parliament Hill Fields
# 139    490010852N Parliament Hill Fields
# 140    490008306E Swains Lane
# 141    490010482N Oakeshott Avenue
# 142    490010482S Oakeshott Avenue
# 143    490015831S Holly Lodge Gardens
# 144    490009837N Merton Lane
# 145    490012812V St Michael's Church
# 146    490016698N Pond Square
# 147    490012303W South Grove
# 148    490012303N South Grove
# 149    490012303E South Grove
# 150    49008160Z1 Highgate School / Hampstead Lane
# 151    490008160S Highgate School
# 152    490008160N Highgate School
# 153    490008158W Highgate Close
#      Sl. No.     Stop ID                         Stop Name
# 0          1  490015209K        Finsbury Square / Moorgate
# 1          2  490015209C                   Finsbury Square
# 2          3  490006850J        Finsbury Square / Moorgate
# 3          4  490006850G                   Finsbury Square
# 4          5  490006850H                   Finsbury Square
# ..       ...         ...                               ...
# 148      149  490012303E                       South Grove
# 149      150  49008160Z1  Highgate School / Hampstead Lane
# 150      151  490008160S                   Highgate School
# 151      152  490008160N                   Highgate School
# 152      153  490008158W                    Highgate Close
#
# [153 rows x 3 columns]
# Enter the row numbers, stop IDs, or stop names of the stops you're interested in (comma separated): 25
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="70e72656-a136-47dd-a8be-53b63d450761" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70e72656-a136-47dd-a8be-53b63d450761")) {                    Plotly.newPlot(                        "70e72656-a136-47dd-a8be-53b63d450761",                        [{"hoverinfo":"text","marker":{"color":"black","size":40,"symbol":"square"},"mode":"markers+text","name":"Stop Point","text":"17:28:46","textposition":"bottom center","x":["17:28:46"],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KBN\u003cbr\u003eArrival Time: 17:28:00","textposition":"top center","x":["17:28:00"],"y":[0.03],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19JZX\u003cbr\u003eArrival Time: 17:35:00","textposition":"top center","x":["17:35:00"],"y":[0.01],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KBU\u003cbr\u003eArrival Time: 17:42:00","textposition":"top center","x":["17:42:00"],"y":[0.05],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KBP\u003cbr\u003eArrival Time: 17:50:00","textposition":"top center","x":["17:50:00"],"y":[0.04],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"blue","size":20,"symbol":"arrow-bar-down"},"mode":"markers+text","name":"Bus Arrival","text":"Bus ID: LA19KBF\u003cbr\u003eArrival Time: 17:57:00","textposition":"top center","x":["17:57:00"],"y":[0.02],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd ...
# Summary Metrics:
#        Line Vehicle ID  Stop Point Direction Expected Arrival (BST)  \
# count     5          5           5         5                      5
# unique    1          5           1         1                      5
# top     214    LA19KBN  490010012N   inbound               17:28:00
# freq      5          1           5         5                      1
# mean    NaN        NaN         NaN       NaN                    NaN
# min     NaN        NaN         NaN       NaN                    NaN
# 25%     NaN        NaN         NaN       NaN                    NaN
# 50%     NaN        NaN         NaN       NaN                    NaN
# 75%     NaN        NaN         NaN       NaN                    NaN
# max     NaN        NaN         NaN       NaN                    NaN
# std     NaN        NaN         NaN       NaN                    NaN
#
#        Expected Arrival (HM)  Headway (minutes)  AWT/bus (minutes)       WAWT
# count                      5           5.000000           5.000000   5.000000
# unique                   NaN                NaN                NaN        NaN
# top                      NaN                NaN                NaN        NaN
# freq                     NaN                NaN                NaN        NaN
# mean     1900-01-01 17:42:24           5.800000           2.900000  21.100000
# min      1900-01-01 17:28:00           0.000000           0.000000   0.000000
# 25%      1900-01-01 17:35:00           7.000000           3.500000  24.500000
# 50%      1900-01-01 17:42:00           7.000000           3.500000  24.500000
# 75%      1900-01-01 17:50:00           7.000000           3.500000  24.500000
# max      1900-01-01 17:57:00           8.000000           4.000000  32.000000
# std                      NaN           3.271085           1.635543  12.234173

# %%
import requests
import csv
import re
import time
from datetime import datetime, timedelta
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pytz

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)

                if all_stop_details:
                    # Write to CSV file
                    write_to_csv(all_stop_details)

                    # Display data from CSV file
                    display_data_from_csv()

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and appending stop details using the lat and lon
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                time.sleep(2**attempt)  # Exponential backoff
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Append to all_stop_details only if stop ID has not been printed before
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })

                        # Add stop ID to printed set
                        printed_stop_ids.add(stop_id)

            else:
                # If no stop points found, continue to next attempt
                continue

            break  # Exit loop if successful

        else:
            # If maximum retries exceeded, handle quietly (you can add logging or alternative handling here)
            pass

    except requests.exceptions.RequestException as e:
        # Handle other request exceptions (you can add logging or alternative handling here)
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']

    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

def display_data_from_csv():
    print("Data from CSV:")

    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)

        # Print headers
        headers_printed = False

        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')  # BST timezone for London

    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)

    return bst_dt.strftime('%H:%M:%S')

def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}

        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        data = response.json()

        if len(data) == 0:
            print("No arrival predictions found.")
            return None, None

        station_name = data[0]['stationName']

        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)  # Convert GMT to BST
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')  # Format to HH:MM
            })

        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))

        return df, station_name

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None  # Return None if there's an error

def create_dashboard(df, station_name):
    current_time_utc = datetime.utcnow()
    current_time_bst = convert_to_bst(current_time_utc)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=[current_time_bst],
        y=[0],
        mode='markers+text',
        marker=dict(size=40, symbol='square', color='black'),
        name='Stop Point',
        text=f"{current_time_bst}",  # Display only the current time below the square
        textposition='bottom center',
        hoverinfo='text'
    ))

    fig.add_annotation(
        x=current_time_bst,
        y=0,
        text=f"{station_name}",
        showarrow=False,
        font=dict(size=14, color="black"),
        yshift=40  # Adjust the yshift to move the label above the square
    )

    y_gap = 0.01  # 1 cm gap in graph units
    for i, row in df.iterrows():
        y_pos = 0 + (i + 1) * y_gap

        fig.add_trace(go.Scatter(
            x=[row['Expected Arrival (BST)']],
            y=[y_pos],
            mode='markers+text',
            marker=dict(size=20, symbol='arrow-bar-down', color='blue'),
            name='Bus Arrival',
            text=f"Bus ID: {row['Vehicle ID']}<br>Arrival Time: {row['Expected Arrival (BST)']}",
            textposition='top center',
            hoverinfo='text'
        ))

    fig.update_layout(
        title=f"Expected Bus Arrivals at {station_name}",
        xaxis_title="Time",
        yaxis_title="",
        yaxis=dict(showticklabels=False),
        showlegend=False,
        height=400,
        margin=dict(l=0, r=0, t=40, b=0)
    )

    fig.show()

def calculate_summary_metrics(df):
    summary = df.describe(include='all')
    return summary

# Sample Inputs
line_id = input("Enter the Line ID (e.g., 205, 25): ")
direction = input("Enter the direction (inbound or outbound): ")
buses_per_hour = int(input("Enter the number of buses per hour: "))

fetch_route_details(line_id, direction)

df_stops = pd.read_csv('stop_details.csv')

print(df_stops)

num_stops = int(input("Enter the number of stops of interest: "))

selected_stops = []
for i in range(num_stops):
    selected_stop = input(f"Enter row number, stop ID, or stop name for stop {i + 1}: ").strip()
    selected_stops.append(selected_stop)

matching_stops = pd.DataFrame()

for stop in selected_stops:
    if stop.isdigit():
        matching_stops = pd.concat([matching_stops, df_stops.loc[df_stops['Sl. No.'] == int(stop)]], ignore_index=True)
    else:
        matching_stops = pd.concat([
            matching_stops,
            df_stops.loc[
                (df_stops['Stop ID'].str.contains(stop, case=False)) |
                (df_stops['Stop Name'].str.contains(stop, case=False))
            ]
        ], ignore_index=True)

if matching_stops.empty:
    print("No matching stops found.")
else:
    for index, stop_row in matching_stops.iterrows():
        stop_point_id = stop_row['Stop ID']
        stop_point_name = stop_row['Stop Name']
        df_predictions, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
        if df_predictions is not None:
            create_dashboard(df_predictions, station_name)

            summary_metrics = calculate_summary_metrics(df_predictions)
            print(f"\nSummary Metrics for {station_name}:")
            print(summary_metrics)
# Out:
# Direction: inbound
# Origination Name: Finsbury Square
# Destination Name: Highgate School
# Originator: 490015209C
# Destination: 490008160N
# ---
# Data written to 'stop_details.csv' successfully.
# Data from CSV:
# 1      490015209K Finsbury Square / Moorgate
# 2      490015209C Finsbury Square
# 3      490006850J Finsbury Square / Moorgate
# 4      490006850G Finsbury Square
# 5      490006850H Finsbury Square
# 6      490003831E Finsbury Street
# 7      490015209D Finsbury Square
# 8      490003831W Finsbury Street
# 9      490000149B Moorgate Station
# 10     490000149M Moorgate
# 11     490006850F Finsbury Square
# 12     490006612E Epworth Street
# 13     490000169ZA Old Street Station
# 14     490015195N Old Street
# 15     490015195M City Road / Leonard Street
# 16     490000169K Shoreditch Fire Station
# 17     490015194F Old Street Station
# 18     490000169L Old Street Station
# 19     490010109E Old Street Roundabout
# 20     490015194G Bunhill Row
# 21     490015193S Old Street Station
# 22     490015193D Old Street Stn   / Moorfields Eye Hosp
# 23     490010108C Old Street Station
# 24     490011249A Moorfields Eye Hospital
# 25     490010012N Moorfields Eye Hospital
# 26     490018497N Bath Street
# 27     490010012E Moorfields Eye Hospital
# 28     490014780W Windsor Terrace
# 29     490014780E Windsor Terrace
# 30     490016371N Shoreditch Police Station
# 31     490018499N Ironmonger Row  Norman Street
# 32     490016371S Shoreditch Police Station
# 33     490018498W Radnor Street  Lizard Street
# 34     490004937W Central Street
# 35     490004937E Central Street
# 36     490006309S Hall Street
# 37     490015107S City University
# 38     490003327K Angel Islington
# 39     490003327H Angel Islington / City Road
# 40     490003327J Angel Islington
# 41     490013229M St John Street / Goswell Road
# 42     490013229P St John Street / Goswell Road
# 43     490011678SA Rosebery Avenue / Sadler's Wells Theatre
# 44     490000007R Pentonville Road / Baron Street
# 45     490015108S Angel Station
# 46     490005904W Penton Rise
# 47     490010926S Penton Rise
# 48     490005904E Penton Rise
# 49     490010929L King's Cross Road / Pentonville Road
# 50     490001172K King's Cross Road
# 51     490004354N Swinton Street
# 52     490001172X King's Cross / Caledonian Road
# 53     490000129R King's Cross Station
# 54     490013117O Swinton Street
# 55     490001171H King's Cross Stn   / Pentonville Rd
# 56     490000129D King's Cross Station
# 57     490000129E King's Cross Station
# 58     490005916N King's Cross Station   / York Way
# 59     490001171G King's Cross Station   / York Way
# 60     490012553B St Pancras Intern'l & King's X Stns
# 61     490004722M St Pancras International Station
# 62     490004722A St Pancras International Station
# 63     490004722W St Pancras International Station
# 64     490001276S St Pancras International Station
# 65     490018897  St Pancras Olympic Shuttle
# 66     490001276Z St Pancras International Station
# 67     490016573N Chenies Place
# 68     490016573S Chenies Place
# 69     490012870W St Pancras Old Church
# 70     490012869S St Pancras Hospital
# 71     490011756W Royal College Street
# 72     490011756E Royal College Street
# 73     490011057H Oakley Square
# 74     490005493N Royal Veterinary College
# 75     490000152K Mornington Crescent Station
# 76     490000152G Mornington Cres Stn / Camden Tn Library
# 77     490000152F Mornington Cres Stn / Camden Tn Library
# 78     490000152C Mornington Crescent Station
# 79     490000152D Mornington Crescent Station
# 80     490000152A Mornington Crescent Station
# 81     490011057L Plender Street
# 82     490004714E Camden High Street
# 83     490004714J Camden High Street
# 84     490011168S1 Pratt Street
# 85     490011168S2 Pratt Street
# 86     490015384V Pratt Street
# 87     490003380N Arlington Road
# 88     490015041Y Camden Town Station
# 89     490003698W Bayham Street
# 90     490015041X Camden Town Station
# 91     490015531T Camden Town Station  / Bayham Street
# 92     490015041Q Camden High Street
# 93     490015531S Camden Town Station
# 94     490000036Z Camden Town Station
# 95     490000036S Camden Town Station
# 96     490000036L Kentish Town Road
# 97     490000036R Camden Town Station / Camden Street
# 98     490000036N Camden Town / Camden Road
# 99     490004713D Camden Gardens
# 100    490004713E Camden Gardens
# 101    490007927A Hawley Road
# 102    490001045E Royal College Street / Ivor Street
# 103    490001045G Camden Road Station
# 104    490011755S Royal College Street
# 105    490008663W Kentish Town Road
# 106    490007927M Hawley Road
# 107    490011199S Kentish Town Road / Prince of Wales Road
# 108    490011199R Prince of Wales Road
# 109    490015246N Kentish Town Road
# 110    490007082K Kentish Town Post Office
# 111    490004894L Kentish Town Post Office
# 112    490000123A Kentish Town Station
# 113    490000123E Kentish Town Station
# 114    490000123B Kentish Town Station
# 115    490006943E Fortess Road
# 116    490008662G Fortess Walk
# 117    490008661N Fortess Walk
# 118    490008660S Greenwood Centre
# 119    490008660N Lady Somerset Road
# 120    490015367S Lady Somerset Road
# 121    490007308N Gordon House Road
# 122    490007308W Gordon House Road
# 123    490005974S Gordon House Road
# 124    490007308E Gordon House Road
# 125    490005974N Glenhurst Avenue / Lissenden Gardens
# 126    490014902N William Ellis School
# 127    490014697S William Ellis School
# 128    490015528S1 Parliament Hill Fields
# 129    490010852S2 Parliament Hill Fields
# 130    490010852N1 Parliament Hill Fields
# 131    490010852N Parliament Hill Fields
# 132    490008306E Swains Lane
# 133    490010482N Oakeshott Avenue
# 134    490010482S Oakeshott Avenue
# 135    490015831S Holly Lodge Gardens
# 136    490009837N Merton Lane
# 137    490012812V St Michael's Church
# 138    490016698N Pond Square
# 139    490012303W South Grove
# 140    490012303N South Grove
# 141    490012303E South Grove
# 142    49008160Z1 Highgate School / Hampstead Lane
# 143    490008160S Highgate School
# 144    490008160N Highgate School
# 145    490008158W Highgate Close
#      Sl. No.     Stop ID                         Stop Name
# 0          1  490015209K        Finsbury Square / Moorgate
# 1          2  490015209C                   Finsbury Square
# 2          3  490006850J        Finsbury Square / Moorgate
# 3          4  490006850G                   Finsbury Square
# 4          5  490006850H                   Finsbury Square
# ..       ...         ...                               ...
# 140      141  490012303E                       South Grove
# 141      142  49008160Z1  Highgate School / Hampstead Lane
# 142      143  490008160S                   Highgate School
# 143      144  490008160N                   Highgate School
# 144      145  490008158W                    Highgate Close
#
# [145 rows x 3 columns]
# Enter the number of stops of interest: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-548b3afea7d5> in <cell line: 282>()
#     281 selected_stops = []
#     282 for i in range(num_stops):
# --> 283     selected_stop = input(f"Enter row number, stop ID, or stop name for stop {i + 1}: ").strip()
#     284     selected_stops.append(selected_stop)
#     285
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import requests
import csv
import re
import time
from datetime import datetime, timedelta
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pytz

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)

                if all_stop_details:
                    # Write to CSV file
                    write_to_csv(all_stop_details)

                    # Display data from CSV file
                    display_data_from_csv()

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates:
                    # Fetching and appending stop details using the lat and lon
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/StopPoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                time.sleep(2**attempt)  # Exponential backoff
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Append to all_stop_details only if stop ID has not been printed before
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })

                        # Add stop ID to printed set
                        printed_stop_ids.add(stop_id)

            else:
                # If no stop points found, continue to next attempt
                continue

            break  # Exit loop if successful

        else:
            # If maximum retries exceeded, handle quietly (you can add logging or alternative handling here)
            pass

    except requests.exceptions.RequestException as e:
        # Handle other request exceptions (you can add logging or alternative handling here)
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']

    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

def display_data_from_csv():
    print("Data from CSV:")

    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)

        # Print headers
        headers_printed = False

        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')  # BST timezone for London

    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)

    return bst_dt.strftime('%H:%M:%S')

def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}

        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        data = response.json()

        if len(data) == 0:
            print("No arrival predictions found.")
            return None, None

        station_name = data[0]['stationName']

        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)  # Convert GMT to BST
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')  # Format to HH:MM
            })

        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))

        return df, station_name

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None  # Return None if there's an error

def create_dashboard(df, station_name):
    current_time_utc = datetime.utcnow()
    current_time_bst = convert_to_bst(current_time_utc)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=[current_time_bst],
        y=[0],
        mode='markers+text',
        marker=dict(size=40, symbol='square', color='black'),
        name='Stop Point',
        text=f"{current_time_bst}",  # Display only the current time below the square
        textposition='bottom center',
        hoverinfo='text'
    ))

    fig.add_annotation(
        x=current_time_bst,
        y=0,
        text=f"{station_name}",
        showarrow=False,
        font=dict(size=14, color="black"),
        yshift=40  # Adjust the yshift to move the label above the square
    )

    y_gap = 0.01  # 1 cm gap in graph units
    for i, row in df.iterrows():
        y_pos = 0 + (i + 1) * y_gap

        fig.add_trace(go.Scatter(
            x=[row['Expected Arrival (BST)']],
            y=[y_pos],
            mode='markers+text',
            marker=dict(size=20, symbol='arrow-bar-down', color='blue'),
            name='Bus Arrival',
            text=f"Bus ID: {row['Vehicle ID']}<br>Arrival Time: {row['Expected Arrival (BST)']}",
            textposition='top center',
            hoverinfo='text'
        ))

    fig.update_layout(
        title=f"Expected Bus Arrivals at {station_name}",
        xaxis_title="Time",
        yaxis_title="",
        yaxis=dict(showticklabels=False),
        showlegend=False,
        height=400,
        margin=dict(l=0, r=0, t=40, b=0)
    )

    fig.show()

def calculate_summary_metrics(df):
    summary = df.describe(include='all')
    return summary

# Sample Inputs
line_id = input("Enter the Line ID (e.g., 205, 25): ")
direction = input("Enter the direction (inbound or outbound): ")
buses_per_hour = int(input("Enter the number of buses per hour: "))

fetch_route_details(line_id, direction)

df_stops = pd.read_csv('stop_details.csv')

print(df_stops)

num_stops = int(input("Enter the number of stops of interest: "))

selected_stops = []
for i in range(num_stops):
    selected_stop = input(f"Enter row number, stop ID, or stop name for stop {i + 1}: ").strip()
    selected_stops.append(selected_stop)

matching_stops = pd.DataFrame()

for stop in selected_stops:
    if stop.isdigit():
        matching_stops = pd.concat([matching_stops, df_stops.loc[df_stops['Sl. No.'] == int(stop)]], ignore_index=True)
    else:
        matching_stops = pd.concat([
            matching_stops,
            df_stops.loc[
                (df_stops['Stop ID'].str.contains(stop, case=False)) |
                (df_stops['Stop Name'].str.contains(stop, case=False))
            ]
        ], ignore_index=True)

if matching_stops.empty:
    print("No matching stops found.")
else:
    for index, stop_row in matching_stops.iterrows():
        stop_point_id = stop_row['Stop ID']
        stop_point_name = stop_row['Stop Name']
        df_predictions, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
        if df_predictions is not None:
            create_dashboard(df_predictions, station_name)

            summary_metrics = calculate_summary_metrics(df_predictions)
            print(f"\nSummary Metrics for {station_name}:")
            print(summary_metrics)
# Out:
# Enter the Line ID (e.g., 205, 25): 214
# Enter the direction (inbound or outbound): inbound
# Enter the number of buses per hour: 6
# Direction: inbound
# Origination Name: Finsbury Square
# Destination Name: Highgate School
# Originator: 490015209C
# Destination: 490008160N
# ---
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-764831fcfa3c> in <cell line: 273>()
#     271 buses_per_hour = int(input("Enter the number of buses per hour: "))
#     272
# --> 273 fetch_route_details(line_id, direction)
#     274
#     275 df_stops = pd.read_csv('stop_details.csv')
#
# <ipython-input-8-764831fcfa3c> in fetch_route_details(line_id, direction)
#      38
#      39                 # Fetch and print sequence of stop points
# ---> 40                 all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
#      41
#      42                 if all_stop_details:
#
# <ipython-input-8-764831fcfa3c> in fetch_and_append_stop_points(line_id, originator, destination, direction)
#      70                 # Parsing the line string to extract latitudes and longitudes
#      71                 coordinates = eval(line_string)  # Evaluating string to list
# ---> 72                 for lon, lat in coordinates:
#      73                     # Fetching and appending stop details using the lat and lon
#      74                     fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
#
# ValueError: too many values to unpack (expected 2)

# %%
import requests
import csv
import re
import time
from datetime import datetime, timedelta
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pytz

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)

                if all_stop_details:
                    # Write to CSV file
                    write_to_csv(all_stop_details)

                    # Display data from CSV file
                    display_data_from_csv()

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for coord_pair in coordinates:
                    lon, lat = coord_pair  # Unpack lon, lat from coord_pair
                    # Fetching and appending stop details using the lat and lon
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/StopPoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                time.sleep(2**attempt)  # Exponential backoff
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Append to all_stop_details only if stop ID has not been printed before
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })

                        # Add stop ID to printed set
                        printed_stop_ids.add(stop_id)

            else:
                # If no stop points found, continue to next attempt
                continue

            break  # Exit loop if successful

        else:
            # If maximum retries exceeded, handle quietly (you can add logging or alternative handling here)
            pass

    except requests.exceptions.RequestException as e:
        # Handle other request exceptions (you can add logging or alternative handling here)
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']

    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

def display_data_from_csv():
    print("Data from CSV:")

    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)

        # Print headers
        headers_printed = False

        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')  # BST timezone for London

    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)

    return bst_dt.strftime('%H:%M:%S')

def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}

        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        data = response.json()

        if len(data) == 0:
            print("No arrival predictions found.")
            return None, None

        station_name = data[0]['stationName']

        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)  # Convert GMT to BST
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')  # Format to HH:MM
            })

        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))

        return df, station_name

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None  # Return None if there's an error

def create_dashboard(df, station_name):
    current_time_utc = datetime.utcnow()
    current_time_bst = convert_to_bst(current_time_utc)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=[current_time_bst],
        y=[0],
        mode='markers+text',
        marker=dict(size=40, symbol='square', color='black'),
        name='Stop Point',
        text=f"{current_time_bst}",  # Display only the current time below the square
        textposition='bottom center',
        hoverinfo='text'
    ))

    fig.add_annotation(
        x=current_time_bst,
        y=0,
        text=f"{station_name}",
        showarrow=False,
        font=dict(size=14, color="black"),
        yshift=40  # Adjust the yshift to move the label above the square
    )

    y_gap = 0.01  # 1 cm gap in graph units
    for i, row in df.iterrows():
        y_pos = 0 + (i + 1) * y_gap

        fig.add_trace(go.Scatter(
            x=[row['Expected Arrival (BST)']],
            y=[y_pos],
            mode='markers+text',
            marker=dict(size=20, symbol='arrow-bar-down', color='blue'),
            name='Bus Arrival',
            text=f"Bus ID: {row['Vehicle ID']}<br>Arrival Time: {row['Expected Arrival (BST)']}",
            textposition='top center',
            hoverinfo='text'
        ))

    fig.update_layout(
        title=f"Expected Bus Arrivals at {station_name}",
        xaxis_title="Time",
        yaxis_title="",
        yaxis=dict(showticklabels=False),
        showlegend=False,
        height=400,
        margin=dict(l=0, r=0, t=40, b=0)
    )

    fig.show()

def calculate_summary_metrics(df):
    summary = df.describe(include='all')
    return summary

# Sample Inputs
line_id = input("Enter the Line ID (e.g., 205, 25): ")
direction = input("Enter the direction (inbound or outbound): ")
buses_per_hour = int(input("Enter the number of buses per hour: "))

fetch_route_details(line_id, direction)

df_stops = pd.read_csv('stop_details.csv')

print(df_stops)

num_stops = int(input("Enter the number of stops of interest: "))

selected_stops = []
for i in range(num_stops):
    selected_stop = input(f"Enter row number, stop ID, or stop name for stop {i + 1}: ").strip()
    selected_stops.append(selected_stop)

matching_stops = pd.DataFrame()

for stop in selected_stops:
    if stop.isdigit():
        matching_stops = pd.concat([matching_stops, df_stops.loc[df_stops['Sl. No.'] == int(stop)]], ignore_index=True)
    else:
        matching_stops = pd.concat([
            matching_stops,
            df_stops.loc[
                (df_stops['Stop ID'].str.contains(stop, case=False)) |
                (df_stops['Stop Name'].str.contains(stop, case=False))
            ]
        ], ignore_index=True)

if matching_stops.empty:
    print("No matching stops found.")
else:
    for index, stop_row in matching_stops.iterrows():
        stop_point_id = stop_row['Stop ID']
        stop_point_name = stop_row['Stop Name']
        df_predictions, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
        if df_predictions is not None:
            create_dashboard(df_predictions, station_name)

            summary_metrics = calculate_summary_metrics(df_predictions)
            print(f"\nSummary Metrics for {station_name}:")
            print(summary_metrics)
# Out:
# Enter the Line ID (e.g., 205, 25): 214
# Enter the direction (inbound or outbound): inbound
# Enter the number of buses per hour: 6
# Direction: inbound
# Origination Name: Finsbury Square
# Destination Name: Highgate School
# Originator: 490015209C
# Destination: 490008160N
# ---
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-521146ccce3f> in <cell line: 274>()
#     272 buses_per_hour = int(input("Enter the number of buses per hour: "))
#     273
# --> 274 fetch_route_details(line_id, direction)
#     275
#     276 df_stops = pd.read_csv('stop_details.csv')
#
# <ipython-input-9-521146ccce3f> in fetch_route_details(line_id, direction)
#      38
#      39                 # Fetch and print sequence of stop points
# ---> 40                 all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
#      41
#      42                 if all_stop_details:
#
# <ipython-input-9-521146ccce3f> in fetch_and_append_stop_points(line_id, originator, destination, direction)
#      71                 coordinates = eval(line_string)  # Evaluating string to list
#      72                 for coord_pair in coordinates:
# ---> 73                     lon, lat = coord_pair  # Unpack lon, lat from coord_pair
#      74                     # Fetching and appending stop details using the lat and lon
#      75                     fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# 25/06/2024

# %%
import requests
import csv
import re
import time

def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {
        'serviceTypes': 'Regular'
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        route_sections = data.get('routeSections', [])

        found_direction = False

        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')

                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                # Fetch and print sequence of stop points
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)

                if all_stop_details:
                    # Write to CSV file
                    write_to_csv(all_stop_details)

                    # Display data from CSV file
                    display_data_from_csv()

                    # Get QSI stop points from the user
                    get_qsi_stop_points()

        if not found_direction:
            print(f"No route found for direction '{direction}'.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise exception for bad status codes

        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()  # To track printed stop IDs

            for line_string in line_strings:
                # Parsing the line string to extract latitudes and longitudes
                coordinates = eval(line_string)  # Evaluating string to list
                for lon, lat in coordinates[0]:
                    # Fetching and appending stop details using the lat and lon
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)

        else:
            print("No stop points found for this route.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"

    try:
        for attempt in range(retries):
            response = requests.get(url)

            if response.status_code == 429:
                time.sleep(2**attempt)  # Exponential backoff
                continue

            response.raise_for_status()  # Raise exception for bad status codes

            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    # Append to all_stop_details only if stop ID has not been printed before
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')

                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })

                        # Add stop ID to printed set
                        printed_stop_ids.add(stop_id)

            else:
                # If no stop points found, continue to next attempt
                continue

            break  # Exit loop if successful

        else:
            # If maximum retries exceeded, handle quietly (you can add logging or alternative handling here)
            pass

    except requests.exceptions.RequestException as e:
        # Handle other request exceptions (you can add logging or alternative handling here)
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']

    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

def display_data_from_csv():
    print("Data from CSV:")

    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)

        # Print headers
        headers_printed = False

        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []

    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)

    # Display the QSI stop points
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Example usage
if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")

    fetch_route_details(line_id, direction)
# Out:
# Enter line ID: 214
# Enter direction (e.g., inbound or outbound): inbound
# Direction: inbound
# Origination Name: Finsbury Square
# Destination Name: Highgate School
# Originator: 490015209C
# Destination: 490008160N
# ---
# Data written to 'stop_details.csv' successfully.
# Data from CSV:
# 1      490015209K Finsbury Square / Moorgate
# 2      490015209C Finsbury Square
# 3      490006850J Finsbury Square / Moorgate
# 4      490006850G Finsbury Square
# 5      490006850H Finsbury Square
# 6      490003831E Finsbury Street
# 7      490015209D Finsbury Square
# 8      490003831W Finsbury Street
# 9      490000149B Moorgate Station
# 10     490000149M Moorgate
# 11     490006850F Finsbury Square
# 12     490006612E Epworth Street
# 13     490000169ZA Old Street Station
# 14     490015195N Old Street
# 15     490015195M City Road / Leonard Street
# 16     490000169K Shoreditch Fire Station
# 17     490015194F Old Street Station
# 18     490000169L Old Street Station
# 19     490010109E Old Street Roundabout
# 20     490015194G Bunhill Row
# 21     490015193S Old Street Station
# 22     490015193D Old Street Stn   / Moorfields Eye Hosp
# 23     490010108C Old Street Station
# 24     490011249A Moorfields Eye Hospital
# 25     490010012N Moorfields Eye Hospital
# 26     490018497N Bath Street
# 27     490010012E Moorfields Eye Hospital
# 28     490014780W Windsor Terrace
# 29     490014780E Windsor Terrace
# 30     490016371N Shoreditch Police Station
# 31     490018499N Ironmonger Row  Norman Street
# 32     490016371S Shoreditch Police Station
# 33     490018498W Radnor Street  Lizard Street
# 34     490004937W Central Street
# 35     490004937E Central Street
# 36     490006309S Hall Street
# 37     490015107S City University
# 38     490003327K Angel Islington
# 39     490003327H Angel Islington / City Road
# 40     490003327J Angel Islington
# 41     490013229M St John Street / Goswell Road
# 42     490013229P St John Street / Goswell Road
# 43     490011678SA Rosebery Avenue / Sadler's Wells Theatre
# 44     490000007R Pentonville Road / Baron Street
# 45     490015108S Angel Station
# 46     490005904W Penton Rise
# 47     490010926S Penton Rise
# 48     490005904E Penton Rise
# 49     490010929L King's Cross Road / Pentonville Road
# 50     490001172K King's Cross Road
# 51     490004354N Swinton Street
# 52     490001172X King's Cross / Caledonian Road
# 53     490000129R King's Cross Station
# 54     490013117O Swinton Street
# 55     490001171H King's Cross Stn   / Pentonville Rd
# 56     490000129D King's Cross Station
# 57     490000129E King's Cross Station
# 58     490005916N King's Cross Station   / York Way
# 59     490001171G King's Cross Station   / York Way
# 60     490012553B St Pancras Intern'l & King's X Stns
# 61     490004722M St Pancras International Station
# 62     490004722A St Pancras International Station
# 63     490004722W St Pancras International Station
# 64     490001276S St Pancras International Station
# 65     490018897  St Pancras Olympic Shuttle
# 66     490001276Z St Pancras International Station
# 67     490016573N Chenies Place
# 68     490016573S Chenies Place
# 69     490012870W St Pancras Old Church
# 70     490012869S St Pancras Hospital
# 71     490011756W Royal College Street
# 72     490011756E Royal College Street
# 73     490011057H Oakley Square
# 74     490005493N Royal Veterinary College
# 75     490000152G Mornington Cres Stn / Camden Tn Library
# 76     490000152K Mornington Crescent Station
# 77     490000152F Mornington Cres Stn / Camden Tn Library
# 78     490000152C Mornington Crescent Station
# 79     490000152D Mornington Crescent Station
# 80     490000152A Mornington Crescent Station
# 81     490011057L Plender Street
# 82     490004714E Camden High Street
# 83     490004714J Camden High Street
# 84     490011168S1 Pratt Street
# 85     490011168S2 Pratt Street
# 86     490015384V Pratt Street
# 87     490003380N Arlington Road
# 88     490015041Y Camden Town Station
# 89     490003698W Bayham Street
# 90     490015041X Camden Town Station
# 91     490015531T Camden Town Station  / Bayham Street
# 92     490015041Q Camden High Street
# 93     490015531S Camden Town Station
# 94     490000036Z Camden Town Station
# 95     490000036S Camden Town Station
# 96     490000036L Kentish Town Road
# 97     490000036R Camden Town Station / Camden Street
# 98     490000036N Camden Town / Camden Road
# 99     490004713D Camden Gardens
# 100    490004713E Camden Gardens
# 101    490007927A Hawley Road
# 102    490001045E Royal College Street / Ivor Street
# 103    490001045G Camden Road Station
# 104    490011755S Royal College Street
# 105    490008663W Kentish Town Road
# 106    490007927M Hawley Road
# 107    490011199S Kentish Town Road / Prince of Wales Road
# 108    490011199R Prince of Wales Road
# 109    490015246N Kentish Town Road
# 110    490007082K Kentish Town Post Office
# 111    490004894L Kentish Town Post Office
# 112    490000123A Kentish Town Station
# 113    490000123E Kentish Town Station
# 114    490000123B Kentish Town Station
# 115    490006943E Fortess Road
# 116    490008662G Fortess Walk
# 117    490008661N Fortess Walk
# 118    490008660S Greenwood Centre
# 119    490008660N Lady Somerset Road
# 120    490015367S Lady Somerset Road
# 121    490007308N Gordon House Road
# 122    490007308W Gordon House Road
# 123    490005974S Gordon House Road
# 124    490007308E Gordon House Road
# 125    490005974N Glenhurst Avenue / Lissenden Gardens
# 126    490014902N William Ellis School
# 127    490014697S William Ellis School
# 128    490015528S1 Parliament Hill Fields
# 129    490010852S2 Parliament Hill Fields
# 130    490010852N1 Parliament Hill Fields
# 131    490010852N Parliament Hill Fields
# 132    490008306E Swains Lane
# 133    490010482N Oakeshott Avenue
# 134    490010482S Oakeshott Avenue
# 135    490015831S Holly Lodge Gardens
# 136    490009837N Merton Lane
# 137    490012812V St Michael's Church
# 138    490016698N Pond Square
# 139    490012303W South Grove
# 140    490012303N South Grove
# 141    490012303E South Grove
# 142    49008160Z1 Highgate School / Hampstead Lane
# 143    490008160S Highgate School
# 144    490008160N Highgate School
# 145    490008158W Highgate Close
# Enter the number of QSI stop points: 4
# Enter the row number for QSI stop point 1: 140
# Enter the row number for QSI stop point 2: 25
# Enter the row number for QSI stop point 3: 56
# Enter the row number for QSI stop point 4: 82
# QSI Stop Points:
# 25     490010012N Moorfields Eye Hospital
# 56     490000129D King's Cross Station
# 82     490004714E Camden High Street
# 140    490012303N South Grove

# %% [markdown]
# Combined code 1

# %%
# Step 2: Install required libraries (if not already installed)
# !pip install requests pandas plotly dash

# Step 3: Import required libraries
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import display, clear_output
import plotly.express as px
import plotly.graph_objects as go
import pytz
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# Function to convert time to BST
def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')
    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)
    return bst_dt.strftime('%H:%M:%S')

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + pd.Timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None

# Fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv()
                    get_qsi_stop_points()
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Display data from CSV
def display_data_from_csv():
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Get QSI stop points
def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []
    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)
    qsi_stop_ids = []
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                qsi_stop_ids.append(row['Stop ID'])
    return qsi_stop_ids

# Main loop to fetch and display data
def main_loop(line_id, direction, qsi_stop_ids):
    while True:
        for idx, stop_point_id in enumerate(qsi_stop_ids):
            df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
            if df is not None and station_name is not None:
                clear_output(wait=True)
                total_wawt = df['WAWT'].sum()
                min_arrival = pd.to_datetime(df['Expected Arrival (BST)']).min().replace(second=0, microsecond=0)
                max_arrival = pd.to_datetime(df['Expected Arrival (BST)']).max().replace(second=0, microsecond=0)
                time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                nbph = len(df) / (time_diff_minutes / 60)
                swt = round(60 / (nbph * 2), 2)
                ewt = round(awt - swt, 2)
                summary_df = pd.DataFrame({
                    'Metric': ['Number of buses scheduled per hour (nbph)', 'Total WAWT (minutes)', 'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                    'Value': [nbph, total_wawt, time_diff_minutes, awt, swt, ewt]
                })
                print(f"Arrival Predictions for QSI Stop Point {idx + 1} ({station_name}):")
                display(df[['Line', 'Vehicle ID', 'Stop Point', 'Direction', 'Expected Arrival (BST)', 'Headway (minutes)', 'AWT/bus (minutes)', 'WAWT']])
                print("\nSummary Metrics:")
                display(summary_df)
            else:
                print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
        time.sleep(15)

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_route_details(line_id, direction)
    qsi_stop_ids = get_qsi_stop_points()
    main_loop(line_id, direction, qsi_stop_ids)
# Out:
# Arrival Predictions for QSI Stop Point 1 (Moorfields Eye Hospital):
# <ipython-input-3-46a2688d1635>:191: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   min_arrival = pd.to_datetime(df['Expected Arrival (BST)']).min().replace(second=0, microsecond=0)
# <ipython-input-3-46a2688d1635>:192: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   max_arrival = pd.to_datetime(df['Expected Arrival (BST)']).max().replace(second=0, microsecond=0)
#   Line Vehicle ID  Stop Point Direction Expected Arrival (BST)  \
# 3  214    LA19KCE  490010012N   inbound               09:43:00
# 2  214    LA19KBZ  490010012N   inbound               09:50:00
# 0  214    LA19KBU  490010012N   inbound               09:58:00
# 1  214    LA19KBV  490010012N   inbound               10:07:00
#
#    Headway (minutes)  AWT/bus (minutes)  WAWT
# 3                0.0                0.0   0.0
# 2                7.0                3.5  24.5
# 0                8.0                4.0  32.0
# 1                9.0                4.5  40.5
# Summary Metrics:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)  10.00
# 1                               Total WAWT (minutes)  97.00
# 2  Time difference between 1st and last observed ...  24.00
# 3                                      AWT (minutes)   4.04
# 4                                      SWT (minutes)   3.00
# 5                                      EWT (minutes)   1.04
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-46a2688d1635> in <cell line: 210>()
#     213     fetch_route_details(line_id, direction)
#     214     qsi_stop_ids = get_qsi_stop_points()
# --> 215     main_loop(line_id, direction, qsi_stop_ids)
#
# <ipython-input-3-46a2688d1635> in main_loop(line_id, direction, qsi_stop_ids)
#     185     while True:
#     186         for idx, stop_point_id in enumerate(qsi_stop_ids):
# --> 187             df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
#     188             if df is not None and station_name is not None:
#     189                 clear_output(wait=True)
#
# <ipython-input-3-46a2688d1635> in fetch_arrival_predictions(line_id, stop_point_id, direction)
#      31         response.raise_for_status()
#      32         data = response.json()
# ---> 33         station_name = data[0]['stationName']
#      34         predictions = []
#      35         for item in data:
#
# IndexError: list index out of range

# %%
# Step 2: Install required libraries (if not already installed)
# !pip install requests pandas plotly dash

# Step 3: Import required libraries
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import display, clear_output
import plotly.express as px
import plotly.graph_objects as go
import pytz
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import csv

# Function to convert time to BST
def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')
    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)
    return bst_dt.strftime('%H:%M:%S')

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None

# Fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv()
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Display data from CSV
def display_data_from_csv():
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Get QSI stop points
def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []
    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)
    qsi_stop_ids = []
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                qsi_stop_ids.append(row['Stop ID'])
    return qsi_stop_ids

# Main loop to fetch and display data
def main_loop(line_id, direction, qsi_stop_ids):
    while True:
        for idx, stop_point_id in enumerate(qsi_stop_ids):
            df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
            if df is not None and station_name is not None:
                clear_output(wait=True)
                total_wawt = df['WAWT'].sum()
                if not df.empty:
                    min_arrival = pd.to_datetime(df['Expected Arrival (BST)']).min().replace(second=0, microsecond=0)
                    max_arrival = pd.to_datetime(df['Expected Arrival (BST)']).max().replace(second=0, microsecond=0)
                    time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                    awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                    nbph = len(df) / (time_diff_minutes / 60)
                    swt = round(60 / (nbph * 2), 2)
                    ewt = round(awt - swt, 2)
                    summary_df = pd.DataFrame({
                        'Metric': ['Number of buses scheduled per hour (nbph)', 'Total WAWT (minutes)', 'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                        'Value': [nbph, total_wawt, time_diff_minutes, awt, swt, ewt]
                    })
                    print(f"Arrival Predictions for QSI Stop Point {idx + 1} ({station_name}):")
                    display(df[['Line', 'Vehicle ID', 'Stop Point', 'Direction', 'Expected Arrival (BST)', 'Headway (minutes)', 'AWT/bus (minutes)', 'WAWT']])
                    print("\nSummary Metrics:")
                    display(summary_df)
                else:
                    print(f"No data available for QSI Stop Point {idx + 1} ({station_name}).")
            else:
                print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
        time.sleep(15)

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_route_details(line_id, direction)
    qsi_stop_ids = get_qsi_stop_points()
    main_loop(line_id, direction, qsi_stop_ids)
# Out:
# Arrival Predictions for QSI Stop Point 1 (Moorfields Eye Hospital):
# <ipython-input-2-d3051239c772>:194: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   min_arrival = pd.to_datetime(df['Expected Arrival (BST)']).min().replace(second=0, microsecond=0)
# <ipython-input-2-d3051239c772>:195: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   max_arrival = pd.to_datetime(df['Expected Arrival (BST)']).max().replace(second=0, microsecond=0)
#   Line Vehicle ID  Stop Point Direction Expected Arrival (BST)  \
# 1  214    LA19KBV  490010012N   inbound               10:07:00
# 0  214    LA19KBP  490010012N   inbound               10:14:00
# 2  214    LA19KBY  490010012N   inbound               10:22:00
#
#    Headway (minutes)  AWT/bus (minutes)  WAWT
# 1                0.0                0.0   0.0
# 0                7.0                3.5  24.5
# 2                8.0                4.0  32.0
# Summary Metrics:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)  12.00
# 1                               Total WAWT (minutes)  56.50
# 2  Time difference between 1st and last observed ...  15.00
# 3                                      AWT (minutes)   3.77
# 4                                      SWT (minutes)   2.50
# 5                                      EWT (minutes)   1.27
# Failed to fetch data for QSI Stop Point 2.
# Failed to fetch data for QSI Stop Point 3.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d3051239c772> in <cell line: 215>()
#     218     fetch_route_details(line_id, direction)
#     219     qsi_stop_ids = get_qsi_stop_points()
# --> 220     main_loop(line_id, direction, qsi_stop_ids)
#
# <ipython-input-2-d3051239c772> in main_loop(line_id, direction, qsi_stop_ids)
#     211             else:
#     212                 print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
# --> 213         time.sleep(15)
#     214
#     215 if __name__ == "__main__":
#
# KeyboardInterrupt:

# %% [markdown]
# Only few stop point ids have next arrival data . Eg row nos: 25, 102, 125 in lineID 214 , inbound

# %%
# Step 2: Install required libraries (if not already installed)
# !pip install requests pandas plotly dash

# Step 3: Import required libraries
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import display, clear_output
import plotly.express as px
import plotly.graph_objects as go
import pytz
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import csv

# Function to convert time to BST
def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')
    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)
    return bst_dt.strftime('%H:%M:%S')

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None

# Fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv()
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Display data from CSV
def display_data_from_csv():
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Get QSI stop points
def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []
    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)
    qsi_stop_ids = []
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                qsi_stop_ids.append(row['Stop ID'])
    return qsi_stop_ids

# Main loop to fetch and display data
def main_loop(line_id, direction, qsi_stop_ids):
    while True:
        for idx, stop_point_id in enumerate(qsi_stop_ids):
            df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
            if df is not None and station_name is not None:
                clear_output(wait=True)
                total_wawt = df['WAWT'].sum()
                if not df.empty:
                    min_arrival = pd.to_datetime(df['Expected Arrival (BST)']).min().replace(second=0, microsecond=0)
                    max_arrival = pd.to_datetime(df['Expected Arrival (BST)']).max().replace(second=0, microsecond=0)
                    time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                    awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                    swt = round(60 / (nbph * 2), 2)
                    ewt = round(awt - swt, 2)
                    summary_df = pd.DataFrame({
                        'Metric': ['Number of buses scheduled per hour (nbph)', 'Total WAWT (minutes)', 'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                        'Value': [nbph, total_wawt, time_diff_minutes, awt, swt, ewt]
                    })
                    print(f"Arrival Predictions for QSI Stop Point {idx + 1} ({station_name}):")
                    display(df[['Line', 'Vehicle ID', 'Stop Point', 'Direction', 'Expected Arrival (BST)', 'Headway (minutes)', 'AWT/bus (minutes)', 'WAWT']])
                    print("\nSummary Metrics:")
                    display(summary_df)
                else:
                    print(f"No data available for QSI Stop Point {idx + 1} ({station_name}).")
            else:
                print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
        time.sleep(15)

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_route_details(line_id, direction)
    qsi_stop_ids = get_qsi_stop_points()
    main_loop(line_id, direction, qsi_stop_ids)
# Out:
# <ipython-input-4-bb08bdbea53f>:194: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   min_arrival = pd.to_datetime(df['Expected Arrival (BST)']).min().replace(second=0, microsecond=0)
# <ipython-input-4-bb08bdbea53f>:195: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   max_arrival = pd.to_datetime(df['Expected Arrival (BST)']).max().replace(second=0, microsecond=0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bb08bdbea53f> in <cell line: 214>()
#     217     fetch_route_details(line_id, direction)
#     218     qsi_stop_ids = get_qsi_stop_points()
# --> 219     main_loop(line_id, direction, qsi_stop_ids)
#
# <ipython-input-4-bb08bdbea53f> in main_loop(line_id, direction, qsi_stop_ids)
#     196                     time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
#     197                     awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
# --> 198                     swt = round(60 / (nbph * 2), 2)
#     199                     ewt = round(awt - swt, 2)
#     200                     summary_df = pd.DataFrame({
#
# NameError: name 'nbph' is not defined

# %% [markdown]
# Taking nbph input from user

# %%
# Step 2: Install required libraries (if not already installed)
# !pip install requests pandas plotly dash

# Step 3: Import required libraries
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import display, clear_output
import plotly.express as px
import plotly.graph_objects as go
import pytz
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import csv

# Function to convert time to BST
def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')
    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)
    return bst_dt.strftime('%H:%M:%S')

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None

# Fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv()
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Display data from CSV
def display_data_from_csv():
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Get QSI stop points
def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []
    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)
    qsi_stop_ids = []
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                qsi_stop_ids.append(row['Stop ID'])
    return qsi_stop_ids

# Main loop to fetch and display data
def main_loop(line_id, direction, qsi_stop_ids):
    while True:
        for idx, stop_point_id in enumerate(qsi_stop_ids):
            df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
            if df is not None and station_name is not None:
                clear_output(wait=True)
                total_wawt = df['WAWT'].sum()
                min_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').min().replace(second=0, microsecond=0)
                max_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').max().replace(second=0, microsecond=0)
                time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                nbph = float(input(f"Enter the number of buses scheduled per hour for QSI Stop Point {idx + 1} ({station_name}): "))
                awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                swt = round(60 / (nbph * 2), 2)
                ewt = round(awt - swt, 2)
                summary_df = pd.DataFrame({
                    'Metric': ['Number of buses scheduled per hour (nbph)', 'Total WAWT (minutes)', 'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                    'Value': [nbph, total_wawt, time_diff_minutes, awt, swt, ewt]
                })
                print(f"Arrival Predictions for QSI Stop Point {idx + 1} ({station_name}):")
                display(df[['Line', 'Vehicle ID', 'Stop Point', 'Direction', 'Expected Arrival (BST)', 'Headway (minutes)', 'AWT/bus (minutes)', 'WAWT']])
                print("\nSummary Metrics:")
                display(summary_df)
            else:
                print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
        time.sleep(15)

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_route_details(line_id, direction)
    qsi_stop_ids = get_qsi_stop_points()
    main_loop(line_id, direction, qsi_stop_ids)
# Out:
# Enter the number of buses scheduled per hour for QSI Stop Point 1 (Moorfields Eye Hospital): 6
# Arrival Predictions for QSI Stop Point 1 (Moorfields Eye Hospital):
#   Line Vehicle ID  Stop Point Direction Expected Arrival (BST)  \
# 3  214    LA19KBY  490010012N   inbound               10:21:00
# 2  214    LA19KBJ  490010012N   inbound               10:30:00
# 1  214    LA19KAO  490010012N   inbound               10:37:00
# 0  214    LA19KAE  490010012N   inbound               10:44:00
#
#    Headway (minutes)  AWT/bus (minutes)  WAWT
# 3                0.0                0.0   0.0
# 2                9.0                4.5  40.5
# 1                7.0                3.5  24.5
# 0                7.0                3.5  24.5
# Summary Metrics:
#                                               Metric  Value
# 0          Number of buses scheduled per hour (nbph)   6.00
# 1                               Total WAWT (minutes)  89.50
# 2  Time difference between 1st and last observed ...  23.00
# 3                                      AWT (minutes)   3.89
# 4                                      SWT (minutes)   5.00
# 5                                      EWT (minutes)  -1.11
# Failed to fetch data for QSI Stop Point 2.
# Failed to fetch data for QSI Stop Point 3.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ef17b15555a0> in <cell line: 212>()
#     215     fetch_route_details(line_id, direction)
#     216     qsi_stop_ids = get_qsi_stop_points()
# --> 217     main_loop(line_id, direction, qsi_stop_ids)
#
# <ipython-input-5-ef17b15555a0> in main_loop(line_id, direction, qsi_stop_ids)
#     208             else:
#     209                 print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
# --> 210         time.sleep(15)
#     211
#     212 if __name__ == "__main__":
#
# KeyboardInterrupt:

# %%
# Step 2: Install required libraries (if not already installed)
# !pip install requests pandas plotly dash

# Step 3: Import required libraries
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import display, clear_output
import plotly.express as px
import plotly.graph_objects as go
import pytz
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import csv

# Function to convert time to BST
def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')
    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)
    return bst_dt.strftime('%H:%M:%S')

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None

# Fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv()
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Display data from CSV
def display_data_from_csv():
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Get QSI stop points
def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []
    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)
    qsi_stop_ids = []
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                qsi_stop_ids.append(row['Stop ID'])
    return qsi_stop_ids

# Main loop to fetch and display data
def main_loop(line_id, direction, qsi_stop_ids):
    nbph = 6  # Fixed number of buses per hour for all QSI stop points
    while True:
        for idx, stop_point_id in enumerate(qsi_stop_ids):
            df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
            if df is not None and station_name is not None:
                clear_output(wait=True)
                total_wawt = df['WAWT'].sum()
                min_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').min().replace(second=0, microsecond=0)
                max_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').max().replace(second=0, microsecond=0)
                time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                swt = round(60 / (nbph * 2), 2)
                ewt = round(awt - swt, 2)
                summary_df = pd.DataFrame({
                    'Metric': ['Number of buses scheduled per hour (nbph)', 'Total WAWT (minutes)', 'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                    'Value': [nbph, total_wawt, time_diff_minutes, awt, swt, ewt]
                })
                print(f"Arrival Predictions for QSI Stop Point {idx + 1} ({station_name}):")
                display(df[['Line', 'Vehicle ID', 'Stop Point', 'Direction', 'Expected Arrival (BST)', 'Headway (minutes)', 'AWT/bus (minutes)', 'WAWT']])
                print("\nSummary Metrics:")
                display(summary_df)
            else:
                print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
        time.sleep(15)

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_route_details(line_id, direction)
    qsi_stop_ids = get_qsi_stop_points()
    main_loop(line_id, direction, qsi_stop_ids)
# Out:
# Arrival Predictions for QSI Stop Point 3 (Lady Somerset Road):
#   Line Vehicle ID  Stop Point Direction Expected Arrival (BST)  \
# 2  214    LA19KBU  490008660N   inbound               10:37:00
# 3  214    LA19KBV  490008660N   inbound               10:44:00
# 1  214    LA19KBP  490008660N   inbound               10:52:00
# 4  214    LA19KBY  490008660N   inbound               11:00:00
# 0  214    LA19KBJ  490008660N   inbound               11:06:00
#
#    Headway (minutes)  AWT/bus (minutes)  WAWT
# 2                0.0                0.0   0.0
# 3                7.0                3.5  24.5
# 1                8.0                4.0  32.0
# 4                8.0                4.0  32.0
# 0                6.0                3.0  18.0
# Summary Metrics:
#                                               Metric   Value
# 0          Number of buses scheduled per hour (nbph)    6.00
# 1                               Total WAWT (minutes)  106.50
# 2  Time difference between 1st and last observed ...   29.00
# 3                                      AWT (minutes)    3.67
# 4                                      SWT (minutes)    5.00
# 5                                      EWT (minutes)   -1.33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2d055154a535> in <cell line: 212>()
#     215     fetch_route_details(line_id, direction)
#     216     qsi_stop_ids = get_qsi_stop_points()
# --> 217     main_loop(line_id, direction, qsi_stop_ids)
#
# <ipython-input-6-2d055154a535> in main_loop(line_id, direction, qsi_stop_ids)
#     208             else:
#     209                 print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")
# --> 210         time.sleep(15)
#     211
#     212 if __name__ == "__main__":
#
# KeyboardInterrupt:

# %% [markdown]
# Working Code: Enter line ID, direction. Gives the origination and destination of the lineID. Writes the  stop points between origination and destination in the sequence as they appears in the given direction of travel. Asks the user to enter the no of QSI points and the row number corresponding to them from the csv file. Returns the arrival predictions and summary metrics of the given QSI points.

# %%
# Step 2: Install required libraries (if not already installed)
# !pip install requests pandas plotly dash

# Step 3: Import required libraries
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import display, clear_output
import plotly.express as px
import plotly.graph_objects as go
import pytz
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import csv

# Function to convert time to BST
def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')
    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)
    return bst_dt.strftime('%H:%M:%S')

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None

# Fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv()
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Display data from CSV
def display_data_from_csv():
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Get QSI stop points
def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []
    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)
    qsi_stop_ids = []
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                qsi_stop_ids.append(row['Stop ID'])
    return qsi_stop_ids

# Main loop to fetch and display data
def main_loop(line_id, direction, qsi_stop_ids):
    nbph = 6  # Fixed number of buses per hour for all QSI stop points
    while True:
        qsi_data = []  # List to accumulate data for all QSI stop points
        for idx, stop_point_id in enumerate(qsi_stop_ids):
            df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
            if df is not None and station_name is not None:
                total_wawt = df['WAWT'].sum()
                min_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').min().replace(second=0, microsecond=0)
                max_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').max().replace(second=0, microsecond=0)
                time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                swt = round(60 / (nbph * 2), 2)
                ewt = round(awt - swt, 2)
                summary_df = pd.DataFrame({
                    'Metric': ['Number of buses scheduled per hour (nbph)', 'Total WAWT (minutes)', 'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                    'Value': [nbph, total_wawt, time_diff_minutes, awt, swt, ewt]
                })
                qsi_data.append({
                    'QSI Stop Point': f"{idx + 1} - {station_name}",
                    'Arrival Predictions': df[['Line', 'Vehicle ID', 'Stop Point', 'Direction', 'Expected Arrival (BST)', 'Headway (minutes)', 'AWT/bus (minutes)', 'WAWT']].to_string(index=False),
                    'Summary Metrics': summary_df.to_string(index=False)
                })
            else:
                print(f"Failed to fetch data for QSI Stop Point {idx + 1}.")

        clear_output(wait=True)
        for qsi in qsi_data:
            print(f"QSI Stop Point: {qsi['QSI Stop Point']}")
            print("Arrival Predictions:")
            print(qsi['Arrival Predictions'])
            print("\nSummary Metrics:")
            print(qsi['Summary Metrics'])
            print("\n--------------------------------------------\n")

        time.sleep(15)

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_route_details(line_id, direction)
    qsi_stop_ids = get_qsi_stop_points()
    main_loop(line_id, direction, qsi_stop_ids)
# Out:
# QSI Stop Point: 1 - Commondale
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    LF67EWP 490012375E  outbound               11:36:00                0.0                0.0   0.0
#   22    BV66VHK 490012375E  outbound               11:47:00               11.0                5.5  60.5
#   22    BV66VLN 490012375E  outbound               11:58:00               11.0                5.5  60.5
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)    6.0
#                                          Total WAWT (minutes)  121.0
# Time difference between 1st and last observed buses (minutes)   22.0
#                                                 AWT (minutes)    5.5
#                                                 SWT (minutes)    5.0
#                                                 EWT (minutes)    0.5
#
# --------------------------------------------
#
# QSI Stop Point: 2 - Putney Bridge Stn / Fulham High Street
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    BV66VJO 490008435E  outbound               11:33:00                0.0                0.0   0.0
#   22    YY66OZK 490008435E  outbound               11:36:00                3.0                1.5   4.5
#   22    LF67EWP 490008435E  outbound               11:45:00                9.0                4.5  40.5
#   22    BV66VHK 490008435E  outbound               11:56:00               11.0                5.5  60.5
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)   6.00
#                                          Total WAWT (minutes) 105.50
# Time difference between 1st and last observed buses (minutes)  23.00
#                                                 AWT (minutes)   4.59
#                                                 SWT (minutes)   5.00
#                                                 EWT (minutes)  -0.41
#
# --------------------------------------------
#
# QSI Stop Point: 4 - Worlds End Health Centre
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    YY66OYW 490009370E  outbound               11:36:00                0.0                0.0   0.0
#   22    BV66VJO 490009370E  outbound               11:45:00                9.0                4.5  40.5
#   22    YY66OZK 490009370E  outbound               11:46:00                1.0                0.5   0.5
#   22    LF67EWP 490009370E  outbound               11:58:00               12.0                6.0  72.0
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)   6.00
#                                          Total WAWT (minutes) 113.00
# Time difference between 1st and last observed buses (minutes)  22.00
#                                                 AWT (minutes)   5.14
#                                                 SWT (minutes)   5.00
#                                                 EWT (minutes)   0.14
#
# --------------------------------------------
#
# QSI Stop Point: 5 - Beaufort Street
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    YY66OYW 490015145E  outbound               11:40:00                0.0                0.0   0.0
#   22    BV66VJO 490015145E  outbound               11:50:00               10.0                5.0  50.0
#   22    YY66OZK 490015145E  outbound               11:51:00                1.0                0.5   0.5
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)   6.00
#                                          Total WAWT (minutes)  50.50
# Time difference between 1st and last observed buses (minutes)  11.00
#                                                 AWT (minutes)   4.59
#                                                 SWT (minutes)   5.00
#                                                 EWT (minutes)  -0.41
#
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0000b37a86b8> in <cell line: 223>()
#     226     fetch_route_details(line_id, direction)
#     227     qsi_stop_ids = get_qsi_stop_points()
# --> 228     main_loop(line_id, direction, qsi_stop_ids)
#
# <ipython-input-9-0000b37a86b8> in main_loop(line_id, direction, qsi_stop_ids)
#     219             print("\n--------------------------------------------\n")
#     220
# --> 221         time.sleep(15)
#     222
#     223 if __name__ == "__main__":
#
# KeyboardInterrupt:

# %%
# Step 2: Install required libraries (if not already installed)
# !pip install requests pandas plotly dash

# Step 3: Import required libraries
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import display, clear_output
import plotly.express as px
import plotly.graph_objects as go
import pytz
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import csv

# Function to convert time to BST
def convert_to_bst(dt):
    utc_tz = pytz.timezone('UTC')
    bst_tz = pytz.timezone('Europe/London')
    utc_dt = utc_tz.localize(dt)
    bst_dt = utc_dt.astimezone(bst_tz)
    return bst_dt.strftime('%H:%M:%S')

# Function to fetch arrival predictions with error handling
def fetch_arrival_predictions(line_id, stop_point_id, direction):
    try:
        base_url = f"https://api.tfl.gov.uk/Line/{line_id}/Arrivals/{stop_point_id}"
        params = {'direction': direction}
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        if len(data) == 0:
            return pd.DataFrame(), None  # No data available
        station_name = data[0]['stationName']
        predictions = []
        for item in data:
            arrival_time = datetime.strptime(item['expectedArrival'], '%Y-%m-%dT%H:%M:%SZ')
            arrival_time_bst = arrival_time + timedelta(hours=1)
            predictions.append({
                'Line': item['lineName'],
                'Vehicle ID': item['vehicleId'],
                'Stop Point': stop_point_id,
                'Direction': direction,
                'Expected Arrival (BST)': arrival_time_bst,
                'Expected Arrival (HM)': arrival_time_bst.strftime('%H:%M')
            })
        df = pd.DataFrame(predictions)
        df = df.sort_values(by='Expected Arrival (BST)', ascending=True)
        df['Expected Arrival (HM)'] = pd.to_datetime(df['Expected Arrival (HM)'], format='%H:%M')
        df['Headway (minutes)'] = df['Expected Arrival (HM)'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds() / 60
        df['AWT/bus (minutes)'] = (df['Headway (minutes)'] / 2).round(2)
        df['WAWT'] = (df['Headway (minutes)'] * df['AWT/bus (minutes)']).round(2)
        df['Expected Arrival (BST)'] = df['Expected Arrival (BST)'].apply(lambda x: x.replace(second=0, microsecond=0).strftime('%H:%M:%S'))
        return df, station_name
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None, None

# Fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv()
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Display data from CSV
def display_data_from_csv():
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for row in reader:
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

# Get QSI stop points
def get_qsi_stop_points():
    count_of_qsi_stop_points = int(input("Enter the number of QSI stop points: "))
    qsi_stop_points = []
    for i in range(count_of_qsi_stop_points):
        row_no = int(input(f"Enter the row number for QSI stop point {i+1}: "))
        qsi_stop_points.append(row_no)
    qsi_stop_ids = []
    print("QSI Stop Points:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if int(row['Sl. No.']) in qsi_stop_points:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                qsi_stop_ids.append(row['Stop ID'])
    return qsi_stop_ids

# Main loop to fetch and display data
def main_loop(line_id, direction, qsi_stop_ids):
    nbph = 6  # Fixed number of buses per hour for all QSI stop points
    while True:
        qsi_data = []  # List to accumulate data for all QSI stop points
        for idx, stop_point_id in enumerate(qsi_stop_ids):
            df, station_name = fetch_arrival_predictions(line_id, stop_point_id, direction)
            if df is not None and station_name is not None:
                total_wawt = df['WAWT'].sum()
                min_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').min().replace(second=0, microsecond=0)
                max_arrival = pd.to_datetime(df['Expected Arrival (BST)'], format='%H:%M:%S').max().replace(second=0, microsecond=0)
                time_diff_minutes = (max_arrival - min_arrival).total_seconds() / 60
                awt = round(total_wawt / time_diff_minutes, 2) if time_diff_minutes > 0 else 0
                swt = round(60 / (nbph * 2), 2)
                ewt = round(awt - swt, 2)
                summary_df = pd.DataFrame({
                    'Metric': ['Number of buses scheduled per hour (nbph)', 'Total WAWT (minutes)', 'Time difference between 1st and last observed buses (minutes)', 'AWT (minutes)', 'SWT (minutes)', 'EWT (minutes)'],
                    'Value': [nbph, total_wawt, time_diff_minutes, awt, swt, ewt]
                })
                qsi_data.append({
                    'QSI Stop Point': f"{idx + 1} - {station_name}",
                    'Arrival Predictions': df[['Line', 'Vehicle ID', 'Stop Point', 'Direction', 'Expected Arrival (BST)', 'Headway (minutes)', 'AWT/bus (minutes)', 'WAWT']].to_string(index=False),
                    'Summary Metrics': summary_df.to_string(index=False)
                })
            else:
                qsi_data.append({
                    'QSI Stop Point': f"{idx + 1} - Fetch Error",
                    'Arrival Predictions': "No data available",
                    'Summary Metrics': "No data available"
                })

        clear_output(wait=True)
        for qsi in qsi_data:
            print(f"QSI Stop Point: {qsi['QSI Stop Point']}")
            print("Arrival Predictions:")
            print(qsi['Arrival Predictions'])
            print("\nSummary Metrics:")
            print(qsi['Summary Metrics'])
            print("\n--------------------------------------------\n")

        time.sleep(15)

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    direction = input("Enter direction (e.g., inbound or outbound): ")
    fetch_route_details(line_id, direction)
    qsi_stop_ids = get_qsi_stop_points()
    main_loop(line_id, direction, qsi_stop_ids)
# Out:
# QSI Stop Point: 1 - Commondale
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    BV66VHK 490012375E  outbound               11:47:00                0.0                0.0   0.0
#   22    BV66VLN 490012375E  outbound               11:58:00               11.0                5.5  60.5
#   22    BV66VJN 490012375E  outbound               12:10:00               12.0                6.0  72.0
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)   6.00
#                                          Total WAWT (minutes) 132.50
# Time difference between 1st and last observed buses (minutes)  23.00
#                                                 AWT (minutes)   5.76
#                                                 SWT (minutes)   5.00
#                                                 EWT (minutes)   0.76
#
# --------------------------------------------
#
# QSI Stop Point: 2 - Putney Bridge Stn / Fulham High Street
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    LF67EWP 490008435E  outbound               11:46:00                0.0                0.0   0.0
#   22    BV66VHK 490008435E  outbound               11:56:00               10.0                5.0  50.0
#   22    BV66VLN 490008435E  outbound               12:07:00               11.0                5.5  60.5
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)   6.00
#                                          Total WAWT (minutes) 110.50
# Time difference between 1st and last observed buses (minutes)  21.00
#                                                 AWT (minutes)   5.26
#                                                 SWT (minutes)   5.00
#                                                 EWT (minutes)   0.26
#
# --------------------------------------------
#
# QSI Stop Point: 3 - Fetch Error
# Arrival Predictions:
# No data available
#
# Summary Metrics:
# No data available
#
# --------------------------------------------
#
# QSI Stop Point: 4 - Worlds End Health Centre
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    YY66OZK 490009370E  outbound               11:52:00                0.0                0.0   0.0
#   22    LF67EWP 490009370E  outbound               11:58:00                6.0                3.0  18.0
#   22    BV66VHK 490009370E  outbound               12:08:00               10.0                5.0  50.0
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)   6.00
#                                          Total WAWT (minutes)  68.00
# Time difference between 1st and last observed buses (minutes)  16.00
#                                                 AWT (minutes)   4.25
#                                                 SWT (minutes)   5.00
#                                                 EWT (minutes)  -0.75
#
# --------------------------------------------
#
# QSI Stop Point: 5 - Beaufort Street
# Arrival Predictions:
# Line Vehicle ID Stop Point Direction Expected Arrival (BST)  Headway (minutes)  AWT/bus (minutes)  WAWT
#   22    BV66VJO 490015145E  outbound               11:47:00                0.0                0.0   0.0
#   22    YY66OZK 490015145E  outbound               11:55:00                8.0                4.0  32.0
#   22    LF67EWP 490015145E  outbound               12:02:00                7.0                3.5  24.5
#   22    BV66VHK 490015145E  outbound               12:12:00               10.0                5.0  50.0
#
# Summary Metrics:
#                                                        Metric  Value
#                     Number of buses scheduled per hour (nbph)   6.00
#                                          Total WAWT (minutes) 106.50
# Time difference between 1st and last observed buses (minutes)  25.00
#                                                 AWT (minutes)   4.26
#                                                 SWT (minutes)   5.00
#                                                 EWT (minutes)  -0.74
#
# --------------------------------------------
