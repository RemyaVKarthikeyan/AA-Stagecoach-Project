# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaVKarthikeyan/AA-Stagecoach-Project/blob/main/02_07_2024_Fetching_the_QSI_points_for_the_given_line_ID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import pandas as pd

# Path to the uploaded file (Assuming it's saved in the Colab environment)
file_path = '/content/QSI points.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to understand its structure
df.head()

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route' column exists
    if 'Route' not in df.columns:
        print("The 'Route' column is not present in the provided file.")
        return

    # Filter the DataFrame based on the lineID
    pattern_A = f"{lineID}_A"
    pattern_B = f"{lineID}_B"

    # Filter rows where the 'Route' column contains the patterns
    filtered_df_A = df[df['Route'].str.contains(pattern_A, na=False)]
    filtered_df_B = df[df['Route'].str.contains(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]
        print(result_df)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 122
# The 'Route' column is not present in the provided file.

# %%
# Importing necessary libraries
import pandas as pd

# Path to the uploaded file (Assuming it's saved in the Colab environment)
file_path = '/content/QSI points.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to understand its structure
df.head()

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'ROUTE' column exists
    if 'ROUTE' not in df.columns:
        print("The 'ROUTE' column is not present in the provided file.")
        return

    # Filter the DataFrame based on the lineID
    pattern_A = f"{lineID}_A"
    pattern_B = f"{lineID}_B"

    # Filter rows where the 'ROUTE' column contains the patterns
    filtered_df_A = df[df['ROUTE'].str.contains(pattern_A, na=False)]
    filtered_df_B = df[df['ROUTE'].str.contains(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]
        print(result_df)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 122
# No matching records found for lineID: 122

# %%
# Importing necessary libraries
import pandas as pd

# Path to the uploaded file (Assuming it's saved in the Colab environment)
file_path = '/content/QSI points.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to understand its structure
df.head()

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Filter the DataFrame based on the lineID
    pattern_A = f"{lineID}_A"
    pattern_B = f"{lineID}_B"

    # Filter rows where the 'Route_Dir_QSI_No' column contains the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.contains(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.contains(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['QSI_No','Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]
        print(result_df)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 122
#     QSI_No Route_Dir_QSI_No STOP_NUMBER  \
# 0        1           122_A1       36510
# 1        2           122_A2       35483
# 2        3           122_A3       26653
# 3        4           122_A4       20134
# 4        5           122_A5       18188
# 5        6           122_A6      BP1115
# 6        7           122_A7       13875
# 7        8           122_A8       13869
# 8        9           122_A9       29309
# 9       10          122_A10       17317
# 10       1           122_B1      BP2417
# 11       2           122_B2       17316
# 12       3           122_B3       17307
# 13       4           122_B4       34481
# 14       5           122_B5       13874
# 15       6           122_B6      BP1114
# 16       7           122_B7      BP4533
# 17       8           122_B8       26679
# 18       9           122_B9       26654
#
#                                  STOP_NAME
# 0       Plumstead Road / Plumstead Station
# 1                 Woolwich Arsenal Station
# 2      Well Hall Road / Shooters Hill Road
# 3           Eltham Road / Westhorne Avenue
# 4                                Lee Green
# 5                          Lewisham Centre
# 6                     Crofton Park Station
# 7                  Brockley Rise / Chandos
# 8   Forest Hill Station  / Devonshire Road
# 9             Sydenham Station  / Kirkdale
# 10                   Crystal Palace Parade
# 11            Sydenham Station  / Kirkdale
# 12   Forest Hill Station  / Dartmouth Road
# 13           Stondon Park / Honor Oak Park
# 14                           Beecroft Road
# 15                         Lewisham Centre
# 16                               Lee Green
# 17          Eltham Road / Westhorne Avenue
# 18       Academy Road / Shooters Hill Road

# %%
# Importing necessary libraries
import pandas as pd

# Path to the uploaded file (Assuming it's saved in the Colab environment)
file_path = '/content/QSI points.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to understand its structure
df.head()

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Filter the DataFrame based on the lineID
    pattern_A = f"{lineID}_A"
    pattern_B = f"{lineID}_B"

    # Filter rows where the 'Route_Dir_QSI_No' column contains the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.contains(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.contains(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 179
#    Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0            179_A1       34016                    Chingford Station
# 1            179_A2       15316                          Friday Hill
# 2            179_A3       15334      Woodford Green / Broadmead Road
# 3            179_A4       29463               South Woodford Station
# 4            179_A5       R0499           Charlie Brown'S Roundabout
# 5            179_A6        8622  Gants Hill Station / Cranbrook Road
# 6            179_A7        FC46                       Ilford Station
# 7            179_B1        FC04                      Hainault Street
# 8            179_B2        FC39                       Ilford Station
# 9            179_B3        8621  Gants Hill Station / Cranbrook Road
# 10           179_B4       R0498                        Southend Road
# 11           179_B5        7509               South Woodford Station
# 12           179_B6        4363      Woodford Green / Broadmead Road
# 13           179_B7       R0478             Kings Road / Friday Hill

# %%
# Importing necessary libraries
import pandas as pd

# Path to the uploaded file (Assuming it's saved in the Colab environment)
file_path = '/content/QSI points.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to understand its structure
df.head()

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"{lineID}_A"
    pattern_B = f"{lineID}_B"

    # Filter rows where the 'Route_Dir_QSI_No' column contains the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.contains(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.contains(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: D7
#    Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0             D7_A1       34215   Poplar / All Saints Church
# 1             D7_A2       15157               Stewart Street
# 2             D7_A3       16347       Island Gardens Station
# 3             D7_A4         559  Arnhem Wharf Primary School
# 4             D7_A5       25270         East India Dock Road
# 5             D7_B1        1422  Mile End Station / Bow Road
# 6             D7_B2       R0780         East India Dock Road
# 7             D7_B3  R0315____2         Canary Wharf Station
# 8             D7_B4       13418  Arnhem Wharf Primary School
# 9             D7_B5      BP1802       Island Gardens Station
# 10            D7_B6       15156               Stewart Street

# %% [markdown]
# File share 12-Fetching the QSI points of the given line ID

# %%
# Importing necessary libraries
import pandas as pd

# Path to the uploaded file (Assuming it's saved in the Colab environment)
file_path = '/content/QSI points.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to understand its structure
df.head()

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#    Route_Dir_QSI_No STOP_NUMBER                              STOP_NAME
# 0             25_A1        FC41                        Hainault Street
# 1             25_A2        4643                      High Street North
# 2             25_A3       14581                           Green Street
# 3             25_A4      BP6275                  Stratford Bus Station
# 4             25_A5       25096                     Bow Church Station
# 5             25_A6        4826                       Mile End Station
# 6             25_A7         943   Whitechapel Stn  / Royal London Hosp
# 7             25_A8       33683                        Aldgate Station
# 8             25_A9        8559               Bank Station  / Cornhill
# 9             25_B1        2018                         Holborn Circus
# 10            25_B2        8558               Bank Station  / Cornhill
# 11            25_B3      BP5998                        Aldgate Station
# 12            25_B4         944  Whitechapel Stn   / Royal London Hosp
# 13            25_B5       20674                       Mile End Station
# 14            25_B6         902                     Bow Church Station
# 15            25_B7       BP976                  Stratford Bus Station
# 16            25_B8        4644                      High Street North

# %%
# Importing necessary libraries
import pandas as pd
import requests

# Path to the uploaded file (Assuming it's saved in the Colab environment)
file_path = '/content/QSI points.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to understand its structure
df.head()

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # Fetch additional details for each stop point
        for index, row in result_df.iterrows():
            direction = 'inbound' if '_A' in row['Route_Dir_QSI_No'] else 'outbound'
            stop_details = get_stop_details(lineID, direction)
            print(f"Details for {row['STOP_NAME']} ({direction}):")
            print(stop_details)
            print('--------------------------------')

# Function to call TfL API and get stop point details
def get_stop_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        stop_points = data.get('stopPointSequences', [])
        return stop_points
    else:
        return f"Error fetching details: {response.status_code}"

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#    Route_Dir_QSI_No STOP_NUMBER                              STOP_NAME
# 0             25_A1        FC41                        Hainault Street
# 1             25_A2        4643                      High Street North
# 2             25_A3       14581                           Green Street
# 3             25_A4      BP6275                  Stratford Bus Station
# 4             25_A5       25096                     Bow Church Station
# 5             25_A6        4826                       Mile End Station
# 6             25_A7         943   Whitechapel Stn  / Royal London Hosp
# 7             25_A8       33683                        Aldgate Station
# 8             25_A9        8559               Bank Station  / Cornhill
# 9             25_B1        2018                         Holborn Circus
# 10            25_B2        8558               Bank Station  / Cornhill
# 11            25_B3      BP5998                        Aldgate Station
# 12            25_B4         944  Whitechapel Stn   / Royal London Hosp
# 13            25_B5       20674                       Mile End Station
# 14            25_B6         902                     Bow Church Station
# 15            25_B7       BP976                  Stratford Bus Station
# 16            25_B8        4644                      High Street North
# Details for Hainault Street (inbound):
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPointSequence, Tfl.Api.Presentation.Entities', 'lineId': '25', 'lineName': '25', 'direction': 'inbound', 'branchId': 0, 'nextBranchIds': [], 'prevBranchIds': [], 'stopPoint': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G000621', 'stationId': '490G000621', 'icsId': '1008748', 'topMostParentId': '490G000621', 'towards': 'Bank, Barbican Or London Bridge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'ST', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '56', 'name': '56', 'uri': '/Line/56', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '8', 'name': '8', 'uri': '/Line/8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n242', 'name': 'N242', 'uri': '/Line/n242', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n25', 'name': 'N25', 'uri': '/Line/n25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n8', 'name': 'N8', 'uri': '/Line/n8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}], 'status': True, 'id': '490000225S', 'name': 'King Edward Street', 'lat': 51.515717, 'lon': -0.09984}, {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G00008743', 'stationId': '490G00008743', 'icsId': '1008743', 'topMostParentId': '490G00008743', 'towards': 'Angel Islington Or Moorgate', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'SV', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '100', 'name': '100', 'uri': '/Line/100', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '4', 'name': '4', 'uri': '/Line/4', ...
# --------------------------------
# Details for High Street North (inbound):
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPointSequence, Tfl.Api.Presentation.Entities', 'lineId': '25', 'lineName': '25', 'direction': 'inbound', 'branchId': 0, 'nextBranchIds': [], 'prevBranchIds': [], 'stopPoint': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G000621', 'stationId': '490G000621', 'icsId': '1008748', 'topMostParentId': '490G000621', 'towards': 'Bank, Barbican Or London Bridge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'ST', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '56', 'name': '56', 'uri': '/Line/56', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '8', 'name': '8', 'uri': '/Line/8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n242', 'name': 'N242', 'uri': '/Line/n242', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n25', 'name': 'N25', 'uri': '/Line/n25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n8', 'name': 'N8', 'uri': '/Line/n8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}], 'status': True, 'id': '490000225S', 'name': 'King Edward Street', 'lat': 51.515717, 'lon': -0.09984}, {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G00008743', 'stationId': '490G00008743', 'icsId': '1008743', 'topMostParentId': '490G00008743', 'towards': 'Angel Islington Or Moorgate', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'SV', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '100', 'name': '100', 'uri': '/Line/100', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '4', 'name': '4', 'uri': '/Line/4', ...
# --------------------------------
# Details for Green Street (inbound):
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPointSequence, Tfl.Api.Presentation.Entities', 'lineId': '25', 'lineName': '25', 'direction': 'inbound', 'branchId': 0, 'nextBranchIds': [], 'prevBranchIds': [], 'stopPoint': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G000621', 'stationId': '490G000621', 'icsId': '1008748', 'topMostParentId': '490G000621', 'towards': 'Bank, Barbican Or London Bridge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'ST', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '56', 'name': '56', 'uri': '/Line/56', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '8', 'name': '8', 'uri': '/Line/8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n242', 'name': 'N242', 'uri': '/Line/n242', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n25', 'name': 'N25', 'uri': '/Line/n25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n8', 'name': 'N8', 'uri': '/Line/n8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}], 'status': True, 'id': '490000225S', 'name': 'King Edward Street', 'lat': 51.515717, 'lon': -0.09984}, {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G00008743', 'stationId': '490G00008743', 'icsId': '1008743', 'topMostParentId': '490G00008743', 'towards': 'Angel Islington Or Moorgate', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'SV', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '100', 'name': '100', 'uri': '/Line/100', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '4', 'name': '4', 'uri': '/Line/4', ...
# --------------------------------
# Details for Stratford Bus Station (inbound):
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPointSequence, Tfl.Api.Presentation.Entities', 'lineId': '25', 'lineName': '25', 'direction': 'inbound', 'branchId': 0, 'nextBranchIds': [], 'prevBranchIds': [], 'stopPoint': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G000621', 'stationId': '490G000621', 'icsId': '1008748', 'topMostParentId': '490G000621', 'towards': 'Bank, Barbican Or London Bridge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'ST', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '56', 'name': '56', 'uri': '/Line/56', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '8', 'name': '8', 'uri': '/Line/8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n242', 'name': 'N242', 'uri': '/Line/n242', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n25', 'name': 'N25', 'uri': '/Line/n25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n8', 'name': 'N8', 'uri': '/Line/n8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}], 'status': True, 'id': '490000225S', 'name': 'King Edward Street', 'lat': 51.515717, 'lon': -0.09984}, {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G00008743', 'stationId': '490G00008743', 'icsId': '1008743', 'topMostParentId': '490G00008743', 'towards': 'Angel Islington Or Moorgate', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'SV', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '100', 'name': '100', 'uri': '/Line/100', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '4', 'name': '4', 'uri': '/Line/4', ...
# --------------------------------
# Details for Bow Church Station (inbound):
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPointSequence, Tfl.Api.Presentation.Entities', 'lineId': '25', 'lineName': '25', 'direction': 'inbound', 'branchId': 0, 'nextBranchIds': [], 'prevBranchIds': [], 'stopPoint': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G000621', 'stationId': '490G000621', 'icsId': '1008748', 'topMostParentId': '490G000621', 'towards': 'Bank, Barbican Or London Bridge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'ST', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '56', 'name': '56', 'uri': '/Line/56', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '8', 'name': '8', 'uri': '/Line/8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n242', 'name': 'N242', 'uri': '/Line/n242', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n25', 'name': 'N25', 'uri': '/Line/n25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n8', 'name': 'N8', 'uri': '/Line/n8', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}], 'status': True, 'id': '490000225S', 'name': 'King Edward Street', 'lat': 51.515717, 'lon': -0.09984}, {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G00008743', 'stationId': '490G00008743', 'icsId': '1008743', 'topMostParentId': '490G00008743', 'towards': 'Angel Islington Or Moorgate', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'SV', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '100', 'name': '100', 'uri': '/Line/100', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '133', 'name': '133', 'uri': '/Line/133', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '4', 'name': '4', 'uri': '/Line/4', ...
# --------------------------------
# Details for Mile End Station (inbound):
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPointSequence, Tfl.Api.Presentation.Entities', 'lineId': '25', 'lineName': '25', 'direction': 'inbound', 'branchId': 0, 'nextBranchIds': [], 'prevBranchIds': [], 'stopPoint': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G000621', 'stationId': '490G000621', 'icsId': '1008748', 'topMostParentId': '490G000621', 'towards': 'Bank, Barbican Or London Bridge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 
ge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'Q', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '123', 'name': '123', 'uri': '/Line/123', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '128', 'name': '128', 'uri': '/Line/128', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '145', 'name': '1 ...
# --------------------------------
# Details for High Street North (outbound):
# [{'$type': 'Tfl.Api.Presentation.Entities.StopPointSequence, Tfl.Api.Presentation.Entities', 'lineId': '25', 'lineName': '25', 'direction': 'outbound', 'branchId': 1, 'nextBranchIds': [], 'prevBranchIds': [], 'stopPoint': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G00007657', 'stationId': '490G00007657', 'icsId': '1007657', 'topMostParentId': '490G00007657', 'towards': 'Manor Park Or Barking', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'V', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '147', 'name': '147', 'uri': '/Line/147', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '169', 'name': '169', 'uri': '/Line/169', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '25', 'name': '25', 'uri': '/Line/25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '425', 'name': '425', 'uri': '/Line/425', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '86', 'name': '86', 'uri': '/Line/86', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n25', 'name': 'N25', 'uri': '/Line/n25', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'n86', 'name': 'N86', 'uri': '/Line/n86', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': 'w19', 'name': 'W19', 'uri': '/Line/w19', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}], 'status': True, 'id': '490007657V', 'name': 'Hainault Street', 'lat': 51.559319, 'lon': 0.076008}, {'$type': 'Tfl.Api.Presentation.Entities.MatchedStop, Tfl.Api.Presentation.Entities', 'parentId': '490G00008466', 'stationId': '490G00008466', 'icsId': '1008466', 'topMostParentId': '490G00008466', 'towards': 'Barking, Gants Hill, Manor Park Or Redbridge', 'modes': ['bus'], 'stopType': 'NaptanPublicBusCoachTram', 'stopLetter': 'Q', 'lines': [{'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '123', 'name': '123', 'uri': '/Line/123', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '128', 'name': '128', 'uri': '/Line/128', 'type': 'Line', 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}, 'routeType': 'Unknown', 'status': 'Unknown'}, {'$type': 'Tfl.Api.Presentation.Entities.Identifier, Tfl.Api.Presentation.Entities', 'id': '145', 'name': '1 ...
# --------------------------------

# %%
import pandas as pd
import requests

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
        return

    # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
    result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

    # Reset the index of the DataFrame and drop the old index column
    result_df.reset_index(drop=True, inplace=True)

    # Print the resulting DataFrame
    print(result_df)

    # Fetching stop details from TFL API based on stop names
    for stop_name in result_df['STOP_NAME']:
        # Define TFL API URL for inbound and outbound directions
        api_url_inbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        api_url_outbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/outbound"

        # Fetch stop details for inbound direction
        response_inbound = requests.get(api_url_inbound)
        if response_inbound.status_code == 200:
            inbound_data = response_inbound.json()['stations']
            for station in inbound_data:
                if station['name'] == stop_name:
                    print(f"ID: {station['id']}, Name: {station['name']}")

        # Fetch stop details for outbound direction
        response_outbound = requests.get(api_url_outbound)
        if response_outbound.status_code == 200:
            outbound_data = response_outbound.json()['stations']
            for station in outbound_data:
                if station['name'] == stop_name:
                    print(f"ID: {station['id']}, Name: {station['name']}")

# Assuming 'df' is already loaded with your Excel data (as shown in your original code)
# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 179
#    Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0            179_A1       34016                    Chingford Station
# 1            179_A2       15316                          Friday Hill
# 2            179_A3       15334      Woodford Green / Broadmead Road
# 3            179_A4       29463               South Woodford Station
# 4            179_A5       R0499           Charlie Brown'S Roundabout
# 5            179_A6        8622  Gants Hill Station / Cranbrook Road
# 6            179_A7        FC46                       Ilford Station
# 7            179_B1        FC04                      Hainault Street
# 8            179_B2        FC39                       Ilford Station
# 9            179_B3        8621  Gants Hill Station / Cranbrook Road
# 10           179_B4       R0498                        Southend Road
# 11           179_B5        7509               South Woodford Station
# 12           179_B6        4363      Woodford Green / Broadmead Road
# 13           179_B7       R0478             Kings Road / Friday Hill
# ID: 490G00007021, Name: Friday Hill
# ID: 490G000842, Name: Woodford Green / Broadmead Road
# ID: 490G000842, Name: Woodford Green / Broadmead Road
# ID: 490G000878, Name: Gants Hill Station / Cranbrook Road
# ID: 490G000878, Name: Gants Hill Station / Cranbrook Road
# ID: 490G00007657, Name: Hainault Street
# ID: 490G00007657, Name: Hainault Street
# ID: 490G000878, Name: Gants Hill Station / Cranbrook Road
# ID: 490G000878, Name: Gants Hill Station / Cranbrook Road
# ID: 490G00007138, Name: Southend Road
# ID: 490G00012285, Name: Southend Road
# ID: 490G00007138, Name: Southend Road
# ID: 490G000842, Name: Woodford Green / Broadmead Road
# ID: 490G000842, Name: Woodford Green / Broadmead Road
# ID: 490G00007022, Name: Kings Road / Friday Hill

# %%
import pandas as pd
import requests

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
        return

    # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
    result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

    # Reset the index of the DataFrame and drop the old index column
    result_df.reset_index(drop=True, inplace=True)

    # Print the resulting DataFrame
    print(result_df)

    # Lists to store IDs for inbound and outbound directions
    inbound_ids = []
    outbound_ids = []

    # Fetching stop details from TFL API based on stop names
    for stop_name in result_df['STOP_NAME']:
        # Define TFL API URL for inbound and outbound directions
        api_url_inbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        api_url_outbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/outbound"

        # Fetch stop details for inbound direction
        response_inbound = requests.get(api_url_inbound)
        if response_inbound.status_code == 200:
            inbound_data = response_inbound.json()['stations']
            for station in inbound_data:
                if station['name'] == stop_name:
                    inbound_ids.append(station['id'])

        # Fetch stop details for outbound direction
        response_outbound = requests.get(api_url_outbound)
        if response_outbound.status_code == 200:
            outbound_data = response_outbound.json()['stations']
            for station in outbound_data:
                if station['name'] == stop_name:
                    outbound_ids.append(station['id'])

    # Print IDs for inbound and outbound directions
    if inbound_ids:
        print(f"Inbound IDs: {', '.join(inbound_ids)}")
    if outbound_ids:
        print(f"Outbound IDs: {', '.join(outbound_ids)}")

# Assuming 'df' is already loaded with your Excel data (as shown in your original code)
# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 179
#    Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0            179_A1       34016                    Chingford Station
# 1            179_A2       15316                          Friday Hill
# 2            179_A3       15334      Woodford Green / Broadmead Road
# 3            179_A4       29463               South Woodford Station
# 4            179_A5       R0499           Charlie Brown'S Roundabout
# 5            179_A6        8622  Gants Hill Station / Cranbrook Road
# 6            179_A7        FC46                       Ilford Station
# 7            179_B1        FC04                      Hainault Street
# 8            179_B2        FC39                       Ilford Station
# 9            179_B3        8621  Gants Hill Station / Cranbrook Road
# 10           179_B4       R0498                        Southend Road
# 11           179_B5        7509               South Woodford Station
# 12           179_B6        4363      Woodford Green / Broadmead Road
# 13           179_B7       R0478             Kings Road / Friday Hill
# Inbound IDs: 490G000842, 490G000878, 490G00007657, 490G000878, 490G00007138, 490G00012285, 490G000842, 490G00007022
# Outbound IDs: 490G00007021, 490G000842, 490G000878, 490G00007657, 490G000878, 490G00007138, 490G000842

# %%
import pandas as pd
import requests
import csv

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
        return

    # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
    result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

    # Reset the index of the DataFrame and drop the old index column
    result_df.reset_index(drop=True, inplace=True)

    # Print the resulting DataFrame
    print(result_df)

    # Lists to store IDs for inbound and outbound directions
    all_stop_details = []

    # Fetching stop details from TFL API based on stop names
    for stop_name in result_df['STOP_NAME']:
        # Define TFL API URL for inbound and outbound directions
        api_url_inbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        api_url_outbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/outbound"

        # Fetch and append stop details for inbound direction
        fetch_and_append_stop_points(lineID, api_url_inbound, stop_name, all_stop_details)

        # Fetch and append stop details for outbound direction
        fetch_and_append_stop_points(lineID, api_url_outbound, stop_name, all_stop_details)

    # Write to CSV
    write_to_csv(all_stop_details)

def fetch_and_append_stop_points(line_id, url, stop_name, all_stop_details):
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print(f"No stop points found for {stop_name} in this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points for {stop_name}: {e}")

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Assuming 'df' is already loaded with your Excel data (as shown in your original code)
# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 179
#    Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0            179_A1       34016                    Chingford Station
# 1            179_A2       15316                          Friday Hill
# 2            179_A3       15334      Woodford Green / Broadmead Road
# 3            179_A4       29463               South Woodford Station
# 4            179_A5       R0499           Charlie Brown'S Roundabout
# 5            179_A6        8622  Gants Hill Station / Cranbrook Road
# 6            179_A7        FC46                       Ilford Station
# 7            179_B1        FC04                      Hainault Street
# 8            179_B2        FC39                       Ilford Station
# 9            179_B3        8621  Gants Hill Station / Cranbrook Road
# 10           179_B4       R0498                        Southend Road
# 11           179_B5        7509               South Woodford Station
# 12           179_B6        4363      Woodford Green / Broadmead Road
# 13           179_B7       R0478             Kings Road / Friday Hill
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-69fd502b80fd> in <cell line: 122>()
#     120
#     121 # Find and display the route details
# --> 122 find_route_details(lineID)
#
# <ipython-input-24-69fd502b80fd> in find_route_details(lineID)
#      51
#      52         # Fetch and append stop details for inbound direction
# ---> 53         fetch_and_append_stop_points(lineID, api_url_inbound, stop_name, all_stop_details)
#      54
#      55         # Fetch and append stop details for outbound direction
#
# <ipython-input-24-69fd502b80fd> in fetch_and_append_stop_points(line_id, url, stop_name, all_stop_details)
#      70                 coordinates = eval(line_string)
#      71                 for lon, lat in coordinates[0]:
# ---> 72                     fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
#      73         else:
#      74             print(f"No stop points found for {stop_name} in this route.")
#
# <ipython-input-24-69fd502b80fd> in fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries)
#      82             response = requests.get(url)
#      83             if response.status_code == 429:
# ---> 84                 time.sleep(2**attempt)
#      85                 continue
#      86             response.raise_for_status()
#
# NameError: name 'time' is not defined

# %%
import pandas as pd
import requests
import csv
import time  # Import the time module for handling retries

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
        return

    # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
    result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

    # Reset the index of the DataFrame and drop the old index column
    result_df.reset_index(drop=True, inplace=True)

    # Print the resulting DataFrame
    print(result_df)

    # Lists to store IDs for inbound and outbound directions
    all_stop_details = []

    # Fetching stop details from TFL API based on stop names
    for stop_name in result_df['STOP_NAME']:
        # Define TFL API URL for inbound and outbound directions
        api_url_inbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        api_url_outbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/outbound"

        # Fetch and append stop details for inbound direction
        fetch_and_append_stop_points(lineID, api_url_inbound, stop_name, all_stop_details)

        # Fetch and append stop details for outbound direction
        fetch_and_append_stop_points(lineID, api_url_outbound, stop_name, all_stop_details)

    # Write to CSV
    write_to_csv(all_stop_details)

def fetch_and_append_stop_points(line_id, url, stop_name, all_stop_details):
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print(f"No stop points found for {stop_name} in this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points for {stop_name}: {e}")

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)  # Retry after exponential backoff
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Assuming 'df' is already loaded with your Excel data (as shown in your original code)
# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 179
#    Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0            179_A1       34016                    Chingford Station
# 1            179_A2       15316                          Friday Hill
# 2            179_A3       15334      Woodford Green / Broadmead Road
# 3            179_A4       29463               South Woodford Station
# 4            179_A5       R0499           Charlie Brown'S Roundabout
# 5            179_A6        8622  Gants Hill Station / Cranbrook Road
# 6            179_A7        FC46                       Ilford Station
# 7            179_B1        FC04                      Hainault Street
# 8            179_B2        FC39                       Ilford Station
# 9            179_B3        8621  Gants Hill Station / Cranbrook Road
# 10           179_B4       R0498                        Southend Road
# 11           179_B5        7509               South Woodford Station
# 12           179_B6        4363      Woodford Green / Broadmead Road
# 13           179_B7       R0478             Kings Road / Friday Hill
# Error fetching stop points for Friday Hill: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Friday Hill: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Woodford Green / Broadmead Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Woodford Green / Broadmead Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for South Woodford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for South Woodford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Charlie Brown'S Roundabout: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Charlie Brown'S Roundabout: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Gants Hill Station / Cranbrook Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Gants Hill Station / Cranbrook Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Ilford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Ilford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Hainault Street: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Hainault Street: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Ilford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Ilford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Gants Hill Station / Cranbrook Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Gants Hill Station / Cranbrook Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Southend Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Southend Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for South Woodford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for South Woodford Station: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Error fetching stop points for Woodford Green / Broadmead Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/inbound
# Error fetching stop points for Woodford Green / Broadmead Road: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/179/Route/Sequence/outbound
# Data written to 'stop_details.csv' successfully.

# %%
import pandas as pd
import requests
import csv
import time  # Import the time module for handling retries

# Function to process user input and display matching records
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the patterns
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered DataFrames
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
        return

    # Display the relevant columns: QSI_No, Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
    result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

    # Reset the index of the DataFrame and drop the old index column
    result_df.reset_index(drop=True, inplace=True)

    # Print the resulting DataFrame
    print(result_df)

    # Lists to store IDs for inbound and outbound directions
    all_stop_details = []

    # Fetching stop details from TFL API based on stop names
    for stop_name in result_df['STOP_NAME']:
        # Define TFL API URL for inbound and outbound directions
        api_url_inbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        api_url_outbound = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/outbound"

        # Fetch and append stop details for inbound direction
        fetch_and_append_stop_points(lineID, api_url_inbound, stop_name, all_stop_details)

        # Fetch and append stop details for outbound direction
        fetch_and_append_stop_points(lineID, api_url_outbound, stop_name, all_stop_details)

    # Write to CSV
    write_to_csv(all_stop_details)

def fetch_and_append_stop_points(line_id, url, stop_name, all_stop_details):
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print(f"No stop points found for {stop_name} in this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points for {stop_name}: {e}")

def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                print(f"Rate limit exceeded. Retrying in {2**attempt} seconds...")
                time.sleep(2**attempt)  # Exponential backoff
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            print(f"Error: Maximum retries exceeded for {url}.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Assuming 'df' is already loaded with your Excel data (as shown in your original code)
# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#    Route_Dir_QSI_No STOP_NUMBER                              STOP_NAME
# 0             25_A1        FC41                        Hainault Street
# 1             25_A2        4643                      High Street North
# 2             25_A3       14581                           Green Street
# 3             25_A4      BP6275                  Stratford Bus Station
# 4             25_A5       25096                     Bow Church Station
# 5             25_A6        4826                       Mile End Station
# 6             25_A7         943   Whitechapel Stn  / Royal London Hosp
# 7             25_A8       33683                        Aldgate Station
# 8             25_A9        8559               Bank Station  / Cornhill
# 9             25_B1        2018                         Holborn Circus
# 10            25_B2        8558               Bank Station  / Cornhill
# 11            25_B3      BP5998                        Aldgate Station
# 12            25_B4         944  Whitechapel Stn   / Royal London Hosp
# 13            25_B5       20674                       Mile End Station
# 14            25_B6         902                     Bow Church Station
# 15            25_B7       BP976                  Stratford Bus Station
# 16            25_B8        4644                      High Street North
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.516269&lon=-0.069298&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.51642&lon=-0.068963&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.51642&lon=-0.068963&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.516852&lon=-0.068026&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.517301&lon=-0.066926&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.517618&lon=-0.065933&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.527045&lon=-0.025808&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.527045&lon=-0.025808&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.527148&lon=-0.025349&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.527243&lon=-0.025115&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.527425&lon=-0.02417&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.52743&lon=-0.023939&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.539716&lon=-0.000709&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.539627&lon=-0.000222&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.540278&lon=0.000614&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.540652&lon=0.001291&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.540652&lon=0.001291&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.541627&lon=0.003269&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.555968&lon=0.063856&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# Rate limit exceeded. Retrying in 4 seconds...
# Error: Maximum retries exceeded for https://api.tfl.gov.uk/Stoppoint?lat=51.556338&lon=0.065009&stopTypes=NaptanPublicBusCoachTram&radius=200.
# Rate limit exceeded. Retrying in 1 seconds...
# Rate limit exceeded. Retrying in 2 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-4114bdcabd97> in <cell line: 124>()
#     122
#     123 # Find and display the route details
# --> 124 find_route_details(lineID)
#     125
#
# <ipython-input-26-4114bdcabd97> in find_route_details(lineID)
#      52
#      53         # Fetch and append stop details for inbound direction
# ---> 54         fetch_and_append_stop_points(lineID, api_url_inbound, stop_name, all_stop_details)
#      55
#      56         # Fetch and append stop details for outbound direction
#
# <ipython-input-26-4114bdcabd97> in fetch_and_append_stop_points(line_id, url, stop_name, all_stop_details)
#      71                 coordinates = eval(line_string)
#      72                 for lon, lat in coordinates[0]:
# ---> 73                     fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
#      74         else:
#      75             print(f"No stop points found for {stop_name} in this route.")
#
# <ipython-input-26-4114bdcabd97> in fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries)
#      84             if response.status_code == 429:
#      85                 print(f"Rate limit exceeded. Retrying in {2**attempt} seconds...")
# ---> 86                 time.sleep(2**attempt)  # Exponential backoff
#      87                 continue
#      88             response.raise_for_status()
#
# KeyboardInterrupt:

# %%
import requests
import csv

def fetch_stop_points(line_id):
    try:
        inbound_stop_points = fetch_direction_stop_points(line_id, 'inbound')
        outbound_stop_points = fetch_direction_stop_points(line_id, 'outbound')
        return inbound_stop_points, outbound_stop_points
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
        return None, None

def fetch_direction_stop_points(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    stop_points = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, stop_points)
        else:
            print(f"No stop points found for {direction} direction.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points for {direction} direction: {e}")
    return stop_points

def fetch_and_append_stop_details(lat, lon, stop_points, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points.extend(data.get('stopPoints', []))
            break
        else:
            print(f"Failed to fetch stop details for lat: {lat}, lon: {lon}")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop details: {e}")

if __name__ == "__main__":
    line_id = input("Enter line ID: ")
    inbound_stop_points, outbound_stop_points = fetch_stop_points(line_id)

    if inbound_stop_points:
        print("Inbound Stop Points:")
        for stop_point in inbound_stop_points:
            print(f"Stop ID: {stop_point.get('id')} - Stop Name: {stop_point.get('commonName')}")

    if outbound_stop_points:
        print("\nOutbound Stop Points:")
        for stop_point in outbound_stop_points:
            print(f"Stop ID: {stop_point.get('id')} - Stop Name: {stop_point.get('commonName')}")
# Out:
# Enter line ID: 25
# Error fetching stop points for inbound direction: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/25/Route/Sequence/inbound
# Error fetching stop points for outbound direction: 429 Client Error: Too Many Requests for url: https://api.tfl.gov.uk/Line/25/Route/Sequence/outbound

# %%
import csv
import requests
import pandas as pd

# Function to fetch route details
def fetch_route_details(line_id, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])
        found_direction = False
        for section in route_sections:
            if section.get('direction', '').lower() == direction.lower():
                found_direction = True
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Direction: {direction}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")
                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv(limit=225)  # Display only up to the provided sample
                    return
        if not found_direction:
            print(f"No route found for direction '{direction}'.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Function to fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])
        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print("No stop points found for this route.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")
    return all_stop_details

# Function to fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])
            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')
                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)
            else:
                continue
            break
        else:
            pass
    except requests.exceptions.RequestException as e:
        pass

# Function to write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)
    print(f"Data written to 'stop_details.csv' successfully.")

# Function to display data from CSV
def display_data_from_csv(limit=None):
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False
        for idx, row in enumerate(reader, start=1):
            if limit and idx > limit:
                break
            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True
            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

if __name__ == "__main__":
    line_id = input("Enter Line ID: ").strip()
    direction = input("Enter Direction (e.g., inbound or outbound): ").strip()

    fetch_route_details(line_id, direction)
# Out:
# Enter Line ID: 25
# Enter Direction (e.g., inbound or outbound): inbound
# Direction: inbound
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# Originator: 490000225S
# Destination: 490007657S
# ---
# Data written to 'stop_details.csv' successfully.
# Data from CSV:
# 1      490000225T St Paul's Station
# 2      490000225U St Paul's Station
# 3      490000225S King Edward Street
# 4      490000225W St Paul's Station
# 5      490003330Z Angel Street
# 6      490008743Z King Edward Street
# 7      490003330E Angel Street (EC1A)
# 8      490008743N King Edward Street / St Pauls Station
# 9      490009443E St Paul's Cathedral
# 10     490012873B St Paul's Cathedral
# 11     490000225X St Paul's Station
# 12     490010199D New Change / Cannon Street
# 13     49000225SY St Paul's Station
# 14     49008743N1 Little Britain
# 15     490010130S London Wall
# 16     490010130N Aldersgate Street
# 17     490010130W London Wall
# 18     490010130E London Wall
# 199    490014800N Wolferton Road
# 200    490009219E Little Ilford Lane
# 201    490006059W Dersingham Avenue
# 202    490010328E North Circular Road
# 203    490008467F Ilford Hill
# 204    490004986P Ilford / Chapel Road
# 205    490004985Y Chapel Road
# 206    490001157G Ilford Station
# 207    490011626C Roden Street
# 208    490001157H Ilford Station
# 209    490008465L Ilford Broadway
# 210    490008471B Ilford Sainsbury's
# 211    490003604S Pioneer Point
# 212    490004985A Chapel Road (IG1)
# 213    490005699RB Ilford Station
# 214    490001157K Ilford Station
# 215    490008470M High Road Ilford
# 216    490003890N Bengal Road
# 217    490008466Q1 Redbridge Central Library
# 218    490008466R Redbridge Central Library
# 219    490007657V Hainault Street
# 220    490007657S Hainault Street
# 221    490007657W Hainault Street
# 222    490007657T Hainault Street

# %%
import csv
import requests

# Function to fetch route details
def fetch_route_details(line_id):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])

        for section in route_sections:
            direction = section.get('direction', '').strip().lower()
            if direction in ['inbound', 'outbound']:
                print(f"Direction: {direction.capitalize()}")
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                all_stop_details = fetch_and_append_stop_points(line_id, originator, destination, direction)
                if all_stop_details:
                    write_to_csv(all_stop_details)
                    display_data_from_csv(limit=225)  # Display only up to the provided sample

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Function to fetch and append stop points
def fetch_and_append_stop_points(line_id, originator, destination, direction):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}"
    all_stop_details = []
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        line_strings = data.get('lineStrings', [])

        if line_strings:
            printed_stop_ids = set()
            for line_string in line_strings:
                coordinates = eval(line_string)
                for lon, lat in coordinates[0]:
                    fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details)
        else:
            print(f"No stop points found for {direction} direction.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

    return all_stop_details

# Function to fetch and append stop details
def fetch_and_append_stop_details(lat, lon, printed_stop_ids, all_stop_details, retries=3):
    url = f"https://api.tfl.gov.uk/Stoppoint?lat={lat}&lon={lon}&stopTypes=NaptanPublicBusCoachTram&radius=200"
    try:
        for attempt in range(retries):
            response = requests.get(url)
            if response.status_code == 429:
                time.sleep(2**attempt)
                continue
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('stopPoints', [])

            if stop_points:
                for stop_point in stop_points:
                    stop_id = stop_point.get('id', 'Unknown')

                    if stop_id and stop_id not in printed_stop_ids:
                        stop_name = stop_point.get('commonName', 'Unknown')
                        all_stop_details.append({
                            'Sl. No.': len(all_stop_details) + 1,
                            'Stop ID': stop_id,
                            'Stop Name': stop_name
                        })
                        printed_stop_ids.add(stop_id)

            else:
                continue

            break

        else:
            pass

    except requests.exceptions.RequestException as e:
        pass

# Function to write to CSV
def write_to_csv(all_stop_details):
    headers = ['Sl. No.', 'Stop ID', 'Stop Name']
    with open('stop_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()

        for stop_detail in all_stop_details:
            writer.writerow(stop_detail)

    print(f"Data written to 'stop_details.csv' successfully.")

# Function to display data from CSV
def display_data_from_csv(limit=None):
    print("Data from CSV:")
    with open('stop_details.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        headers_printed = False

        for idx, row in enumerate(reader, start=1):
            if limit and idx > limit:
                break

            if not headers_printed:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")
                headers_printed = True

            else:
                print(f"{row['Sl. No.']:<6} {row['Stop ID']:<10} {row['Stop Name']}")

if __name__ == "__main__":
    line_id = input("Enter Line ID: ").strip()

    fetch_route_details(line_id)
# Out:
# Enter Line ID: 25
# Direction: Inbound
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# Originator: 490000225S
# Destination: 490007657S
# ---
# Data written to 'stop_details.csv' successfully.
# Data from CSV:
# 1      490000225T St Paul's Station
# 2      490000225U St Paul's Station
# 3      490000225S King Edward Street
# 4      490000225W St Paul's Station
# 5      490003330Z Angel Street
# 6      490008743Z King Edward Street
# 7      490003330E Angel Street (EC1A)
# 8      490008743N King Edward Street / St Pauls Station
# 9      490009443E St Paul's Cathedral
# 10     490012873B St Paul's Cathedral
# 11     490000225X St Paul's Station
# 12     490010199D New Change / Cannon Street
# 13     49000225SY St Paul's Station
# 14     49008743N1 Little Britain
# 15     490010130S London Wall
# 16     490010130N Aldersgate Street
# 17     490010130W London Wall
# 18     490010130E London Wall
# 19     490015124Z Bread Street
# 20     490010199E New Change / Cannon Street
# 21     490012873A St Paul's Cathedral
# 157    490009606N Mansell Street
# 158    490000003Y Aldgate Station
# 159    490009606S Mansell Street
# 160    490000003R Aldgate Station
# 161    490000003DS Aldgate Station
# 162    490003184L Aldgate Bus Station
# 163    490000003B St Botolph Street
# 164    490000003N Aldgate Station
# 165    490006229Z Duke's Place
# 166    490000003H Aldgate Bus Station
# 167    490005818K Minories
# 168    490019038Z St Botolph Street
# 169    490000003E Aldgate Station
# 170    490012755E St Katharine Cree
# 171    490012755W St Katharine Cree
# 172    490001108E Fenchurch Street Station
# 173    490001108W Fenchurch Street Station
# 174    490006229ZY Duke's Place
# 175    490006229N Duke's Place
# 176    490012783W St Mary Axe
# 177    490012783E St Mary Axe
# 178    490011049W Rood Lane
# 179    490000001Z Fenchurch Street Station
# 180    490011049E Rood Lane
# 181    490009037S Threadneedle Street
# 182    490009037N Threadneedle Street
# 183    490015079E Bishopsgate
# 184    490000148M Fenchurch Street
# 185    490010527E Old Broad Street
# 186    490010527W Old Broad Street
# 187    490000013D Bank Station  / Cornhill
# 188    490000013E Bank Station  / Cornhill
# 189    490000013C Bank Station  / Threadneedle Street
# 190    490000013F Bank Station  / King William Street
# 191    490000148G King William Street / Monument Stn
# 192    490012823W Threadneedle Street
# 193    490011218B Bank Station  / Princes Street
# 194    490013195H Bank Station  / Queen Victoria Street
# 195    490011218A Bank Station  / Princes Street
# 196    490007596L Poultry / Bank Station
# 197    490000040A Cannon Street Station
# 198    490000040B Cannon Street Station
# 199    490007596K Bank Station  / Poultry
# 200    490013195J Bank Station  / Queen Victoria Street
# 201    490000040E Cannon Street Station
# 202    49000004046 Cannon Street Station
# 203    490000143E1 Mansion House Station
# 204    490015124Z Bread Street
# 205    49000225SY St Paul's Station
# 206    490000225X St Paul's Station
# 207    490010199E New Change / Cannon Street
# 208    490010199D New Change / Cannon Street
# 209    490000143E Mansion House Station
# 210    490012873A St Paul's Cathedral
# 211    490010200C St Paul's Churchyard
# 212    490000225W St Paul's Station
# 213    490000225U St Paul's Station
# 214    490000225T St Paul's Station
# 215    490012873B St Paul's Cathedral
# 216    490008743Z King Edward Street
# 217    490003330Z Angel Street
# 218    490003330E Angel Street (EC1A)
# 219    490000225S King Edward Street
# 220    490008743N King Edward Street / St Pauls Station

# %%
import csv
import requests

# Importing necessary libraries for regular expressions
import re

# Function to fetch route details
def fetch_route_details(line_id):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])

        for section in route_sections:
            direction = section.get('direction', '').strip().lower()
            if direction in ['inbound', 'outbound']:
                print(f"Direction: {direction.capitalize()}")
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                if direction == 'inbound':
                    lineID_A_pattern = re.compile(f"{line_id}_A\\d+", re.IGNORECASE)
                    stop_names = set()
                    for index, row in df.iterrows():
                        if lineID_A_pattern.match(row['Route_Dir_QSI_No']):
                            stop_names.add(row['STOP_NAME'])
                    fetch_and_print_matching_stops(origination_name, destination_name, stop_names)

                elif direction == 'outbound':
                    lineID_B_pattern = re.compile(f"{line_id}_B\\d+", re.IGNORECASE)
                    stop_names = set()
                    for index, row in df.iterrows():
                        if lineID_B_pattern.match(row['Route_Dir_QSI_No']):
                            stop_names.add(row['STOP_NAME'])
                    fetch_and_print_matching_stops(origination_name, destination_name, stop_names)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Function to fetch and print matching stop details
def fetch_and_print_matching_stops(origination_name, destination_name, stop_names):
    url = "https://api.tfl.gov.uk/StopPoint/Search"
    try:
        response = requests.get(url, params={'query': ' '.join(stop_names)})
        response.raise_for_status()
        data = response.json()
        stop_points = data.get('matches', [])

        if stop_points:
            for stop_point in stop_points:
                common_name = stop_point.get('name', 'Unknown')
                print(f"Matching Stop Name: {common_name}")
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print("---")
        else:
            print("No matching stop names found.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

if __name__ == "__main__":
    line_id = input("Enter Line ID: ").strip()

    # Assuming df is the DataFrame loaded from Code 1
    df = pd.read_excel('/content/QSI points.xlsx')

    fetch_route_details(line_id)
# Out:
# Enter Line ID: 25
# Direction: Inbound
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# Originator: 490000225S
# Destination: 490007657S
# ---
# No matching stop names found.
# Direction: Outbound
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# Originator: 490007657V
# Destination: 490000225T
# ---
# No matching stop names found.

# %%
import csv
import requests
import pandas as pd
import re

# Function to fetch route details
def fetch_route_details(line_id, df):
    url = f"https://api.tfl.gov.uk/Line/{line_id}/Route"
    params = {'serviceTypes': 'Regular'}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        route_sections = data.get('routeSections', [])

        for section in route_sections:
            direction = section.get('direction', '').strip().lower()
            if direction in ['inbound', 'outbound']:
                print(f"Direction: {direction.capitalize()}")
                origination_name = section.get('originationName', 'Unknown')
                destination_name = section.get('destinationName', 'Unknown')
                originator = section.get('originator', 'Unknown')
                destination = section.get('destination', 'Unknown')
                print(f"Origination Name: {origination_name}")
                print(f"Destination Name: {destination_name}")
                print(f"Originator: {originator}")
                print(f"Destination: {destination}")
                print("---")

                if direction == 'inbound':
                    lineID_A_pattern = re.compile(f"{line_id}_A\\d+", re.IGNORECASE)
                    stop_data = df[df['Route_Dir_QSI_No'].str.match(lineID_A_pattern, na=False)][['STOP_NAME', 'STOP_NUMBER']]
                    fetch_and_print_matching_stops(origination_name, destination_name, stop_data)

                elif direction == 'outbound':
                    lineID_B_pattern = re.compile(f"{line_id}_B\\d+", re.IGNORECASE)
                    stop_data = df[df['Route_Dir_QSI_No'].str.match(lineID_B_pattern, na=False)][['STOP_NAME', 'STOP_NUMBER']]
                    fetch_and_print_matching_stops(origination_name, destination_name, stop_data)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")

# Function to fetch and print matching stop details
def fetch_and_print_matching_stops(origination_name, destination_name, stop_data):
    url = "https://api.tfl.gov.uk/StopPoint/Search"
    try:
        for index, row in stop_data.iterrows():
            stop_name = row['STOP_NAME']
            response = requests.get(url, params={'query': stop_name})
            response.raise_for_status()
            data = response.json()
            stop_points = data.get('matches', [])

            if stop_points:
                for stop_point in stop_points:
                    common_name = stop_point.get('name', 'Unknown')
                    if common_name == stop_name:
                        stop_id = stop_point.get('id', 'Unknown')
                        print(f"Matching Stop Name: {common_name}")
                        print(f"Origination Name: {origination_name}")
                        print(f"Destination Name: {destination_name}")
                        print(f"ID Sample: {stop_id}")
                        print("---")
            else:
                print(f"No matching stop names found for: {stop_name}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching stop points: {e}")

if __name__ == "__main__":
    line_id = input("Enter Line ID: ").strip()

    # Load QSI points.xlsx into DataFrame
    df = pd.read_excel('/content/QSI points.xlsx')

    # Call fetch_route_details with df
    fetch_route_details(line_id, df)
# Out:
# Enter Line ID: 25
# Direction: Inbound
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# Originator: 490000225S
# Destination: 490007657S
# ---
# Matching Stop Name: Hainault Street
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00007657
# ---
# Matching Stop Name: High Street North
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00006360
# ---
# Matching Stop Name: High Street North
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00008190
# ---
# Matching Stop Name: High Street North
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G000596
# ---
# Matching Stop Name: Green Street
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 400G4402058A
# ---
# Matching Stop Name: Green Street
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00004314
# ---
# Matching Stop Name: Green Street
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00007497
# ---
# Matching Stop Name: Green Street
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G000545
# ---
# Matching Stop Name: Stratford Bus Station
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G000773
# ---
# Matching Stop Name: Bow Church Station
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G02019A
# ---
# Matching Stop Name: Mile End Station
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00146B
# ---
# Matching Stop Name: Mile End Station
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00146C
# ---
# Matching Stop Name: Whitechapel Stn  / Royal London Hosp
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G000793
# ---
# Matching Stop Name: Aldgate Station
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G00003N
# ---
# Matching Stop Name: Bank Station  / Cornhill
# Origination Name: King Edward Street
# Destination Name: Hainault Street
# ID Sample: 490G000556
# ---
# Direction: Outbound
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# Originator: 490007657V
# Destination: 490000225T
# ---
# Matching Stop Name: Holborn Circus
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G00015096
# ---
# Matching Stop Name: Bank Station  / Cornhill
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G000556
# ---
# Matching Stop Name: Aldgate Station
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G00003N
# ---
# Matching Stop Name: Whitechapel Stn   / Royal London Hosp
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G000796
# ---
# Matching Stop Name: Mile End Station
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G00146B
# ---
# Matching Stop Name: Mile End Station
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G00146C
# ---
# Matching Stop Name: Bow Church Station
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G02019A
# ---
# Matching Stop Name: Stratford Bus Station
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G000773
# ---
# Matching Stop Name: High Street North
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G00006360
# ---
# Matching Stop Name: High Street North
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G00008190
# ---
# Matching Stop Name: High Street North
# Origination Name: Hainault Street
# Destination Name: St Paul's Station
# ID Sample: 490G000596
# ---

# %%
import requests

def get_naptan_ids(stop_name):
    # TfL Unified API endpoint for searching stop points
    url = f"https://api.tfl.gov.uk/StopPoint/Search/{stop_name}"

    try:
        # Sending GET request to the API
        response = requests.get(url)

        # Checking if the request was successful (status code 200)
        if response.status_code == 200:
            data = response.json()

            # Iterate over each match found
            for match in data["matches"]:
                print(f"Stop Name: {match['name']}")
                print(f"Naptan ID: {match['id']}")
                print()
        else:
            print(f"Error: {response.status_code} - {response.text}")

    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")

# Example usage:
stop_name = "Oxford Circus"
get_naptan_ids(stop_name)
# Out:
# Stop Name: Oxford Circus Underground Station
# Naptan ID: 940GZZLUOXC
#
# Stop Name: Oxford Circus Station  / John Lewis
# Naptan ID: 490G00015204
#
# Stop Name: Great Titchfield St / Oxford Circus Stn
# Naptan ID: 490G000691
#
# Stop Name: John Prince's Street / Oxford Circus
# Naptan ID: 490G000692
#
# Stop Name: Margaret Street / Oxford Circus
# Naptan ID: 490G000693
#
# Stop Name: Oxford Circus Stn  / Margaret Street
# Naptan ID: 490G000694

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]

    # Check if any matching rows are found
    if filtered_df_A.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # Iterate through each row and fetch corresponding stop information from TfL API
        for index, row in result_df.iterrows():
            stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            # Make API call to fetch stop information
            api_url = f"https://api.tfl.gov.uk/StopPoint/{row['STOP_NUMBER']}"
            response = requests.get(api_url)

            if response.status_code == 200:
                stop_data = response.json()
                stop_id = stop_data['id']

                # Print the stop information
                print(f"{route_dir_qsi_no}  {stop_name}  {stop_id}")
            else:
                print(f"Failed to fetch data for {stop_name} ({response.status_code})")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#   Route_Dir_QSI_No STOP_NUMBER                             STOP_NAME
# 0            25_A1        FC41                       Hainault Street
# 1            25_A2        4643                     High Street North
# 2            25_A3       14581                          Green Street
# 3            25_A4      BP6275                 Stratford Bus Station
# 4            25_A5       25096                    Bow Church Station
# 5            25_A6        4826                      Mile End Station
# 6            25_A7         943  Whitechapel Stn  / Royal London Hosp
# 7            25_A8       33683                       Aldgate Station
# 8            25_A9        8559              Bank Station  / Cornhill
# Failed to fetch data for Hainault Street (404)
# Failed to fetch data for High Street North (404)
# Failed to fetch data for Green Street (404)
# Failed to fetch data for Stratford Bus Station (404)
# Failed to fetch data for Bow Church Station (404)
# Failed to fetch data for Mile End Station (404)
# Failed to fetch data for Whitechapel Stn  / Royal London Hosp (404)
# Failed to fetch data for Aldgate Station (404)
# Failed to fetch data for Bank Station  / Cornhill (404)

# %%
import pandas as pd
import requests
import time

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]

    # Check if any matching rows are found
    if filtered_df_A.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # Iterate through each row and fetch corresponding stop information from TfL API
        for index, row in result_df.iterrows():
            stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            stop_number = row['STOP_NUMBER']

            # Make API call to fetch stop information
            api_url = f"https://api.tfl.gov.uk/StopPoint/{stop_number}"
            response = requests.get(api_url)

            if response.status_code == 200:
                stop_data = response.json()
                stop_id = stop_data['id']

                # Print the stop information
                print(f"{route_dir_qsi_no}  {stop_name}  {stop_id}")
            else:
                print(f"Failed to fetch data for {stop_name} ({response.status_code})")
                # Retry after a short delay (in case of rate limiting or temporary issues)
                time.sleep(1)

                # Retry once
                response = requests.get(api_url)
                if response.status_code == 200:
                    stop_data = response.json()
                    stop_id = stop_data['id']

                    # Print the stop information
                    print(f"{route_dir_qsi_no}  {stop_name}  {stop_id}")
                else:
                    print(f"Retry failed for {stop_name} ({response.status_code})")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#   Route_Dir_QSI_No STOP_NUMBER                             STOP_NAME
# 0            25_A1        FC41                       Hainault Street
# 1            25_A2        4643                     High Street North
# 2            25_A3       14581                          Green Street
# 3            25_A4      BP6275                 Stratford Bus Station
# 4            25_A5       25096                    Bow Church Station
# 5            25_A6        4826                      Mile End Station
# 6            25_A7         943  Whitechapel Stn  / Royal London Hosp
# 7            25_A8       33683                       Aldgate Station
# 8            25_A9        8559              Bank Station  / Cornhill
# Failed to fetch data for Hainault Street (404)
# Retry failed for Hainault Street (404)
# Failed to fetch data for High Street North (404)
# Retry failed for High Street North (404)
# Failed to fetch data for Green Street (404)
# Retry failed for Green Street (404)
# Failed to fetch data for Stratford Bus Station (404)
# Retry failed for Stratford Bus Station (404)
# Failed to fetch data for Bow Church Station (404)
# Retry failed for Bow Church Station (404)
# Failed to fetch data for Mile End Station (404)
# Retry failed for Mile End Station (404)
# Failed to fetch data for Whitechapel Stn  / Royal London Hosp (404)
# Retry failed for Whitechapel Stn  / Royal London Hosp (404)
# Failed to fetch data for Aldgate Station (404)
# Retry failed for Aldgate Station (404)
# Failed to fetch data for Bank Station  / Cornhill (404)
# Retry failed for Bank Station  / Cornhill (404)

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]

    # Check if any matching rows are found
    if filtered_df_A.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # Make API call to fetch route sequence data from TfL API
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        response = requests.get(api_url)

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stations']:
                stop_name_api = stop['name']
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame
                matched_row = result_df[result_df['STOP_NAME'].str.contains(stop_name_api, case=False, na=False)]
                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    print(f"STOP_Name:{stop_name_api} and the id:{stop_id} result.")
                else:
                    print(f"No match found for {stop_name_api} in Excel data.")

        else:
            print(f"Failed to fetch route sequence data from TfL API. Status code: {response.status_code}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#   Route_Dir_QSI_No STOP_NUMBER                             STOP_NAME
# 0            25_A1        FC41                       Hainault Street
# 1            25_A2        4643                     High Street North
# 2            25_A3       14581                          Green Street
# 3            25_A4      BP6275                 Stratford Bus Station
# 4            25_A5       25096                    Bow Church Station
# 5            25_A6        4826                      Mile End Station
# 6            25_A7         943  Whitechapel Stn  / Royal London Hosp
# 7            25_A8       33683                       Aldgate Station
# 8            25_A9        8559              Bank Station  / Cornhill
# No match found for Ilford / Chapel Road in Excel data.
# No match found for Atherton Leisure Centre in Excel data.
# No match found for Booth Memorial in Excel data.
# No match found for First Avenue in Excel data.
# No match found for Woodgrange Road in Excel data.
# No match found for Margery Park Road in Excel data.
# No match found for Regents Canal in Excel data.
# STOP_Name:Green Street and the id:490G00007497 result.
# STOP_Name:Hainault Street and the id:490G00007657 result.
# No match found for Redbridge Central Library in Excel data.
# No match found for Katherine Road in Excel data.
# No match found for Little Britain in Excel data.
# No match found for Little Ilford Lane in Excel data.
# No match found for Rabbits Road in Excel data.
# No match found for The East London Mosque in Excel data.
# No match found for North Circular Road in Excel data.
# No match found for Bancroft Road / Ocean Estate in Excel data.
# No match found for Queen Mary / University of London in Excel data.
# No match found for Seventh Avenue in Excel data.
# No match found for Shrewsbury Road in Excel data.
# No match found for Coborn Road in Excel data.
# No match found for St Mary Axe in Excel data.
# No match found for Stratford Centre in Excel data.
# No match found for Litchfield Avenue in Excel data.
# No match found for Stratford High St Stn  / Carpenters Rd in Excel data.
# No match found for Warton Road in Excel data.
# No match found for Water Lane / University of East London in Excel data.
# No match found for Bishopsgate in Excel data.
# No match found for Stepney Green in Excel data.
# STOP_Name:Bow Church and the id:490G000421 result.
# No match found for Altab Ali Park in Excel data.
# STOP_Name:High Street North and the id:490G000596 result.
# No match found for Ilford Hill in Excel data.
# No match found for King Edward Street in Excel data.
# No match found for Marshgate Lane in Excel data.
# No match found for St Katharine Cree in Excel data.
# No match found for Whitechapel Stn   / Royal London Hosp in Excel data.
# No match found for Woodgrange Park Rail Station in Excel data.
# No match found for Bow Church DLR Station in Excel data.
# No match found for Aldgate East Underground Station in Excel data.
# No match found for Aldgate Underground Station in Excel data.
# No match found for Bow Road Underground Station in Excel data.
# No match found for Mile End Underground Station in Excel data.
# No match found for Stepney Green Underground Station in Excel data.
# No match found for St. Paul's Underground Station in Excel data.
# STOP_Name:Bank and the id:HUBBAN result.
# STOP_Name:Stratford and the id:HUBSRA result.

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]

    # Check if any matching rows are found
    if filtered_df_A.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # Make API call to fetch route sequence data from TfL API
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        response = requests.get(api_url)

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = stop['name']
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame
                matched_row = result_df[result_df['STOP_NAME'].str.lower() == stop_name_api.lower()]
                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    print(f"Route_Dir_QSI_No: {route_dir_qsi_no}, STOP_Name: {stop_name_api}, ID: {stop_id}")
                else:
                    print(f"No match found for {stop_name_api} in Excel data.")

        else:
            print(f"Failed to fetch route sequence data from TfL API. Status code: {response.status_code}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#   Route_Dir_QSI_No STOP_NUMBER                             STOP_NAME
# 0            25_A1        FC41                       Hainault Street
# 1            25_A2        4643                     High Street North
# 2            25_A3       14581                          Green Street
# 3            25_A4      BP6275                 Stratford Bus Station
# 4            25_A5       25096                    Bow Church Station
# 5            25_A6        4826                      Mile End Station
# 6            25_A7         943  Whitechapel Stn  / Royal London Hosp
# 7            25_A8       33683                       Aldgate Station
# 8            25_A9        8559              Bank Station  / Cornhill
# No match found for King Edward Street in Excel data.
# No match found for Little Britain in Excel data.
# No match found for St Paul's Station in Excel data.
# No match found for St Paul's Station in Excel data.
# No match found for Bank Station  / Poultry in Excel data.
# Route_Dir_QSI_No: 25_A9, STOP_Name: Bank Station  / Cornhill, ID: 490000013D
# No match found for Bishopsgate in Excel data.
# No match found for St Mary Axe in Excel data.
# No match found for St Katharine Cree in Excel data.
# Route_Dir_QSI_No: 25_A8, STOP_Name: Aldgate Station, ID: 490000003Y
# No match found for Aldgate East Station in Excel data.
# No match found for Altab Ali Park in Excel data.
# No match found for The East London Mosque in Excel data.
# No match found for Whitechapel Stn   / Royal London Hosp in Excel data.
# No match found for Booth Memorial in Excel data.
# No match found for Stepney Green in Excel data.
# No match found for Stepney Green Station in Excel data.
# No match found for Bancroft Road / Ocean Estate in Excel data.
# No match found for Queen Mary / University of London in Excel data.
# No match found for Regents Canal in Excel data.
# Route_Dir_QSI_No: 25_A6, STOP_Name: Mile End Station, ID: 490000146D
# No match found for Coborn Road in Excel data.
# No match found for Bow Road Station in Excel data.
# Route_Dir_QSI_No: 25_A5, STOP_Name: Bow Church Station, ID: 490002019A
# No match found for Bow Church in Excel data.
# No match found for Marshgate Lane in Excel data.
# No match found for Warton Road in Excel data.
# No match found for Stratford High St Stn  / Carpenters Rd in Excel data.
# Route_Dir_QSI_No: 25_A4, STOP_Name: Stratford Bus Station, ID: 490012904N
# Route_Dir_QSI_No: 25_A4, STOP_Name: Stratford Bus Station, ID: 490012904B
# No match found for Stratford Centre in Excel data.
# No match found for Litchfield Avenue in Excel data.
# No match found for Water Lane / University of East London in Excel data.
# No match found for Atherton Leisure Centre in Excel data.
# No match found for Margery Park Road in Excel data.
# No match found for Woodgrange Road in Excel data.
# Route_Dir_QSI_No: 25_A3, STOP_Name: Green Street, ID: 490007497E
# No match found for Katherine Road in Excel data.
# No match found for Shrewsbury Road in Excel data.
# No match found for Woodgrange Park Station in Excel data.
# Route_Dir_QSI_No: 25_A2, STOP_Name: High Street North, ID: 490008189E
# No match found for First Avenue in Excel data.
# No match found for Rabbits Road in Excel data.
# No match found for Seventh Avenue in Excel data.
# No match found for Little Ilford Lane in Excel data.
# No match found for North Circular Road in Excel data.
# No match found for Ilford Hill in Excel data.
# No match found for Ilford / Chapel Road in Excel data.
# No match found for Redbridge Central Library in Excel data.
# Route_Dir_QSI_No: 25_A1, STOP_Name: Hainault Street, ID: 490007657S

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]

    # Check if any matching rows are found
    if filtered_df_A.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # Make API call to fetch route sequence data from TfL API
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        response = requests.get(api_url)

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = stop['name']
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame
                matched_row = result_df[result_df['STOP_NAME'].str.lower() == stop_name_api.lower()]
                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    print(f"Route_Dir_QSI_No: {route_dir_qsi_no}, STOP_Name: {stop_name_api}, ID: {stop_id}")

        else:
            print(f"Failed to fetch route sequence data from TfL API. Status code: {response.status_code}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#   Route_Dir_QSI_No STOP_NUMBER                             STOP_NAME
# 0            25_A1        FC41                       Hainault Street
# 1            25_A2        4643                     High Street North
# 2            25_A3       14581                          Green Street
# 3            25_A4      BP6275                 Stratford Bus Station
# 4            25_A5       25096                    Bow Church Station
# 5            25_A6        4826                      Mile End Station
# 6            25_A7         943  Whitechapel Stn  / Royal London Hosp
# 7            25_A8       33683                       Aldgate Station
# 8            25_A9        8559              Bank Station  / Cornhill
# Route_Dir_QSI_No: 25_A9, STOP_Name: Bank Station  / Cornhill, ID: 490000013D
# Route_Dir_QSI_No: 25_A8, STOP_Name: Aldgate Station, ID: 490000003Y
# Route_Dir_QSI_No: 25_A6, STOP_Name: Mile End Station, ID: 490000146D
# Route_Dir_QSI_No: 25_A5, STOP_Name: Bow Church Station, ID: 490002019A
# Route_Dir_QSI_No: 25_A4, STOP_Name: Stratford Bus Station, ID: 490012904N
# Route_Dir_QSI_No: 25_A4, STOP_Name: Stratford Bus Station, ID: 490012904B
# Route_Dir_QSI_No: 25_A3, STOP_Name: Green Street, ID: 490007497E
# Route_Dir_QSI_No: 25_A2, STOP_Name: High Street North, ID: 490008189E
# Route_Dir_QSI_No: 25_A1, STOP_Name: Hainault Street, ID: 490007657S

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]

    # Check if any matching rows are found
    if filtered_df_A.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # Make API call to fetch route sequence data from TfL API
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        response = requests.get(api_url)

        if response.status_code == 200:
            route_data = response.json()

            # List to store the matched results
            matched_results = []

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = stop['name']
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame
                matched_row = result_df[result_df['STOP_NAME'].str.lower() == stop_name_api.lower()]
                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    matched_results.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop_name_api,
                        'ID': stop_id
                    })

            # Create a DataFrame from the matched results
            matched_results_df = pd.DataFrame(matched_results)

            # Print the matched results DataFrame
            print(matched_results_df)

        else:
            print(f"Failed to fetch route sequence data from TfL API. Status code: {response.status_code}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#   Route_Dir_QSI_No STOP_NUMBER                             STOP_NAME
# 0            25_A1        FC41                       Hainault Street
# 1            25_A2        4643                     High Street North
# 2            25_A3       14581                          Green Street
# 3            25_A4      BP6275                 Stratford Bus Station
# 4            25_A5       25096                    Bow Church Station
# 5            25_A6        4826                      Mile End Station
# 6            25_A7         943  Whitechapel Stn  / Royal London Hosp
# 7            25_A8       33683                       Aldgate Station
# 8            25_A9        8559              Bank Station  / Cornhill
#   Route_Dir_QSI_No                 STOP_Name          ID
# 0            25_A9  Bank Station  / Cornhill  490000013D
# 1            25_A8           Aldgate Station  490000003Y
# 2            25_A6          Mile End Station  490000146D
# 3            25_A5        Bow Church Station  490002019A
# 4            25_A4     Stratford Bus Station  490012904N
# 5            25_A4     Stratford Bus Station  490012904B
# 6            25_A3              Green Street  490007497E
# 7            25_A2         High Street North  490008189E
# 8            25_A1           Hainault Street  490007657S

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]

    # Check if any matching rows are found
    if filtered_df_A.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Make API call to fetch route sequence data from TfL API
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/inbound"
        response = requests.get(api_url)

        if response.status_code == 200:
            route_data = response.json()

            # List to store the matched results
            matched_results = []

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = stop['name']
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame
                matched_row = result_df[result_df['STOP_NAME'].str.lower() == stop_name_api.lower()]
                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    matched_results.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop_name_api,
                        'ID': stop_id
                    })

            # Create a DataFrame from the matched results
            matched_results_df = pd.DataFrame(matched_results)

            # Print the matched results DataFrame
            print(matched_results_df)

        else:
            print(f"Failed to fetch route sequence data from TfL API. Status code: {response.status_code}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#   Route_Dir_QSI_No                 STOP_Name          ID
# 0            25_A9  Bank Station  / Cornhill  490000013D
# 1            25_A8           Aldgate Station  490000003Y
# 2            25_A6          Mile End Station  490000146D
# 3            25_A5        Bow Church Station  490002019A
# 4            25_A4     Stratford Bus Station  490012904N
# 5            25_A4     Stratford Bus Station  490012904B
# 6            25_A3              Green Street  490007497E
# 7            25_A2         High Street North  490008189E
# 8            25_A1           Hainault Street  490007657S

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # List to store the matched results
        matched_results = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = stop['name']
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = result_df[result_df['STOP_NAME'].str.lower() == stop_name_api.lower()]
                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        matched_results.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop_name_api,
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data
        fetch_and_process_route_data('inbound')

        # Fetch and process outbound route data
        fetch_and_process_route_data('outbound')

        # Create a DataFrame from the matched results
        matched_results_df = pd.DataFrame(matched_results)

        # Print the matched results DataFrame
        print(matched_results_df)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 179
#    Route_Dir_QSI_No                            STOP_Name          ID
# 0            179_B1                      Hainault Street  490007657W
# 1            179_A7                       Ilford Station  490001157G
# 2            179_A6  Gants Hill Station / Cranbrook Road  490015202M
# 3            179_B4                        Southend Road  490012285S
# 4            179_A4               South Woodford Station  490000217E
# 5            179_B4                        Southend Road  490007137L
# 6            179_A3      Woodford Green / Broadmead Road  490014847N
# 7            179_B7             Kings Road / Friday Hill  490007021W
# 8            179_A1                    Chingford Station  490001063F
# 9            179_A1                    Chingford Station  490001063C
# 10           179_A2                          Friday Hill  490007021E
# 11           179_A3      Woodford Green / Broadmead Road  490014847S
# 12           179_B4                        Southend Road  490007137M
# 13           179_A4               South Woodford Station  490015122C
# 14           179_A5           Charlie Brown's Roundabout  490005002N
# 15           179_A6  Gants Hill Station / Cranbrook Road  490015202N
# 16           179_A7                       Ilford Station  490005699D
# 17           179_B1                      Hainault Street  490007657S

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # List to store the matched results
        matched_results = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = stop['name']
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = result_df[result_df['STOP_NAME'].str.lower() == stop_name_api.lower()]
                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        matched_results.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop_name_api,
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data
        fetch_and_process_route_data('inbound')

        # Fetch and process outbound route data
        fetch_and_process_route_data('outbound')

        # Create a DataFrame from the matched results
        matched_results_df = pd.DataFrame(matched_results)

        # Print the matched results DataFrame
        print(matched_results_df)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#    Route_Dir_QSI_No                              STOP_Name          ID
# 0             25_A9               Bank Station  / Cornhill  490000013D
# 1             25_A8                        Aldgate Station  490000003Y
# 2             25_B4  Whitechapel Stn   / Royal London Hosp  490009873D
# 3             25_A6                       Mile End Station  490000146D
# 4             25_A5                     Bow Church Station  490002019A
# 5             25_A4                  Stratford Bus Station  490012904N
# 6             25_A4                  Stratford Bus Station  490012904B
# 7             25_A3                           Green Street  490007497E
# 8             25_A2                      High Street North  490008189E
# 9             25_A1                        Hainault Street  490007657S
# 10            25_A1                        Hainault Street  490007657V
# 11            25_A2                      High Street North  490008189W
# 12            25_A3                           Green Street  490007497W
# 13            25_A4                  Stratford Bus Station  490012904T
# 14            25_A5                     Bow Church Station  490002019B
# 15            25_A6                       Mile End Station  490000146C
# 16            25_A7   Whitechapel Stn  / Royal London Hosp  490013541A
# 17            25_A8                        Aldgate Station  490000003R
# 18            25_A9               Bank Station  / Cornhill  490000013E

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # List to store the matched results
        matched_results = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = stop['name']
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = result_df[(result_df['STOP_NAME'].str.lower() == stop_name_api.lower()) &
                                            (result_df['Route_Dir_QSI_No'].str.match(pattern))]
                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        matched_results.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop_name_api,
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B)

        # Create a DataFrame from the matched results
        matched_results_df = pd.DataFrame(matched_results)

        # Print the matched results DataFrame
        print(matched_results_df)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#    Route_Dir_QSI_No STOP_NUMBER                              STOP_NAME
# 0             25_A1        FC41                        Hainault Street
# 1             25_A2        4643                      High Street North
# 2             25_A3       14581                           Green Street
# 3             25_A4      BP6275                  Stratford Bus Station
# 4             25_A5       25096                     Bow Church Station
# 5             25_A6        4826                       Mile End Station
# 6             25_A7         943   Whitechapel Stn  / Royal London Hosp
# 7             25_A8       33683                        Aldgate Station
# 8             25_A9        8559               Bank Station  / Cornhill
# 9             25_B1        2018                         Holborn Circus
# 10            25_B2        8558               Bank Station  / Cornhill
# 11            25_B3      BP5998                        Aldgate Station
# 12            25_B4         944  Whitechapel Stn   / Royal London Hosp
# 13            25_B5       20674                       Mile End Station
# 14            25_B6         902                     Bow Church Station
# 15            25_B7       BP976                  Stratford Bus Station
# 16            25_B8        4644                      High Street North
#    Route_Dir_QSI_No                 STOP_Name          ID
# 0             25_A9  Bank Station  / Cornhill  490000013D
# 1             25_A8           Aldgate Station  490000003Y
# 2             25_A6          Mile End Station  490000146D
# 3             25_A5        Bow Church Station  490002019A
# 4             25_A4     Stratford Bus Station  490012904N
# 5             25_A4     Stratford Bus Station  490012904B
# 6             25_A3              Green Street  490007497E
# 7             25_A2         High Street North  490008189E
# 8             25_A1           Hainault Street  490007657S
# 9             25_B8         High Street North  490008189W
# 10            25_B7     Stratford Bus Station  490012904T
# 11            25_B6        Bow Church Station  490002019B
# 12            25_B5          Mile End Station  490000146C
# 13            25_B3           Aldgate Station  490000003R
# 14            25_B2  Bank Station  / Cornhill  490000013E

# %%
import pandas as pd
import requests

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # List to store the matched results
        matched_results = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = stop['name'].strip().lower()
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = result_df[(result_df['STOP_NAME'].str.strip().str.lower() == stop_name_api) &
                                            (result_df['Route_Dir_QSI_No'].str.match(pattern))]
                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        matched_results.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B)

        # Create a DataFrame from the matched results
        matched_results_df = pd.DataFrame(matched_results)

        # Print the matched results DataFrame
        print(matched_results_df)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#    Route_Dir_QSI_No STOP_NUMBER                              STOP_NAME
# 0             25_A1        FC41                        Hainault Street
# 1             25_A2        4643                      High Street North
# 2             25_A3       14581                           Green Street
# 3             25_A4      BP6275                  Stratford Bus Station
# 4             25_A5       25096                     Bow Church Station
# 5             25_A6        4826                       Mile End Station
# 6             25_A7         943   Whitechapel Stn  / Royal London Hosp
# 7             25_A8       33683                        Aldgate Station
# 8             25_A9        8559               Bank Station  / Cornhill
# 9             25_B1        2018                         Holborn Circus
# 10            25_B2        8558               Bank Station  / Cornhill
# 11            25_B3      BP5998                        Aldgate Station
# 12            25_B4         944  Whitechapel Stn   / Royal London Hosp
# 13            25_B5       20674                       Mile End Station
# 14            25_B6         902                     Bow Church Station
# 15            25_B7       BP976                  Stratford Bus Station
# 16            25_B8        4644                      High Street North
#    Route_Dir_QSI_No                 STOP_Name          ID
# 0             25_A9  Bank Station  / Cornhill  490000013D
# 1             25_A8           Aldgate Station  490000003Y
# 2             25_A6          Mile End Station  490000146D
# 3             25_A5        Bow Church Station  490002019A
# 4             25_A4     Stratford Bus Station  490012904N
# 5             25_A4     Stratford Bus Station  490012904B
# 6             25_A3              Green Street  490007497E
# 7             25_A2         High Street North  490008189E
# 8             25_A1           Hainault Street  490007657S
# 9             25_B8         High Street North  490008189W
# 10            25_B7     Stratford Bus Station  490012904T
# 11            25_B6        Bow Church Station  490002019B
# 12            25_B5          Mile End Station  490000146C
# 13            25_B3           Aldgate Station  490000003R
# 14            25_B2  Bank Station  / Cornhill  490000013E

# %%
import pandas as pd
import requests

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME
        result_df = filtered_df[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrame and drop the old index column
        result_df.reset_index(drop=True, inplace=True)

        # Print the resulting DataFrame
        print(result_df)

        # List to store the matched results
        matched_results = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = result_df[(result_df['STOP_NAME'] == stop_name_api) &
                                            (result_df['Route_Dir_QSI_No'].str.match(pattern))]
                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        matched_results.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B)

        # Create a DataFrame from the matched results
        matched_results_df = pd.DataFrame(matched_results)

        # Print the matched results DataFrame
        print(matched_results_df)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
#    Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0             25_A1        FC41                      hainault street
# 1             25_A2        4643                    high street north
# 2             25_A3       14581                         green street
# 3             25_A4      BP6275                stratford bus station
# 4             25_A5       25096                   bow church station
# 5             25_A6        4826                     mile end station
# 6             25_A7         943  whitechapel stn / royal london hosp
# 7             25_A8       33683                      aldgate station
# 8             25_A9        8559              bank station / cornhill
# 9             25_B1        2018                       holborn circus
# 10            25_B2        8558              bank station / cornhill
# 11            25_B3      BP5998                      aldgate station
# 12            25_B4         944  whitechapel stn / royal london hosp
# 13            25_B5       20674                     mile end station
# 14            25_B6         902                   bow church station
# 15            25_B7       BP976                stratford bus station
# 16            25_B8        4644                    high street north
#    Route_Dir_QSI_No                              STOP_Name          ID
# 0             25_A9               Bank Station  / Cornhill  490000013D
# 1             25_A8                        Aldgate Station  490000003Y
# 2             25_A7  Whitechapel Stn   / Royal London Hosp  490009873D
# 3             25_A6                       Mile End Station  490000146D
# 4             25_A5                     Bow Church Station  490002019A
# 5             25_A4                  Stratford Bus Station  490012904N
# 6             25_A4                  Stratford Bus Station  490012904B
# 7             25_A3                           Green Street  490007497E
# 8             25_A2                      High Street North  490008189E
# 9             25_A1                        Hainault Street  490007657S
# 10            25_B8                      High Street North  490008189W
# 11            25_B7                  Stratford Bus Station  490012904T
# 12            25_B6                     Bow Church Station  490002019B
# 13            25_B5                       Mile End Station  490000146C
# 14            25_B4   Whitechapel Stn  / Royal London Hosp  490013541A
# 15            25_B3                        Aldgate Station  490000003R
# 16            25_B2               Bank Station  / Cornhill  490000013E

# %% [markdown]
# File share 13

# %%
import pandas as pd
import requests

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction A
        result_df_A = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction B
        result_df_B = filtered_df_B[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrames and drop the old index column
        result_df_A.reset_index(drop=True, inplace=True)
        result_df_B.reset_index(drop=True, inplace=True)

        # Print the results for direction A
        print("QSI points in direction A")
        print(result_df_A)

        # Print the results for direction B
        print("QSI points in direction B")
        print(result_df_B)

        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]
                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Print the matched results for direction A
        print("Matched results for direction A")
        print(matched_results_df_A)

        # Print the matched results for direction B
        print("Matched results for direction B")
        print(matched_results_df_B)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 25
# QSI points in direction A
#   Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0            25_A1        FC41                      hainault street
# 1            25_A2        4643                    high street north
# 2            25_A3       14581                         green street
# 3            25_A4      BP6275                stratford bus station
# 4            25_A5       25096                   bow church station
# 5            25_A6        4826                     mile end station
# 6            25_A7         943  whitechapel stn / royal london hosp
# 7            25_A8       33683                      aldgate station
# 8            25_A9        8559              bank station / cornhill
# QSI points in direction B
#   Route_Dir_QSI_No STOP_NUMBER                            STOP_NAME
# 0            25_B1        2018                       holborn circus
# 1            25_B2        8558              bank station / cornhill
# 2            25_B3      BP5998                      aldgate station
# 3            25_B4         944  whitechapel stn / royal london hosp
# 4            25_B5       20674                     mile end station
# 5            25_B6         902                   bow church station
# 6            25_B7       BP976                stratford bus station
# 7            25_B8        4644                    high street north
# Matched results for direction A
#   Route_Dir_QSI_No                              STOP_Name          ID
# 0            25_A9               Bank Station  / Cornhill  490000013D
# 1            25_A8                        Aldgate Station  490000003Y
# 2            25_A7  Whitechapel Stn   / Royal London Hosp  490009873D
# 3            25_A6                       Mile End Station  490000146D
# 4            25_A5                     Bow Church Station  490002019A
# 5            25_A4                  Stratford Bus Station  490012904N
# 6            25_A4                  Stratford Bus Station  490012904B
# 7            25_A3                           Green Street  490007497E
# 8            25_A2                      High Street North  490008189E
# 9            25_A1                        Hainault Street  490007657S
# Matched results for direction B
#   Route_Dir_QSI_No                             STOP_Name          ID
# 0            25_B8                     High Street North  490008189W
# 1            25_B7                 Stratford Bus Station  490012904T
# 2            25_B6                    Bow Church Station  490002019B
# 3            25_B5                      Mile End Station  490000146C
# 4            25_B4  Whitechapel Stn  / Royal London Hosp  490013541A
# 5            25_B3                       Aldgate Station  490000003R
# 6            25_B2              Bank Station  / Cornhill  490000013E

# %%
import pandas as pd
import requests

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction A
        result_df_A = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction B
        result_df_B = filtered_df_B[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrames and drop the old index column
        result_df_A.reset_index(drop=True, inplace=True)
        result_df_B.reset_index(drop=True, inplace=True)

        # Print the results for direction A
        print("QSI points in direction A")
        print(result_df_A)

        # Print the results for direction B
        print("QSI points in direction B")
        print(result_df_B)

        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]
                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Print the matched results for direction A
        print("Matched results for direction A")
        print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

        # Print the matched results for direction B
        print("Matched results for direction B")
        print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
# QSI points in direction A
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_A1       34215   poplar / all saints church
# 1            D7_A2       15157               stewart street
# 2            D7_A3       16347       island gardens station
# 3            D7_A4         559  arnhem wharf primary school
# 4            D7_A5       25270         east india dock road
# QSI points in direction B
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_B1        1422  mile end station / bow road
# 1            D7_B2       R0780         east india dock road
# 2            D7_B3  R0315____2         canary wharf station
# 3            D7_B4       13418  arnhem wharf primary school
# 4            D7_B5      BP1802       island gardens station
# 5            D7_B6       15156               stewart street
# Matched results for direction A
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A5         East India Dock Road  490004584S
# 1            D7_A4  Arnhem Wharf Primary School  490006092S
# 2            D7_A3       Island Gardens Station  490002048X
# 3            D7_A2               Stewart Street  490013513N
# 4            D7_A1   Poplar / All Saints Church  490011107Z
# Matched results for direction B
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B6               Stewart Street  490013513S
# 1            D7_B5       Island Gardens Station  490002048Z
# 2            D7_B4  Arnhem Wharf Primary School  490006092N
# 3            D7_B3         Canary Wharf Station  490016668K
# 4            D7_B3         Canary Wharf Station  490000038G
# 5            D7_B2         East India Dock Road  490004584N

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction A
        result_df_A = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction B
        result_df_B = filtered_df_B[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrames and drop the old index column
        result_df_A.reset_index(drop=True, inplace=True)
        result_df_B.reset_index(drop=True, inplace=True)

        # Print the results for direction A
        print("QSI points in direction A")
        print(result_df_A)

        # Print the results for direction B
        print("QSI points in direction B")
        print(result_df_B)

        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                    # If exact match not found, try partial matching based on words before and after '/'
                    if matched_row.empty:
                        api_stop_name_parts = stop_name_api.split('/')
                        for index, row in filtered_df.iterrows():
                            df_stop_name_parts = row['STOP_NAME'].split('/')
                            for api_part in api_stop_name_parts:
                                for df_part in df_stop_name_parts:
                                    if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                        matched_row = pd.DataFrame([row])
                                        break
                                if not matched_row.empty:
                                    break
                            if not matched_row.empty:
                                break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Print the matched results for direction A
        print("Matched results for direction A")
        print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

        # Print the matched results for direction B
        print("Matched results for direction B")
        print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
# QSI points in direction A
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_A1       34215   poplar / all saints church
# 1            D7_A2       15157               stewart street
# 2            D7_A3       16347       island gardens station
# 3            D7_A4         559  arnhem wharf primary school
# 4            D7_A5       25270         east india dock road
# QSI points in direction B
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_B1        1422  mile end station / bow road
# 1            D7_B2       R0780         east india dock road
# 2            D7_B3  R0315____2         canary wharf station
# 3            D7_B4       13418  arnhem wharf primary school
# 4            D7_B5      BP1802       island gardens station
# 5            D7_B6       15156               stewart street
# Matched results for direction A
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 1            D7_B1             Mile End Station  490000146A
# 2            D7_A5         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_A4  Arnhem Wharf Primary School  490006092S
# 6            D7_A3       Island Gardens Station  490002048X
# 7            D7_A2               Stewart Street  490013513N
# 8            D7_A1   Poplar / All Saints Church  490011107Z
# Matched results for direction B
#   Route_Dir_QSI_No                               STOP_Name          ID
# 0            D7_A1              Poplar / All Saints Church  490011107G
# 1            D7_B6                          Stewart Street  490013513S
# 2            D7_B5                  Island Gardens Station  490002048Z
# 3            D7_B4             Arnhem Wharf Primary School  490006092N
# 4            D7_B3                    Canary Wharf Station  490016668K
# 5            D7_B3  Canada Square South / Canary Wharf Stn  490000038J
# 6            D7_B3                    Canary Wharf Station  490000038G
# 7            D7_A2                           Salter Street  490011878N
# 8            D7_B2                    East India Dock Road  490004584N
# 9            D7_B1                        Mile End Station  490000146B

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction A
        result_df_A = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction B
        result_df_B = filtered_df_B[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrames and drop the old index column
        result_df_A.reset_index(drop=True, inplace=True)
        result_df_B.reset_index(drop=True, inplace=True)

        # Print the results for direction A
        print("QSI points in direction A")
        print(result_df_A)

        # Print the results for direction B
        print("QSI points in direction B")
        print(result_df_B)

        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Determine direction from route_type
                direction = route_type.lower()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern)) &
                                              (filtered_df['Route_Dir_QSI_No'].str.endswith(f"_{direction}"))]

                    # If exact match not found, try partial matching based on words before and after '/'
                    if matched_row.empty:
                        api_stop_name_parts = stop_name_api.split('/')
                        for index, row in filtered_df.iterrows():
                            df_stop_name_parts = row['STOP_NAME'].split('/')
                            for api_part in api_stop_name_parts:
                                for df_part in df_stop_name_parts:
                                    if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                        matched_row = pd.DataFrame([row])
                                        break
                                if not matched_row.empty:
                                    break
                            if not matched_row.empty:
                                break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Print the matched results for direction A
        print(f"Matched results for direction {lineID}_A")
        matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
        print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

        # Print the matched results for direction B
        print(f"Matched results for direction {lineID}_B")
        matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
        print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
# QSI points in direction A
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_A1       34215   poplar / all saints church
# 1            D7_A2       15157               stewart street
# 2            D7_A3       16347       island gardens station
# 3            D7_A4         559  arnhem wharf primary school
# 4            D7_A5       25270         east india dock road
# QSI points in direction B
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_B1        1422  mile end station / bow road
# 1            D7_B2       R0780         east india dock road
# 2            D7_B3  R0315____2         canary wharf station
# 3            D7_B4       13418  arnhem wharf primary school
# 4            D7_B5      BP1802       island gardens station
# 5            D7_B6       15156               stewart street
# Matched results for direction D7_A
#   Route_Dir_QSI_No                    STOP_Name          ID
# 2            D7_A5         East India Dock Road  490004584S
# 5            D7_A4  Arnhem Wharf Primary School  490006092S
# 6            D7_A3       Island Gardens Station  490002048X
# 7            D7_A2               Stewart Street  490013513N
# 8            D7_A1   Poplar / All Saints Church  490011107Z
# Matched results for direction D7_B
#   Route_Dir_QSI_No                               STOP_Name          ID
# 4            D7_B3                    Canary Wharf Station  490016668K
# 5            D7_B3  Canada Square South / Canary Wharf Stn  490000038J
# 6            D7_B3                    Canary Wharf Station  490000038G
# 9            D7_B1                        Mile End Station  490000146B

# %% [markdown]
# File share 14

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction A
        result_df_A = filtered_df_A[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Display the relevant columns: Route_Dir_QSI_No, STOP_NUMBER, STOP_NAME for direction B
        result_df_B = filtered_df_B[['Route_Dir_QSI_No', 'STOP_NUMBER', 'STOP_NAME']]

        # Reset the index of the DataFrames and drop the old index column
        result_df_A.reset_index(drop=True, inplace=True)
        result_df_B.reset_index(drop=True, inplace=True)

        # Print the results for direction A
        print("QSI points in direction A")
        print(result_df_A)

        # Print the results for direction B
        print("QSI points in direction B")
        print(result_df_B)

        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                    # If exact match not found, try partial matching based on words before and after '/'
                    if matched_row.empty:
                        api_stop_name_parts = stop_name_api.split('/')
                        for index, row in filtered_df.iterrows():
                            df_stop_name_parts = row['STOP_NAME'].split('/')
                            for api_part in api_stop_name_parts:
                                for df_part in df_stop_name_parts:
                                    if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                        matched_row = pd.DataFrame([row])
                                        break
                                if not matched_row.empty:
                                    break
                            if not matched_row.empty:
                                break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Print the matched results for direction A
        print(f"Matched results for direction {lineID}_A")
        matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
        print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

        # Print the matched results for direction B
        print(f"Matched results for direction {lineID}_B")
        matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
        print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
# QSI points in direction A
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_A1       34215   poplar / all saints church
# 1            D7_A2       15157               stewart street
# 2            D7_A3       16347       island gardens station
# 3            D7_A4         559  arnhem wharf primary school
# 4            D7_A5       25270         east india dock road
# QSI points in direction B
#   Route_Dir_QSI_No STOP_NUMBER                    STOP_NAME
# 0            D7_B1        1422  mile end station / bow road
# 1            D7_B2       R0780         east india dock road
# 2            D7_B3  R0315____2         canary wharf station
# 3            D7_B4       13418  arnhem wharf primary school
# 4            D7_B5      BP1802       island gardens station
# 5            D7_B6       15156               stewart street
# Matched results for direction D7_A
#   Route_Dir_QSI_No                    STOP_Name          ID
# 2            D7_A5         East India Dock Road  490004584S
# 5            D7_A4  Arnhem Wharf Primary School  490006092S
# 6            D7_A3       Island Gardens Station  490002048X
# 7            D7_A2               Stewart Street  490013513N
# 8            D7_A1   Poplar / All Saints Church  490011107Z
# Matched results for direction D7_B
#   Route_Dir_QSI_No                               STOP_Name          ID
# 1            D7_B6                          Stewart Street  490013513S
# 2            D7_B5                  Island Gardens Station  490002048Z
# 3            D7_B4             Arnhem Wharf Primary School  490006092N
# 4            D7_B3                    Canary Wharf Station  490016668K
# 5            D7_B3  Canada Square South / Canary Wharf Stn  490000038J
# 6            D7_B3                    Canary Wharf Station  490000038G
# 8            D7_B2                    East India Dock Road  490004584N
# 9            D7_B1                        Mile End Station  490000146B

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                    # If exact match not found, try partial matching based on words before and after '/'
                    if matched_row.empty:
                        api_stop_name_parts = stop_name_api.split('/')
                        for index, row in filtered_df.iterrows():
                            df_stop_name_parts = row['STOP_NAME'].split('/')
                            for api_part in api_stop_name_parts:
                                for df_part in df_stop_name_parts:
                                    if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                        matched_row = pd.DataFrame([row])
                                        break
                                if not matched_row.empty:
                                    break
                            if not matched_row.empty:
                                break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Print the matched results for direction A
        print(f"QSI stop points for direction {lineID}_A")
        matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
        print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

        # Print the matched results for direction B
        print(f"QSI stop points for direction {lineID}_B")
        matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
        print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 122
# QSI stop points for direction 122_A
#    Route_Dir_QSI_No                              STOP_Name           ID
# 3           122_A10       Sydenham Station / Westwood Hill   490009026C
# 4           122_A10           Sydenham Station  / Kirkdale   490005453E
# 5           122_A10                Sydenham Police Station  490013131N2
# 7            122_A9  Forest Hill Station  / Dartmouth Road   490001112E
# 8            122_A9               Forest Hill Fire Station   490006920E
# 10           122_A7                   Crofton Park Station   490018484N
# 12           122_A6                        Lewisham Centre   490009105V
# 13           122_A5                              Lee Green   490009060E
# 14           122_A4      Eltham Road / Kidbrooke Park Road   490008704E
# 15           122_A4         Eltham Road / Westhorne Avenue  490015018E1
# 16           122_A4         Westhorne Avenue / Briset Road   490004351N
# 17           122_A4      Westhorne Avenue / Kidbrooke Lane  490008701N1
# 18           122_A3         Well Hall Road / Dunblane Road   490013592N
# 19           122_A3            Well Hall Road / Broad Walk   490004379N
# 20           122_A3      Academy Road / Shooters Hill Road   490012108N
# 21           122_A2               Woolwich Arsenal Station  490001344N1
# QSI stop points for direction 122_B
#    Route_Dir_QSI_No                               STOP_Name           ID
# 7            122_B8          Eltham Road / Westhorne Avenue  490015018W2
# 9            122_B7                               Lee Green   490009060A
# 10           122_B6                         Lewisham Centre   490009105X
# 17           122_B3      Dartmouth Road / Thorpewood Avenue   490013646S
# 18           122_B2            Sydenham Station  / Kirkdale   490005453F
# 20           122_B1                Crystal Palace Park Road   490005872W
# 21           122_B1  Crystal Palace Parade / Fountain Drive   490006963S
# 22           122_B1    Crystal Palace Parade / College Road  490005494S2
# 23           122_B1                   Crystal Palace Parade   490005869A

# %%
import pandas as pd
import requests

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for 25_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for 25_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # List to store the matched results for direction A and B
    matched_results_A = []
    matched_results_B = []

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, results_list, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]
                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

    # Fetch and process inbound route data for _A**
    fetch_and_process_route_data('inbound', pattern_A, matched_results_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    fetch_and_process_route_data('outbound', pattern_B, matched_results_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Print the matched results for direction A
    print("QSI stop points for direction A")
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print("QSI stop points for direction B")
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 122
# QSI stop points for direction A
#   Route_Dir_QSI_No                       STOP_Name           ID
# 0          122_A10    Sydenham Station  / Kirkdale   490005453E
# 1           122_A7            Crofton Park Station   490018484N
# 2           122_A6                 Lewisham Centre   490009105V
# 3           122_A5                       Lee Green   490009060E
# 4           122_A4  Eltham Road / Westhorne Avenue  490015018E1
# 5           122_A2        Woolwich Arsenal Station  490001344N1
# QSI stop points for direction B
#   Route_Dir_QSI_No                       STOP_Name           ID
# 0           122_B8  Eltham Road / Westhorne Avenue  490015018W2
# 1           122_B7                       Lee Green   490009060A
# 2           122_B6                 Lewisham Centre   490009105X
# 3           122_B2    Sydenham Station  / Kirkdale   490005453F
# 4           122_B1           Crystal Palace Parade   490005869A

# %% [markdown]
# 01/07/2024

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                    # If exact match not found, try partial matching based on words before and after '/'
                    if matched_row.empty:
                        api_stop_name_parts = stop_name_api.split('/')
                        for index, row in filtered_df.iterrows():
                            df_stop_name_parts = row['STOP_NAME'].split('/')
                            for api_part in api_stop_name_parts:
                                for df_part in df_stop_name_parts:
                                    if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                        matched_row = pd.DataFrame([row])
                                        break
                                if not matched_row.empty:
                                    break
                            if not matched_row.empty:
                                break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Print the matched results for direction A
        print(f"QSI stop points for direction {lineID}_A")
        matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
        print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

        # Print the matched results for direction B
        print(f"QSI stop points for direction {lineID}_B")
        matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
        print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 122
# QSI stop points for direction 122_A
#    Route_Dir_QSI_No                              STOP_Name           ID
# 3           122_A10       Sydenham Station / Westwood Hill   490009026C
# 4           122_A10           Sydenham Station  / Kirkdale   490005453E
# 5           122_A10                Sydenham Police Station  490013131N2
# 7            122_A9  Forest Hill Station  / Dartmouth Road   490001112E
# 8            122_A9               Forest Hill Fire Station   490006920E
# 10           122_A7                   Crofton Park Station   490018484N
# 12           122_A6                        Lewisham Centre   490009105V
# 13           122_A5                              Lee Green   490009060E
# 14           122_A4      Eltham Road / Kidbrooke Park Road   490008704E
# 15           122_A4         Eltham Road / Westhorne Avenue  490015018E1
# 16           122_A4         Westhorne Avenue / Briset Road   490004351N
# 17           122_A4      Westhorne Avenue / Kidbrooke Lane  490008701N1
# 18           122_A3         Well Hall Road / Dunblane Road   490013592N
# 19           122_A3            Well Hall Road / Broad Walk   490004379N
# 20           122_A3      Academy Road / Shooters Hill Road   490012108N
# 21           122_A2               Woolwich Arsenal Station  490001344N1
# QSI stop points for direction 122_B
#    Route_Dir_QSI_No                               STOP_Name           ID
# 7            122_B8          Eltham Road / Westhorne Avenue  490015018W2
# 9            122_B7                               Lee Green   490009060A
# 10           122_B6                         Lewisham Centre   490009105X
# 17           122_B3      Dartmouth Road / Thorpewood Avenue   490013646S
# 18           122_B2            Sydenham Station  / Kirkdale   490005453F
# 20           122_B1                Crystal Palace Park Road   490005872W
# 21           122_B1  Crystal Palace Parade / Fountain Drive   490006963S
# 22           122_B1    Crystal Palace Parade / College Road  490005494S2
# 23           122_B1                   Crystal Palace Parade   490005869A

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Combine the filtered dataframes
    filtered_df = pd.concat([filtered_df_A, filtered_df_B])

    # Check if any matching rows are found
    if filtered_df.empty:
        print(f"No matching records found for lineID: {lineID}")
    else:
        # List to store the matched results
        matched_results_A = []
        matched_results_B = []

        # Function to fetch and process route sequence data from TfL API
        def fetch_and_process_route_data(route_type, pattern, results_list):
            api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
            response = requests.get(api_url)

            if response.status_code == 200:
                route_data = response.json()

                # Iterate through each stop in the route data
                for stop in route_data['stopPointSequences'][0]['stopPoint']:
                    stop_name_api = normalize_stop_name(stop['name'])
                    stop_id = stop['id']

                    # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                    matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                              (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
                    else:
                        # If exact match not found, try partial matching based on words before and after '/'
                        api_stop_name_parts = stop_name_api.split('/')
                        for index, row in filtered_df.iterrows():
                            df_stop_name_parts = row['STOP_NAME'].split('/')
                            for api_part in api_stop_name_parts:
                                for df_part in df_stop_name_parts:
                                    if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                        matched_row = pd.DataFrame([row])
                                        break
                                if not matched_row.empty:
                                    break
                            if not matched_row.empty:
                                break

                        if not matched_row.empty:
                            route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                            results_list.append({
                                'Route_Dir_QSI_No': route_dir_qsi_no,
                                'STOP_Name': stop['name'],
                                'ID': stop_id
                            })
            else:
                print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        # Fetch and process inbound route data for _A**
        fetch_and_process_route_data('inbound', pattern_A, matched_results_A)

        # Fetch and process outbound route data for _B**
        fetch_and_process_route_data('outbound', pattern_B, matched_results_B)

        # Create DataFrames from the matched results for each direction
        matched_results_df_A = pd.DataFrame(matched_results_A)
        matched_results_df_B = pd.DataFrame(matched_results_B)

        # Remove duplicate entries based on 'Route_Dir_QSI_No' and 'STOP_Name' to avoid partial matches if exact matches are found
        matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'])
        matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'])

        # Print the matched results for direction A
        print(f"QSI stop points for direction {lineID}_A")
        matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
        print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

        # Print the matched results for direction B
        print(f"QSI stop points for direction {lineID}_B")
        matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
        print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 122
# QSI stop points for direction 122_A
#    Route_Dir_QSI_No                              STOP_Name           ID
# 3           122_A10       Sydenham Station / Westwood Hill   490009026C
# 4           122_A10           Sydenham Station  / Kirkdale   490005453E
# 5           122_A10                Sydenham Police Station  490013131N2
# 7            122_A9  Forest Hill Station  / Dartmouth Road   490001112E
# 8            122_A9               Forest Hill Fire Station   490006920E
# 10           122_A7                   Crofton Park Station   490018484N
# 12           122_A6                        Lewisham Centre   490009105V
# 13           122_A5                              Lee Green   490009060E
# 14           122_A4      Eltham Road / Kidbrooke Park Road   490008704E
# 15           122_A4         Eltham Road / Westhorne Avenue  490015018E1
# 16           122_A4         Westhorne Avenue / Briset Road   490004351N
# 17           122_A4      Westhorne Avenue / Kidbrooke Lane  490008701N1
# 18           122_A3         Well Hall Road / Dunblane Road   490013592N
# 19           122_A3            Well Hall Road / Broad Walk   490004379N
# 20           122_A3      Academy Road / Shooters Hill Road   490012108N
# 21           122_A2               Woolwich Arsenal Station  490001344N1
# QSI stop points for direction 122_B
#    Route_Dir_QSI_No                               STOP_Name           ID
# 7            122_B8          Eltham Road / Westhorne Avenue  490015018W2
# 9            122_B7                               Lee Green   490009060A
# 10           122_B6                         Lewisham Centre   490009105X
# 17           122_B3      Dartmouth Road / Thorpewood Avenue   490013646S
# 18           122_B2            Sydenham Station  / Kirkdale   490005453F
# 20           122_B1                Crystal Palace Park Road   490005872W
# 21           122_B1  Crystal Palace Parade / Fountain Drive   490006963S
# 22           122_B1    Crystal Palace Parade / College Road  490005494S2
# 23           122_B1                   Crystal Palace Parade   490005869A

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('inbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('outbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Remove duplicate entries based on 'Route_Dir_QSI_No' and 'STOP_Name' to avoid partial matches if exact matches are found
    matched_results_df_A = matched_results_df_A.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'])
    matched_results_df_B = matched_results_df_B.drop_duplicates(subset=['Route_Dir_QSI_No', 'STOP_Name'])

    # Print the matched results for direction A
    print(f"QSI stop points for direction {lineID}_A")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"QSI stop points for direction {lineID}_B")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID:
# 6            122_A6                        Lewisham Centre   490009105V
# 7            122_A5                              Lee Green   490009060E
# 9            122_A4         Eltham Road / Westhorne Avenue  490015018E1
# 12           122_A3         Well Hall Road / Dunblane Road   490013592N
# 13           122_A3            Well Hall Road / Broad Walk   490004379N
# 14           122_A3      Academy Road / Shooters Hill Road   490012108N
# 15           122_A2               Woolwich Arsenal Station  490001344N1
#
#
# QSI stop points for direction 122_B
#
#    Route_Dir_QSI_No                                STOP_Name           ID
# 0            122_B9      Well Hall Road / Shooters Hill Road   490012108S
# 2            122_B8           Eltham Road / Westhorne Avenue  490015018W2
# 4            122_B7                                Lee Green   490009060A
# 5            122_B6                          Lewisham Centre   490009105X
# 6            122_B3                 Forest Hill Fire Station   490006920W
# 7            122_B3  Forest Hill Station  / Waldram Crescent   490006919K
# 8            122_B3   Forest Hill Station  / Devonshire Road   490001112F
# 9            122_B3       Dartmouth Road / Thorpewood Avenue   490013646S
# 10           122_B2             Sydenham Station  / Kirkdale   490005453F
# 15           122_B1                    Crystal Palace Parade   490005869A

# %% [markdown]
# File share 15

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 160
#
#
# Stop names from the Excel file for direction 160_A
#
#     Route_Dir_QSI_No                            STOP_NAME
# 113           160_A1                          thomas lane
# 114           160_A2        sandhurst road / verdant lane
# 115           160_A3                          baring road
# 116           160_A4                      newmarket green
# 117           160_A5    eltham high street / passey place
# 118           160_A6  new eltham station / footscray road
# 119           160_A7            chislehurst / gordon arms
# 120           160_A8    centre common road / war memorial
# 121           160_A9                sidcup / carlton road
#
#
# Stop names from the Excel file for direction 160_B
#
#     Route_Dir_QSI_No                            STOP_NAME
# 122           160_B1                       sidcup station
# 123           160_B2                sidcup / carlton road
# 124           160_B3    centre common road / war memorial
# 125           160_B4            chislehurst / gordon arms
# 126           160_B5  new eltham station / footscray road
# 127           160_B6    eltham high street / passey place
# 128           160_B7                      newmarket green
# 129           160_B8                          baring road
# 130           160_B9        sandhurst road / verdant lane
#
#
# QSI stop points for direction 160_A
#
#    Route_Dir_QSI_No                             STOP_Name           ID
# 0            160_A1                           Thomas Lane   490013615Q
# 2            160_A2         Sandhurst Road / Verdant Lane   490014368E
# 3            160_A3                           Baring Road   490003599E
# 4            160_A4                       Newmarket Green  490010238N2
# 5            160_A5     Eltham High Street / Passey Place   490006537L
# 7            160_A6  New Eltham Station  / Footscray Road   490010209B
# 9            160_A7             Chislehurst / Gordon Arms   490005198D
# 10           160_A8     Centre Common Road / War Memorial   490005205P
# 11           160_A9                 Sidcup / Carlton Road   490012140R
#
#
# QSI stop points for direction 160_B
#
#    Route_Dir_QSI_No                             STOP_Name           ID
# 0            160_B1                        Sidcup Station   490001249F
# 2            160_B2                 Sidcup / Carlton Road   490012140S
# 3            160_B3     Centre Common Road / War Memorial   490005205N
# 5            160_B4             Chislehurst / Gordon Arms   490005198C
# 7            160_B5  New Eltham Station  / Footscray Road   490001205A
# 11           160_B6     Eltham High Street / Passey Place   490006537M
# 12           160_B7                       Newmarket Green  490010238N1
# 13           160_B8                           Baring Road   490003599W
# 14           160_B9         Sandhurst Road / Verdant Lane   490014368W

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N

# %%
File share 15 + File share 17

# %% [markdown]
# File share 15

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N

# %% [markdown]
# File share 17

# %%
import requests
from datetime import datetime
import pytz

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = input("Enter the line ID: ")
    stop_point_id = input("Enter the stop point ID: ")
    direction = input("Enter the direction (outbound/inbound): ")

    # Fetching data
    url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
    data = fetch_data(url)

    # Extracting schedule names
    schedule_names_dict = extract_schedule_names(data)

    # Fetch day of the week
    day_of_week = get_day_of_week()
    print(f"\nToday is {day_of_week}.")

    # Print extracted schedule names
    print("\nExtracted Schedule Names:")
    for i, schedule_name in enumerate(schedule_names_dict.keys(), start=1):
        print(f"{i}. {schedule_name}")

    # Determine the matching schedule name based on the current day of the week
    selected_schedule_name = None

    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        # Check for the preferred schedule names for Monday to Thursday
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        # Check for the preferred schedule names for Friday
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        # Check for the preferred schedule names for Saturday
        preferred_schedule_names = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        # Check for the preferred schedule names for Sunday
        preferred_schedule_names = ['Sunday']
    else:
        # For other days of the week, select based on exact match
        preferred_schedule_names = [day_of_week]

    for preferred_name in preferred_schedule_names:
        if preferred_name in schedule_names_dict:
            selected_schedule_name = preferred_name
            break

    if selected_schedule_name:
        print(f"\nSelected schedule name: {selected_schedule_name}")

        # Categorizing the timetable into hourly slots
        timetable = schedule_names_dict[selected_schedule_name]
        slots = categorize_into_slots(timetable)

        # Get the current time in BST
        bst = pytz.timezone('Europe/London')
        now = datetime.now(bst)
        current_hour = now.hour
        current_minute = now.minute

        # Calculate the number of buses scheduled for the current hour
        total_buses_this_hour = len(slots[current_hour])
        print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

        # Calculate the number of buses scheduled between the first time available in the current slot and the current time
        bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
        print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

        # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
        hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
        print("\nTimetable:")
        print("Time   Line ID  Stop Point ID  Direction")
        for hour in hours_to_print:
            if 0 <= hour < 24:
                print(f"\nSlot {hour}:")
                for journey in slots[hour]:
                    journey_hour = str(journey['hour']).zfill(2)
                    journey_minute = str(journey['minute']).zfill(2)
                    time = f"{journey_hour}:{journey_minute}"
                    print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

    else:
        print("No matching schedule name found for today.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# Enter the stop point ID: 490011107G
# Enter the direction (outbound/inbound): outbound
#
# Today is Monday.
#
# Extracted Schedule Names:
# 1. Monday to Friday
# 2. Saturday
# 3. Sunday
#
# Selected schedule name: Monday to Friday
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
#
# Slot 13:
# 13:09   d7    490011107G  Outbound
# 13:21   d7    490011107G  Outbound
# 13:33   d7    490011107G  Outbound
# 13:45   d7    490011107G  Outbound
# 13:58   d7    490011107G  Outbound
#
# Slot 14:
# 14:10   d7    490011107G  Outbound
# 14:22   d7    490011107G  Outbound
# 14:34   d7    490011107G  Outbound
# 14:46   d7    490011107G  Outbound
# 14:57   d7    490011107G  Outbound
#
# Slot 15:
# 15:08   d7    490011107G  Outbound
# 15:19   d7    490011107G  Outbound
# 15:31   d7    490011107G  Outbound
# 15:43   d7    490011107G  Outbound
# 15:55   d7    490011107G  Outbound

# %% [markdown]
# Combined Code

# %%
import requests
from datetime import datetime
import pytz

# Function to fetch data from the API
def fetch_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to get user input and validate it
def get_user_input(prompt, valid_values=None):
    while True:
        user_input = input(prompt).strip()
        if valid_values and user_input not in valid_values:
            print(f"Invalid input. Please enter one of the following: {', '.join(valid_values)}")
        else:
            return user_input

# Function to select the appropriate schedule name based on the day of the week
def select_schedule_name(schedule_names_dict, day_of_week):
    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        preferred_schedule_names = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        preferred_schedule_names = ['Sunday']
    else:
        preferred_schedule_names = [day_of_week]

    for preferred_name in preferred_schedule_names:
        if preferred_name in schedule_names_dict:
            return preferred_name
    return None

# Function to fetch QSI stop points for a given line ID and direction
def fetch_qsi_stop_points(line_id, direction):
    url = f'https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}'
    data = fetch_data(url)
    if not data:
        return None, None, None

    stop_points = [stop['id'] for stop in data['stopPointSequences'][0]['stopPoint']]
    print(f"\nStop Points for {direction.capitalize()} Direction:")
    for stop in stop_points:
        print(stop)

    line_name = data['lineName']
    originator = data['stopPointSequences'][0]['stopPoint'][0]['name']
    destination = data['stopPointSequences'][0]['stopPoint'][-1]['name']

    print(f"Line Name: {line_name}")
    print(f"Originator: {originator}")
    print(f"Destination: {destination}")

    return stop_points, line_name, originator, destination

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = get_user_input("Enter the line ID: ")

    # Fetch QSI stop points for outbound direction
    stop_points_outbound, line_name_outbound, originator_outbound, destination_outbound = fetch_qsi_stop_points(line_id, 'outbound')

    # Fetch QSI stop points for inbound direction
    stop_points_inbound, line_name_inbound, originator_inbound, destination_inbound = fetch_qsi_stop_points(line_id, 'inbound')

    # Process data for both outbound and inbound directions
    for direction, stop_points in zip(['outbound', 'inbound'], [stop_points_outbound, stop_points_inbound]):
        if not stop_points:
            continue

        print(f"\nProcessing {direction.capitalize()} Direction Timetable")

        for stop_point_id in stop_points:
            # Fetching data
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)
            if not data:
                continue

            # Extracting schedule names
            schedule_names_dict = extract_schedule_names(data)

            # Fetch day of the week
            day_of_week = get_day_of_week()
            print(f"\nToday is {day_of_week}.")

            # Print extracted schedule names
            print("\nExtracted Schedule Names:")
            for i, schedule_name in enumerate(schedule_names_dict.keys(), start=1):
                print(f"{i}. {schedule_name}")

            # Select the appropriate schedule name based on the current day of the week
            selected_schedule_name = select_schedule_name(schedule_names_dict, day_of_week)

            if selected_schedule_name:
                print(f"\nSelected schedule name: {selected_schedule_name}")

                # Categorizing the timetable into hourly slots
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Get the current time in BST
                bst = pytz.timezone('Europe/London')
                now = datetime.now(bst)
                current_hour = now.hour
                current_minute = now.minute

                # Calculate the number of buses scheduled for the current hour
                total_buses_this_hour = len(slots[current_hour])
                print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                # Print the timetable slots corresponding to the current hour, the previous hour, and the next h
Inbound
#
# Today is Monday.
#
# Extracted Schedule Names:
# 1. Monday to Friday
# 2. Saturday
# 3. Sunday
#
# Selected schedule name: Monday to Friday
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 1
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
#
# Slot 14:
# 14:06   d7    490003459R  Inbound
# 14:18   d7    490003459R  Inbound
# 14:30   d7    490003459R  Inbound
# 14:42   d7    490003459R  Inbound
# 14:54   d7    490003459R  Inbound
#
# Slot 15:
# 15:06   d7    490003459R  Inbound
# 15:18   d7    490003459R  Inbound
# 15:30   d7    490003459R  Inbound
# 15:41   d7    490003459R  Inbound
# 15:53   d7    490003459R  Inbound
#
# Slot 16:
# 16:05   d7    490003459R  Inbound
# 16:17   d7    490003459R  Inbound
# 16:29   d7    490003459R  Inbound
# 16:41   d7    490003459R  Inbound
# 16:53   d7    490003459R  Inbound
#
# Today is Monday.
#
# Extracted Schedule Names:
# 1. Monday to Friday
# 2. Saturday
# 3. Sunday
#
# Selected schedule name: Monday to Friday
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 1
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
#
# Slot 14:
# 14:08   d7    490011111W1  Inbound
# 14:20   d7    490011111W1  Inbound
# 14:32   d7    490011111W1  Inbound
# 14:44   d7    490011111W1  Inbound
# 14:56   d7    490011111W1  Inbound
#
# Slot 15:
# 15:07   d7    490011111W1  Inbound
# 15:19   d7    490011111W1  Inbound
# 15:31   d7    490011111W1  Inbound
# 15:43   d7    490011111W1  Inbound
# 15:55   d7    490011111W1  Inbound
#
# Slot 16:
# 16:07   d7    490011111W1  Inbound
# 16:19   d7    490011111W1  Inbound
# 16:31   d7    490011111W1  Inbound
# 16:43   d7    490011111W1  Inbound
# 16:55   d7    490011111W1  Inbound
#
# Today is Monday.
#
# Extracted Schedule Names:
# 1. Monday to Friday
# 2. Saturday
# 3. Sunday
#
# Selected schedule name: Monday to Friday
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 1
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
#
# Slot 14:
# 14:08   d7    490011107Z  Inbound
# 14:20   d7    490011107Z  Inbound
# 14:32   d7    490011107Z  Inbound
# 14:44   d7    490011107Z  Inbound
# 14:56   d7    490011107Z  Inbound
#
# Slot 15:
# 15:07   d7    490011107Z  Inbound
# 15:19   d7    490011107Z  Inbound
# 15:31   d7    490011107Z  Inbound
# 15:43   d7    490011107Z  Inbound
# 15:55   d7    490011107Z  Inbound
#
# Slot 16:
# 16:07   d7    490011107Z  Inbound
# 16:19   d7    490011107Z  Inbound
# 16:31   d7    490011107Z  Inbound
# 16:43   d7    490011107Z  Inbound
# 16:55   d7    490011107Z  Inbound

# %%
import requests
from datetime import datetime
import pytz

# Function to fetch data from the API
def fetch_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to get user input and validate it
def get_user_input(prompt):
    return input(prompt).strip()

# Function to select the appropriate schedule name based on the day of the week
def select_schedule_name(schedule_names_dict, day_of_week):
    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        preferred_schedule_names = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        preferred_schedule_names = ['Sunday']
    else:
        preferred_schedule_names = [day_of_week]

    for preferred_name in preferred_schedule_names:
        if preferred_name in schedule_names_dict:
            return preferred_name
    return None

# Function to fetch QSI stop points for a given line ID and direction
def fetch_qsi_stop_points(line_id, direction):
    url = f'https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}'
    data = fetch_data(url)
    if not data:
        return None

    stop_points = [stop['id'] for stop in data['stopPointSequences'][0]['stopPoint']]
    return stop_points

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = get_user_input("Enter the line ID: ")

    # Fetch QSI stop points for outbound direction
    stop_points_outbound = fetch_qsi_stop_points(line_id, 'outbound')

    # Fetch QSI stop points for inbound direction
    stop_points_inbound = fetch_qsi_stop_points(line_id, 'inbound')

    # Fetch day of the week
    day_of_week = get_day_of_week()
    print(f"\nToday is {day_of_week}.")

    all_schedule_names_dict = {}
    stop_point_directions = {'outbound': stop_points_outbound, 'inbound': stop_points_inbound}

    # Process data for both outbound and inbound directions
    for direction, stop_points in stop_point_directions.items():
        if not stop_points:
            continue

        for stop_point_id in stop_points:
            # Fetching data
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)
            if not data:
                continue

            # Extracting schedule names
            schedule_names_dict = extract_schedule_names(data)
            all_schedule_names_dict.update(schedule_names_dict)

    # Print extracted schedule names
    print("\nExtracted Schedule Names:")
    for i, schedule_name in enumerate(all_schedule_names_dict.keys(), start=1):
        print(f"{i}. {schedule_name}")

    # Select the appropriate schedule name based on the current day of the week
    selected_schedule_name = select_schedule_name(all_schedule_names_dict, day_of_week)

    if selected_schedule_name:
        print(f"\nSelected schedule name: {selected_schedule_name}")

        # Get the current time in BST
        bst = pytz.timezone('Europe/London')
        now = datetime.now(bst)
        current_hour = now.hour
        current_minute = now.minute

        # Process data for both outbound and inbound directions for the selected schedule name
        for direction, stop_points in stop_point_directions.items():
            if not stop_points:
                continue

            print(f"\nProcessing {direction.capitalize()} Direction Timetable")

            for stop_point_id in stop_points:
                # Fetching data
                url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
                data = fetch_data(url)
                if not data:
                    continue

                # Extracting schedule names
                schedule_names_dict = extract_schedule_names(data)

                if selected_schedule_name in schedule_names_dict:
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable for the current hour
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for journey in slots[current_hour]:
                        journey_hour = str(journey['hour']).zfill(2)
                        journey_minute = str(journey['minute']).zfill(2)
                        time = f"{journey_hour}:{journey_minute}"
                        print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

    else:
        print("No matching schedule name found for today.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
#
# Today is Monday.
#
# Extracted Schedule Names:
# 1. Monday to Friday
# 2. Saturday
# 3. Sunday
#
# Selected schedule name: Monday to Friday
#
# Processing Outbound Direction Timetable
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:08   d7    490011107G  Outbound
# 15:19   d7    490011107G  Outbound
# 15:31   d7    490011107G  Outbound
# 15:43   d7    490011107G  Outbound
# 15:55   d7    490011107G  Outbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:09   d7    490011111T  Outbound
# 15:20   d7    490011111T  Outbound
# 15:32   d7    490011111T  Outbound
# 15:44   d7    490011111T  Outbound
# 15:56   d7    490011111T  Outbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:10   d7    490003459Q  Outbound
# 15:22   d7    490003459Q  Outbound
# 15:34   d7    490003459Q  Outbound
# 15:46   d7    490003459Q  Outbound
# 15:58   d7    490003459Q  Outbound
#
# Number of buses scheduled for this hour: 6
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:01   d7    490005461S  Outbound
# 15:12   d7    490005461S  Outbound
# 15:23   d7    490005461S  Outbound
# 15:35   d7    490005461S  Outbound
# 15:47   d7    490005461S  Outbound
# 15:59   d7    490005461S  Outbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15
Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:09   d7    490002048X  Inbound
# 15:21   d7    490002048X  Inbound
# 15:32   d7    490002048X  Inbound
# 15:44   d7    490002048X  Inbound
# 15:56   d7    490002048X  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:09   d7    490007161E  Inbound
# 15:21   d7    490007161E  Inbound
# 15:32   d7    490007161E  Inbound
# 15:44   d7    490007161E  Inbound
# 15:56   d7    490007161E  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:10   d7    490007241N  Inbound
# 15:22   d7    490007241N  Inbound
# 15:33   d7    490007241N  Inbound
# 15:45   d7    490007241N  Inbound
# 15:57   d7    490007241N  Inbound
#
# Number of buses scheduled for this hour: 6
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:00   d7    490010999N  Inbound
# 15:11   d7    490010999N  Inbound
# 15:23   d7    490010999N  Inbound
# 15:34   d7    490010999N  Inbound
# 15:46   d7    490010999N  Inbound
# 15:58   d7    490010999N  Inbound
#
# Number of buses scheduled for this hour: 6
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:01   d7    490005878N  Inbound
# 15:12   d7    490005878N  Inbound
# 15:24   d7    490005878N  Inbound
# 15:35   d7    490005878N  Inbound
# 15:47   d7    490005878N  Inbound
# 15:59   d7    490005878N  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:02   d7    490012736N  Inbound
# 15:14   d7    490012736N  Inbound
# 15:26   d7    490012736N  Inbound
# 15:37   d7    490012736N  Inbound
# 15:49   d7    490012736N  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:03   d7    490013513N  Inbound
# 15:15   d7    490013513N  Inbound
# 15:27   d7    490013513N  Inbound
# 15:38   d7    490013513N  Inbound
# 15:50   d7    490013513N  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:04   d7    490013270N  Inbound
# 15:16   d7    490013270N  Inbound
# 15:28   d7    490013270N  Inbound
# 15:39   d7    490013270N  Inbound
# 15:51   d7    490013270N  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:05   d7    490004321N  Inbound
# 15:17   d7    490004321N  Inbound
# 15:29   d7    490004321N  Inbound
# 15:40   d7    490004321N  Inbound
# 15:52   d7    490004321N  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:06   d7    490003459R  Inbound
# 15:18   d7    490003459R  Inbound
# 15:30   d7    490003459R  Inbound
# 15:41   d7    490003459R  Inbound
# 15:53   d7    490003459R  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:07   d7    490011111W1  Inbound
# 15:19   d7    490011111W1  Inbound
# 15:31   d7    490011111W1  Inbound
# 15:43   d7    490011111W1  Inbound
# 15:55   d7    490011111W1  Inbound
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 3
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 15:07   d7    490011107Z  Inbound
# 15:19   d7    490011107Z  Inbound
# 15:31   d7    490011107Z  Inbound
# 15:43   d7    490011107Z  Inbound
# 15:55   d7    490011107Z  Inbound

# %%
import requests
from datetime import datetime
import pytz
import pandas as pd

# Function to fetch data from the API
def fetch_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to get user input and validate it
def get_user_input(prompt):
    return input(prompt).strip()

# Function to select the appropriate schedule name based on the day of the week
def select_schedule_name(schedule_names_dict, day_of_week):
    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        preferred_schedule_names = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        preferred_schedule_names = ['Sunday']
    else:
        preferred_schedule_names = [day_of_week]

    for preferred_name in preferred_schedule_names:
        if preferred_name in schedule_names_dict:
            return preferred_name
    return None

# Function to fetch QSI stop points for a given line ID and direction
def fetch_qsi_stop_points(line_id, direction):
    url = f'https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}'
    data = fetch_data(url)
    if not data:
        return None

    stop_points = [{'Route_Dir_QSI_No': f"{line_id}_{direction[0].upper()}{i+1}", 'STOP_Name': stop['name'], 'ID': stop['id']}
                   for i, stop in enumerate(data['stopPointSequences'][0]['stopPoint'])]
    return stop_points

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = get_user_input("Enter the line ID: ")

    # Fetch QSI stop points for outbound direction
    stop_points_outbound = fetch_qsi_stop_points(line_id, 'outbound')
    if stop_points_outbound:
        df_outbound = pd.DataFrame(stop_points_outbound)
        print("\nQSI stop points for direction D7_A (outbound)")
        print(df_outbound)
    else:
        print("No QSI stop points found for outbound direction.")

    # Fetch QSI stop points for inbound direction
    stop_points_inbound = fetch_qsi_stop_points(line_id, 'inbound')
    if stop_points_inbound:
        df_inbound = pd.DataFrame(stop_points_inbound)
        print("\nQSI stop points for direction D7_B (inbound)")
        print(df_inbound)
    else:
        print("No QSI stop points found for inbound direction.")

    # Fetch day of the week
    day_of_week = get_day_of_week()
    print(f"\nToday is {day_of_week}.")

    all_schedule_names_dict = {}
    stop_point_directions = {'outbound': stop_points_outbound, 'inbound': stop_points_inbound}

    # Process data for both outbound and inbound directions
    for direction, stop_points in stop_point_directions.items():
        if not stop_points:
            continue

        for stop_point in stop_points:
            stop_point_id = stop_point['ID']
            # Fetching data
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)
            if not data:
                continue

            # Extracting schedule names
            schedule_names_dict = extract_schedule_names(data)
            all_schedule_names_dict.update(schedule_names_dict)

    # Print extracted schedule names
    print("\nExtracted Schedule Names:")
    for i, schedule_name in enumerate(all_schedule_names_dict.keys(), start=1):
        print(f"{i}. {schedule_name}")

    # Select the appropriate schedule name based on the current day of the week
    selected_schedule_name = select_schedule_name(all_schedule_names_dict, day_of_week)

    if selected_schedule_name:
        print(f"\nSelected schedule name: {selected_schedule_name}")

        # Get the current time in BST
        bst = pytz.timezone('Europe/London')
        now = datetime.now(bst)
        current_hour = now.hour
        current_minute = now.minute

        # Process data for both outbound and inbound directions for the selected schedule name
        for direction, stop_points in stop_point_directions.items():
            if not stop_points:
                continue

            print(f"\nProcessing {direction.capitalize()} Direction Timetable")

            for stop_point in stop_points:
                stop_point_id = stop_point['ID']
                # Fetching data
                url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
                data = fetch_data(url)
                if not data:
                    continue

                # Extracting schedule names
                schedule_names_dict = extract_schedule_names(data)

                if selected_schedule_name in schedule_names_dict:
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable for the current hour
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for journey in slots[current_hour]:
                        journey_hour = str(journey['hour']).zfill(2)
                        journey_minute = str(journey['minute']).zfill(2)
                        time = f"{journey_hour}:{journey_minute}"
                        print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

    else:
        print("No matching schedule name found for today.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter
# 22           d7_I23                  Island Gardens Station   490002048X
# 23           d7_I24                   George Green's School   490007161E
# 24           d7_I25              Christ Church Isle of Dogs   490007241N
# 25           d7_I26                             Pier Street   490010999N
# 26           d7_I27                      Cubitt Town School   490005878N
# 27           d7_I28                          St John's Park   490012736N
# 28           d7_I29                          Stewart Street   490013513N
# 29           d7_I30                         The Blue Bridge   490013270N
# 30           d7_I31                             Coldharbour   490004321N
# 31           d7_I32                               Aspen Way   490003459R
# 32           d7_I33          Poplar High Street / Blackwall  490011111W1
# 33           d7_I34              Poplar / All Saints Church   490011107Z
#
# Today is Monday.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c3f163078aa9> in <cell line: 193>()
#     192 # Run the main function
#     193 if __name__ == "__main__":
# --> 194     main()
#
# <ipython-input-6-c3f163078aa9> in main()
#     123             # Fetching data
#     124             url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
# --> 125             data = fetch_data(url)
#     126             if not data:
#     127                 continue
#
# <ipython-input-6-c3f163078aa9> in fetch_data(url)
#       7 def fetch_data(url):
#       8     try:
# ----> 9         response = requests.get(url)
#      10         response.raise_for_status()
#      11         return response.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from datetime import datetime
import pytz
import pandas as pd

# Function to fetch data from the API
def fetch_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to get user input and validate it
def get_user_input(prompt):
    return input(prompt).strip()

# Function to select the appropriate schedule name based on the day of the week
def select_schedule_name(schedule_names_dict, day_of_week):
    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        preferred_schedule_names = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        preferred_schedule_names = ['Sunday']
    else:
        preferred_schedule_names = [day_of_week]

    for preferred_name in preferred_schedule_names:
        if preferred_name in schedule_names_dict:
            return preferred_name
    return None

# Function to fetch QSI stop points for a given line ID and direction
def fetch_qsi_stop_points(line_id, direction):
    url = f'https://api.tfl.gov.uk/Line/{line_id}/Route/Sequence/{direction}'
    data = fetch_data(url)
    if not data:
        return None

    stop_points = [{'Route_Dir_QSI_No': f"{line_id}_{direction[0].upper()}{i+1}", 'STOP_Name': stop['name'], 'ID': stop['id']}
                   for i, stop in enumerate(data['stopPointSequences'][0]['stopPoint'])]
    return stop_points

# Function to print timetable for a given direction and stop points
def print_timetable(line_id, stop_points, direction, selected_schedule_name, current_hour, current_minute):
    print(f"\nProcessing {direction.capitalize()} Direction Timetable")

    for stop_point in stop_points:
        stop_point_id = stop_point['ID']
        # Fetching data
        url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)
        if not data:
            continue

        # Extracting schedule names
        schedule_names_dict = extract_schedule_names(data)

        if selected_schedule_name in schedule_names_dict:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Calculate the number of buses scheduled for the current hour
            total_buses_this_hour = len(slots[current_hour])
            print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time
            bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
            print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

            # Print the timetable for the current hour
            print("\nTimetable:")
            print("Time   Line ID  Stop Point ID  Direction")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = get_user_input("Please enter the line ID: ")

    # Fetch QSI stop points for outbound direction
    stop_points_outbound = fetch_qsi_stop_points(line_id, 'outbound')
    if stop_points_outbound:
        df_outbound = pd.DataFrame(stop_points_outbound)
        print("\nQSI stop points for direction D7_A (outbound)")
        print(df_outbound)
    else:
        print("No QSI stop points found for outbound direction.")

    # Fetch QSI stop points for inbound direction
    stop_points_inbound = fetch_qsi_stop_points(line_id, 'inbound')
    if stop_points_inbound:
        df_inbound = pd.DataFrame(stop_points_inbound)
        print("\nQSI stop points for direction D7_B (inbound)")
        print(df_inbound)
    else:
        print("No QSI stop points found for inbound direction.")

    # Fetch day of the week
    day_of_week = get_day_of_week()
    print(f"\nToday is {day_of_week}.")

    # Process data for both outbound and inbound directions
    all_schedule_names_dict = {}
    stop_point_directions = {'outbound': stop_points_outbound, 'inbound': stop_points_inbound}

    for direction, stop_points in stop_point_directions.items():
        if not stop_points:
            continue

        for stop_point in stop_points:
            stop_point_id = stop_point['ID']
            # Fetching data
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)
            if not data:
                continue

            # Extracting schedule names
            schedule_names_dict = extract_schedule_names(data)
            all_schedule_names_dict.update(schedule_names_dict)

            # Select schedule name based on the day of the week
            selected_schedule_name = select_schedule_name(schedule_names_dict, day_of_week)
            if selected_schedule_name:
                # Print timetable for the current hour
                bst = pytz.timezone('Europe/London')
                now = datetime.now(bst)
                current_hour = now.hour
                current_minute = now.minute
                print_timetable(line_id, [stop_point], direction, selected_schedule_name, current_hour, current_minute)

    # Print extracted schedule names only once
    print("\nExtracted Schedule Names:")
    for i, schedule_name in enumerate(all_schedule_names_dict.keys(), start=1):
        print(f"{i}. {schedule_name}")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Please enter the line ID: d7
#
# QSI stop points for direction D7_A (outbound)
#    Route_Dir_QSI_No                               STOP_Name          ID
# 0             d7_O1              Poplar / All Saints Church  490011107G
# 1             d7_O2          Poplar High Street / Blackwall  490011111T
# 2             d7_O3                               Aspen Way  490003459Q
# 3             d7_O4                             Coldharbour  490005461S
# 4             d7_O5                          Stewart Street  490013513S
# 5             d7_O6                          St John's Park  490012736S
# 6             d7_O7                      Cubitt Town School  490005878S
# 7             d7_O8                             Pier Street  490010999S
# 8             d7_O9              Christ Church Isle of Dogs  490007241S
# 9            d7_O10                  Island Gardens Station  490002048Z
# 10           d7_O11                         East Ferry Road  490006345W
# 11           d7_O12                        Langbourne Place  490013550W
# 12           d7_O13  Harbinger School / Masthouse Ter. Pier  490007774N
# 13           d7_O14                      St Edmund's School  490012438N
# 14           d7_O15                            Crews Street  490008757N
# 15           d7_O16             Arnhem Wharf Primary School  490006092N
# 16           d7_O17              Sir John Mcdougall Gardens  490012181N
# 17           d7_O18    Barkantine Clinic / Hutchings Street  490003602N
# 18           d7_O19                             Byng Street  490009545N
# 19           d7_O20                 Marsh Wall / Heron Quay  490005323N
# 20           d7_O21                    Canary Wharf Station  490016668K
# 21           d7_O22  Canada Square South / Canary Wharf Stn  490000038J
# 22           d7_O23                    Canary Wharf Station  490000038G
# 23           d7_O24                       West India Avenue  490014483E
# 24           d7_O25    Westferry Circus / Canary Wharf Pier  490014457B
# 25           d7_O26                       Westferry Station  490014459B
# 26           d7_O27                           Salter Street  490011878N
# 27           d7_O28                    East India Dock Road  490004584N
# 28           d7_O29                           Pixley Street  490011031N
# 29           d7_O30                           St Paul's Way  490012881N
# 30           d7_O31                           Ackroyd Drive  490013846N
# 31           d7_O32                             Eric Street  490006614N
# 32           d7_O33                        Mile End Station  490000146B
#
# QSI stop points for direction D7_B (inbound)
#    Route_Dir_QSI_No                               STOP_Name           ID
# 0             d7_I1             Mile End Station / Bow Road   490015151H
# 1             d7_I2                        Mile End Station   490000146A
# 2             d7_I3                             Eric Street   490006614S
# 3             d7_I4            Mile End Park Leisure Centre   490003783S
# 4             d7_I5                           St Paul's Way   490012881S
# 5             d7_I6                           Pixley Street   490011031S
# 6             d7_I7                    East India Dock Road   490004584S
# 7             d7_I8                Limehouse Police Station   490009159S
# 8             d7_I9                       Westferry Station   490002083A
# 9            d7_I10                       West India Avenue   490014483C
# 10           d7_I11                    Canary Wharf Station   490000038F
# 11           d7_I12                    Canary Wharf Station   490016668L
# 12           d7_I13                 Marsh Wall / Heron Quay   490005323S
# 13           d7_I14                             Cuba Street   490009545S
# 14           d7_I15    Barkantine Clinic / Hutchings Street   490003602S
# 15           d7_I16              Sir John Mcdougall Gardens   490012181S
# 16           d7_I17             Arnhem Wharf Primary School   490006092S
# 17           d7_I18        Crews Street / the Space Theatre   490008757S
# 18           d7_I19                      St Edmund's School   490012438S
# 19           d7_I20  Harbinger School / Masthouse Ter. Pier   490007774S
# 20           d7_I21                        Maconochies Road   490013550E
# 21           d7_I22                         East Ferry Road   490006345E
# 22           d7_I23                  Island Gardens Station   490002048X
# 23           d7_I24                   George Green's School   490007161E
# 24           d7_I25              Christ Church Isle of Dogs   490007241N
# 25           d7_I26                             Pier Street   490010999N
# 26           d7_I27                      Cubitt Town School   490005878N
# 27           d7_I28                          St John's Park   490012736N
# 28           d7_I29                          Stewart Street   490013513N
# 29           d7_I30                         The Blue Bridge   490013270N
# 30           d7_I31                             Coldharbour   490004321N
# 31           d7_I32                               Aspen Way   490003459R
# 32           d7_I33          Poplar High Street / Blackwall  490011111W1
# 33           d7_I34              Poplar / All Saints Church   490011107Z
#
# Today is Monday.
#
# Processing Outbound Direction Timetable
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 16:07   d7    490011107G  Outbound
# 16:19   d7    490011107G  Outbound
# 16:31   d7    490011107G  Outbound
# 16:43   d7    490011107G  Outbound
# 16:55   d7    490011107G  Outbound
#
# Processing Outbound Direction Timetable
#
# Number of buses scheduled for this hour: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Timetable:
# Time   Line ID  Stop Point ID  Direction
# 16:08   d7    490011111T  Outbound
# 16:20   d7    490011111T  Outbound
# 16:32   d7    490011111T  Outbound
# 16:44   d7    490011111T  Outbound
# 16:56   d7    490011111T  Outbound
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d4a00ea9ae14> in <cell line: 185>()
#     184 # Run the main function
#     185 if __name__ == "__main__":
# --> 186     main()
#
# <ipython-input-7-d4a00ea9ae14> in main()
#     159             # Fetching data
#     160             url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
# --> 161             data = fetch_data(url)
#     162             if not data:
#     163                 continue
#
# <ipython-input-7-d4a00ea9ae14> in fetch_data(url)
#       7 def fetch_data(url):
#       8     try:
# ----> 9         response = requests.get(url)
#      10         response.raise_for_status()
#      11         return response.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from datetime import datetime
import pytz
import pandas as pd

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = input("Enter the line ID: ")
    stop_point_id_A = input("Enter the stop point ID for direction A: ")
    stop_point_id_B = input("Enter the stop point ID for direction B: ")

    # Fetching data for direction A
    url_A = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id_A}?direction=outbound'
    data_A = fetch_data(url_A)

    # Fetching data for direction B
    url_B = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id_B}?direction=inbound'
    data_B = fetch_data(url_B)

    # Extracting schedule names for direction A
    schedule_names_dict_A = extract_schedule_names(data_A)

    # Extracting schedule names for direction B
    schedule_names_dict_B = extract_schedule_names(data_B)

    # Fetch day of the week
    day_of_week = get_day_of_week()
    print(f"\nToday is {day_of_week}.")

    # Determine the matching schedule name based on the current day of the week for direction A
    selected_schedule_name_A = None
    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        preferred_schedule_names_A = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        preferred_schedule_names_A = ['Sunday']
    else:
        preferred_schedule_names_A = [day_of_week]

    for preferred_name_A in preferred_schedule_names_A:
        if preferred_name_A in schedule_names_dict_A:
            selected_schedule_name_A = preferred_name_A
            break

    if selected_schedule_name_A:
        print(f"\nSelected schedule name for direction A: {selected_schedule_name_A}")

        # Categorizing the timetable into hourly slots for direction A
        timetable_A = schedule_names_dict_A[selected_schedule_name_A]
        slots_A = categorize_into_slots(timetable_A)

        # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction A
        print("\nTimetable for direction A:")
        print("Time   Line ID  Stop Point ID  Direction")
        current_hour = datetime.now(pytz.timezone('Europe/London')).hour
        hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
        for hour in hours_to_print:
            if 0 <= hour < 24:
                print(f"\nSlot {hour}:")
                for journey in slots_A[hour]:
                    journey_hour = str(journey['hour']).zfill(2)
                    journey_minute = str(journey['minute']).zfill(2)
                    time = f"{journey_hour}:{journey_minute}"
                    print(f"{time}   {line_id}    {stop_point_id_A}  Outbound")

    else:
        print("No matching schedule name found for direction A.")

    # Determine the matching schedule name based on the current day of the week for direction B
    selected_schedule_name_B = None
    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        preferred_schedule_names_B = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        preferred_schedule_names_B = ['Sunday']
    else:
        preferred_schedule_names_B = [day_of_week]

    for preferred_name_B in preferred_schedule_names_B:
        if preferred_name_B in schedule_names_dict_B:
            selected_schedule_name_B = preferred_name_B
            break

    if selected_schedule_name_B:
        print(f"\nSelected schedule name for direction B: {selected_schedule_name_B}")

        # Categorizing the timetable into hourly slots for direction B
        timetable_B = schedule_names_dict_B[selected_schedule_name_B]
        slots_B = categorize_into_slots(timetable_B)

        # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction B
        print("\nTimetable for direction B:")
        print("Time   Line ID  Stop Point ID  Direction")
        current_hour = datetime.now(pytz.timezone('Europe/London')).hour
        hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
        for hour in hours_to_print:
            if 0 <= hour < 24:
                print(f"\nSlot {hour}:")
                for journey in slots_B[hour]:
                    journey_hour = str(journey['hour']).zfill(2)
                    journey_minute = str(journey['minute']).zfill(2)
                    time = f"{journey_hour}:{journey_minute}"
                    print(f"{time}   {line_id}    {stop_point_id_B}  Inbound")

    else:
        print("No matching schedule name found for direction B.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-46b7a84d7162> in <cell line: 158>()
#     157 # Run the main function
#     158 if __name__ == "__main__":
# --> 159     main()
#
# <ipython-input-8-46b7a84d7162> in main()
#      50 def main():
#      51     line_id = input("Enter the line ID: ")
# ---> 52     stop_point_id_A = input("Enter the stop point ID for direction A: ")
#      53     stop_point_id_B = input("Enter the stop point ID for direction B: ")
#      54
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the QSI points, stop names, and IDs for direction A
    print(f"\n\n\033[1m\033[4mQSI points, stop names, and IDs for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the QSI points, stop names, and IDs for direction B
    print(f"\n\n\033[1m\033[4mQSI points, stop names, and IDs for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Extract stop IDs for direction A and B
    stop_ids_A = filtered_df_A.index.tolist()
    stop_ids_B = filtered_df_B.index.tolist()

    # Function to fetch and print timetable based on stop point ID and direction
    def fetch_and_print_timetable(line_id, stop_point_ids, direction):
        for stop_point_id in stop_point_ids:
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()

                # Extract schedule names
                schedule_names_dict = extract_schedule_names(data)

                # Fetch day of the week
                day_of_week = get_day_of_week()
                print(f"\nToday is {day_of_week}.")

                # Determine the matching schedule name based on the current day of the week
                selected_schedule_name = None

                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    # Check for the preferred schedule names for Monday to Thursday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    # Check for the preferred schedule names for Friday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    # Check for the preferred schedule names for Saturday
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    # Check for the preferred schedule names for Sunday
                    preferred_schedule_names = ['Sunday']
                else:
                    # For other days of the week, select based on exact match
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

                if selected_schedule_name:
                    print(f"\nSelected schedule name for direction {direction}: {selected_schedule_name}")

                    # Categorizing the timetable into hourly slots
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Get the current time in BST
                    bst = pytz.timezone('Europe/London')
                    now = datetime.now(bst)
                    current_hour = now.hour
                    current_minute = now.minute

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
                    hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for hour in hours_to_print:
                        if 0 <= hour < 24:
                            print(f"\nSlot {hour}:")
                            for journey in slots[hour]:
                                journey_hour = str(journey['hour']).zfill(2)
                                journey_minute = str(journey['minute']).zfill(2)
                                time = f"{journey_hour}:{journey_minute}"
                                print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

                else:
                    print(f"No matching schedule name found for {day_of_week} in direction {direction}.")

            else:
                print(f"Failed to fetch timetable data for stop point ID {stop_point_id} and direction {direction}. Status code: {response.status_code}")

    # Fetch and print timetable for direction A
    fetch_and_print_timetable(lineID, stop_ids_A, 'outbound')

    # Fetch and print timetable for direction B
    fetch_and_print_timetable(lineID, stop_ids_B, 'inbound')

# Example usage
if __name__ == "__main__":
    lineID = input("Please enter the lineID: ")
    find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# QSI points, stop names, and IDs for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# QSI points, stop names, and IDs for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
# Failed to fetch timetable data for stop point ID 1312 and direction outbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1313 and direction outbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1314 and direction outbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1315 and direction outbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1316 and direction outbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1317 and direction inbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1318 and direction inbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1319 and direction inbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1320 and direction inbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1321 and direction inbound. Status code: 400
# Failed to fetch timetable data for stop point ID 1322 and direction inbound. Status code: 400

# %%
import requests
from datetime import datetime
import pytz
import pandas as pd

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to load stop points from a file (you can modify this to fetch from a database or API)
def load_stop_points(file_path):
    df = pd.read_csv(file_path)
    return df

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = input("Enter the line ID: ")

    # Example paths for stop points data files (replace with your actual file paths or data retrieval method)
    file_path_A = 'path_to_file_A.csv'
    file_path_B = 'path_to_file_B.csv'

    # Load stop points for direction A
    df_A = load_stop_points(file_path_A)

    # Loop through each stop ID from QSI stop points direction lineID_A
    for stop_id_A in df_A['ID']:
        # Fetching data for outbound direction
        url_A = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_A}?direction=outbound'
        data_A = fetch_data(url_A)

        # Extracting schedule names for direction A
        schedule_names_dict_A = extract_schedule_names(data_A)

        # Fetch day of the week
        day_of_week_A = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction A
        selected_schedule_name_A = None

        if day_of_week_A.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_A.lower() == 'friday':
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_A.lower() == 'saturday':
            preferred_schedule_names_A = ['Saturday']
        elif day_of_week_A.lower() == 'sunday':
            preferred_schedule_names_A = ['Sunday']
        else:
            preferred_schedule_names_A = [day_of_week_A]

        for preferred_name_A in preferred_schedule_names_A:
            if preferred_name_A in schedule_names_dict_A:
                selected_schedule_name_A = preferred_name_A
                break

        if selected_schedule_name_A:
            print(f"\nSelected schedule name for {stop_id_A} (Direction A): {selected_schedule_name_A}")

            # Categorizing the timetable into hourly slots for direction A
            timetable_A = schedule_names_dict_A[selected_schedule_name_A]
            slots_A = categorize_into_slots(timetable_A)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction A
            total_buses_this_hour_A = len(slots_A[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction A
            bus_count_A = calculate_buses(slots_A[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction A
            hours_to_print_A = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction A:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_A in hours_to_print_A:
                if 0 <= hour_A < 24:
                    print(f"\nSlot {hour_A}:")
                    for journey_A in slots_A[hour_A]:
                        journey_hour_A = str(journey_A['hour']).zfill(2)
                        journey_minute_A = str(journey_A['minute']).zfill(2)
                        time_A = f"{journey_hour_A}:{journey_minute_A}"
                        print(f"{time_A}   {line_id}    {stop_id_A}  Outbound")

        else:
            print(f"No matching schedule name found for {day_of_week_A} for {stop_id_A} (Direction A).")

    # Load stop points for direction B
    df_B = load_stop_points(file_path_B)

    # Loop through each stop ID from QSI stop points direction lineID_B
    for stop_id_B in df_B['ID']:
        # Fetching data for inbound direction
        url_B = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_B}?direction=inbound'
        data_B = fetch_data(url_B)

        # Extracting schedule names for direction B
        schedule_names_dict_B = extract_schedule_names(data_B)

        # Fetch day of the week
        day_of_week_B = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction B
        selected_schedule_name_B = None

        if day_of_week_B.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_B.lower() == 'friday':
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_B.lower() == 'saturday':
            preferred_schedule_names_B = ['Saturday']
        elif day_of_week_B.lower() == 'sunday':
            preferred_schedule_names_B = ['Sunday']
        else:
            preferred_schedule_names_B = [day_of_week_B]

        for preferred_name_B in preferred_schedule_names_B:
            if preferred_name_B in schedule_names_dict_B:
                selected_schedule_name_B = preferred_name_B
                break

        if selected_schedule_name_B:
            print(f"\nSelected schedule name for {stop_id_B} (Direction B): {selected_schedule_name_B}")

            # Categorizing the timetable into hourly slots for direction B
            timetable_B = schedule_names_dict_B[selected_schedule_name_B]
            slots_B = categorize_into_slots(timetable_B)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction B
            total_buses_this_hour_B = len(slots_B[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction B
            bus_count_B = calculate_buses(slots_B[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction B
            hours_to_print_B = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction B:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_B in hours_to_print_B:
                if 0 <= hour_B < 24:
                    print(f"\nSlot {hour_B}:")
                    for journey_B in slots_B[hour_B]:
                        journey_hour_B = str(journey_B['hour']).zfill(2)
                        journey_minute_B = str(journey_B['minute']).zfill(2)
                        time_B = f"{journey_hour_B}:{journey_minute_B}"
                        print(f"{time_B}   {line_id}    {stop_id_B}  Inbound")

        else:
            print(f"No matching schedule name found for {day_of_week_B} for {stop_id_B} (Direction B).")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-6e1ff8b0bf7c> in <cell line: 201>()
#     200 # Run the main function
#     201 if __name__ == "__main__":
# --> 202     main()
#
# <ipython-input-17-6e1ff8b0bf7c> in main()
#      61
#      62     # Load stop points for direction A
# ---> 63     df_A = load_stop_points(file_path_A)
#      64
#      65     # Loop through each stop ID from QSI stop points direction lineID_A
#
# <ipython-input-17-6e1ff8b0bf7c> in load_stop_points(file_path)
#      49 # Function to load stop points from a file (you can modify this to fetch from a database or API)
#      50 def load_stop_points(file_path):
# ---> 51     df = pd.read_csv(file_path)
#      52     return df
#      53
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_file_A.csv'

# %%
import requests
from datetime import datetime
import pytz
import pandas as pd

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to load stop points from Excel file
def load_stop_points(file_path, sheet_name):
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    return df

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = input("Enter the line ID: ")

    # Example path for the Excel file containing QSI points data
    file_path = '/content/QSI points.xlsx'

    # Load stop points for direction A
    df_A = load_stop_points(file_path, sheet_name='Direction A')

    # Loop through each stop ID from QSI stop points direction lineID_A
    for stop_id_A in df_A['ID']:
        # Fetching data for outbound direction
        url_A = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_A}?direction=outbound'
        data_A = fetch_data(url_A)

        # Extracting schedule names for direction A
        schedule_names_dict_A = extract_schedule_names(data_A)

        # Fetch day of the week
        day_of_week_A = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction A
        selected_schedule_name_A = None

        if day_of_week_A.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_A.lower() == 'friday':
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_A.lower() == 'saturday':
            preferred_schedule_names_A = ['Saturday']
        elif day_of_week_A.lower() == 'sunday':
            preferred_schedule_names_A = ['Sunday']
        else:
            preferred_schedule_names_A = [day_of_week_A]

        for preferred_name_A in preferred_schedule_names_A:
            if preferred_name_A in schedule_names_dict_A:
                selected_schedule_name_A = preferred_name_A
                break

        if selected_schedule_name_A:
            print(f"\nSelected schedule name for {stop_id_A} (Direction A): {selected_schedule_name_A}")

            # Categorizing the timetable into hourly slots for direction A
            timetable_A = schedule_names_dict_A[selected_schedule_name_A]
            slots_A = categorize_into_slots(timetable_A)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction A
            total_buses_this_hour_A = len(slots_A[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction A
            bus_count_A = calculate_buses(slots_A[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction A
            hours_to_print_A = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction A:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_A in hours_to_print_A:
                if 0 <= hour_A < 24:
                    print(f"\nSlot {hour_A}:")
                    for journey_A in slots_A[hour_A]:
                        journey_hour_A = str(journey_A['hour']).zfill(2)
                        journey_minute_A = str(journey_A['minute']).zfill(2)
                        time_A = f"{journey_hour_A}:{journey_minute_A}"
                        print(f"{time_A}   {line_id}    {stop_id_A}  Outbound")

        else:
            print(f"No matching schedule name found for {day_of_week_A} for {stop_id_A} (Direction A).")

    # Load stop points for direction B
    df_B = load_stop_points(file_path, sheet_name='Direction B')

    # Loop through each stop ID from QSI stop points direction lineID_B
    for stop_id_B in df_B['ID']:
        # Fetching data for inbound direction
        url_B = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_B}?direction=inbound'
        data_B = fetch_data(url_B)

        # Extracting schedule names for direction B
        schedule_names_dict_B = extract_schedule_names(data_B)

        # Fetch day of the week
        day_of_week_B = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction B
        selected_schedule_name_B = None

        if day_of_week_B.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_B.lower() == 'friday':
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_B.lower() == 'saturday':
            preferred_schedule_names_B = ['Saturday']
        elif day_of_week_B.lower() == 'sunday':
            preferred_schedule_names_B = ['Sunday']
        else:
            preferred_schedule_names_B = [day_of_week_B]

        for preferred_name_B in preferred_schedule_names_B:
            if preferred_name_B in schedule_names_dict_B:
                selected_schedule_name_B = preferred_name_B
                break

        if selected_schedule_name_B:
            print(f"\nSelected schedule name for {stop_id_B} (Direction B): {selected_schedule_name_B}")

            # Categorizing the timetable into hourly slots for direction B
            timetable_B = schedule_names_dict_B[selected_schedule_name_B]
            slots_B = categorize_into_slots(timetable_B)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction B
            total_buses_this_hour_B = len(slots_B[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction B
            bus_count_B = calculate_buses(slots_B[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction B
            hours_to_print_B = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction B:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_B in hours_to_print_B:
                if 0 <= hour_B < 24:
                    print(f"\nSlot {hour_B}:")
                    for journey_B in slots_B[hour_B]:
                        journey_hour_B = str(journey_B['hour']).zfill(2)
                        journey_minute_B = str(journey_B['minute']).zfill(2)
                        time_B = f"{journey_hour_B}:{journey_minute_B}"
                        print(f"{time_B}   {line_id}    {stop_id_B}  Inbound")

        else:
            print(f"No matching schedule name found for {day_of_week_B} for {stop_id_B} (Direction B).")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4e344ae98c56> in <cell line: 200>()
#     199 # Run the main function
#     200 if __name__ == "__main__":
# --> 201     main()
#
# <ipython-input-18-4e344ae98c56> in main()
#      60
#      61     # Load stop points for direction A
# ---> 62     df_A = load_stop_points(file_path, sheet_name='Direction A')
#      63
#      64     # Loop through each stop ID from QSI stop points direction lineID_A
#
# <ipython-input-18-4e344ae98c56> in load_stop_points(file_path, sheet_name)
#      49 # Function to load stop points from Excel file
#      50 def load_stop_points(file_path, sheet_name):
# ---> 51     df = pd.read_excel(file_path, sheet_name=sheet_name)
#      52     return df
#      53
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     484
#     485     try:
# --> 486         data = io.parse(
#     487             sheet_name=sheet_name,
#     488             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1549             DataFrame from the passed in Excel file.
#    1550         """
# -> 1551         return self._reader.parse(
#    1552             sheet_name=sheet_name,
#    1553             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     744
#     745             if isinstance(asheetname, str):
# --> 746                 sheet = self.get_sheet_by_name(asheetname)
#     747             else:  # assume an integer if not a string
#     748                 sheet = self.get_sheet_by_index(asheetname)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in get_sheet_by_name(self, name)
#     567
#     568     def get_sheet_by_name(self, name: str):
# --> 569         self.raise_if_bad_sheet_by_name(name)
#     570         return self.book[name]
#     571
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in raise_if_bad_sheet_by_name(self, name)
#     595     def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     596         if name not in self.sheet_names:
# --> 597             raise ValueError(f"Worksheet named '{name}' not found")
#     598
#     599     def _check_skiprows_func(
#
# ValueError: Worksheet named 'Direction A' not found

# %%
import pandas as pd
import requests
from datetime import datetime
import pytz

# Function to fetch data from the API
def fetch_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad response status
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from API: {e}")
        return None

# Function to load stop points from Excel file
def load_stop_points(file_path):
    try:
        df = pd.read_excel(file_path)
        return df
    except Exception as e:
        print(f"Error loading Excel file: {e}")
        return None

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Main function to get user input and print the schedule names and timetable
def main():
    line_id = input("Enter the line ID: ")

    # Example path for the Excel file containing QSI points data
    file_path = '/content/QSI points.xlsx'

    # Load stop points from Excel file
    df = load_stop_points(file_path)
    if df is None:
        return

    # Loop through each stop ID from QSI stop points for direction lineID_A (outbound)
    for stop_id_A in df['ID']:
        # Fetching data for outbound direction
        url_A = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_A}?direction=outbound'
        data_A = fetch_data(url_A)

        if data_A is None:
            print(f"Failed to fetch data for {stop_id_A} (Direction A).")
            continue

        # Extracting schedule names for direction A
        schedule_names_dict_A = extract_schedule_names(data_A)

        # Fetch day of the week
        day_of_week_A = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction A
        selected_schedule_name_A = None

        if day_of_week_A.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_A.lower() == 'friday':
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_A.lower() == 'saturday':
            preferred_schedule_names_A = ['Saturday']
        elif day_of_week_A.lower() == 'sunday':
            preferred_schedule_names_A = ['Sunday']
        else:
            preferred_schedule_names_A = [day_of_week_A]

        for preferred_name_A in preferred_schedule_names_A:
            if preferred_name_A in schedule_names_dict_A:
                selected_schedule_name_A = preferred_name_A
                break

        if selected_schedule_name_A:
            print(f"\nSelected schedule name for {stop_id_A} (Direction A): {selected_schedule_name_A}")

            # Categorizing the timetable into hourly slots for direction A
            timetable_A = schedule_names_dict_A[selected_schedule_name_A]
            slots_A = categorize_into_slots(timetable_A)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction A
            total_buses_this_hour_A = len(slots_A[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction A
            bus_count_A = calculate_buses(slots_A[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction A
            hours_to_print_A = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction A:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_A in hours_to_print_A:
                if 0 <= hour_A < 24:
                    print(f"\nSlot {hour_A}:")
                    for journey_A in slots_A[hour_A]:
                        journey_hour_A = str(journey_A['hour']).zfill(2)
                        journey_minute_A = str(journey_A['minute']).zfill(2)
                        time_A = f"{journey_hour_A}:{journey_minute_A}"
                        print(f"{time_A}   {line_id}    {stop_id_A}  Outbound")

        else:
            print(f"No matching schedule name found for {day_of_week_A} for {stop_id_A} (Direction A).")

        # Fetching data for inbound direction
        url_B = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_A}?direction=inbound'
        data_B = fetch_data(url_B)

        if data_B is None:
            print(f"Failed to fetch data for {stop_id_A} (Direction B).")
            continue

        # Extracting schedule names for direction B
        schedule_names_dict_B = extract_schedule_names(data_B)

        # Fetch day of the week
        day_of_week_B = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction B
        selected_schedule_name_B = None

        if day_of_week_B.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_B.lower() == 'friday':
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_B.lower() == 'saturday':
            preferred_schedule_names_B = ['Saturday']
        elif day_of_week_B.lower() == 'sunday':
            preferred_schedule_names_B = ['Sunday']
        else:
            preferred_schedule_names_B = [day_of_week_B]

        for preferred_name_B in preferred_schedule_names_B:
            if preferred_name_B in schedule_names_dict_B:
                selected_schedule_name_B = preferred_name_B
                break

        if selected_schedule_name_B:
            print(f"\nSelected schedule name for {stop_id_A} (Direction B): {selected_schedule_name_B}")

            # Categorizing the timetable into hourly slots for direction B
            timetable_B = schedule_names_dict_B[selected_schedule_name_B]
            slots_B = categorize_into_slots(timetable_B)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction B
            total_buses_this_hour_B = len(slots_B[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction B
            bus_count_B = calculate_buses(slots_B[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction B
            hours_to_print_B = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction B:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_B in hours_to_print_B:
                if 0 <= hour_B < 24:
                    print(f"\nSlot {hour_B}:")
                    for journey_B in slots_B[hour_B]:
                        journey_hour_B = str(journey_B['hour']).zfill(2)
                        journey_minute_B = str(journey_B['minute']).zfill(2)
                        time_B = f"{journey_hour_B}:{journey_minute_B}"
                        print(f"{time_B}   {line_id}    {stop_id_A}  Inbound")

        else:
            print(f"No matching schedule name found for {day_of_week_B} for {stop_id_A} (Direction B).")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-4d0eb591eefa> in <cell line: 214>()
#     213 # Run the main function
#     214 if __name__ == "__main__":
# --> 215     main()
#
# <ipython-input-19-4d0eb591eefa> in main()
#      74
#      75     # Loop through each stop ID from QSI stop points for direction lineID_A (outbound)
# ---> 76     for stop_id_A in df['ID']:
#      77         # Fetching data for outbound direction
#      78         url_A = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_A}?direction=outbound'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ID'

# %%
def main():
    line_id = input("Enter the line ID: ")

    # Example path for the Excel file containing QSI points data
    file_path = '/content/QSI points.xlsx'

    # Load stop points from Excel file
    df = load_stop_points(file_path)
    if df is None:
        return

    # Check if 'ID' column exists in the DataFrame
    if 'ID' not in df.columns:
        print("Error: 'ID' column not found in the loaded DataFrame.")
        return

    # Loop through each stop ID from QSI stop points for direction lineID_A (outbound)
    for stop_id_A in df['ID']:
        # Fetching data for outbound direction
        url_A = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_A}?direction=outbound'
        data_A = fetch_data(url_A)

        if data_A is None:
            print(f"Failed to fetch data for {stop_id_A} (Direction A).")
            continue

        # Extracting schedule names for direction A
        schedule_names_dict_A = extract_schedule_names(data_A)

        # Fetch day of the week
        day_of_week_A = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction A
        selected_schedule_name_A = None

        if day_of_week_A.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_A.lower() == 'friday':
            preferred_schedule_names_A = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_A.lower() == 'saturday':
            preferred_schedule_names_A = ['Saturday']
        elif day_of_week_A.lower() == 'sunday':
            preferred_schedule_names_A = ['Sunday']
        else:
            preferred_schedule_names_A = [day_of_week_A]

        for preferred_name_A in preferred_schedule_names_A:
            if preferred_name_A in schedule_names_dict_A:
                selected_schedule_name_A = preferred_name_A
                break

        if selected_schedule_name_A:
            print(f"\nSelected schedule name for {stop_id_A} (Direction A): {selected_schedule_name_A}")

            # Categorizing the timetable into hourly slots for direction A
            timetable_A = schedule_names_dict_A[selected_schedule_name_A]
            slots_A = categorize_into_slots(timetable_A)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction A
            total_buses_this_hour_A = len(slots_A[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction A
            bus_count_A = calculate_buses(slots_A[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction A
            hours_to_print_A = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction A:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_A in hours_to_print_A:
                if 0 <= hour_A < 24:
                    print(f"\nSlot {hour_A}:")
                    for journey_A in slots_A[hour_A]:
                        journey_hour_A = str(journey_A['hour']).zfill(2)
                        journey_minute_A = str(journey_A['minute']).zfill(2)
                        time_A = f"{journey_hour_A}:{journey_minute_A}"
                        print(f"{time_A}   {line_id}    {stop_id_A}  Outbound")

        else:
            print(f"No matching schedule name found for {day_of_week_A} for {stop_id_A} (Direction A).")

        # Fetching data for inbound direction
        url_B = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_id_A}?direction=inbound'
        data_B = fetch_data(url_B)

        if data_B is None:
            print(f"Failed to fetch data for {stop_id_A} (Direction B).")
            continue

        # Extracting schedule names for direction B
        schedule_names_dict_B = extract_schedule_names(data_B)

        # Fetch day of the week
        day_of_week_B = get_day_of_week()

        # Determine the matching schedule name based on the current day of the week for direction B
        selected_schedule_name_B = None

        if day_of_week_B.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week_B.lower() == 'friday':
            preferred_schedule_names_B = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week_B.lower() == 'saturday':
            preferred_schedule_names_B = ['Saturday']
        elif day_of_week_B.lower() == 'sunday':
            preferred_schedule_names_B = ['Sunday']
        else:
            preferred_schedule_names_B = [day_of_week_B]

        for preferred_name_B in preferred_schedule_names_B:
            if preferred_name_B in schedule_names_dict_B:
                selected_schedule_name_B = preferred_name_B
                break

        if selected_schedule_name_B:
            print(f"\nSelected schedule name for {stop_id_A} (Direction B): {selected_schedule_name_B}")

            # Categorizing the timetable into hourly slots for direction B
            timetable_B = schedule_names_dict_B[selected_schedule_name_B]
            slots_B = categorize_into_slots(timetable_B)

            # Get the current time in BST
            bst = pytz.timezone('Europe/London')
            now = datetime.now(bst)
            current_hour = now.hour
            current_minute = now.minute

            # Calculate the number of buses scheduled for the current hour for direction B
            total_buses_this_hour_B = len(slots_B[current_hour])

            # Calculate the number of buses scheduled between the first time available in the current slot and the current time for direction B
            bus_count_B = calculate_buses(slots_B[current_hour], current_hour, current_minute)

            # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour for direction B
            hours_to_print_B = [current_hour - 1, current_hour, current_hour + 1]
            print("\nTimetable for Direction B:")
            print("Time   Line ID  Stop Point ID  Direction")
            for hour_B in hours_to_print_B:
                if 0 <= hour_B < 24:
                    print(f"\nSlot {hour_B}:")
                    for journey_B in slots_B[hour_B]:
                        journey_hour_B = str(journey_B['hour']).zfill(2)
                        journey_minute_B = str(journey_B['minute']).zfill(2)
                        time_B = f"{journey_hour_B}:{journey_minute_B}"
                        print(f"{time_B}   {line_id}    {stop_id_A}  Inbound")

        else:
            print(f"No matching schedule name found for {day_of_week_B} for {stop_id_A} (Direction B).")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# Error: 'ID' column not found in the loaded DataFrame.

# %%
import pandas as pd

def load_stop_points(file_path, sheet_name):
    try:
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        return df
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None
    except Exception as e:
        print(f"Error loading Excel file '{file_path}': {e}")
        return None

def main():
    line_id = input("Enter the line ID: ")

    # Example path for the Excel file containing QSI points data
    file_path = 'QSI points.xlsx'

    # Load stop points from Excel file
    df = load_stop_points(file_path, sheet_name='QSI points')
    if df is None:
        return

    # Print columns of the DataFrame to understand its structure
    print("Columns of the loaded DataFrame:")
    print(df.columns)

    # Check if 'ID' column exists in the DataFrame
    if 'ID' not in df.columns:
        print("Error: 'ID' column not found in the loaded DataFrame.")
        return

    # Continue with the rest of your logic here...

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# Error loading Excel file 'QSI points.xlsx': Worksheet named 'QSI points' not found

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and print timetable based on stop point ID and direction
    def fetch_and_print_timetable(line_id, stop_point_ids, direction):
        for stop_point_id in stop_point_ids:
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()

                # Extract schedule names
                schedule_names_dict = extract_schedule_names(data)

                # Fetch day of the week
                day_of_week = get_day_of_week()
                print(f"\nToday is {day_of_week}.")

                # Determine the matching schedule name based on the current day of the week
                selected_schedule_name = None

                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    # Check for the preferred schedule names for Monday to Thursday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    # Check for the preferred schedule names for Friday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    # Check for the preferred schedule names for Saturday
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    # Check for the preferred schedule names for Sunday
                    preferred_schedule_names = ['Sunday']
                else:
                    # For other days of the week, select based on exact match
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

                if selected_schedule_name:
                    print(f"\nSelected schedule name for direction {direction}: {selected_schedule_name}")

                    # Categorizing the timetable into hourly slots
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Get the current time in BST
                    bst = pytz.timezone('Europe/London')
                    now = datetime.now(bst)
                    current_hour = now.hour
                    current_minute = now.minute

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
                    hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for hour in hours_to_print:
                        if 0 <= hour < 24:
                            print(f"\nSlot {hour}:")
                            for journey in slots[hour]:
                                journey_hour = str(journey['hour']).zfill(2)
                                journey_minute = str(journey['minute']).zfill(2)
                                time = f"{journey_hour}:{journey_minute}"
                                print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

                else:
                    print(f"No matching schedule name found for {day_of_week} in direction {direction}.")

            else:
                print(f"Failed to fetch timetable data for stop point ID {stop_point_id} and direction {direction}. Status code: {response.status_code}")

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])


# Example usage
if __name__ == "__main__":
    lineID = input("Please enter the lineID: ")
    find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and print timetable based on stop point ID and direction
    def fetch_and_print_timetable(line_id, stop_point_ids, direction):
        for stop_point_id in stop_point_ids:
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()

                # Extract schedule names
                schedule_names_dict = extract_schedule_names(data)

                # Fetch day of the week
                day_of_week = get_day_of_week()
                print(f"\nToday is {day_of_week}.")

                # Determine the matching schedule name based on the current day of the week
                selected_schedule_name = None

                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    # Check for the preferred schedule names for Monday to Thursday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    # Check for the preferred schedule names for Friday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    # Check for the preferred schedule names for Saturday
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    # Check for the preferred schedule names for Sunday
                    preferred_schedule_names = ['Sunday']
                else:
                    # For other days of the week, select based on exact match
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

                if selected_schedule_name:
                    print(f"\nSelected schedule name for direction {direction}: {selected_schedule_name}")

                    # Categorizing the timetable into hourly slots
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Get the current time in BST
                    bst = pytz.timezone('Europe/London')
                    now = datetime.now(bst)
                    current_hour = now.hour
                    current_minute = now.minute

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
                    hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for hour in hours_to_print:
                        if 0 <= hour < 24:
                            print(f"\nSlot {hour}:")
                            for journey in slots[hour]:
                                journey_hour = str(journey['hour']).zfill(2)
                                journey_minute = str(journey['minute']).zfill(2)
                                time = f"{journey_hour}:{journey_minute}"
                                print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

                else:
                    print(f"No matching schedule name found for {day_of_week} in direction {direction}.")

            else:
                print(f"Failed to fetch timetable data for stop point ID {stop_point_id} and direction {direction}. Status code: {response.status_code}")

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(matched_results_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(matched_results_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])


# Example usage
if __name__ == "__main__":
    lineID = input("Please enter the lineID: ")
    find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'STOP_NAME'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d953aa087947> in <cell line: 219>()
#     219 if __name__ == "__main__":
#     220     lineID = input("Please enter the lineID: ")
# --> 221     find_route_details(lineID)
#
# <ipython-input-22-d953aa087947> in find_route_details(lineID)
#     202
#     203     # Remove partial matches for direction A
# --> 204     matched_results_df_A = remove_partial_matches(matched_results_df_A, matched_results_df_A)
#     205
#     206     # Remove partial matches for direction B
#
# <ipython-input-22-d953aa087947> in remove_partial_matches(exact_df, matched_df)
#     190     def remove_partial_matches(exact_df, matched_df):
#     191         for index, row in exact_df.iterrows():
# --> 192             exact_stop_name = row['STOP_NAME']
#     193             route_dir_qsi_no = row['Route_Dir_QSI_No']
#     194             # Find exact matches in matched_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'STOP_NAME'

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    if filtered_df_A.empty:
        print(f"No data found for direction {lineID}_A.")
    else:
        # Print the stop names from the Excel file for direction A
        print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
        print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    if filtered_df_B.empty:
        print(f"No data found for direction {lineID}_B.")
    else:
        # Print the stop names from the Excel file for direction B
        print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
        print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and print timetable based on stop point ID and direction
    def fetch_and_print_timetable(line_id, stop_point_ids, direction):
        for stop_point_id in stop_point_ids:
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()

                # Extract schedule names
                schedule_names_dict = extract_schedule_names(data)

                # Fetch day of the week
                day_of_week = get_day_of_week()
                print(f"\nToday is {day_of_week}.")

                # Determine the matching schedule name based on the current day of the week
                selected_schedule_name = None

                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    # Check for the preferred schedule names for Monday to Thursday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    # Check for the preferred schedule names for Friday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    # Check for the preferred schedule names for Saturday
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    # Check for the preferred schedule names for Sunday
                    preferred_schedule_names = ['Sunday']
                else:
                    # For other days of the week, select based on exact match
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

                if selected_schedule_name:
                    print(f"\nSelected schedule name for direction {direction}: {selected_schedule_name}")

                    # Categorizing the timetable into hourly slots
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Get the current time in BST
                    bst = pytz.timezone('Europe/London')
                    now = datetime.now(bst)
                    current_hour = now.hour
                    current_minute = now.minute

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
                    hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for hour in hours_to_print:
                        if 0 <= hour < 24:
                            print(f"\nSlot {hour}:")
                            for journey in slots[hour]:
                                journey_hour = str(journey['hour']).zfill(2)
                                journey_minute = str(journey['minute']).zfill(2)
                                time = f"{journey_hour}:{journey_minute}"
                                print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

                else:
                    print(f"No matching schedule name found for {day_of_week} in direction {direction}.")

            else:
                print(f"Failed to fetch timetable data for stop point ID {stop_point_id} and direction {direction}. Status code: {response.status_code}")

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    print(f"Skipping stop {stop['name']} as no matching entry found in the filtered DataFrame.")

        else:
            print(f"Failed to fetch route data from TfL API for route type {route_type}. Status code: {response.status_code}")

        return pd.DataFrame(results_list)

    # Remove partial matches function
    def remove_partial_matches(matched_df, df):
        def normalize_stop_name(name):
            return ' '.join(name.lower().split())

        matched_df['STOP_Name'] = matched_df['STOP_Name'].apply(normalize_stop_name)

        for route_dir_qsi_no, exact_stop_name in zip(matched_df['Route_Dir_QSI_No'], matched_df['STOP_Name']):
            exact_matches = df[(df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                               (df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(matched_results_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(matched_results_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])


# Example usage
if __name__ == "__main__":
    lineID = input("Please enter the lineID: ")
    find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-23-275fd7362707> in <cell line: 220>()
#     220 if __name__ == "__main__":
#     221     lineID = input("Please enter the lineID: ")
# --> 222     find_route_details(lineID)
#
# <ipython-input-23-275fd7362707> in find_route_details(lineID)
#     203
#     204     # Remove partial matches for direction A
# --> 205     matched_results_df_A = remove_partial_matches(matched_results_df_A, matched_results_df_A)
#     206
#     207     # Remove partial matches for direction B
#
# UnboundLocalError: local variable 'matched_results_df_A' referenced before assignment

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    if filtered_df_A.empty:
        print(f"No data found for direction {lineID}_A.")
        matched_results_df_A = pd.DataFrame()  # Initialize as empty DataFrame
    else:
        matched_results_df_A = remove_partial_matches(filtered_df_A.copy(), df.copy())  # Use .copy() to avoid modifying original DataFrame

    if filtered_df_B.empty:
        print(f"No data found for direction {lineID}_B.")
        matched_results_df_B = pd.DataFrame()  # Initialize as empty DataFrame
    else:
        matched_results_df_B = remove_partial_matches(filtered_df_B.copy(), df.copy())  # Use .copy() to avoid modifying original DataFrame

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Function to fetch and print timetable based on stop point ID and direction
    def fetch_and_print_timetable(line_id, stop_point_ids, direction):
        for stop_point_id in stop_point_ids:
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()

                # Extract schedule names
                schedule_names_dict = extract_schedule_names(data)

                # Fetch day of the week
                day_of_week = get_day_of_week()
                print(f"\nToday is {day_of_week}.")

                # Determine the matching schedule name based on the current day of the week
                selected_schedule_name = None

                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    # Check for the preferred schedule names for Monday to Thursday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    # Check for the preferred schedule names for Friday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    # Check for the preferred schedule names for Saturday
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    # Check for the preferred schedule names for Sunday
                    preferred_schedule_names = ['Sunday']
                else:
                    # For other days of the week, select based on exact match
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

                if selected_schedule_name:
                    print(f"\nSelected schedule name for direction {direction}: {selected_schedule_name}")

                    # Categorizing the timetable into hourly slots
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Get the current time in BST
                    bst = pytz.timezone('Europe/London')
                    now = datetime.now(bst)
                    current_hour = now.hour
                    current_minute = now.minute

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
                    hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for hour in hours_to_print:
                        if 0 <= hour < 24:
                            print(f"\nSlot {hour}:")
                            for journey in slots[hour]:
                                journey_hour = str(journey['hour']).zfill(2)
                                journey_minute = str(journey['minute']).zfill(2)
                                time = f"{journey_hour}:{journey_minute}"
                                print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

                else:
                    print(f"No matching schedule name found for {day_of_week} in direction {direction}.")

            else:
                print(f"Failed to fetch timetable data for stop point ID {stop_point_id} and direction {direction}. Status code: {response.status_code}")

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    print(f"Skipping stop {stop['name']} as no matching entry found in the filtered DataFrame.")

        else:
            print(f"Failed to fetch route data from TfL API for route type {route_type}. Status code: {response.status_code}")

        return pd.DataFrame(results_list)

    # Function to remove partial matches
    def remove_partial_matches(matched_df, df):
        def normalize_stop_name(name):
            return ' '.join(name.lower().split())

        matched_df['STOP_Name'] = matched_df['STOP_Name'].apply(normalize_stop_name)

        for route_dir_qsi_no, exact_stop_name in zip(matched_df['Route_Dir_QSI_No'], matched_df['STOP_Name']):
            exact_matches = df[(df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                               (df['STOP_NAME'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Fetch and print timetables for direction A
    if not matched_results_df_A.empty:
        stop_point_ids_A = matched_results_df_A['ID'].tolist()
        fetch_and_print_timetable(lineID, stop_point_ids_A, 'outbound')

    # Fetch and print timetables for direction B
    if not matched_results_df_B.empty:
        stop_point_ids_B = matched_results_df_B['ID'].tolist()
        fetch_and_print_timetable(lineID, stop_point_ids_B, 'inbound')


# Example usage
if __name__ == "__main__":
    lineID = input("Please enter the lineID: ")
    find_route_details(lineID)
# Out:
# Please enter the lineID: d7
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-24-72bb96c93017> in <cell line: 208>()
#     208 if __name__ == "__main__":
#     209     lineID = input("Please enter the lineID: ")
# --> 210     find_route_details(lineID)
#
# <ipython-input-24-72bb96c93017> in find_route_details(lineID)
#      41         matched_results_df_A = pd.DataFrame()  # Initialize as empty DataFrame
#      42     else:
# ---> 43         matched_results_df_A = remove_partial_matches(filtered_df_A.copy(), df.copy())  # Use .copy() to avoid modifying original DataFrame
#      44
#      45     if filtered_df_B.empty:
#
# UnboundLocalError: local variable 'remove_partial_matches' referenced before assignment

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    if filtered_df_A.empty:
        print(f"No data found for direction {lineID}_A.")
        matched_results_df_A = pd.DataFrame()  # Initialize as empty DataFrame
    else:
        matched_results_df_A = remove_partial_matches(filtered_df_A.copy(), df.copy())  # Use .copy() to avoid modifying original DataFrame

    if filtered_df_B.empty:
        print(f"No data found for direction {lineID}_B.")
        matched_results_df_B = pd.DataFrame()  # Initialize as empty DataFrame
    else:
        matched_results_df_B = remove_partial_matches(filtered_df_B.copy(), df.copy())  # Use .copy() to avoid modifying original DataFrame

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Function to fetch and print timetable based on stop point ID and direction
    def fetch_and_print_timetable(line_id, stop_point_ids, direction):
        for stop_point_id in stop_point_ids:
            url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()

                # Extract schedule names
                schedule_names_dict = extract_schedule_names(data)

                # Fetch day of the week
                day_of_week = get_day_of_week()
                print(f"\nToday is {day_of_week}.")

                # Determine the matching schedule name based on the current day of the week
                selected_schedule_name = None

                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    # Check for the preferred schedule names for Monday to Thursday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    # Check for the preferred schedule names for Friday
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    # Check for the preferred schedule names for Saturday
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    # Check for the preferred schedule names for Sunday
                    preferred_schedule_names = ['Sunday']
                else:
                    # For other days of the week, select based on exact match
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

                if selected_schedule_name:
                    print(f"\nSelected schedule name for direction {direction}: {selected_schedule_name}")

                    # Categorizing the timetable into hourly slots
                    timetable = schedule_names_dict[selected_schedule_name]
                    slots = categorize_into_slots(timetable)

                    # Get the current time in BST
                    bst = pytz.timezone('Europe/London')
                    now = datetime.now(bst)
                    current_hour = now.hour
                    current_minute = now.minute

                    # Calculate the number of buses scheduled for the current hour
                    total_buses_this_hour = len(slots[current_hour])
                    print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

                    # Calculate the number of buses scheduled between the first time available in the current slot and the current time
                    bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
                    print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

                    # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
                    hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
                    print("\nTimetable:")
                    print("Time   Line ID  Stop Point ID  Direction")
                    for hour in hours_to_print:
                        if 0 <= hour < 24:
                            print(f"\nSlot {hour}:")
                            for journey in slots[hour]:
                                journey_hour = str(journey['hour']).zfill(2)
                                journey_minute = str(journey['minute']).zfill(2)
                                time = f"{journey_hour}:{journey_minute}"
                                print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

                else:
                    print(f"No matching schedule name found for {day_of_week} in direction {direction}.")

            else:
                print(f"Failed to fetch timetable data for stop point ID {stop_point_id} and direction {direction}. Status code: {response.status_code}")

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    print(f"Skipping stop {stop['name']} as no matching entry found in the filtered DataFrame.")

        else:
            print(f"Failed to fetch route data from TfL API for route type {route_type}. Status code: {response.status_code}")

        return pd.DataFrame(results_list)

    # Function to remove partial matches
    def remove_partial_matches(matched_df, df):
        def normalize_stop_name(name):
            return ' '.join(name.lower().split())

        matched_df['STOP_Name'] = matched_df['STOP_Name'].apply(normalize_stop_name)

        for route_dir_qsi_no, exact_stop_name in zip(matched_df['Route_Dir_QSI_No'], matched_df['STOP_Name']):
            exact_matches = df[(df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                               (df['STOP_NAME'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Fetch and print timetables for direction A
    if not matched_results_df_A.empty:
        stop_point_ids_A = matched_results_df_A['ID'].tolist()
        fetch_and_print_timetable(lineID, stop_point_ids_A, 'outbound')

    # Fetch and print timetables for direction B
    if not matched_results_df_B.empty:
        stop_point_ids_B = matched_results_df_B['ID'].tolist()
        fetch_and_print_timetable(lineID, stop_point_ids_B, 'inbound')


# Example usage
if __name__ == "__main__":
    lineID = input("Please enter the lineID: ")
    find_route_details(lineID)
# Out:
# Please enter the lineID: d7
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-25-72bb96c93017> in <cell line: 208>()
#     208 if __name__ == "__main__":
#     209     lineID = input("Please enter the lineID: ")
# --> 210     find_route_details(lineID)
#
# <ipython-input-25-72bb96c93017> in find_route_details(lineID)
#      41         matched_results_df_A = pd.DataFrame()  # Initialize as empty DataFrame
#      42     else:
# ---> 43         matched_results_df_A = remove_partial_matches(filtered_df_A.copy(), df.copy())  # Use .copy() to avoid modifying original DataFrame
#      44
#      45     if filtered_df_B.empty:
#
# UnboundLocalError: local variable 'remove_partial_matches' referenced before assignment

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return None, None

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Initialize lists to store matched results
    results_A = []
    results_B = []

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    df_A = pd.DataFrame(results_A)
    df_B = pd.DataFrame(results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_Name']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    df_A = remove_partial_matches(filtered_df_A, df_A)

    # Remove partial matches for direction B
    df_B = remove_partial_matches(filtered_df_B, df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    print(df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    print(df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Return the DataFrames df_A and df_B
    return df_A, df_B

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
df_A, df_B = find_route_details(lineID)

# Now df_A and df_B contain the QSI stop points for direction lineID_A and lineID_B respectively
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'STOP_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-5caaf8d440c2> in <cell line: 148>()
#     146
#     147 # Find and display the route details
# --> 148 df_A, df_B = find_route_details(lineID)
#     149
#     150 # Now df_A and df_B contain the QSI stop points for direction lineID_A and lineID_B respectively
#
# <ipython-input-27-5caaf8d440c2> in find_route_details(lineID)
#     121
#     122     # Remove partial matches for direction A
# --> 123     df_A = remove_partial_matches(filtered_df_A, df_A)
#     124
#     125     # Remove partial matches for direction B
#
# <ipython-input-27-5caaf8d440c2> in remove_partial_matches(exact_df, matched_df)
#     109     def remove_partial_matches(exact_df, matched_df):
#     110         for index, row in exact_df.iterrows():
# --> 111             exact_stop_name = row['STOP_Name']
#     112             route_dir_qsi_no = row['Route_Dir_QSI_No']
#     113             # Find exact matches in matched_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'STOP_Name'

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return None, None

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Initialize lists to store matched results
    results_A = []
    results_B = []

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_NAME': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_NAME': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    df_A = pd.DataFrame(results_A)
    df_B = pd.DataFrame(results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_NAME'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_NAME'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    df_A = remove_partial_matches(filtered_df_A, df_A)

    # Remove partial matches for direction B
    df_B = remove_partial_matches(filtered_df_B, df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    print(df_A[['Route_Dir_QSI_No', 'STOP_NAME', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    print(df_B[['Route_Dir_QSI_No', 'STOP_NAME', 'ID']])

    # Return the DataFrames df_A and df_B
    return df_A, df_B

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
df_A, df_B = find_route_details(lineID)

# Now df_A and df_B contain the QSI stop points for direction lineID_A and lineID_B respectively
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_NAME          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_NAME          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Main function to get user input and print the schedule names and timetable
def main():
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path, sheet_name=None)  # Load all sheets into a dictionary

    # Ask the user to enter a line ID
    line_id = input("Enter the line ID: ").upper()  # Convert to uppercase for consistency

    # Check if the line ID is valid and load corresponding DataFrames
    df_A = None
    df_B = None

    for sheet_name in df.keys():
        if sheet_name.startswith(line_id):
            if sheet_name.endswith('_A'):
                df_A = df[sheet_name]
            elif sheet_name.endswith('_B'):
                df_B = df[sheet_name]

    if df_A is None or df_B is None:
        print(f"No data found for line ID '{line_id}'. Please check the Excel file.")
        return

    # Determine direction based on line_id
    if line_id.endswith('_A'):
        direction = 'outbound'
        stop_point_id = df_A['ID'].iloc[0]  # Assuming the first ID from df_A for outbound direction
    elif line_id.endswith('_B'):
        direction = 'inbound'
        stop_point_id = df_B['ID'].iloc[0]  # Assuming the first ID from df_B for inbound direction
    else:
        print(f"Invalid line ID format: {line_id}. Please enter a valid line ID ending with '_A' or '_B'.")
        return

    # Fetching data
    url = f'https://api.tfl.gov.uk/Line/{line_id}/Timetable/{stop_point_id}?direction={direction}'
    data = fetch_data(url)

    # Extracting schedule names
    schedule_names_dict = extract_schedule_names(data)

    # Fetch day of the week
    day_of_week = get_day_of_week()
    print(f"\nToday is {day_of_week}.")

    # Print extracted schedule names
    print("\nExtracted Schedule Names:")
    for i, schedule_name in enumerate(schedule_names_dict.keys(), start=1):
        print(f"{i}. {schedule_name}")

    # Determine the matching schedule name based on the current day of the week
    selected_schedule_name = None

    if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
        # Check for the preferred schedule names for Monday to Thursday
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
    elif day_of_week.lower() == 'friday':
        # Check for the preferred schedule names for Friday
        preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
    elif day_of_week.lower() == 'saturday':
        # Check for the preferred schedule names for Saturday
        preferred_schedule_names = ['Saturday']
    elif day_of_week.lower() == 'sunday':
        # Check for the preferred schedule names for Sunday
        preferred_schedule_names = ['Sunday']
    else:
        # For other days of the week, select based on exact match
        preferred_schedule_names = [day_of_week]

    for preferred_name in preferred_schedule_names:
        if preferred_name in schedule_names_dict:
            selected_schedule_name = preferred_name
            break

    if selected_schedule_name:
        print(f"\nSelected schedule name: {selected_schedule_name}")

        # Categorizing the timetable into hourly slots
        timetable = schedule_names_dict[selected_schedule_name]
        slots = categorize_into_slots(timetable)

        # Get the current time in BST
        bst = pytz.timezone('Europe/London')
        now = datetime.now(bst)
        current_hour = now.hour
        current_minute = now.minute

        # Calculate the number of buses scheduled for the current hour
        total_buses_this_hour = len(slots[current_hour])
        print(f"\nNumber of buses scheduled for this hour: {total_buses_this_hour}")

        # Calculate the number of buses scheduled between the first time available in the current slot and the current time
        bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
        print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

        # Print the timetable slots corresponding to the current hour, the previous hour, and the next hour
        hours_to_print = [current_hour - 1, current_hour, current_hour + 1]
        print("\nTimetable:")
        print("Time   Line ID  Stop Point ID  Direction")
        for hour in hours_to_print:
            if 0 <= hour < 24:
                print(f"\nSlot {hour}:")
                for journey in slots[hour]:
                    journey_hour = str(journey['hour']).zfill(2)
                    journey_minute = str(journey['minute']).zfill(2)
                    time = f"{journey_hour}:{journey_minute}"
                    print(f"{time}   {line_id}    {stop_point_id}  {direction.capitalize()}")

    else:
        print("No matching schedule name found for today.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the line ID: d7
# No data found for line ID 'D7'. Please check the Excel file.

# %% [markdown]
# 02/07/2024

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Save the combined DataFrame to an Excel file
    output_file_path = 'matched_qsi_stop_points.xlsx'
    combined_df.to_excel(output_file_path, index=False)
    print(f"\n\n\033[1m\033[4mMatched QSI stop points have been saved to {output_file_path}\033[0m\n")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
#
# Matched QSI stop points have been saved to matched_qsi_stop_points.xlsx

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Save the combined DataFrame to an Excel file
    output_file_path = 'matched_qsi_stop_points.xlsx'
    combined_df.to_excel(output_file_path, index=False)
    print(f"\n\n\033[1m\033[4mMatched QSI stop points have been saved to {output_file_path}\033[0m\n")

    # Fetch timetable for each stop point ID and print the number of scheduled buses for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    current_minute = now.minute
    day_of_week = get_day_of_week()

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)
        print(f"\nToday is {day_of_week}.")

        selected_schedule_name = None
        if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
            preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
        elif day_of_week.lower() == 'friday':
            preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
        elif day_of_week.lower() == 'saturday':
            preferred_schedule_names = ['Saturday']
        elif day_of_week.lower() == 'sunday':
            preferred_schedule_names = ['Sunday']
        else:
            preferred_schedule_names = [day_of_week]

        for preferred_name in preferred_schedule_names:
            if preferred_name in schedule_names_dict:
                selected_schedule_name = preferred_name
                break

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            total_buses_this_hour = len(slots[current_hour])
            print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

            bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
            print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

        else:
            print(f"No matching schedule name found for stop point {stop_point_id}.")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
#
# Matched QSI stop points have been saved to matched_qsi_stop_points.xlsx
#
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490011107G: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490013513S: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490002048Z: 6
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490006092N: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490004584N: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490015151H: 6
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490004584S: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490000038F: 6
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490016668L: 6
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490006092S: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490002048X: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday.
#
# Number of buses scheduled for this hour at stop point 490013513N: 5
# Number of buses scheduled between the first time available in the current slot and now: 4

# %% [markdown]
# printin the day of week and selected schedule name only once.

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Save the combined DataFrame to an Excel file
    output_file_path = 'matched_qsi_stop_points.xlsx'
    combined_df.to_excel(output_file_path, index=False)
    print(f"\n\nMatched QSI stop points have been saved to {output_file_path}\n")

    # Fetch timetable for each stop point ID and print the number of scheduled buses for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    current_minute = now.minute
    day_of_week = get_day_of_week()

    # Store selected schedule name
    selected_schedule_name = None

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            total_buses_this_hour = len(slots[current_hour])
            print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

            bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
            print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

    if selected_schedule_name:
        print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
    else:
        print("No matching schedule name found for today.")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
#
# Matched QSI stop points have been saved to matched_qsi_stop_points.xlsx
#
#
# Number of buses scheduled for this hour at stop point 490011107G: 5
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Number of buses scheduled for this hour at stop point 490013513S: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Number of buses scheduled for this hour at stop point 490002048Z: 6
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Number of buses scheduled for this hour at stop point 490006092N: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Number of buses scheduled for this hour at stop point 490004584N: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Number of buses scheduled for this hour at stop point 490015151H: 6
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Number of buses scheduled for this hour at stop point 490004584S: 5
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Number of buses scheduled for this hour at stop point 490000038F: 6
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Number of buses scheduled for this hour at stop point 490016668L: 6
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Number of buses scheduled for this hour at stop point 490006092S: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Number of buses scheduled for this hour at stop point 490002048X: 5
# Number of buses scheduled between the first time available in the current slot and now: 5
#
# Number of buses scheduled for this hour at stop point 490013513N: 5
# Number of buses scheduled between the first time available in the current slot and now: 4
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.

# %% [markdown]
# Preventing the conversion of combined_df to xlsx file. Printing the da of week and selected schedule name once.

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to calculate the number of buses between the first time available in the slot and the current time
def calculate_buses(slot, current_hour, current_minute):
    bus_count = 0
    for journey in slot:
        journey_hour = int(journey['hour'])
        journey_minute = int(journey['minute'])
        if journey_hour == current_hour and journey_minute <= current_minute:
            bus_count += 1
    return bus_count

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Fetch timetable for each stop point ID and print the number of scheduled buses for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    current_minute = now.minute
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            total_buses_this_hour = len(slots[current_hour])
            print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

            bus_count = calculate_buses(slots[current_hour], current_hour, current_minute)
            print(f"Number of buses scheduled between the first time available in the current slot and now: {bus_count}")

    if not printed_schedule_name:
        print("No matching schedule name found for today.")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
#
# Number of buses scheduled for this hour at stop point 490011107G: 6
# Number of buses scheduled between the first time available in the current slot and now: 1
#
# Number of buses scheduled for this hour at stop point 490013513S: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Number of buses scheduled for this hour at stop point 490002048Z: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Number of buses scheduled for this hour at stop point 490006092N: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Number of buses scheduled for this hour at stop point 490004584N: 4
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Number of buses scheduled for this hour at stop point 490015151H: 5
# Number of buses scheduled between the first time available in the current slot and now: 1
#
# Number of buses scheduled for this hour at stop point 490004584S: 5
# Number of buses scheduled between the first time available in the current slot and now: 1
#
# Number of buses scheduled for this hour at stop point 490000038F: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Number of buses scheduled for this hour at stop point 490016668L: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Number of buses scheduled for this hour at stop point 490006092S: 5
# Number of buses scheduled between the first time available in the current slot and now: 0
#
# Number of buses scheduled for this hour at stop point 490002048X: 5
# Number of buses scheduled between the first time available in the current slot and now: 1
#
# Number of buses scheduled for this hour at stop point 490013513N: 5
# Number of buses scheduled between the first time available in the current slot and now: 0

# %% [markdown]
# printing the timetable of the stop points

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Fetch timetable for each stop point ID and print the timetable for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Print timetable for the current hour
            print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
#
# Timetable for stop point 490011107G at hour 8:
# 08:00   D7    490011107G  Outbound
# 08:11   D7    490011107G  Outbound
# 08:22   D7    490011107G  Outbound
# 08:33   D7    490011107G  Outbound
# 08:45   D7    490011107G  Outbound
# 08:57   D7    490011107G  Outbound
#
# Timetable for stop point 490013513S at hour 8:
# 08:06   D7    490013513S  Outbound
# 08:17   D7    490013513S  Outbound
# 08:28   D7    490013513S  Outbound
# 08:40   D7    490013513S  Outbound
# 08:52   D7    490013513S  Outbound
#
# Timetable for stop point 490002048Z at hour 8:
# 08:11   D7    490002048Z  Outbound
# 08:23   D7    490002048Z  Outbound
# 08:35   D7    490002048Z  Outbound
# 08:47   D7    490002048Z  Outbound
# 08:59   D7    490002048Z  Outbound
#
# Timetable for stop point 490006092N at hour 8:
# 08:06   D7    490006092N  Outbound
# 08:18   D7    490006092N  Outbound
# 08:30   D7    490006092N  Outbound
# 08:42   D7    490006092N  Outbound
# 08:54   D7    490006092N  Outbound
#
# Timetable for stop point 490004584N at hour 8:
# 08:12   D7    490004584N  Outbound
# 08:24   D7    490004584N  Outbound
# 08:36   D7    490004584N  Outbound
# 08:48   D7    490004584N  Outbound
#
# Timetable for stop point 490015151H at hour 8:
# 08:05   D7    490015151H  Inbound
# 08:17   D7    490015151H  Inbound
# 08:29   D7    490015151H  Inbound
# 08:42   D7    490015151H  Inbound
# 08:55   D7    490015151H  Inbound
#
# Timetable for stop point 490004584S at hour 8:
# 08:01   D7    490004584S  Inbound
# 08:12   D7    490004584S  Inbound
# 08:24   D7    490004584S  Inbound
# 08:36   D7    490004584S  Inbound
# 08:49   D7    490004584S  Inbound
#
# Timetable for stop point 490000038F at hour 8:
# 08:07   D7    490000038F  Inbound
# 08:19   D7    490000038F  Inbound
# 08:31   D7    490000038F  Inbound
# 08:43   D7    490000038F  Inbound
# 08:55   D7    490000038F  Inbound
#
# Timetable for stop point 490016668L at hour 8:
# 08:10   D7    490016668L  Inbound
# 08:22   D7    490016668L  Inbound
# 08:34   D7    490016668L  Inbound
# 08:46   D7    490016668L  Inbound
# 08:58   D7    490016668L  Inbound
#
# Timetable for stop point 490006092S at hour 8:
# 08:06   D7    490006092S  Inbound
# 08:17   D7    490006092S  Inbound
# 08:29   D7    490006092S  Inbound
# 08:41   D7    490006092S  Inbound
# 08:53   D7    490006092S  Inbound
#
# Timetable for stop point 490002048X at hour 8:
# 08:01   D7    490002048X  Inbound
# 08:12   D7    490002048X  Inbound
# 08:24   D7    490002048X  Inbound
# 08:36   D7    490002048X  Inbound
# 08:48   D7    490002048X  Inbound
#
# Timetable for stop point 490013513N at hour 8:
# 08:06   D7    490013513N  Inbound
# 08:18   D7    490013513N  Inbound
# 08:30   D7    490013513N  Inbound
# 08:42   D7    490013513N  Inbound
# 08:54   D7    490013513N  Inbound

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Fetch timetable for each stop point ID and print the timetable for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Print timetable for the current hour
            print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}:")
            print(f"Timetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
# Timetable for stop point 490002048X at hour 8:
# 08:01   D7    490002048X  Inbound
# 08:12   D7    490002048X  Inbound
# 08:24   D7    490002048X  Inbound
# 08:36   D7    490002048X  Inbound
# 08:48   D7    490002048X  Inbound
#
# Number of buses scheduled for this hour at stop point 490013513N:
# Timetable for stop point 490013513N at hour 8:
# 08:06   D7    490013513N  Inbound
# 08:18   D7    490013513N  Inbound
# 08:30   D7    490013513N  Inbound
# 08:42   D7    490013513N  Inbound
# 08:54   D7    490013513N  Inbound

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process inbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process outbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Fetch timetable for each stop point ID and print the timetable for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Print timetable for the current hour
            print(f"\nNumber of buses scheduled for this hour at stop point ***********:")
            print(f"Timetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490011107G at hour 8:
# 08:00   D7    490011107G  Outbound
# 08:11   D7    490011107G  Outbound
# 08:22   D7    490011107G  Outbound
# 08:33   D7    490011107G  Outbound
# 08:45   D7    490011107G  Outbound
# 08:57   D7    490011107G  Outbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490013513S at hour 8:
# 08:06   D7    490013513S  Outbound
# 08:17   D7    490013513S  Outbound
# 08:28   D7    490013513S  Outbound
# 08:40   D7    490013513S  Outbound
# 08:52   D7    490013513S  Outbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490002048Z at hour 8:
# 08:11   D7    490002048Z  Outbound
# 08:23   D7    490002048Z  Outbound
# 08:35   D7    490002048Z  Outbound
# 08:47   D7    490002048Z  Outbound
# 08:59   D7    490002048Z  Outbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490006092N at hour 8:
# 08:06   D7    490006092N  Outbound
# 08:18   D7    490006092N  Outbound
# 08:30   D7    490006092N  Outbound
# 08:42   D7    490006092N  Outbound
# 08:54   D7    490006092N  Outbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490004584N at hour 8:
# 08:12   D7    490004584N  Outbound
# 08:24   D7    490004584N  Outbound
# 08:36   D7    490004584N  Outbound
# 08:48   D7    490004584N  Outbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490015151H at hour 8:
# 08:05   D7    490015151H  Inbound
# 08:17   D7    490015151H  Inbound
# 08:29   D7    490015151H  Inbound
# 08:42   D7    490015151H  Inbound
# 08:55   D7    490015151H  Inbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490004584S at hour 8:
# 08:01   D7    490004584S  Inbound
# 08:12   D7    490004584S  Inbound
# 08:24   D7    490004584S  Inbound
# 08:36   D7    490004584S  Inbound
# 08:49   D7    490004584S  Inbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490000038F at hour 8:
# 08:07   D7    490000038F  Inbound
# 08:19   D7    490000038F  Inbound
# 08:31   D7    490000038F  Inbound
# 08:43   D7    490000038F  Inbound
# 08:55   D7    490000038F  Inbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490016668L at hour 8:
# 08:10   D7    490016668L  Inbound
# 08:22   D7    490016668L  Inbound
# 08:34   D7    490016668L  Inbound
# 08:46   D7    490016668L  Inbound
# 08:58   D7    490016668L  Inbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490006092S at hour 8:
# 08:06   D7    490006092S  Inbound
# 08:17   D7    490006092S  Inbound
# 08:29   D7    490006092S  Inbound
# 08:41   D7    490006092S  Inbound
# 08:53   D7    490006092S  Inbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490002048X at hour 8:
# 08:01   D7    490002048X  Inbound
# 08:12   D7    490002048X  Inbound
# 08:24   D7    490002048X  Inbound
# 08:36   D7    490002048X  Inbound
# 08:48   D7    490002048X  Inbound
#
# Number of buses scheduled for this hour at stop point ***********:
# Timetable for stop point 490013513N at hour 8:
# 08:06   D7    490013513N  Inbound
# 08:18   D7    490013513N  Inbound
# 08:30   D7    490013513N  Inbound
# 08:42   D7    490013513N  Inbound
# 08:54   D7    490013513N  Inbound

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Fetch timetable for each stop point ID and print the timetable for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Print number of buses scheduled for this hour at stop point
            total_buses_this_hour = len(slots[current_hour])
            print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

            # Print timetable for the current hour
            print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
#
# Number of buses scheduled for this hour at stop point 490011107G: 6
#
# Timetable for stop point 490011107G at hour 8:
# 08:00   D7    490011107G  Outbound
# 08:11   D7    490011107G  Outbound
# 08:22   D7    490011107G  Outbound
# 08:33   D7    490011107G  Outbound
# 08:45   D7    490011107G  Outbound
# 08:57   D7    490011107G  Outbound
#
# Number of buses scheduled for this hour at stop point 490013513S: 5
#
# Timetable for stop point 490013513S at hour 8:
# 08:06   D7    490013513S  Outbound
# 08:17   D7    490013513S  Outbound
# 08:28   D7    490013513S  Outbound
# 08:40   D7    490013513S  Outbound
# 08:52   D7    490013513S  Outbound
#
# Number of buses scheduled for this hour at stop point 490002048Z: 5
#
# Timetable for stop point 490002048Z at hour 8:
# 08:11   D7    490002048Z  Outbound
# 08:23   D7    490002048Z  Outbound
# 08:35   D7    490002048Z  Outbound
# 08:47   D7    490002048Z  Outbound
# 08:59   D7    490002048Z  Outbound
#
# Number of buses scheduled for this hour at stop point 490006092N: 5
#
# Timetable for stop point 490006092N at hour 8:
# 08:06   D7    490006092N  Outbound
# 08:18   D7    490006092N  Outbound
# 08:30   D7    490006092N  Outbound
# 08:42   D7    490006092N  Outbound
# 08:54   D7    490006092N  Outbound
#
# Number of buses scheduled for this hour at stop point 490004584N: 4
#
# Timetable for stop point 490004584N at hour 8:
# 08:12   D7    490004584N  Outbound
# 08:24   D7    490004584N  Outbound
# 08:36   D7    490004584N  Outbound
# 08:48   D7    490004584N  Outbound
#
# Number of buses scheduled for this hour at stop point 490015151H: 5
#
# Timetable for stop point 490015151H at hour 8:
# 08:05   D7    490015151H  Inbound
# 08:17   D7    490015151H  Inbound
# 08:29   D7    490015151H  Inbound
# 08:42   D7    490015151H  Inbound
# 08:55   D7    490015151H  Inbound
#
# Number of buses scheduled for this hour at stop point 490004584S: 5
#
# Timetable for stop point 490004584S at hour 8:
# 08:01   D7    490004584S  Inbound
# 08:12   D7    490004584S  Inbound
# 08:24   D7    490004584S  Inbound
# 08:36   D7    490004584S  Inbound
# 08:49   D7    490004584S  Inbound
#
# Number of buses scheduled for this hour at stop point 490000038F: 5
#
# Timetable for stop point 490000038F at hour 8:
# 08:07   D7    490000038F  Inbound
# 08:19   D7    490000038F  Inbound
# 08:31   D7    490000038F  Inbound
# 08:43   D7    490000038F  Inbound
# 08:55   D7    490000038F  Inbound
#
# Number of buses scheduled for this hour at stop point 490016668L: 5
#
# Timetable for stop point 490016668L at hour 8:
# 08:10   D7    490016668L  Inbound
# 08:22   D7    490016668L  Inbound
# 08:34   D7    490016668L  Inbound
# 08:46   D7    490016668L  Inbound
# 08:58   D7    490016668L  Inbound
#
# Number of buses scheduled for this hour at stop point 490006092S: 5
#
# Timetable for stop point 490006092S at hour 8:
# 08:06   D7    490006092S  Inbound
# 08:17   D7    490006092S  Inbound
# 08:29   D7    490006092S  Inbound
# 08:41   D7    490006092S  Inbound
# 08:53   D7    490006092S  Inbound
#
# Number of buses scheduled for this hour at stop point 490002048X: 5
#
# Timetable for stop point 490002048X at hour 8:
# 08:01   D7    490002048X  Inbound
# 08:12   D7    490002048X  Inbound
# 08:24   D7    490002048X  Inbound
# 08:36   D7    490002048X  Inbound
# 08:48   D7    490002048X  Inbound
#
# Number of buses scheduled for this hour at stop point 490013513N: 5
#
# Timetable for stop point 490013513N at hour 8:
# 08:06   D7    490013513N  Inbound
# 08:18   D7    490013513N  Inbound
# 08:30   D7    490013513N  Inbound
# 08:42   D7    490013513N  Inbound
# 08:54   D7    490013513N  Inbound

# %% [markdown]
# File share 18

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Fetch timetable for each stop point ID and print the timetable for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Print number of buses scheduled for this hour at stop point
            total_buses_this_hour = len(slots[current_hour])
            print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

            # Print timetable for the current hour
            print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: 8
#
#
# Stop names from the Excel file for direction 8_A
#
#      Route_Dir_QSI_No                           STOP_NAME
# 1225             8_A1                          bow church
# 1226             8_A2                       old ford road
# 1227             8_A3               bethnal green station
# 1228             8_A4  commercial street / worship street
# 1229             8_A5            liverpool street station
# 1230             8_A6                   st paul's station
#
#
# Stop names from the Excel file for direction 8_B
#
#      Route_Dir_QSI_No                                STOP_NAME
# 1231             8_B1                        new oxford street
# 1232             8_B2                           procter street
# 1233             8_B3                       king edward street
# 1234             8_B4                 liverpool street station
# 1235             8_B5  bethnal grn rd / shoreditch high st stn
# 1236             8_B6                    bethnal green station
# 1237             8_B7                        roman road market
#
#
# QSI stop points for direction 8_A
#
#   Route_Dir_QSI_No                           STOP_Name          ID
# 0             8_A1                          Bow Church  490004215M
# 1             8_A2                       Old Ford Road  490010552N
# 3             8_A3               Bethnal Green Station  490000022B
# 4             8_A4  Commercial Street / Worship Street  490005524D
# 5             8_A5            Liverpool Street Station  490000138L
# 6             8_A6                   St Paul's Station  490000225T
#
#
# QSI stop points for direction 8_B
#
#   Route_Dir_QSI_No                                STOP_Name          ID
# 0             8_B1                        New Oxford Street  490000235Z
# 1             8_B2                           Procter Street  490011244J
# 2             8_B3                       King Edward Street  490000225S
# 3             8_B4                 Liverpool Street Station  490000138F
# 4             8_B5  Bethnal Grn Rd / Shoreditch High St Stn  490006398J
# 5             8_B6                    Bethnal Green Station  490000022D
# 6             8_B7                        Roman Road Market  490011654S
#
# Today is Tuesday. The selected Schedule name is Monday to Thursday.
#
# Number of buses scheduled for this hour at stop point 490004215M: 8
#
# Timetable for stop point 490004215M at hour 8:
# 08:03   8    490004215M  Outbound
# 08:09   8    490004215M  Outbound
# 08:16   8    490004215M  Outbound
# 08:23   8    490004215M  Outbound
# 08:31   8    490004215M  Outbound
# 08:38   8    490004215M  Outbound
# 08:46   8    490004215M  Outbound
# 08:54   8    490004215M  Outbound
#
# Number of buses scheduled for this hour at stop point 490010552N: 8
#
# Timetable for stop point 490010552N at hour 8:
# 08:05   8    490010552N  Outbound
# 08:11   8    490010552N  Outbound
# 08:18   8    490010552N  Outbound
# 08:25   8    490010552N  Outbound
# 08:32   8    490010552N  Outbound
# 08:40   8    490010552N  Outbound
# 08:47   8    490010552N  Outbound
# 08:55   8    490010552N  Outbound
#
# Number of buses scheduled for this hour at stop point 490000022B: 9
#
# Timetable for stop point 490000022B at hour 8:
# 08:00   8    490000022B  Outbound
# 08:07   8    490000022B  Outbound
# 08:14   8    490000022B  Outbound
# 08:20   8    490000022B  Outbound
# 08:27   8    490000022B  Outbound
# 08:34   8    490000022B  Outbound
# 08:41   8    490000022B  Outbound
# 08:48   8    490000022B  Outbound
# 08:56   8    490000022B  Outbound
#
# Number of buses scheduled for this hour at stop point 490005524D: 9
#
# Timetable for stop point 490005524D at hour 8:
# 08:04   8    490005524D  Outbound
# 08:11   8    490005524D  Outbound
# Timetable for stop point 490000022D at hour 8:
# 08:03   8    490000022D  Inbound
# 08:11   8    490000022D  Inbound
# 08:19   8    490000022D  Inbound
# 08:26   8    490000022D  Inbound
# 08:34   8    490000022D  Inbound
# 08:42   8    490000022D  Inbound
# 08:50   8    490000022D  Inbound
# 08:57   8    490000022D  Inbound
#
# Number of buses scheduled for this hour at stop point 490011654S: 7
#
# Timetable for stop point 490011654S at hour 8:
# 08:08   8    490011654S  Inbound
# 08:17   8    490011654S  Inbound
# 08:25   8    490011654S  Inbound
# 08:33   8    490011654S  Inbound
# 08:41   8    490011654S  Inbound
# 08:49   8    490011654S  Inbound
# 08:57   8    490011654S  Inbound

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Print the stop names from the Excel file for direction A
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_A\033[0m\n")
    print(filtered_df_A[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Print the stop names from the Excel file for direction B
    print(f"\n\n\033[1m\033[4mStop names from the Excel file for direction {lineID}_B\033[0m\n")
    print(filtered_df_B[['Route_Dir_QSI_No', 'STOP_NAME']])

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # Fetch timetable for each stop point ID and print the timetable for the current hour
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Print number of buses scheduled for this hour at stop point
            total_buses_this_hour = len(slots[current_hour])
            print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

            # Calculate Scheduled Wait Time (SWT)
            if total_buses_this_hour > 0:
                scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
            else:
                scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

            # Print Scheduled Wait Time rounded to two decimal places
            print(f"Scheduled Wait Time (SWT) for stop point {stop_point_id}: {scheduled_wait_time:.2f} minutes")

            # Print timetable for the current hour
            print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# Stop names from the Excel file for direction D7_A
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1312            D7_A1   poplar / all saints church
# 1313            D7_A2               stewart street
# 1314            D7_A3       island gardens station
# 1315            D7_A4  arnhem wharf primary school
# 1316            D7_A5         east india dock road
#
#
# Stop names from the Excel file for direction D7_B
#
#      Route_Dir_QSI_No                    STOP_NAME
# 1317            D7_B1  mile end station / bow road
# 1318            D7_B2         east india dock road
# 1319            D7_B3         canary wharf station
# 1320            D7_B4  arnhem wharf primary school
# 1321            D7_B5       island gardens station
# 1322            D7_B6               stewart street
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
#
# Number of buses scheduled for this hour at stop point 490011107G: 5
# Scheduled Wait Time (SWT) for stop point 490011107G: 6.00 minutes
#
# Timetable for stop point 490011107G at hour 9:
# 09:09   D7    490011107G  Outbound
# 09:21   D7    490011107G  Outbound
# 09:33   D7    490011107G  Outbound
# 09:45   D7    490011107G  Outbound
# 09:57   D7    490011107G  Outbound
#
# Number of buses scheduled for this hour at stop point 490013513S: 5
# Scheduled Wait Time (SWT) for stop point 490013513S: 6.00 minutes
# Scheduled Wait Time (SWT) for stop point 490013513N: 6.00 minutes
#
# Timetable for stop point 490013513N at hour 9:
# 09:06   D7    490013513N  Inbound
# 09:17   D7    490013513N  Inbound
# 09:28   D7    490013513N  Inbound
# 09:40   D7    490013513N  Inbound
# 09:52   D7    490013513N  Inbound

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Calculate Scheduled Wait Time (SWT)
            total_buses_this_hour = len(slots[current_hour])
            if total_buses_this_hour > 0:
                scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
            else:
                scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

            # Store SWT data
            swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
            swt_data['ID'].append(stop_point_id)
            swt_data['SWT_minutes'].append(scheduled_wait_time)

            # Print Scheduled Wait Time rounded to two decimal places
            print(f"\nScheduled Wait Time (SWT) for stop point {stop_point_id}: {scheduled_wait_time:.2f} minutes")

            # Print timetable for the current hour
            print(f"Timetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

    # Create DataFrame for SWT data
    swt_df = pd.DataFrame(swt_data)

    return swt_df

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
swt_df = find_route_details(lineID)

# Print the SWT DataFrame
print("\n\nSWT DataFrame:")
print(swt_df)
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
#
# Scheduled Wait Time (SWT) for stop point 490011107G: 6.00 minutes
# Timetable for stop point 490011107G at hour 9:
# 09:09   D7    490011107G  Outbound
# 09:21   D7    490011107G  Outbound
# 09:33   D7    490011107G  Outbound
# 09:45   D7    490011107G  Outbound
# 09:57   D7    490011107G  Outbound
#
# Scheduled Wait Time (SWT) for stop point 490013513S: 6.00 minutes
# Timetable for stop point 490013513S at hour 9:
# 09:04   D7    490013513S  Outbound
# 09:16   D7    490013513S  Outbound
# 09:28   D7    490013513S  Outbound
# 09:40   D7    490013513S  Outbound
# 09:51   D7    490013513S  Outbound
#
# Scheduled Wait Time (SWT) for stop point 490002048Z: 6.00 minutes
# Timetable for stop point 490002048Z at hour 9:
# 09:11   D7    490002048Z  Outbound
# 09:22   D7    490002048Z  Outbound
# 09:34   D7    490002048Z  Outbound
# 09:45   D7    490002048Z  Outbound
# 09:56   D7    490002048Z  Outbound
#
# Scheduled Wait Time (SWT) for stop point 490006092N: 6.00 minutes
# Timetable for stop point 490006092N at hour 9:
# 09:06   D7    490006092N  Outbound
# 09:17   D7    490006092N  Outbound
# 09:28   D7    490006092N  Outbound
# 09:40   D7    490006092N  Outbound
# 09:51   D7    490006092N  Outbound
#
# Scheduled Wait Time (SWT) for stop point 490004584N: 5.00 minutes
# Timetable for stop point 490004584N at hour 9:
# 09:00   D7    490004584N  Outbound
# 09:12   D7    490004584N  Outbound
# 09:24   D7    490004584N  Outbound
# 09:35   D7    490004584N  Outbound
# 09:46   D7    490004584N  Outbound
# 09:57   D7    490004584N  Outbound
#
# Scheduled Wait Time (SWT) for stop point 490015151H: 6.00 minutes
# Timetable for stop point 490015151H at hour 9:
# 09:08   D7    490015151H  Inbound
# 09:21   D7    490015151H  Inbound
# 09:33   D7    490015151H  Inbound
# 09:45   D7    490015151H  Inbound
# 09:57   D7    490015151H  Inbound
#
# Scheduled Wait Time (SWT) for stop point 490004584S: 6.00 minutes
# Timetable for stop point 490004584S at hour 9:
# 09:02   D7    490004584S  Inbound
# 09:15   D7    490004584S  Inbound
# 09:27   D7    490004584S  Inbound
# 09:39   D7    490004584S  Inbound
# 09:51   D7    490004584S  Inbound
#
# Scheduled Wait Time (SWT) for stop point 490000038F: 6.00 minutes
# Timetable for stop point 490000038F at hour 9:
# 09:08   D7    490000038F  Inbound
# 09:21   D7    490000038F  Inbound
# 09:33   D7    490000038F  Inbound
# 09:45   D7    490000038F  Inbound
# 09:57   D7    490000038F  Inbound
#
# Scheduled Wait Time (SWT) for stop point 490016668L: 6.00 minutes
# Timetable for stop point 490016668L at hour 9:
# 09:10   D7    490016668L  Inbound
# 09:23   D7    490016668L  Inbound
# 09:35   D7    490016668L  Inbound
# 09:47   D7    490016668L  Inbound
# 09:59   D7    490016668L  Inbound
#
# Scheduled Wait Time (SWT) for stop point 490006092S: 6.00 minutes
# Timetable for stop point 490006092S at hour 9:
# 09:05   D7    490006092S  Inbound
# 09:17   D7    490006092S  Inbound
# 09:30   D7    490006092S  Inbound
# 09:42   D7    490006092S  Inbound
# 09:54   D7    490006092S  Inbound
#
# Scheduled Wait Time (SWT) for stop point 490002048X: 5.00 minutes
# Timetable for stop point 490002048X at hour 9:
# 09:00   D7    490002048X  Inbound
# 09:11   D7    490002048X  Inbound
# 09:23   D7    490002048X  Inbound
# 09:35   D7    490002048X  Inbound
# 09:47   D7    490002048X  Inbound
# 09:59   D7    490002048X  Inbound
#
# Scheduled Wait Time (SWT) for stop point 490013513N: 6.00 minutes
# Timetable for stop point 490013513N at hour 9:
# 09:06   D7    490013513N  Inbound
# 09:17   D7    490013513N  Inbound
# 09:28   D7    490013513N  Inbound
# 09:40   D7    490013513N  Inbound
# 09:52   D7    490013513N  Inbound
#
#
# SWT DataFrame:
#    Route_Dir_QSI_No          ID  SWT_minutes
# 0             D7_A1  490011107G          6.0
# 1             D7_A2  490013513S          6.0
# 2             D7_A3  490002048Z          6.0
# 3             D7_A4  490006092N          6.0
# 4             D7_A5  490004584N          5.0
# 5             D7_B1  490015151H          6.0
# 6             D7_B2  490004584S          6.0
# 7             D7_B3  490000038F          6.0
# 8             D7_B3  490016668L          6.0
# 9             D7_B4  490006092S          6.0
# 10            D7_B5  490002048X          5.0
# 11            D7_B6  490013513N          6.0

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime
import pytz

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    for index, row in combined_df.iterrows():
        stop_point_id = row['ID']
        route_dir_qsi_no = row['Route_Dir_QSI_No']

        if f"{lineID}_A" in route_dir_qsi_no:
            direction = 'outbound'
        elif f"{lineID}_B" in route_dir_qsi_no:
            direction = 'inbound'
        else:
            continue

        url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
        data = fetch_data(url)

        schedule_names_dict = extract_schedule_names(data)

        if not selected_schedule_name:
            if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
            elif day_of_week.lower() == 'friday':
                preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
            elif day_of_week.lower() == 'saturday':
                preferred_schedule_names = ['Saturday']
            elif day_of_week.lower() == 'sunday':
                preferred_schedule_names = ['Sunday']
            else:
                preferred_schedule_names = [day_of_week]

            for preferred_name in preferred_schedule_names:
                if preferred_name in schedule_names_dict:
                    selected_schedule_name = preferred_name
                    break

        if selected_schedule_name and not printed_schedule_name:
            print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
            printed_schedule_name = True

        if selected_schedule_name:
            timetable = schedule_names_dict[selected_schedule_name]
            slots = categorize_into_slots(timetable)

            # Calculate Scheduled Wait Time (SWT)
            total_buses_this_hour = len(slots[current_hour])
            if total_buses_this_hour > 0:
                scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
            else:
                scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

            # Store SWT data
            swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
            swt_data['ID'].append(stop_point_id)
            swt_data['SWT_minutes'].append(scheduled_wait_time)
            swt_data['Number_of_buses'].append(total_buses_this_hour)

            # Print Scheduled Wait Time rounded to two decimal places
            print(f"Scheduled Wait Time (SWT) for stop point {stop_point_id}: {scheduled_wait_time:.2f} minutes")

            # Print number of buses scheduled for this hour at stop point
            print(f"Number of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

            # Print timetable for the current hour
            print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
            for journey in slots[current_hour]:
                journey_hour = str(journey['hour']).zfill(2)
                journey_minute = str(journey['minute']).zfill(2)
                time = f"{journey_hour}:{journey_minute}"
                print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

    # Create DataFrame for SWT data
    swt_df = pd.DataFrame(swt_data)

    return swt_df

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
swt_df = find_route_details(lineID)

# Print the SWT DataFrame
print("\n\nSWT DataFrame:")
print(swt_df)
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
# Scheduled Wait Time (SWT) for stop point 490011107G: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490011107G: 5
#
# Timetable for stop point 490011107G at hour 9:
# 09:09   D7    490011107G  Outbound
# 09:21   D7    490011107G  Outbound
# 09:33   D7    490011107G  Outbound
# 09:45   D7    490011107G  Outbound
# 09:57   D7    490011107G  Outbound
# Scheduled Wait Time (SWT) for stop point 490013513S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490013513S: 5
#
# Timetable for stop point 490013513S at hour 9:
# 09:04   D7    490013513S  Outbound
# 09:16   D7    490013513S  Outbound
# 09:28   D7    490013513S  Outbound
# 09:40   D7    490013513S  Outbound
# 09:51   D7    490013513S  Outbound
# Scheduled Wait Time (SWT) for stop point 490002048Z: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490002048Z: 5
#
# Timetable for stop point 490002048Z at hour 9:
# 09:11   D7    490002048Z  Outbound
# 09:22   D7    490002048Z  Outbound
# 09:34   D7    490002048Z  Outbound
# 09:45   D7    490002048Z  Outbound
# 09:56   D7    490002048Z  Outbound
# Scheduled Wait Time (SWT) for stop point 490006092N: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490006092N: 5
#
# Timetable for stop point 490006092N at hour 9:
# 09:06   D7    490006092N  Outbound
# 09:17   D7    490006092N  Outbound
# 09:28   D7    490006092N  Outbound
# 09:40   D7    490006092N  Outbound
# 09:51   D7    490006092N  Outbound
# Scheduled Wait Time (SWT) for stop point 490004584N: 5.00 minutes
# Number of buses scheduled for this hour at stop point 490004584N: 6
#
# Timetable for stop point 490004584N at hour 9:
# 09:00   D7    490004584N  Outbound
# 09:12   D7    490004584N  Outbound
# 09:24   D7    490004584N  Outbound
# 09:35   D7    490004584N  Outbound
# 09:46   D7    490004584N  Outbound
# 09:57   D7    490004584N  Outbound
# Scheduled Wait Time (SWT) for stop point 490015151H: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490015151H: 5
#
# Timetable for stop point 490015151H at hour 9:
# 09:08   D7    490015151H  Inbound
# 09:21   D7    490015151H  Inbound
# 09:33   D7    490015151H  Inbound
# 09:45   D7    490015151H  Inbound
# 09:57   D7    490015151H  Inbound
# Scheduled Wait Time (SWT) for stop point 490004584S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490004584S: 5
#
# Timetable for stop point 490004584S at hour 9:
# 09:02   D7    490004584S  Inbound
# 09:15   D7    490004584S  Inbound
# 09:27   D7    490004584S  Inbound
# 09:39   D7    490004584S  Inbound
# 09:51   D7    490004584S  Inbound
# Scheduled Wait Time (SWT) for stop point 490000038F: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490000038F: 5
#
# Timetable for stop point 490000038F at hour 9:
# 09:08   D7    490000038F  Inbound
# 09:21   D7    490000038F  Inbound
# 09:33   D7    490000038F  Inbound
# 09:45   D7    490000038F  Inbound
# 09:57   D7    490000038F  Inbound
# Scheduled Wait Time (SWT) for stop point 490016668L: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490016668L: 5
#
# Timetable for stop point 490016668L at hour 9:
# 09:10   D7    490016668L  Inbound
# 09:23   D7    490016668L  Inbound
# 09:35   D7    490016668L  Inbound
# 09:47   D7    490016668L  Inbound
# 09:59   D7    490016668L  Inbound
# Scheduled Wait Time (SWT) for stop point 490006092S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490006092S: 5
#
# Timetable for stop point 490006092S at hour 9:
# 09:05   D7    490006092S  Inbound
# 09:17   D7    490006092S  Inbound
# 09:30   D7    490006092S  Inbound
# 09:42   D7    490006092S  Inbound
# 09:54   D7    490006092S  Inbound
# Scheduled Wait Time (SWT) for stop point 490002048X: 5.00 minutes
# Number of buses scheduled for this hour at stop point 490002048X: 6
#
# Timetable for stop point 490002048X at hour 9:
# 09:00   D7    490002048X  Inbound
# 09:11   D7    490002048X  Inbound
# 09:23   D7    490002048X  Inbound
# 09:35   D7    490002048X  Inbound
# 09:47   D7    490002048X  Inbound
# 09:59   D7    490002048X  Inbound
# Scheduled Wait Time (SWT) for stop point 490013513N: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490013513N: 5
#
# Timetable for stop point 490013513N at hour
 6.00 minutes
# Number of buses scheduled for this hour at stop point 490002048X: 5
#
# Timetable for stop point 490002048X at hour 13:
# 13:11   D7    490002048X  Inbound
# 13:23   D7    490002048X  Inbound
# 13:35   D7    490002048X  Inbound
# 13:47   D7    490002048X  Inbound
# 13:59   D7    490002048X  Inbound
# Scheduled Wait Time (SWT) for stop point 490013513N: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490013513N: 5
#
# Timetable for stop point 490013513N at hour 13:
# 13:04   D7    490013513N  Inbound
# 13:16   D7    490013513N  Inbound
# 13:28   D7    490013513N  Inbound
# 13:40   D7    490013513N  Inbound
# 13:52   D7    490013513N  Inbound
#
#
# SWT DataFrame:
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             D7_A1  490011107G          6.0                5
# 1             D7_A2  490013513S          6.0                5
# 2             D7_A3  490002048Z          6.0                5
# 3             D7_A4  490006092N          6.0                5
# 4             D7_A5  490004584N          6.0                5
# 5             D7_B1  490015151H          6.0                5
# 6             D7_B2  490004584S          6.0                5
# 7             D7_B3  490000038F          6.0                5
# 8             D7_B3  490016668L          6.0                5
# 9             D7_B4  490006092S          6.0                5
# 10            D7_B5  490002048X          6.0                5
# 11            D7_B6  490013513N          6.0                5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-f792a36904a2> in <cell line: 278>()
#     276
#     277 # Find and display the route details
# --> 278 find_route_details(lineID)
#
# <ipython-input-38-f792a36904a2> in find_route_details(lineID)
#     265
#     266         # Wait for the next hour (3600 seconds = 1 hour)
# --> 267         time.sleep(3600)
#     268
#     269 # Example usage
#
# AttributeError: 'str' object has no attribute 'sleep'

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time  # Import the time module for sleep functionality

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    global df  # Use global variable df

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    while True:
        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        # Store selected schedule name to ensure it's printed only once
        selected_schedule_name = None
        printed_schedule_name = False

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT_minutes'].append(scheduled_wait_time)
                swt_data['Number_of_buses'].append(total_buses_this_hour)

                # Print Scheduled Wait Time rounded to two decimal places
                print(f"Scheduled Wait Time (SWT) for stop point {stop_point_id}: {scheduled_wait_time:.2f} minutes")

                # Print number of buses scheduled for this hour at stop point
                print(f"Number of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

                # Print timetable for the current hour
                print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
                for journey in slots[current_hour]:
                    journey_hour = str(journey['hour']).zfill(2)
                    journey_minute = str(journey['minute']).zfill(2)
                    time = f"{journey_hour}:{journey_minute}"
                    print(f"{time}   {lineID}    {stop_point_id}  {direction.capitalize()}")

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)

        # Print the SWT DataFrame
        print("\n\nSWT DataFrame:")
        print(swt_df)

        # Wait for the next hour (3600 seconds = 1 hour)
        time.sleep(3600)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
# Scheduled Wait Time (SWT) for stop point 490011107G: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490011107G: 5
#
# Timetable for stop point 490011107G at hour 9:
# 09:09   D7    490011107G  Outbound
# 09:21   D7    490011107G  Outbound
# 09:33   D7    490011107G  Outbound
# 09:45   D7    490011107G  Outbound
# 09:57   D7    490011107G  Outbound
# Scheduled Wait Time (SWT) for stop point 490013513S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490013513S: 5
#
# Timetable for stop point 490013513S at hour 9:
# 09:04   D7    490013513S  Outbound
# 09:16   D7    490013513S  Outbound
# 09:28   D7    490013513S  Outbound
# 09:40   D7    490013513S  Outbound
# 09:51   D7    490013513S  Outbound
# Scheduled Wait Time (SWT) for stop point 490002048Z: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490002048Z: 5
#
# Timetable for stop point 490002048Z at hour 9:
# 09:11   D7    490002048Z  Outbound
# 09:22   D7    490002048Z  Outbound
# 09:34   D7    490002048Z  Outbound
# 09:45   D7    490002048Z  Outbound
# 09:56   D7    490002048Z  Outbound
# Scheduled Wait Time (SWT) for stop point 490006092N: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490006092N: 5
#
# Timetable for stop point 490006092N at hour 9:
# 09:06   D7    490006092N  Outbound
# 09:17   D7    490006092N  Outbound
# 09:28   D7    490006092N  Outbound
# 09:40   D7    490006092N  Outbound
# 09:51   D7    490006092N  Outbound
# Scheduled Wait Time (SWT) for stop point 490004584N: 5.00 minutes
# Number of buses scheduled for this hour at stop point 490004584N: 6
#
# Timetable for stop point 490004584N at hour 9:
# 09:00   D7    490004584N  Outbound
# 09:12   D7    490004584N  Outbound
# 09:24   D7    490004584N  Outbound
# 09:35   D7    490004584N  Outbound
# 09:46   D7    490004584N  Outbound
# 09:57   D7    490004584N  Outbound
# Scheduled Wait Time (SWT) for stop point 490015151H: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490015151H: 5
#
# Timetable for stop point 490015151H at hour 9:
# 09:08   D7    490015151H  Inbound
# 09:21   D7    490015151H  Inbound
# 09:33   D7    490015151H  Inbound
# 09:45   D7    490015151H  Inbound
# 09:57   D7    490015151H  Inbound
# Scheduled Wait Time (SWT) for stop point 490004584S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490004584S: 5
#
# Timetable for stop point 490004584S at hour 9:
# 09:02   D7    490004584S  Inbound
# 09:15   D7    490004584S  Inbound
# 09:27   D7    490004584S  Inbound
# 09:39   D7    490004584S  Inbound
# 09:51   D7    490004584S  Inbound
# Scheduled Wait Time (SWT) for stop point 490000038F: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490000038F: 5
#
# Timetable for stop point 490000038F at hour 9:
# 09:08   D7    490000038F  Inbound
# 09:21   D7    490000038F  Inbound
# 09:33   D7    490000038F  Inbound
# 09:45   D7    490000038F  Inbound
# 09:57   D7    490000038F  Inbound
# Scheduled Wait Time (SWT) for stop point 490016668L: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490016668L: 5
#
# Timetable for stop point 490016668L at hour 9:
# 09:10   D7    490016668L  Inbound
# 09:23   D7    490016668L  Inbound
# 09:35   D7    490016668L  Inbound
# 09:47   D7    490016668L  Inbound
# 09:59   D7    490016668L  Inbound
# Scheduled Wait Time (SWT) for stop point 490006092S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490006092S: 5
#
# Timetable for stop point 490006092S at hour 9:
# 09:05   D7    490006092S  Inbound
# 09:17   D7    490006092S  Inbound
# 09:30   D7    490006092S  Inbound
# 09:42   D7    490006092S  Inbound
# 09:54   D7    490006092S  Inbound
# Scheduled Wait Time (SWT) for stop point 490002048X: 5.00 minutes
# Number of buses scheduled for this hour at stop point 490002048X: 6
#
# Timetable for stop point 490002048X at hour 9:
# 09:00   D7    490002048X  Inbound
# 09:11   D7    490002048X  Inbound
# 09:23   D7    490002048X  Inbound
# 09:35   D7    490002048X  Inbound
# 09:47   D7    490002048X  Inbound
# 09:59   D7    490002048X  Inbound
# Scheduled Wait Time (SWT) for stop point 490013513N: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490013513N: 5
#
# Timetable for stop point 490013513N at hour 9:
# 09:06   D7    490013513N  Inbound
# 09:17   D7    490013513N  Inbound
# 09:28   D7    490013513N  Inbound
# 09:40   D7    490013513N  Inbound
# 09:52   D7    490013513N  Inbound
#
#
# SWT DataFrame:
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             D7_A1  490011107G          6.0                5
# 1             D7_A2  490013513S          6.0                5
# 2             D7_A3  490002048Z          6.0                5
# 3             D7_A4  490006092N          6.0                5
# 4             D7_A5  490004584N          5.0                6
# 5             D7_B1  490015151H          6.0                5
# 6             D7_B2  490004584S          6.0                5
# 7             D7_B3  490000038F          6.0                5
# 8             D7_B3  490016668L          6.0                5
# 9             D7_B4  490006092S          6.0                5
# 10            D7_B5  490002048X          5.0                6
# 11            D7_B6  490013513N          6.0                5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a9652b95769b> in <cell line: 274>()
#     272
#     273 # Find and display the route details
# --> 274 find_route_details(lineID)
#
# <ipython-input-20-a9652b95769b> in find_route_details(lineID)
#     261
#     262         # Wait for the next hour (3600 seconds = 1 hour)
# --> 263         time.sleep(3600)
#     264
#     265 # Example usage
#
# AttributeError: 'str' object has no attribute 'sleep'

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time  # Import the time module for sleep functionality

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    global df  # Use global variable df

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    while True:
        # Update current time and hour
        current_time = datetime.now(bst)
        current_hour = current_time.hour
        day_of_week = get_day_of_week()

        # Store selected schedule name to ensure it's printed only once
        selected_schedule_name = None
        printed_schedule_name = False

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\nToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT_minutes'].append(scheduled_wait_time)
                swt_data['Number_of_buses'].append(total_buses_this_hour)

                # Print Scheduled Wait Time rounded to two decimal places
                print(f"Scheduled Wait Time (SWT) for stop point {stop_point_id}: {scheduled_wait_time:.2f} minutes")

                # Print number of buses scheduled for this hour at stop point
                print(f"Number of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

                # Print timetable for the current hour
                print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
                for journey in slots[current_hour]:
                    journey_hour = str(journey['hour']).zfill(2)
                    journey_minute = str(journey['minute']).zfill(2)
                    time_slot = f"{journey_hour}:{journey_minute}"
                    print(f"{time_slot}   {lineID}    {stop_point_id}  {direction.capitalize()}")

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)

        # Print the SWT DataFrame
        print("\n\nSWT DataFrame:")
        print(swt_df)

        # Wait for the next hour (3600 seconds = 1 hour)
        time.sleep(3600)

# Example usage
# Load the Excel file into a DataFrame
file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
df = pd.read_excel(file_path)

# Ask the user to enter a lineID
lineID = input("Please enter the lineID: ")

# Find and display the route details
find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
# Today is Tuesday. The selected Schedule name is Monday to Friday.
# Scheduled Wait Time (SWT) for stop point 490011107G: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490011107G: 5
#
# Timetable for stop point 490011107G at hour 9:
# 09:09   D7    490011107G  Outbound
# 09:21   D7    490011107G  Outbound
# 09:33   D7    490011107G  Outbound
# 09:45   D7    490011107G  Outbound
# 09:57   D7    490011107G  Outbound
# Scheduled Wait Time (SWT) for stop point 490013513S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490013513S: 5
#
# Timetable for stop point 490013513S at hour 9:
# 09:04   D7    490013513S  Outbound
# 09:16   D7    490013513S  Outbound
# 09:28   D7    490013513S  Outbound
# 09:40   D7    490013513S  Outbound
# 09:51   D7    490013513S  Outbound
# Scheduled Wait Time (SWT) for stop point 490002048Z: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490002048Z: 5
#
# Timetable for stop point 490002048Z at hour 9:
# 09:11   D7    490002048Z  Outbound
# 09:22   D7    490002048Z  Outbound
# 09:34   D7    490002048Z  Outbound
# 09:45   D7    490002048Z  Outbound
# 09:56   D7    490002048Z  Outbound
# Scheduled Wait Time (SWT) for stop point 490006092N: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490006092N: 5
#
# Timetable for stop point 490006092N at hour 9:
# 09:06   D7    490006092N  Outbound
# 09:17   D7    490006092N  Outbound
# 09:28   D7    490006092N  Outbound
# 09:40   D7    490006092N  Outbound
# 09:51   D7    490006092N  Outbound
# Scheduled Wait Time (SWT) for stop point 490004584N: 5.00 minutes
# Number of buses scheduled for this hour at stop point 490004584N: 6
#
# Timetable for stop point 490004584N at hour 9:
# 09:00   D7    490004584N  Outbound
# 09:12   D7    490004584N  Outbound
# 09:24   D7    490004584N  Outbound
# 09:35   D7    490004584N  Outbound
# 09:46   D7    490004584N  Outbound
# 09:57   D7    490004584N  Outbound
# Scheduled Wait Time (SWT) for stop point 490015151H: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490015151H: 5
#
# Timetable for stop point 490015151H at hour 9:
# 09:08   D7    490015151H  Inbound
# 09:21   D7    490015151H  Inbound
# 09:33   D7    490015151H  Inbound
# 09:45   D7    490015151H  Inbound
# 09:57   D7    490015151H  Inbound
# Scheduled Wait Time (SWT) for stop point 490004584S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490004584S: 5
#
# Timetable for stop point 490004584S at hour 9:
# 09:02   D7    490004584S  Inbound
# 09:15   D7    490004584S  Inbound
# 09:27   D7    490004584S  Inbound
# 09:39   D7    490004584S  Inbound
# 09:51   D7    490004584S  Inbound
# Scheduled Wait Time (SWT) for stop point 490000038F: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490000038F: 5
#
# Timetable for stop point 490000038F at hour 9:
# 09:08   D7    490000038F  Inbound
# 09:21   D7    490000038F  Inbound
# 09:33   D7    490000038F  Inbound
# 09:45   D7    490000038F  Inbound
# 09:57   D7    490000038F  Inbound
# Scheduled Wait Time (SWT) for stop point 490016668L: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490016668L: 5
#
# Timetable for stop point 490016668L at hour 9:
# 09:10   D7    490016668L  Inbound
# 09:23   D7    490016668L  Inbound
# 09:35   D7    490016668L  Inbound
# 09:47   D7    490016668L  Inbound
# 09:59   D7    490016668L  Inbound
# Scheduled Wait Time (SWT) for stop point 490006092S: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490006092S: 5
#
# Timetable for stop point 490006092S at hour 9:
# 09:05   D7    490006092S  Inbound
# 09:17   D7    490006092S  Inbound
# 09:30   D7    490006092S  Inbound
# 09:42   D7    490006092S  Inbound
# 09:54   D7    490006092S  Inbound
# Scheduled Wait Time (SWT) for stop point 490002048X: 5.00 minutes
# Number of buses scheduled for this hour at stop point 490002048X: 6
#
# Timetable for stop point 490002048X at hour 9:
# 09:00   D7    490002048X  Inbound
# 09:11   D7    490002048X  Inbound
# 09:23   D7    490002048X  Inbound
# 09:35   D7    490002048X  Inbound
# 09:47   D7    490002048X  Inbound
# 09:59   D7    490002048X  Inbound
# Scheduled Wait Time (SWT) for stop point 490013513N: 6.00 minutes
# Number of buses scheduled for this hour at stop point 490013513N: 5
#
# Timetable for stop point 490013513N at hour 9:
# 09:06   D7    490013513N  Inbound
# 09:17   D7    490013513N  Inbound
# 09:28   D7    490013513N  Inbound
# 09:40   D7    490013513N  Inbound
# 09:52   D7    490013513N  Inbound
#
#
# SWT DataFrame:
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             D7_A1  490011107G          6.0                5
# 1             D7_A2  490013513S          6.0                5
# 2             D7_A3  490002048Z          6.0                5
# 3             D7_A4  490006092N          6.0                5
# 4             D7_A5  490004584N          5.0                6
# 5             D7_B1  490015151H          6.0                5
# 6             D7_B2  490004584S          6.0                5
# 7             D7_B3  490000038F          6.0                5
# 8             D7_B3  490016668L          6.0                5
# 9             D7_B4  490006092S          6.0                5
# 10            D7_B5  490002048X          5.0                6
# 11            D7_B6  490013513N          6.0                5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-b888695dedaa> in <cell line: 274>()
#     272
#     273 # Find and display the route details
# --> 274 find_route_details(lineID)
#
# <ipython-input-21-b888695dedaa> in find_route_details(lineID)
#     261
#     262         # Wait for the next hour (3600 seconds = 1 hour)
# --> 263         time.sleep(3600)
#     264
#     265 # Example usage
#
# KeyboardInterrupt:

# %% [markdown]
# file share 19

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time  # Import the time module for sleep functionality

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    global df  # Use global variable df

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    while True:
        # Update current time and hour
        current_time = datetime.now(bst)
        current_hour = current_time.hour
        day_of_week = get_day_of_week()

        # Store selected schedule name to ensure it's printed only once
        selected_schedule_name = None
        printed_schedule_name = False

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday']:
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Thursday', 'Monday to Friday']
                elif day_of_week.lower() == 'friday':
                    preferred_schedule_names = ['Mon-Fri Schooldays', 'Monday to Friday', 'Friday']
                elif day_of_week.lower() == 'saturday':
                    preferred_schedule_names = ['Saturday']
                elif day_of_week.lower() == 'sunday':
                    preferred_schedule_names = ['Sunday']
                else:
                    preferred_schedule_names = [day_of_week]

                for preferred_name in preferred_schedule_names:
                    if preferred_name in schedule_names_dict:
                        selected_schedule_name = preferred_name
                        break

            if selected_schedule_name and not printed_schedule_name:
                print(f"\n\033[1m\033[4mToday is {day_of_week}. The selected Schedule name is {selected_schedule_name}.\033[0m")
                printed_schedule_name = True

            if selected_schedule_name:
                timetable = schedule_names_dict[selected_schedule_name]
                slots = categorize_into_slots(timetable)

                # Calculate Scheduled Wait Time (SWT)
                total_buses_this_hour = len(slots[current_hour])
                if total_buses_this_hour > 0:
                    scheduled_wait_time = 60 / (total_buses_this_hour * 2)  # SWT formula
                else:
                    scheduled_wait_time = float('inf')  # Handle division by zero scenario (though unlikely)

                # Store SWT data
                swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
                swt_data['ID'].append(stop_point_id)
                swt_data['SWT_minutes'].append(scheduled_wait_time)
                swt_data['Number_of_buses'].append(total_buses_this_hour)


                print ("................................................................\n")
                # Print Scheduled Wait Time rounded to two decimal places
                print(f"\nScheduled Wait Time (SWT) for stop point {stop_point_id}: {scheduled_wait_time:.2f} minutes")

                # Print number of buses scheduled for this hour at stop point
                print(f"\nNumber of buses scheduled for this hour at stop point {stop_point_id}: {total_buses_this_hour}")

                # Print timetable for the current hour
                print(f"\nTimetable for stop point {stop_point_id} at hour {current_hour}:")
                for journey in slots[current_hour]:
                    journey_hour = str(journey['hour']).zfill(2)
                    journey_minute = str(journey['minute']).zfill(2)
                    time_slot = f"{journey_hour}:{journey_minute}"
                    print(f"{time_slot}   {lineID}    {stop_point_id}  {direction.capitalize()}")

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)

        # Print the SWT DataFrame
        
: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490004584N: 5
#
# Timetable for stop point 490004584N at hour 12:
# 12:04   D7    490004584N  Outbound
# 12:16   D7    490004584N  Outbound
# 12:28   D7    490004584N  Outbound
# 12:40   D7    490004584N  Outbound
# 12:52   D7    490004584N  Outbound
# ................................................................
#
#
# Scheduled Wait Time (SWT) for stop point 490015151H: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490015151H: 5
#
# Timetable for stop point 490015151H at hour 12:
# 12:09   D7    490015151H  Inbound
# 12:21   D7    490015151H  Inbound
# 12:33   D7    490015151H  Inbound
# 12:45   D7    490015151H  Inbound
# 12:57   D7    490015151H  Inbound
# ................................................................
#
#
# Scheduled Wait Time (SWT) for stop point 490004584S: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490004584S: 5
#
# Timetable for stop point 490004584S at hour 12:
# 12:03   D7    490004584S  Inbound
# 12:15   D7    490004584S  Inbound
# 12:27   D7    490004584S  Inbound
# 12:39   D7    490004584S  Inbound
# 12:51   D7    490004584S  Inbound
# ................................................................
#
#
# Scheduled Wait Time (SWT) for stop point 490000038F: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490000038F: 5
#
# Timetable for stop point 490000038F at hour 12:
# 12:09   D7    490000038F  Inbound
# 12:21   D7    490000038F  Inbound
# 12:33   D7    490000038F  Inbound
# 12:45   D7    490000038F  Inbound
# 12:57   D7    490000038F  Inbound
# ................................................................
#
#
# Scheduled Wait Time (SWT) for stop point 490016668L: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490016668L: 5
#
# Timetable for stop point 490016668L at hour 12:
# 12:11   D7    490016668L  Inbound
# 12:23   D7    490016668L  Inbound
# 12:35   D7    490016668L  Inbound
# 12:47   D7    490016668L  Inbound
# 12:59   D7    490016668L  Inbound
# ................................................................
#
#
# Scheduled Wait Time (SWT) for stop point 490006092S: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490006092S: 5
#
# Timetable for stop point 490006092S at hour 12:
# 12:06   D7    490006092S  Inbound
# 12:18   D7    490006092S  Inbound
# 12:30   D7    490006092S  Inbound
# 12:42   D7    490006092S  Inbound
# 12:54   D7    490006092S  Inbound
# ................................................................
#
#
# Scheduled Wait Time (SWT) for stop point 490002048X: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490002048X: 5
#
# Timetable for stop point 490002048X at hour 12:
# 12:11   D7    490002048X  Inbound
# 12:23   D7    490002048X  Inbound
# 12:35   D7    490002048X  Inbound
# 12:47   D7    490002048X  Inbound
# 12:59   D7    490002048X  Inbound
# ................................................................
#
#
# Scheduled Wait Time (SWT) for stop point 490013513N: 6.00 minutes
#
# Number of buses scheduled for this hour at stop point 490013513N: 5
#
# Timetable for stop point 490013513N at hour 12:
# 12:04   D7    490013513N  Inbound
# 12:16   D7    490013513N  Inbound
# 12:28   D7    490013513N  Inbound
# 12:40   D7    490013513N  Inbound
# 12:52   D7    490013513N  Inbound
#
# _____________________________________________
#
#
# SWT DataFrame:
#    Route_Dir_QSI_No          ID  SWT_minutes  Number_of_buses
# 0             D7_A1  490011107G          6.0                5
# 1             D7_A2  490013513S          6.0                5
# 2             D7_A3  490002048Z          6.0                5
# 3             D7_A4  490006092N          6.0                5
# 4             D7_A5  490004584N          6.0                5
# 5             D7_B1  490015151H          6.0                5
# 6             D7_B2  490004584S          6.0                5
# 7             D7_B3  490000038F          6.0                5
# 8             D7_B3  490016668L          6.0                5
# 9             D7_B4  490006092S          6.0                5
# 10            D7_B5  490002048X          6.0                5
# 11            D7_B6  490013513N          6.0                5
# _____________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-17aa7ea1bc6b> in <cell line: 276>()
#     274
#     275 # Find and display the route details
# --> 276 find_route_details(lineID)
#
# <ipython-input-34-17aa7ea1bc6b> in find_route_details(lineID)
#     263
#     264         # Wait for the next hour (3600 seconds = 1 hour)
# --> 265         time.sleep(60)
#     266
#     267 # Example usage
#
# KeyboardInterrupt:

# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
from datetime import datetime, timedelta
import pytz
import time  # Keep time module import

# Function to normalize stop names
def normalize_stop_name(name):
    return ' '.join(name.lower().split())

# Function to fetch data from the API
def fetch_data(url):
    response = requests.get(url)
    return response.json()

# Function to extract schedule names
def extract_schedule_names(data, schedule_names_dict={}):
    if isinstance(data, dict):
        if data.get('$type') == "Tfl.Api.Presentation.Entities.Schedule, Tfl.Api.Presentation.Entities" and 'knownJourneys' in data:
            if 'name' in data:
                schedule_names_dict[data['name']] = data['knownJourneys']
        for key, value in data.items():
            extract_schedule_names(value, schedule_names_dict)
    elif isinstance(data, list):
        for item in data:
            extract_schedule_names(item, schedule_names_dict)
    return schedule_names_dict

# Function to categorize journeys into hourly slots
def categorize_into_slots(timetable):
    slots = [[] for _ in range(24)]
    for journey in timetable:
        hour = int(journey['hour'])  # Convert hour to integer
        if 0 <= hour < 24:  # Ensure hour is within the valid range
            slots[hour].append(journey)
    return slots

# Function to fetch the current day of the week
def get_day_of_week():
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    return now.strftime('%A')  # %A gives full weekday name (e.g., 'Monday')

# Function to retrieve stop names from TfL API and match with Route_Dir_QSI_No
def find_route_details(lineID):
    global df  # Use global variable df

    # Ensure the 'Route_Dir_QSI_No' column exists
    if 'Route_Dir_QSI_No' not in df.columns:
        print("The 'Route_Dir_QSI_No' column is not present in the provided file.")
        return

    # Convert the lineID to uppercase to ensure case-insensitivity
    lineID = lineID.upper()

    # Convert the 'Route_Dir_QSI_No' column to uppercase for comparison
    df['Route_Dir_QSI_No'] = df['Route_Dir_QSI_No'].str.upper()

    # Normalize the stop names in the DataFrame
    df['STOP_NAME'] = df['STOP_NAME'].apply(normalize_stop_name)

    # Filter the DataFrame based on the lineID
    pattern_A = f"^{lineID}_A\\d+$"  # Regular expression for D7_A**
    pattern_B = f"^{lineID}_B\\d+$"  # Regular expression for D7_B**

    # Filter rows where the 'Route_Dir_QSI_No' column matches the pattern
    filtered_df_A = df[df['Route_Dir_QSI_No'].str.match(pattern_A, na=False)]
    filtered_df_B = df[df['Route_Dir_QSI_No'].str.match(pattern_B, na=False)]

    # Function to fetch and process route sequence data from TfL API
    def fetch_and_process_route_data(route_type, pattern, filtered_df):
        api_url = f"https://api.tfl.gov.uk/Line/{lineID}/Route/Sequence/{route_type}"
        response = requests.get(api_url)

        results_list = []

        if response.status_code == 200:
            route_data = response.json()

            # Iterate through each stop in the route data
            for stop in route_data['stopPointSequences'][0]['stopPoint']:
                stop_name_api = normalize_stop_name(stop['name'])
                stop_id = stop['id']

                # Check if the stop_name_api exists in the filtered DataFrame for the correct direction
                matched_row = filtered_df[(filtered_df['STOP_NAME'] == stop_name_api) &
                                          (filtered_df['Route_Dir_QSI_No'].str.match(pattern))]

                if not matched_row.empty:
                    route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                    results_list.append({
                        'Route_Dir_QSI_No': route_dir_qsi_no,
                        'STOP_Name': stop['name'],
                        'ID': stop_id
                    })
                else:
                    # If exact match not found, try partial matching based on words before and after '/'
                    api_stop_name_parts = stop_name_api.split('/')
                    for index, row in filtered_df.iterrows():
                        df_stop_name_parts = row['STOP_NAME'].split('/')
                        for api_part in api_stop_name_parts:
                            for df_part in df_stop_name_parts:
                                if SequenceMatcher(None, df_part.strip(), api_part.strip()).ratio() > 0.8:
                                    matched_row = pd.DataFrame([row])
                                    break
                            if not matched_row.empty:
                                break
                        if not matched_row.empty:
                            break

                    if not matched_row.empty:
                        route_dir_qsi_no = matched_row.iloc[0]['Route_Dir_QSI_No']
                        results_list.append({
                            'Route_Dir_QSI_No': route_dir_qsi_no,
                            'STOP_Name': stop['name'],
                            'ID': stop_id
                        })
        else:
            print(f"Failed to fetch route sequence data from TfL API for {route_type} route. Status code: {response.status_code}")

        return results_list

    # Fetch and process outbound route data for _A**
    matched_results_A = fetch_and_process_route_data('outbound', pattern_A, filtered_df_A)

    # Fetch and process inbound route data for _B**
    matched_results_B = fetch_and_process_route_data('inbound', pattern_B, filtered_df_B)

    # Create DataFrames from the matched results for each direction
    matched_results_df_A = pd.DataFrame(matched_results_A)
    matched_results_df_B = pd.DataFrame(matched_results_B)

    # Function to remove partial matches if exact matches are found
    def remove_partial_matches(exact_df, matched_df):
        for index, row in exact_df.iterrows():
            exact_stop_name = row['STOP_NAME']
            route_dir_qsi_no = row['Route_Dir_QSI_No']
            # Find exact matches in matched_df
            exact_matches = matched_df[(matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                       (matched_df['STOP_Name'].apply(normalize_stop_name) == exact_stop_name)]
            if not exact_matches.empty:
                # Remove partial matches
                matched_df = matched_df[~((matched_df['Route_Dir_QSI_No'] == route_dir_qsi_no) &
                                          (matched_df['STOP_Name'].apply(normalize_stop_name) != exact_stop_name))]
        return matched_df

    # Remove partial matches for direction A
    matched_results_df_A = remove_partial_matches(filtered_df_A, matched_results_df_A)

    # Remove partial matches for direction B
    matched_results_df_B = remove_partial_matches(filtered_df_B, matched_results_df_B)

    # Print the matched results for direction A
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_A\033[0m\n")
    matched_results_df_A = matched_results_df_A[matched_results_df_A['Route_Dir_QSI_No'].str.match(pattern_A)]
    print(matched_results_df_A[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Print the matched results for direction B
    print(f"\n\n\033[1m\033[4mQSI stop points for direction {lineID}_B\033[0m\n")
    matched_results_df_B = matched_results_df_B[matched_results_df_B['Route_Dir_QSI_No'].str.match(pattern_B)]
    print(matched_results_df_B[['Route_Dir_QSI_No', 'STOP_Name', 'ID']])

    # Concatenate the matched results DataFrames for directions A and B
    combined_df = pd.concat([matched_results_df_A, matched_results_df_B], ignore_index=True)

    # DataFrames to store SWT data
    swt_data = {
        'Route_Dir_QSI_No': [],
        'ID': [],
        'SWT_minutes': [],
        'Number_of_buses': []
    }

    # Fetch timetable for each stop point ID and calculate SWT
    bst = pytz.timezone('Europe/London')
    now = datetime.now(bst)
    current_hour = now.hour
    day_of_week = get_day_of_week()

    # Store selected schedule name to ensure it's printed only once
    selected_schedule_name = None
    printed_schedule_name = False

    while True:
        # Update current time and hour
        now = datetime.now(bst)
        current_hour = now.hour
        day_of_week = get_day_of_week()

        for index, row in combined_df.iterrows():
            stop_point_id = row['ID']
            route_dir_qsi_no = row['Route_Dir_QSI_No']

            if f"{lineID}_A" in route_dir_qsi_no:
                direction = 'outbound'
            elif f"{lineID}_B" in route_dir_qsi_no:
                direction = 'inbound'
            else:
                continue

            url = f'https://api.tfl.gov.uk/Line/{lineID}/Timetable/{stop_point_id}?direction={direction}'
            data = fetch_data(url)

            schedule_names_dict = extract_schedule_names(data)

            if not selected_schedule_name:
                if day_of_week.lower() in ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']:
                    selected_schedule_name = 'Weekday'
                elif day_of_week.lower() in ['saturday']:
                    selected_schedule_name = 'Saturday'
                elif day_of_week.lower() in ['sunday']:
                    selected_schedule_name = 'Sunday'

            if selected_schedule_name in schedule_names_dict:
                schedule_name_data = schedule_names_dict[selected_schedule_name]
                schedule_name_data = categorize_into_slots(schedule_name_data)
                if not printed_schedule_name:
                    print(f"\n\n\033[1m\033[4mSchedule Timetable for {selected_schedule_name}\033[0m\n")
                    printed_schedule_name = True
            else:
                continue

            # Calculate SWT
            number_of_buses = len(schedule_name_data[current_hour])
            swt_minutes = 60 / number_of_buses
            swt_data['Route_Dir_QSI_No'].append(route_dir_qsi_no)
            swt_data['ID'].append(stop_point_id)
            swt_data['SWT_minutes'].append(swt_minutes)
            swt_data['Number_of_buses'].append(number_of_buses)

        # Create DataFrame for SWT data
        swt_df = pd.DataFrame(swt_data)

        # Print the SWT DataFrame
        print("\n\n\033[1mSWT DataFrame:\033[0m\n")
        print(swt_df)

        # Wait for the next hour (3600 seconds = 1 hour)
        time_to_wait = 3600
        time.sleep(time_to_wait)

# Example usage
if __name__ == "__main__":
    # Load the Excel file into a DataFrame
    file_path = '/content/QSI points.xlsx'  # Modify this path accordingly
    df = pd.read_excel(file_path)

    # Ask the user to enter a lineID
    lineID = input("Please enter the lineID: ")

    # Find and display the route details
    find_route_details(lineID)
# Out:
# Please enter the lineID: d7
#
#
# QSI stop points for direction D7_A
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_A1   Poplar / All Saints Church  490011107G
# 1            D7_A2               Stewart Street  490013513S
# 2            D7_A3       Island Gardens Station  490002048Z
# 3            D7_A4  Arnhem Wharf Primary School  490006092N
# 5            D7_A5         East India Dock Road  490004584N
#
#
# QSI stop points for direction D7_B
#
#   Route_Dir_QSI_No                    STOP_Name          ID
# 0            D7_B1  Mile End Station / Bow Road  490015151H
# 2            D7_B2         East India Dock Road  490004584S
# 3            D7_B3         Canary Wharf Station  490000038F
# 4            D7_B3         Canary Wharf Station  490016668L
# 5            D7_B4  Arnhem Wharf Primary School  490006092S
# 6            D7_B5       Island Gardens Station  490002048X
# 7            D7_B6               Stewart Street  490013513N
#
#
# SWT DataFrame:
#
# Empty DataFrame
# Columns: [Route_Dir_QSI_No, ID, SWT_minutes, Number_of_buses]
# Index: []
